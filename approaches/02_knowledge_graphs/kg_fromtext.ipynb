# %%
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain_core.documents import Document
from langchain_ollama import OllamaLLM
import os
from pprint import pprint
# Out:
# c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %% [markdown]
# # Opportunity KG

# %% [markdown]
# ## Input data

# %%
text = """
Albert Einstein[a] (14 March 1879 - 18 April 1955) was a German-born theoretical physicist who is best known for developing the theory of relativity. Einstein also made important contributions to quantum mechanics.[1][5] His mass–energy equivalence formula E = mc2, which arises from special relativity, has been called "the world's most famous equation".[6] He received the 1921 Nobel Prize in Physics for his services to theoretical physics, and especially for his discovery of the law of the photoelectric effect.[7]

Born in the German Empire, Einstein moved to Switzerland in 1895, forsaking his German citizenship (as a subject of the Kingdom of Württemberg)[note 1] the following year. In 1897, at the age of seventeen, he enrolled in the mathematics and physics teaching diploma program at the Swiss federal polytechnic school in Zurich, graduating in 1900. He acquired Swiss citizenship a year later, which he kept for the rest of his life, and afterwards secured a permanent position at the Swiss Patent Office in Bern. In 1905, he submitted a successful PhD dissertation to the University of Zurich. In 1914, he moved to Berlin to join the Prussian Academy of Sciences and the Humboldt University of Berlin, becoming director of the Kaiser Wilhelm Institute for Physics in 1917; he also became a German citizen again, this time as a subject of the Kingdom of Prussia.[note 1] In 1933, while Einstein was visiting the United States, Adolf Hitler came to power in Germany. Horrified by the Nazi persecution of his fellow Jews,[8] he decided to remain in the US, and was granted American citizenship in 1940.[9] On the eve of World War II, he endorsed a letter to President Franklin D. Roosevelt alerting him to the potential German nuclear weapons program and recommending that the US begin similar research.

In 1905, sometimes described as his annus mirabilis (miracle year), he published four groundbreaking papers.[10] In them, he outlined a theory of the photoelectric effect, explained Brownian motion, introduced his special theory of relativity, and demonstrated that if the special theory is correct, mass and energy are equivalent to each other. In 1915, he proposed a general theory of relativity that extended his system of mechanics to incorporate gravitation. A cosmological paper that he published the following year laid out the implications of general relativity for the modeling of the structure and evolution of the universe as a whole.[11][12] In 1917, Einstein wrote a paper which introduced the concepts of spontaneous emission and stimulated emission, the latter of which is the core mechanism behind the laser and maser, and which contained a trove of information that would be beneficial to developments in physics later on, such as quantum electrodynamics and quantum optics.[13]

In the middle part of his career, Einstein made important contributions to statistical mechanics and quantum theory. Especially notable was his work on the quantum physics of radiation, in which light consists of particles, subsequently called photons. With physicist Satyendra Nath Bose, he laid the groundwork for Bose–Einstein statistics. For much of the last phase of his academic life, Einstein worked on two endeavors that ultimately proved unsuccessful. First, he advocated against quantum theory's introduction of fundamental randomness into science's picture of the world, objecting that God does not play dice.[14] Second, he attempted to devise a unified field theory by generalizing his geometric theory of gravitation to include electromagnetism. As a result, he became increasingly isolated from mainstream modern physics.
"""

documents = [Document(page_content=text)]
display(documents)
# Out:
# [Document(metadata={}, page_content='\nAlbert Einstein[a] (14 March 1879 - 18 April 1955) was a German-born theoretical physicist who is best known for developing the theory of relativity. Einstein also made important contributions to quantum mechanics.[1][5] His mass–energy equivalence formula E = mc2, which arises from special relativity, has been called "the world\'s most famous equation".[6] He received the 1921 Nobel Prize in Physics for his services to theoretical physics, and especially for his discovery of the law of the photoelectric effect.[7]\n\nBorn in the German Empire, Einstein moved to Switzerland in 1895, forsaking his German citizenship (as a subject of the Kingdom of Württemberg)[note 1] the following year. In 1897, at the age of seventeen, he enrolled in the mathematics and physics teaching diploma program at the Swiss federal polytechnic school in Zurich, graduating in 1900. He acquired Swiss citizenship a year later, which he kept for the rest of his life, and afterwards secured a permanent position at the Swiss Patent Office in Bern. In 1905, he submitted a successful PhD dissertation to the University of Zurich. In 1914, he moved to Berlin to join the Prussian Academy of Sciences and the Humboldt University of Berlin, becoming director of the Kaiser Wilhelm Institute for Physics in 1917; he also became a German citizen again, this time as a subject of the Kingdom of Prussia.[note 1] In 1933, while Einstein was visiting the United States, Adolf Hitler came to power in Germany. Horrified by the Nazi persecution of his fellow Jews,[8] he decided to remain in the US, and was granted American citizenship in 1940.[9] On the eve of World War II, he endorsed a letter to President Franklin D. Roosevelt alerting him to the potential German nuclear weapons program and recommending that the US begin similar research.\n\nIn 1905, sometimes described as his annus mirabilis (miracle year), he published four groundbreaking papers.[10] In them, he outlined a theory of the photoelectric effect, explained Brownian motion, introduced his special theory of relativity, and demonstrated that if the special theory is correct, mass and energy are equivalent to each other. In 1915, he proposed a general theory of relativity that extended his system of mechanics to incorporate gravitation. A cosmological paper that he published the following year laid out the implications of general relativity for the modeling of the structure and evolution of the universe as a whole.[11][12] In 1917, Einstein wrote a paper which introduced the concepts of spontaneous emission and stimulated emission, the latter of which is the core mechanism behind the laser and maser, and which contained a trove of information that would be beneficial to developments in physics later on, such as quantum electrodynamics and quantum optics.[13]\n\nIn the middle part of his career, Einstein made important contributions to statistical mechanics and quantum theory. Especially notable was his work on the quantum physics of radiation, in which light consists of particles, subsequently called photons. With physicist Satyendra Nath Bose, he laid the groundwork for Bose–Einstein statistics. For much of the last phase of his academic life, Einstein worked on two endeavors that ultimately proved unsuccessful. First, he advocated against quantum theory\'s introduction of fundamental randomness into science\'s picture of the world, objecting that God does not play dice.[14] Second, he attempted to devise a unified field theory by generalizing his geometric theory of gravitation to include electromagnetism. As a result, he became increasingly isolated from mainstream modern physics.\n')]

# %%
input_txt_folder = "../../data/texts"

# Import opportunity file 
for filename in os.listdir(input_txt_folder):
    if filename.endswith('opportunity_example_eng.txt'):
        file_path = os.path.join(input_txt_folder, filename)
        print(f"Processing {filename}...")

        try:
            with open(file_path, 'r', encoding='utf-8') as file:
                content = file.read()
                print(type(content))
        except Exception as e:
            print(f"Error processing {filename}: {e}")

documents = [Document(page_content=content)]
print(documents)
# Out:
# Processing opportunity_example_eng.txt...
# <class 'str'>
# [Document(metadata={}, page_content='European Funds closer to you.  \n           \n \n          1/23\nCall for applications  \nCall code   MAR2030 -2023 -22 \nDate of publication  14/11/2023  \nNature of the notice   Tender  \nScope of action:  Operations  \nApproved by SRMAR on 25/07/2023  \n \n \nName of the  notice  \nProcessing  of Fishery and Aquaculture Products in the Field of Productive Investments -  Autonomous Region \nof Madeira  \n \nSupport to  \npromote the marketing, quality, and added value of fishery and aquaculture products, as well as \nthe processing of these products . \nActions covered by this notice  \nThis notice covers actions promoted by companies, as provided for in Article 50 of Ordinance No. \n559/2023 of July 25, relating to: \na) Productive investments as well as investments that promote decarbonization, the use of renewable energy \nand energy efficiency, the circular economy, digitization, and internationalization,  \nb) Investments that promote entrepreneurship by supporting the creation and development of start-ups\nand spin-offs; \nc) Investments in the certification and promotion of sustainable fisheries and aquaculture products, including \nthe processes leading to the registration of trademarks or patents;  \nd) Investments that reduce the impact of the activity on the environment;  \ne) Development of marketing and internationalization strategies, including promotional \nor prospecting and product development actions that are not part of actions organized by \nproducers\' associations and organizations;  The European Funds closest to you.  \n           \n \n          2/23 \nf) Marketing innovation , involving the implementation of a new marketing method  with significant changes \nin product design or packaging, or in its promotion and distribution;  \ng) Initiatives that promote consumption diversification through the processing of fishery products \nrelating to more abundant species with lower commercial value;  \nh) Promotion of short distribution and marketing circuits.  \nProjects in co-promotion innovation may also be supported, provided they are led by a company, within the \nmeaning of Article 23(2)(c) of DL 20-A/2023, namely:  \ni) projects developed between two or more independent entities that cooperate strategically \nand effectively in the medium and long term, sharing infrastructure, skills, and resources, \nincluding human resources, according to their specific contributions to the project\'s objectives, with a view to \ndeveloping the actions that make up the common activity plan and achieving the objectives \nand results;  \nii) in which the company assumes the role of lead entity, being responsible for ensuring the overall coordination \nof the project and the dialogue with the various co-promoters and between them and the managing authority, with \nregard to the technical, administrative, and financial management of the project;  \niii) in which a written agreement must be established, signed by all entities participating in the \nproject, which specifies the scope of cooperation between the entities involved, the identification of the \nlead entity, the joint responsibility between the parties, the individual contribution of each entity to the \nimplementation of the project, as well as the terms of sharing costs, risks, and results;  \niv) in which all entities participating in the project are considered beneficiaries and must therefore \ncomply with all eligibility requirements, obligations, and impediments of beneficiaries;  \nand \nv) payments are made to all co-promoters, who are individually responsible \nfor the repayment of the support they have received and jointly responsible for the pursuit of the \nproject\'s objectives, as well as for the achievement of the results . \n \nEntities that can apply  \nSMEs whose activity falls within the CAE subclasses \nprovided for in Article 52(1) of Ordinance No. 559/2023 of July 25 may benefit from the support provided  ...

# %% [markdown]
# ## LLM and Graph Transformer

# %%
#from dotenv import load_dotenv
#load_dotenv()
#GROQ_API_KEY = os.getenv("GROQ_API_KEY")
#
#from langchain_groq import ChatGroq
#
#llm = ChatGroq(
#    model="llama-3.1-8b-instant",
#    api_key=GROQ_API_KEY
#)

# %%
from langchain_openai import AzureChatOpenAI
import os
from dotenv import load_dotenv
load_dotenv()
AZURE_OPENAI_API_KEY = os.getenv("AZURE_OPENAI_API_KEY")
AZURE_OPENAI_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
AZURE_OPENAI_API_VERSION = os.getenv("AZURE_OPENAI_API_VERSION")

AZURE_DEPLOYMENT_GPT41 = os.getenv("AZURE_DEPLOYMENT_GPT41")
AZURE_DEPLOYMENT_GPT41_NANO = os.getenv("AZURE_DEPLOYMENT_GPT41_NANO")

gpt41 = AzureChatOpenAI(
    deployment_name=AZURE_DEPLOYMENT_GPT41,
    api_version=AZURE_OPENAI_API_VERSION,
    azure_endpoint=AZURE_OPENAI_ENDPOINT,
    openai_api_key=AZURE_OPENAI_API_KEY,
)

gpt41_nano = AzureChatOpenAI(
    azure_deployment=AZURE_DEPLOYMENT_GPT41_NANO,
    api_version=AZURE_OPENAI_API_VERSION,
    azure_endpoint=AZURE_OPENAI_ENDPOINT,
    api_key=AZURE_OPENAI_API_KEY,
)

# %%
#llm = OllamaLLM(model="llama3.2:3b")
graph_transformer = LLMGraphTransformer(llm=gpt41_nano)

# %%
graph = await graph_transformer.aconvert_to_graph_documents(documents)

# %%
graph[0]
# Out:
# GraphDocument(nodes=[Node(id='Mar2030', type='Program', properties={}), Node(id='Fund And Maximum Co-Financing Rate', type='Concept', properties={}), Node(id='€770,000 Feampa', type='Fund', properties={}), Node(id='Regional Coordinator Of Mar 2030 - Autonomous Region Of Madeira', type='Person', properties={}), Node(id='Funds Hotline', type='Person', properties={}), Node(id='Linhadosfundos@Linhadosfundos.Pt', type='Person', properties={}), Node(id='+ 351 291 203 250', type='Person', properties={}), Node(id='Drp@Madeira.Gov.Pt', type='Person', properties={}), Node(id='Autonomous Region Of Madeira', type='Location', properties={}), Node(id='14/11/2023', type='Date', properties={}), Node(id='30/12/2027', type='Date', properties={}), Node(id='Article 50 Of Ordinance No. 559/2023 Of July 25', type='Policy', properties={}), Node(id='Ordinance No. 559/2023, Of July 25', type='Policy', properties={}), Node(id='Support To Promote The Marketing, Quality, And Added Value Of Fishery And Aquaculture Products, As Well As The Processing Of These Products', type='Concept', properties={}), Node(id='Productive Investments In Processing', type='Concept', properties={}), Node(id='Investments In Energy Efficiency, The Circular Economy, Digitization, And Internationalization', type='Concept', properties={}), Node(id='Investment In Reducing Energy Consumption And Energy Efficiency', type='Concept', properties={}), Node(id='Investment In Renewable Energy Systems', type='Concept', properties={}), Node(id='Investments To Support Business Development (Strategy Development, Administration, Equipment)', type='Concept', properties={}), Node(id='Development Of Commercial Innovation', type='Concept', properties={}), Node(id='Development Of Process Innovation', type='Concept', properties={}), Node(id='Development Of Product Innovation', type='Concept', properties={}), Node(id='Use Of Unwanted Catches', type='Concept', properties={}), Node(id='Water Consumption And Water Quality Improvement', type='Concept', properties={}), Node(id='Food Quality, Safety, And Hygiene', type='Concept', properties={}), Node(id='Marketing Activities', type='Concept', properties={}), Node(id='Investments In Working Conditions', type='Concept', properties={}), Node(id='Tel + 351 291 203 250', type='Contact', properties={}), Node(id='Support Management Entity/Intermediate Body', type='Organization', properties={}), Node(id='Mar 2030 Program', type='Program', properties={}), Node(id='Support To Promote The Marketing, Quality, And Added Value Of Fishery And Aquaculture Products', type='Program', properties={}), Node(id='Eligible Smes (Caes)', type='Concept', properties={}), Node(id='10201', type='Subclass', properties={}), Node(id='Preparation Of Fishery And Aquaculture Products', type='Concept', properties={}), Node(id='10202', type='Subclass', properties={}), Node(id='Freezing Of Fishery And Aquaculture Products', type='Concept', properties={}), Node(id='10203', type='Subclass', properties={}), Node(id='Preservation Of Fishery And Aquaculture Products In Olive Oil And Other Vegetable Oils And Other Sauces', type='Concept', properties={}), Node(id='10204', type='Subclass', properties={}), Node(id='Salting, Drying, And Other Processing Of Fishery And Aquaculture Products', type='Concept', properties={}), Node(id='10411', type='Subclass', properties={}), Node(id='Production Of Crude Animal Oils And Fats, If Related To Fishery And Aquaculture Products', type='Concept', properties={}), Node(id='10850', type='Subclass', properties={}), Node(id='Manufacture Of Pre-Cooked Meals And Dishes, If Related To Fishery And Aquaculture Products', type='Concept', properties={}), Node(id='Higher Education Institutions, Their Institutes, And R&D Units', type='Organization', properties={}), Node(id='State Or International Laboratories With Headquarters Or Permanent Representation In Portugal', type='Organization', properties={}), Node(id='Private Non-Profit Institutions Whose Main Purpose Is R&D Activitie ...

# %%
type(graph[0])
# Out:
# langchain_community.graphs.graph_document.GraphDocument

# %% [markdown]
# ### Saving the graph NOT LIKE THIS

# %%
import json

def save_graph_documents(graph_documents, filename):
    """Save GraphDocument objects to JSON"""
    graph_data = []
    
    for doc in graph_documents:
        doc_data = {
            "nodes": [{"id": node.id, "type": node.type} for node in doc.nodes],
            "relationships": [
                {
                    "source_id": rel.source.id,
                    "target_id": rel.target.id, 
                    "type": rel.type
                }
                for rel in doc.relationships
            ]
        }
        graph_data.append(doc_data)
    
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(graph_data, f, ensure_ascii=False, indent=2)

save_graph_documents(graph, "output/kg_llmgraphtransformer.json")

# %%
print(f"Nodes:{graph[0].nodes}")
print(f"Relationships:{graph[0].relationships}")
# Out:
# Nodes:[Node(id='Mar2030', type='Program', properties={}), Node(id='Fundo Feampa', type='Program', properties={}), Node(id='Região Autónoma Da Madeira', type='Region', properties={}), Node(id='Coordenador Regional Do Mar 2030 - Região Autónoma Da Madeira', type='Organization', properties={}), Node(id='Instituto De Financiamento Da Agricultura E Pescas, Ip', type='Organization', properties={}), Node(id='Linha Dos Fundos 800 10 35 10', type='Contact', properties={}), Node(id='Drp@Madeira.Gov.Pt', type='Contact', properties={}), Node(id='+351 291 203 250', type='Contact', properties={}), Node(id='Linhadosfundos@Linhadosfundos.Pt', type='Contact', properties={}), Node(id='14/11/2023', type='Date', properties={}), Node(id='30/12/2027', type='Date', properties={}), Node(id='770000', type='Amount', properties={}), Node(id='70%', type='Rate', properties={}), Node(id='8503', type='Operation_code', properties={}), Node(id='8504', type='Operation_code', properties={}), Node(id='8515', type='Operation_code', properties={}), Node(id='8517', type='Operation_code', properties={}), Node(id='8518', type='Operation_code', properties={}), Node(id='8519', type='Operation_code', properties={}), Node(id='8510', type='Operation_code', properties={}), Node(id='8548', type='Operation_code', properties={}), Node(id='8512', type='Operation_code', properties={}), Node(id='8546', type='Operation_code', properties={}), Node(id='8513', type='Operation_code', properties={}), Node(id='40%', type='Rate', properties={}), Node(id='20000', type='Amount', properties={}), Node(id='Portugal 2030', type='Program', properties={}), Node(id='Eu Common Fisheries Policy', type='Policy', properties={}), Node(id='Eu Maritime Policy', type='Policy', properties={})]
# Relationships:[Relationship(source=Node(id='Mar2030', type='Program', properties={}), target=Node(id='Fundo Feampa', type='Program', properties={}), type='FUNDS', properties={}), Relationship(source=Node(id='Mar2030', type='Program', properties={}), target=Node(id='Região Autónoma Da Madeira', type='Region', properties={}), type='COVERAGE', properties={}), Relationship(source=Node(id='Coordenador Regional Do Mar 2030 - Região Autónoma Da Madeira', type='Organization', properties={}), target=Node(id='Mar2030', type='Program', properties={}), type='ORGANIZES', properties={}), Relationship(source=Node(id='Instituto De Financiamento Da Agricultura E Pescas, Ip', type='Organization', properties={}), target=Node(id='Mar2030', type='Program', properties={}), type='INVOLVED_IN', properties={}), Relationship(source=Node(id='Linha Dos Fundos 800 10 35 10', type='Contact', properties={}), target=Node(id='Mar2030', type='Program', properties={}), type='CONTACT', properties={}), Relationship(source=Node(id='Drp@Madeira.Gov.Pt', type='Contact', properties={}), target=Node(id='Mar2030', type='Program', properties={}), type='CONTACT', properties={}), Relationship(source=Node(id='+351 291 203 250', type='Contact', properties={}), target=Node(id='Mar2030', type='Program', properties={}), type='CONTACT', properties={}), Relationship(source=Node(id='Linhadosfundos@Linhadosfundos.Pt', type='Contact', properties={}), target=Node(id='Mar2030', type='Program', properties={}), type='CONTACT', properties={}), Relationship(source=Node(id='14/11/2023', type='Date', properties={}), target=Node(id='Mar2030', type='Program', properties={}), type='START_DATE', properties={}), Relationship(source=Node(id='30/12/2027', type='Date', properties={}), target=Node(id='Mar2030', type='Program', properties={}), type='END_DATE', properties={}), Relationship(source=Node(id='770000', type='Amount', properties={}), target=Node(id='Mar2030', type='Program', properties={}), type='FUND_AMOUNT', properties={}), Relationship(source=Node(id='70%', type='Rate', properties={}), target=Node(id='Mar2030', type='Program', properties={}), type='COFUND_RATE', properties={}), Relationship(source=Node(id='8503', type='Operation_code', properties={}), target=Node(id='Mar2030', type='Program', properties={}), type='INVOLVES_OPERATION', properties={}), Relationship(source=Node(id='8504', type='Operation_code', properties={}), target=Node(id='Mar2030', type='Program', properties={}), type='INVOLVES_OPERATION', properties={}), Relationship(source=Node(id='8515', type='Operation_code', properties={}), target=Node(id='Mar2030', type='Program', properties={}), type='INVOLVES_OPERATION', properties={}), Relationship(source=Node(id='8517', type='Operation_code', properties={}), target=Node(id='Mar2030', type='Program', properties={}), type='INVOLVES_OPERATION', properties={}), Relationship(source=Node(id='8518', type='Operation_code', properties={}), target=Node(id='Mar2030', type='Program', properties={}), type='INVOLVES_OPERATION', properties={}), Relationship(source=Node(id='8519', type='Operation_code', properties={}), target=Node(id='Mar2030', type='Program', properties={}), type='INVOLVES_OPERATION', properties={}), Relationship(source=Node(id='8510', type='Operation_code', properties={}), target=Node(id='Mar2030', type='Program', properties={}), type='INVOLVES_OPERATION', properties={}), Relationship(source=Node(id='8548', type='Operation_code', properties={}), target=Node(id='Mar2030', type='Program', properties={}), type='INVOLVES_OPERATION', properties={}), Relationship(source=Node(id='8512', type='Operation_code', properties={}), target=Node(id='Mar2030', type='Program', properties={}), type='INVOLVES_OPERATION', properties={}), Relationship(source=Node(id='8546', type='Operation_code', properties={}), target=Node(id='Mar2030', type='Program', properties={}), type='INVOLVES_OPERATION', properties={}), Relationship(source=Node(id='8513', type='Operation_code', properties={}), target=No ...

# %% [markdown]
# ## Visualize the graph

# %%
from pyvis.network import Network

def visualize_graph(graph_documents):

    # Create network
    net = Network(height="1200px", width="100%", directed=True,
                      notebook=False, bgcolor="#222222", font_color="white")
    
    nodes = graph_documents[0].nodes
    relationships = graph_documents[0].relationships

    # Build lookup for valid nodes
    node_dict = {node.id: node for node in nodes}
    
    # Filter out invalid edges and collect valid node IDs
    valid_edges = []
    valid_node_ids = set()
    for rel in relationships:
        if rel.source.id in node_dict and rel.target.id in node_dict:
            valid_edges.append(rel)
            valid_node_ids.update([rel.source.id, rel.target.id])


    # Track which nodes are part of any relationship
    connected_node_ids = set()
    for rel in relationships:
        connected_node_ids.add(rel.source.id)
        connected_node_ids.add(rel.target.id)

    # Add valid nodes
    for node_id in valid_node_ids:
        node = node_dict[node_id]
        try:
            net.add_node(node.id, label=node.id, title=node.type, group=node.type)
        except:
            continue  # skip if error

    # Add valid edges
    for rel in valid_edges:
        try:
            net.add_edge(rel.source.id, rel.target.id, label=rel.type.lower())
        except:
            continue  # skip if error

    # Configure physics
    net.set_options("""
            {
                "physics": {
                    "forceAtlas2Based": {
                        "gravitationalConstant": -100,
                        "centralGravity": 0.01,
                        "springLength": 200,
                        "springConstant": 0.08
                    },
                    "minVelocity": 0.75,
                    "solver": "forceAtlas2Based"
                }
            }
            """)
        
    output_file = "knowledge_graph.html"
    net.save_graph(output_file)
    print(f"Graph saved to {os.path.abspath(output_file)}")

    # Try to open in browser
    try:
        import webbrowser
        webbrowser.open(f"file://{os.path.abspath(output_file)}")
    except:
        print("Could not open browser automatically")
        
# Run the function
visualize_graph(graph)
# Out:
# Graph saved to c:\Users\tiago\Documents\Granter Ai Internship\Implementation\KGs_for_Vertical_AI\approaches\02_knowledge_graphs\knowledge_graph.html
