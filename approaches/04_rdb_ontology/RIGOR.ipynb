# %% [markdown]
# # Notes

# %% [markdown]
# **What we need for the implementation**
# - Relational Database Schema
#     - R set of relations
#     - K function that maps each relation to its set of primary key attributes
#     - F function that maps each relation to its set of attributes,
#         where each attribute is given by its column name together with its datatype
# - Each relation has:
#     - Atribute set (F)
#     - pk set (K)
#     - Foreign key set (subset of F)
# - Functions:
#     - docTable: returns the textual description of a relation
#     - docAttr: returns the textual description of an attribute a in relation r
# - Ontology Representation:
#     - C set of class identifiers (concepts)
#     - P set of properties
#         - Pobj subset of object properties
#         - Pdata subset of data properties
#     - A set of axioms
#         - class hierarchies,
#         - domain and range assertions,
#         - property characteristics
#     - M set of annotation assertions
#         - labels
#         - comments
#         - provenance info
# - External Ontology Repo
#     - DINGO
# - Lexical view converter
#     - of any ontology
#     - **CHECK**
# - RAG pipeline
#     - Embed lexical views of
#         - external ontologies
#         - Relational schema
#         - core ontology
#     - Index in FAISS
#     - At each relation (...)

# %% [markdown]
# # Database Schema

# %%
import re
from pprint import pprint

def parse_mysql_ddl_file(filepath):
    with open(filepath, 'r', encoding='utf-8') as f:
        ddl = f.read()

    # Remove comments and MySQL directives
    ddl = re.sub(r'/\*.*?\*/', '', ddl, flags=re.DOTALL)
    ddl = re.sub(r'--.*?$', '', ddl, flags=re.MULTILINE)
    ddl = re.sub(r'/\!.*?\*/;', '', ddl, flags=re.DOTALL)
    ddl = re.sub(r'/\!.*?\*/', '', ddl, flags=re.DOTALL)

    # Find all CREATE TABLE statements (handles backticks and multiline)
    table_regex = re.compile(
        r'CREATE TABLE\s+`?(\w+)`?\s*\((.*?)\)\s*ENGINE=.*?;',
        re.DOTALL | re.IGNORECASE
    )
    tables = table_regex.findall(ddl)
    result = {}

    for table_name, table_body in tables:
        # Raw DDL
        raw_ddl = f"CREATE TABLE `{table_name}` ({table_body});"

        # Split lines, remove empty and trailing commas
        lines = [line.strip().rstrip(',') for line in table_body.splitlines() if line.strip()]
        columns = []
        primary_keys = []
        foreign_keys = []

        for line in lines:
            # Column definition (starts with backtick or word, not constraint)
            if re.match(r'^`?\w+`?\s', line) and not line.upper().startswith(('PRIMARY KEY', 'FOREIGN KEY', 'CONSTRAINT', 'UNIQUE', 'KEY')):
                col_name = re.match(r'^`?(\w+)`?', line).group(1)
                columns.append(col_name)
            # Primary key
            elif line.upper().startswith('PRIMARY KEY'):
                pk_match = re.search(r'\((.*?)\)', line)
                if pk_match:
                    pk_cols = [col.strip(' `') for col in pk_match.group(1).split(',')]
                    primary_keys.extend(pk_cols)
            # Foreign key
            elif line.upper().startswith('CONSTRAINT') and 'FOREIGN KEY' in line.upper():
                fk_match = re.search(r'FOREIGN KEY\s*\((.*?)\)\s*REFERENCES\s*`?(\w+)`?\s*\((.*?)\)', line, re.IGNORECASE)
                if fk_match:
                    fk_cols = [col.strip(' `') for col in fk_match.group(1).split(',')]
                    ref_table = fk_match.group(2)
                    ref_cols = [col.strip(' `') for col in fk_match.group(3).split(',')]
                    foreign_keys.append({
                        'columns': fk_cols,
                        'ref_table': ref_table,
                        'ref_columns': ref_cols
                    })

        result[table_name] = {
            'raw_ddl': raw_ddl,
            'columns': columns,
            'primary_keys': primary_keys,
            'foreign_keys': foreign_keys
        }

    return result

# %%
schema = parse_mysql_ddl_file('../../database/schema/usable_schema.sql')
pprint(schema)
# Out:
# {'granter_activity': {'columns': ['id',
#                                   'created_at',
#                                   'updated_at',
#                                   'type',
#                                   'title',
#                                   'description',
#                                   'application_id',
#                                   'company_id',
#                                   'file_id',
#                                   'profile_id',
#                                   'created_by_expert',
#                                   'activity_date',
#                                   'data',
#                                   'data_id',
#                                   'opportunity_id',
#                                   'data_type'],
#                       'foreign_keys': [{'columns': ['application_id'],
#                                         'ref_columns': ['id'],
#                                         'ref_table': 'granter_application'},
#                                        {'columns': ['company_id'],
#                                         'ref_columns': ['id'],
#                                         'ref_table': 'granter_company'},
#                                        {'columns': ['file_id'],
#                                         'ref_columns': ['id'],
#                                         'ref_table': 'granter_companyfile'},
#                                        {'columns': ['opportunity_id'],
#                                         'ref_columns': ['id'],
#                                         'ref_table': 'granter_opportunity'},
#                                        {'columns': ['profile_id'],
#                                         'ref_columns': ['id'],
#                                         'ref_table': 'granter_profile'}],
#                       'primary_keys': ['id'],
#                       'raw_ddl': 'CREATE TABLE `granter_activity` (\n'
#                                  '  `id` bigint NOT NULL AUTO_INCREMENT,\n'
#                                  '  `created_at` datetime(6) NOT NULL,\n'
#                                  '  `updated_at` datetime(6) NOT NULL,\n'
#                                  '  `type` varchar(100) NOT NULL,\n'
#                                  '  `title` varchar(100) DEFAULT NULL,\n'
#                                  '  `description` longtext,\n'
#                                  '  `application_id` bigint DEFAULT NULL,\n'
#                                  '  `company_id` bigint NOT NULL,\n'
#                                  '  `file_id` bigint DEFAULT NULL,\n'
#                                  '  `profile_id` bigint NOT NULL,\n'
#                                  '  `created_by_expert` tinyint(1) NOT NULL,\n'
#                                  '  `activity_date` datetime(6) DEFAULT NULL,\n'
#                                  '  `data` longtext,\n'
#                                  '  `data_id` varchar(100) DEFAULT NULL,\n'
#                                  '  `opportunity_id` bigint DEFAULT NULL,\n'
#                                  '  `data_type` varchar(100) DEFAULT NULL,\n'
#                                  '  PRIMARY KEY (`id`),\n'
#                                  '  KEY '
#                                  '`granter_activity_application_id_4284cf67_fk_granter_a` '
#                                  '(`application_id`),\n'
#                                  '  KEY '
#                                  '`granter_activity_company_id_b2808af0_fk_granter_company_id` '
#                                  '(`company_id`),\n'
#                                  '  KEY '
#                                  '`granter_activity_file_id_6f2e8b31_fk_granter_companyfile_id` '
#                                  '(`file_id`),\n'
#                                  '  KEY '
#                                  '`granter_activity_profile_id_6f7995a1_fk_granter_profile_id` '
#                                  '(`profile_id`),\n'
#                                  '  KEY '
#                                  '`granter_activity_opportunity_id_8907ad01_fk_granter_o` '
#                                  '(`opportunity_id`),\n'
#                                  '  CONSTRAINT '
#                                  '`granter_activity_application_id_4284cf67_fk_granter_a` '
#                                  'FOREIGN KEY (`application_id`) REFERENCES '
#                                  '`granter_application` (`id`),\n'
#                                  '  CONSTRAINT '
#                                  '`granter_activity_company_id_b2808af0_fk_granter_company_id` '
#                                  'FOREIGN KEY (`company_id`) REFERENCES '
#                                  '`granter_company` (`id`),\n'
#                                  '  CONSTRAINT '
#                                  '`granter_activity_file_id_6f2e8b31_fk_granter_companyfile_id` '
#                                  'FOREIGN KEY (`file_id`) REFERENCES '
#                                  '`granter_companyfile` (`id`),\n'
#                                  '  CONSTRAINT '
#                                  '`granter_activity_opportunity_id_8907ad01_fk_granter_o` '
#                                  'FOREIGN KEY (`opportunity_id`) REFERENCES '
#                                  '`granter_opportunity` (`id`),\n'
#                                  '  CONSTRAINT '
#                                  '`granter_activity_profile_id_6f7995a1_fk_granter_profile_id` '
#                                  'FOREIGN KEY (`profile_id`) REFERENCES '
#                                  '`granter_profile` (`id`)\n'
#                                  ');'},
#  'granter_application': {'columns': ['id',
#                                      'created_at',
#                                      'updated_at',
#                                      'state',
#                                      'codename',
#                                      'title',
#                                      'other_data',
#                                      'company_id',
#                                      'opportunity_id',
#                                      'profile_creator_id',
#                                      'pricing_option',
#                                      'ai_review_state',
#                                      'consortium_id',
#                                      'sale_confirmed',
#                                      'approved_grant_amount',
#                                      'success_fee',
#                                      'success_payment_amount',
#                                      'upfront_payment_amount',
#                                      'initial_summary',
#                                      'writer_mode'],
#                          'foreign_keys': [{'columns': ['company_id'],
#                                            'ref_columns': ['id'],
#                                            'ref_table': 'granter_company'},
#                                           {'columns': ['consortium_id'],
#                                            'ref_columns': ['id'],
#                                            'ref_table': 'granter_consortium'},
#                                           {'columns': ['opportunity_id'],
#                                            'ref_columns': ['id'],
#                                            'ref_table': 'granter_opportunity'},
#                                           {'columns': ['profile_creator_id'],
#                                            'ref_columns': ['id'],
#                                            'ref_table': 'granter_profile'}],
#                          'primary_keys': ['id'],
#                          'raw_ddl': 'CREATE TABLE `granter_application` (\n'
#                                     '  `id` bigint NOT NULL AUTO_INCREMENT,\n'
#                                     '  `created_at` datetime(6) NOT NULL,\n'
#                                     '  `updated_at` datetime(6) NOT NULL,\n'
#                                     '  `state` varchar(30) NOT NULL,\n'
#                                     '  `codename` varchar(60) NOT NULL,\n'
#                                     '  `title` varchar(150) NOT NULL,\n'
#                                     '  `other_data` json DEFAULT NULL,\n'
#                                     '  `company_id` bigint DEFAULT NULL,\n'
#                                     '  `opportunity_id` bigint DEFAULT NULL,\n'
#                                     '  `profile_creator_id` bigint DEFAULT '
#                                     'NULL,\n'
#                                     '  `pricing_option` varchar(30) DEFAULT '
#                                     'NULL,\n'
#                                     '  `ai_review_state` varchar(30) DEFAULT '
#                                     'NULL,\n'
#                                     '  `consortium_id` bigint DEFAULT NULL,\n'
#                                     '  `sale_confirmed` tinyint(1) NOT NULL,\n'
#                                     '  `approved_grant_amount` varchar(100) '
#                                     'DEFAULT NULL,\n'
#                                     '  `success_fee` varchar(50) DEFAULT '
#                                     'NULL,\n'
#                                     '  `success_payment_amount` varchar(100) '
#                                     'DEFAULT NULL,\n'
#                                     '  `upfront_payment_amount` varchar(100) '
#                                     'DEFAULT NULL,\n'
#                                     '  `initial_summary` longtext,\n'
#                                     '  `writer_mode` varchar(30) DEFAULT '
#                                     'NULL,\n'
#                                     '  PRIMARY KEY (`id`),\n'
#                                     '  UNIQUE KEY `consortium_id` '
#                                     '(`consortium_id`),\n'
#                                     '  KEY '
#                                     '`granter_application_company_id_847c5b4f_fk_granter_company_id` '
#                                     '(`company_id`),\n'
#                                     '  KEY '
#                                     '`granter_application_opportunity_id_6a6373f2_fk_granter_o` '
#                                     '(`opportunity_id`),\n'
#                                     '  KEY '
#                                     '`granter_application_profile_creator_id_4a94343d_fk_granter_p` '
#                                     '(`profile_creator_id`),\n'
#                                     '  CONSTRAINT '
#                                     '`granter_application_company_id_847c5b4f_fk_granter_company_id` '
#                                     'FOREIGN KEY (`company_id`) REFERENCES '
#                                     '`granter_company` (`id`),\n'
#                                     '  CONSTRAINT '
#                                     '`granter_application_consortium_id_ff9bdeba_fk_granter_c` '
#                                     'FOREIGN KEY (`consortium_id`) REFERENCES '
#                                     '`granter_consortium` (`id`),\n'
#                                     '  CONSTRAINT '
#                                     '`granter_application_opportunity_id_6a6373f2_fk_granter_o` '
#                                     'FOREIGN KEY (`opportunity_id`) REFERENCES '
#                                     '`granter_opportunity` (`id`),\n'
#                                     '  CONSTRAINT '
#                                     '`granter_application_profile_creator_id_4a94343d_fk_granter_p` '
#                                     'FOREIGN KEY (`profile_creator_id`) '
#                                     'REFERENCES `granter_profile` (`id`)\n'
#                                     ');'},
#  'granter_applicationfile': {'columns': ['id',
#                                          'created_at',
#                                          'updated_at',
#                                          'name',
#                                          'uploaded_file',
#                                          'vector_indexed',
#                                          'type',
#                                          'application_id',
#                                          'document_type_id'],
#                              'foreign_keys': [{'columns': ['application_id'],
#                                                'ref_columns': ['id'],
#                                                'ref_table': 'granter_application'},
#                                               {'columns': ['document_type_id'],
#                                                'ref_columns': ['id'],
#                                                'ref_table': 'granter_doctype'}],
#                              'primary_keys': ['id'],
#                              'raw_ddl': 'CREATE TABLE '
#                                         '`granter_applicationfile` (\n'
#                                         '  `id` bigint NOT NULL '
#                                         'AUTO_INCREMENT,\n'
#                                         '  `created_at` datetime(6) NOT NULL,\n'
#                                         '  `updated_at` datetime(6) NOT NULL,\n'
#                                         '  `name` varchar(1500) NOT NULL,\n'
#                                         '  `uploaded_file` varchar(1500) NOT '
#                                         'NULL,\n'
#                                         '  `vector_indexed` tinyint(1) NOT '
#                                         'NULL,\n'
#                                         '  `type` varchar(30) NOT NULL,\n'
#                                         '  `application_id` bigint NOT NULL,\n'
#                                         '  `document_type_id` bigint DEFAULT '
#                                         'NULL,\n'
#                                         '  PRIMARY KEY (`id`),\n'
#                                         '  KEY '
#                                         '`granter_applicationf_application_id_1aa2b0d5_fk_granter_a` '
#                                         '(`application_id`),\n'
#                                         '  KEY '
#                                         '`granter_applicationf_document_type_id_83886dda_fk_granter_d` '
#                                         '(`document_type_id`),\n'
#                                         '  CONSTRAINT '
#                                         '`granter_applicationf_application_id_1aa2b0d5_fk_granter_a` '
#                                         'FOREIGN KEY (`application_id`) '
#                                         'REFERENCES `granter_application` '
#                                         '(`id`),\n'
#                                         '  CONSTRAINT '
#                                         '`granter_applicationf_document_type_id_83886dda_fk_granter_d` '
#                                         'FOREIGN KEY (`document_type_id`) '
#                                         'REFERENCES `granter_doctype` (`id`)\n'
#                                         ');'},
#  'granter_company': {'columns': ['id',
#                                  'created_at',
#                                  'updated_at',
#                                  'name',
#                                  'legal_name',
#                                  'address',
#                                  'post_code',
#                                  'city',
#                                  'country',
#                                  'url',
#                                  'legal_form',
#                                  'activity_date',
#                                  'company_id',
#                                  'tax_id',
#                                  'social_security_id',
#                                  'is_sme',
#                                  'employees_n',
#                                  'annual_revenue',
#                                  'description',
#                                  'cover_image',
#                                  'website_data',
#                                  'owner_id',
#                                  'stripe_customer_id',
#                                  'digital_component',
#                                  'future_goals_infrastructure',
#                                  'future_goals_internationalization',
#                                  'future_goals_machinery_and_equipments',
#                                  'future_goals_marketing',
#                                  'future_goals_rd',
#                                  'green_component',
#                                  'team_description',
#                                  'future_goals_hr',
#                                  'onboarding_state',
#                                  'matches_generating',
#                                  'userless',
#                                  'cae',
#                                  'whitelabel_id',
#                                  'related_operations',
#                                  'shareholders',
#                                  'other_data',
#                                  'source',
#                                  'subscription_id',
#                                  'extra_information',
#                                  'matching_order',
#                                  'agent_language'],
#                      'foreign_keys': [{'columns': ['owner_id'],
#                                        'ref_columns': ['id'],
#                                        'ref_table': 'granter_profile'},
#                                       {'columns': ['subscription_id'],
#                                        'ref_columns': ['id'],
#                                        'ref_table': 'granter_subscription'},
#                                       {'columns': ['whitelabel_id'],
#                                        'ref_columns': ['id'],
#                                        'ref_table': 'granter_whitelabel'}],
#                      'primary_keys': ['id'],
#                      'raw_ddl': 'CREATE TABLE `granter_company` (\n'
#                                 '  `id` bigint NOT NULL AUTO_INCREMENT,\n'
#                                 '  `created_at` datetime(6) NOT NULL,\n'
#                                 '  `updated_at` datetime(6) NOT NULL,\n'
#                                 '  `name` varchar(100) NOT NULL,\n'
#                                 '  `legal_name` varchar(100) NOT NULL,\n'
#                                 '  `address` varchar(200) NOT NULL,\n'
#                                 '  `post_code` varchar(100) NOT NULL,\n'
#                                 '  `city` varchar(100) NOT NULL,\n'
#                                 '  `country` varchar(30) NOT NULL,\n'
#                                 '  `url` varchar(1000) NOT NULL,\n'
#                                 '  `legal_form` varchar(100) DEFAULT NULL,\n'
#                                 '  `activity_date` date DEFAULT NULL,\n'
#                                 '  `company_id` varchar(50) NOT NULL,\n'
#                                 '  `tax_id` varchar(50) NOT NULL,\n'
#                                 '  `social_security_id` varchar(50) NOT NULL,\n'
#                                 '  `is_sme` tinyint(1) NOT NULL,\n'
#                                 '  `employees_n` int unsigned DEFAULT NULL,\n'
#                                 '  `annual_revenue` decimal(14,2) DEFAULT '
#                                 'NULL,\n'
#                                 '  `description` longtext NOT NULL,\n'
#                                 '  `cover_image` varchar(100) NOT NULL,\n'
#                                 '  `website_data` longtext,\n'
#                                 '  `owner_id` bigint DEFAULT NULL,\n'
#                                 '  `stripe_customer_id` varchar(200) DEFAULT '
#                                 'NULL,\n'
#                                 '  `digital_component` longtext,\n'
#                                 '  `future_goals_infrastructure` longtext,\n'
#                                 '  `future_goals_internationalization` '
#                                 'longtext,\n'
#                                 '  `future_goals_machinery_and_equipments` '
#                                 'longtext,\n'
#                                 '  `future_goals_marketing` longtext,\n'
#                                 '  `future_goals_rd` longtext,\n'
#                                 '  `green_component` longtext,\n'
#                                 '  `team_description` longtext,\n'
#                                 '  `future_goals_hr` longtext,\n'
#                                 '  `onboarding_state` varchar(100) DEFAULT '
#                                 'NULL,\n'
#                                 '  `matches_generating` tinyint(1) NOT NULL,\n'
#                                 '  `userless` tinyint(1) NOT NULL,\n'
#                                 '  `cae` json DEFAULT NULL,\n'
#                                 '  `whitelabel_id` bigint DEFAULT NULL,\n'
#                                 '  `related_operations` longtext,\n'
#                                 '  `shareholders` longtext,\n'
#                                 '  `other_data` json DEFAULT NULL,\n'
#                                 '  `source` varchar(200) NOT NULL,\n'
#                                 '  `subscription_id` bigint DEFAULT NULL,\n'
#                                 '  `extra_information` longtext,\n'
#                                 '  `matching_order` json NOT NULL DEFAULT '
#                                 '(_utf8mb3\'{"closing_soon": 1, '
#                                 '"co_financing_percentage": 2, "grant_amount": '
#                                 '3, "application_difficulty": 4}\'),\n'
#                                 '  `agent_language` varchar(10) NOT NULL,\n'
#                                 '  PRIMARY KEY (`id`),\n'
#                                 '  KEY '
#                                 '`granter_company_owner_id_a5db6676_fk_granter_profile_id` '
#                                 '(`owner_id`),\n'
#                                 '  KEY '
#                                 '`granter_company_whitelabel_id_8f5b3ccd_fk_granter_whitelabel_id` '
#                                 '(`whitelabel_id`),\n'
#                                 '  KEY '
#                                 '`granter_company_subscription_id_bdda824d_fk_granter_s` '
#                                 '(`subscription_id`),\n'
#                                 '  CONSTRAINT '
#                                 '`granter_company_owner_id_a5db6676_fk_granter_profile_id` '
#                                 'FOREIGN KEY (`owner_id`) REFERENCES '
#                                 '`granter_profile` (`id`),\n'
#                                 '  CONSTRAINT '
#                                 '`granter_company_subscription_id_bdda824d_fk_granter_s` '
#                                 'FOREIGN KEY (`subscription_id`) REFERENCES '
#                                 '`granter_subscription` (`id`),\n'
#                                 '  CONSTRAINT '
#                                 '`granter_company_whitelabel_id_8f5b3ccd_fk_granter_whitelabel_id` '
#                                 'FOREIGN KEY (`whitelabel_id`) REFERENCES '
#                                 '`granter_whitelabel` (`id`),\n'
#                                 '  CONSTRAINT `granter_company_chk_1` CHECK '
#                                 '((`employees_n` >= 0))\n'
#                                 ');'},
#  'granter_companyfile': {'columns': ['id',
#                                      'created_at',
#                                      'updated_at',
#                                      'name',
#                                      'uploaded_file',
#                                      'company_id',
#                                      'document_type_id',
#                                      'vector_indexed',
#                                      'codename',
#                                      'type',
#                                      'uploaded_by_id'],
#                          'foreign_keys': [{'columns': ['company_id'],
#                                            'ref_columns': ['id'],
#                                            'ref_table': 'granter_company'},
#                                           {'columns': ['document_type_id'],
#                                            'ref_columns': ['id'],
#                                            'ref_table': 'granter_doctype'},
#                                           {'columns': ['uploaded_by_id'],
#                                            'ref_columns': ['id'],
#                                            'ref_table': 'granter_profile'}],
#                          'primary_keys': ['id'],
#                          'raw_ddl': 'CREATE TABLE `granter_companyfile` (\n'
#                                     '  `id` bigint NOT NULL AUTO_INCREMENT,\n'
#                                     '  `created_at` datetime(6) NOT NULL,\n'
#                                     '  `updated_at` datetime(6) NOT NULL,\n'
#                                     '  `name` varchar(1500) NOT NULL,\n'
#                                     '  `uploaded_file` varchar(100) NOT NULL,\n'
#                                     '  `company_id` bigint NOT NULL,\n'
#                                     '  `document_type_id` bigint DEFAULT '
#                                     'NULL,\n'
#                                     '  `vector_indexed` tinyint(1) NOT NULL,\n'
#                                     '  `codename` varchar(1500) DEFAULT NULL,\n'
#                                     '  `type` varchar(30) NOT NULL,\n'
#                                     '  `uploaded_by_id` bigint DEFAULT NULL,\n'
#                                     '  PRIMARY KEY (`id`),\n'
#                                     '  KEY '
#                                     '`granter_companyfile_company_id_e278b4dd_fk_granter_company_id` '
#                                     '(`company_id`),\n'
#                                     '  KEY '
#                                     '`granter_companyfile_document_type_id_5ceadfe3_fk_granter_d` '
#                                     '(`document_type_id`),\n'
#                                     '  KEY '
#                                     '`granter_companyfile_uploaded_by_id_442c2144_fk_granter_p` '
#                                     '(`uploaded_by_id`),\n'
#                                     '  CONSTRAINT '
#                                     '`granter_companyfile_company_id_e278b4dd_fk_granter_company_id` '
#                                     'FOREIGN KEY (`company_id`) REFERENCES '
#                                     '`granter_company` (`id`),\n'
#                                     '  CONSTRAINT '
#                                     '`granter_companyfile_document_type_id_5ceadfe3_fk_granter_d` '
#                                     'FOREIGN KEY (`document_type_id`) '
#                                     'REFERENCES `granter_doctype` (`id`),\n'
#                                     '  CONSTRAINT '
#                                     '`granter_companyfile_uploaded_by_id_442c2144_fk_granter_p` '
#                                     'FOREIGN KEY (`uploaded_by_id`) REFERENCES '
#                                     '`granter_profile` (`id`)\n'
#                                     ');'},
#  'granter_companymemory': {'columns': ['id',
#                                        'created_at',
#                                        'updated_at',
#                                        'content',
#                                        'vector_indexed',
#                                        'company_id',
#                                        'created_by_id',
#                                        'type'],
#                            'foreign_keys': [{'columns': ['created_by_id'],
#                                              'ref_columns': ['id'],
#                                              'ref_table': 'granter_profile'},
#                                             {'columns': ['company_id'],
#                                              'ref_columns': ['id'],
#                                              'ref_table': 'granter_company'}],
#                            'primary_keys': ['id'],
#                            'raw_ddl': 'CREATE TABLE `granter_companymemory` (\n'
#                                       '  `id` bigint NOT NULL AUTO_INCREMENT,\n'
#                                       '  `created_at` datetime(6) NOT NULL,\n'
#                                       '  `updated_at` datetime(6) NOT NULL,\n'
#                                       '  `content` longtext NOT NULL,\n'
#                                       '  `vector_indexed` tinyint(1) NOT '
#                                       'NULL,\n'
#                                       '  `company_id` bigint NOT NULL,\n'
#                                       '  `created_by_id` bigint DEFAULT NULL,\n'
#                                       '  `type` varchar(30) NOT NULL,\n'
#                                       '  PRIMARY KEY (`id`),\n'
#                                       '  KEY '
#                                       '`granter_companymemory_company_id_1649f842_fk_granter_company_id` '
#                                       '(`company_id`),\n'
#                                       '  KEY '
#                                       '`granter_companymemor_created_by_id_627bba35_fk_granter_p` '
#                                       '(`created_by_id`),\n'
#                                       '  CONSTRAINT '
#                                       '`granter_companymemor_created_by_id_627bba35_fk_granter_p` '
#                                       'FOREIGN KEY (`created_by_id`) '
#                                       'REFERENCES `granter_profile` (`id`),\n'
#                                       '  CONSTRAINT '
#                                       '`granter_companymemory_company_id_1649f842_fk_granter_company_id` '
#                                       'FOREIGN KEY (`company_id`) REFERENCES '
#                                       '`granter_company` (`id`)\n'
#                                       ');'},
#  'granter_consortium': {'columns': ['id',
#                                     'created_at',
#                                     'updated_at',
#                                     'opportunity_id',
#                                     'project_description',
#                                     'state'],
#                         'foreign_keys': [{'columns': ['opportunity_id'],
#                                           'ref_columns': ['id'],
#                                           'ref_table': 'granter_opportunity'}],
#                         'primary_keys': ['id'],
#                         'raw_ddl': 'CREATE TABLE `granter_consortium` (\n'
#                                    '  `id` bigint NOT NULL AUTO_INCREMENT,\n'
#                                    '  `created_at` datetime(6) NOT NULL,\n'
#                                    '  `updated_at` datetime(6) NOT NULL,\n'
#                                    '  `opportunity_id` bigint NOT NULL,\n'
#                                    '  `project_description` longtext,\n'
#                                    '  `state` varchar(30) NOT NULL,\n'
#                                    '  PRIMARY KEY (`id`),\n'
#                                    '  KEY '
#                                    '`granter_consortium_opportunity_id_f321d531_fk_granter_o` '
#                                    '(`opportunity_id`),\n'
#                                    '  CONSTRAINT '
#                                    '`granter_consortium_opportunity_id_f321d531_fk_granter_o` '
#                                    'FOREIGN KEY (`opportunity_id`) REFERENCES '
#                                    '`granter_opportunity` (`id`)\n'
#                                    ');'},
#  'granter_consortiumpartner': {'columns': ['id',
#                                            'created_at',
#                                            'updated_at',
#                                            'partner_description',
#                                            'company_id',
#                                            'consortium_id',
#                                            'partner_type_id'],
#                                'foreign_keys': [{'columns': ['company_id'],
#                                                  'ref_columns': ['id'],
#                                                  'ref_table': 'granter_company'},
#                                                 {'columns': ['consortium_id'],
#                                                  'ref_columns': ['id'],
#                                                  'ref_table': 'granter_consortium'},
#                                                 {'columns': ['partner_type_id'],
#                                                  'ref_columns': ['id'],
#                                                  'ref_table': 'granter_consortiumpartnertype'}],
#                                'primary_keys': ['id'],
#                                'raw_ddl': 'CREATE TABLE '
#                                           '`granter_consortiumpartner` (\n'
#                                           '  `id` bigint NOT NULL '
#                                           'AUTO_INCREMENT,\n'
#                                           '  `created_at` datetime(6) NOT '
#                                           'NULL,\n'
#                                           '  `updated_at` datetime(6) NOT '
#                                           'NULL,\n'
#                                           '  `partner_description` longtext,\n'
#                                           '  `company_id` bigint NOT NULL,\n'
#                                           '  `consortium_id` bigint NOT NULL,\n'
#                                           '  `partner_type_id` bigint NOT '
#                                           'NULL,\n'
#                                           '  PRIMARY KEY (`id`),\n'
#                                           '  KEY '
#                                           '`granter_consortiumpa_company_id_13a72d88_fk_granter_c` '
#                                           '(`company_id`),\n'
#                                           '  KEY '
#                                           '`granter_consortiumpa_consortium_id_c667f18f_fk_granter_c` '
#                                           '(`consortium_id`),\n'
#                                           '  KEY '
#                                           '`granter_consortiumpa_partner_type_id_1069b08a_fk_granter_c` '
#                                           '(`partner_type_id`),\n'
#                                           '  CONSTRAINT '
#                                           '`granter_consortiumpa_company_id_13a72d88_fk_granter_c` '
#                                           'FOREIGN KEY (`company_id`) '
#                                           'REFERENCES `granter_company` '
#                                           '(`id`),\n'
#                                           '  CONSTRAINT '
#                                           '`granter_consortiumpa_consortium_id_c667f18f_fk_granter_c` '
#                                           'FOREIGN KEY (`consortium_id`) '
#                                           'REFERENCES `granter_consortium` '
#                                           '(`id`),\n'
#                                           '  CONSTRAINT '
#                                           '`granter_consortiumpa_partner_type_id_1069b08a_fk_granter_c` '
#                                           'FOREIGN KEY (`partner_type_id`) '
#                                           'REFERENCES '
#                                           '`granter_consortiumpartnertype` '
#                                           '(`id`)\n'
#                                           ');'},
#  'granter_consortiumpartnertype': {'columns': ['id',
#                                                'created_at',
#                                                'updated_at',
#                                                'codename',
#                                                'description',
#                                                'description_en',
#                                                'description_pt',
#                                                'title',
#                                                'title_en',
#                                                'title_pt',
#                                                'type',
#                                                'description_es',
#                                                'description_it',
#                                                'description_pl',
#                                                'title_es',
#                                                'title_it',
#                                                'title_pl'],
#                                    'foreign_keys': [],
#                                    'primary_keys': ['id'],
#                                    'raw_ddl': 'CREATE TABLE '
#                                               '`granter_consortiumpartnertype` '
#                                               '(\n'
#                                               '  `id` bigint NOT NULL '
#                                               'AUTO_INCREMENT,\n'
#                                               '  `created_at` datetime(6) NOT '
#                                               'NULL,\n'
#                                               '  `updated_at` datetime(6) NOT '
#                                               'NULL,\n'
#                                               '  `codename` varchar(60) NOT '
#                                               'NULL,\n'
#                                               '  `description` longtext,\n'
#                                               '  `description_en` longtext,\n'
#                                               '  `description_pt` longtext,\n'
#                                               '  `title` varchar(100) NOT '
#                                               'NULL,\n'
#                                               '  `title_en` varchar(100) '
#                                               'DEFAULT NULL,\n'
#                                               '  `title_pt` varchar(100) '
#                                               'DEFAULT NULL,\n'
#                                               '  `type` varchar(50) NOT NULL,\n'
#                                               '  `description_es` longtext,\n'
#                                               '  `description_it` longtext,\n'
#                                               '  `description_pl` longtext,\n'
#                                               '  `title_es` varchar(100) '
#                                               'DEFAULT NULL,\n'
#                                               '  `title_it` varchar(100) '
#                                               'DEFAULT NULL,\n'
#                                               '  `title_pl` varchar(100) '
#                                               'DEFAULT NULL,\n'
#                                               '  PRIMARY KEY (`id`),\n'
#                                               '  UNIQUE KEY `codename` '
#                                               '(`codename`)\n'
#                                               ');'},
#  'granter_consortiumpartnertype_consortium': {'columns': ['id',
#                                                           'consortiumpartnertype_id',
#                                                           'consortium_id'],
#                                               'foreign_keys': [{'columns': ['consortium_id'],
#                                                                 'ref_columns': ['id'],
#                                                                 'ref_table': 'granter_consortium'},
#                                                                {'columns': ['consortiumpartnertype_id'],
#                                                                 'ref_columns': ['id'],
#                                                                 'ref_table': 'granter_consortiumpartnertype'}],
#                                               'primary_keys': ['id'],
#                                               'raw_ddl': 'CREATE TABLE '
#                                                          '`granter_consortiumpartnertype_consortium` '
#                                                          '(\n'
#                                                          '  `id` bigint NOT '
#                                                          'NULL '
#                                                          'AUTO_INCREMENT,\n'
#                                                          '  '
#                                                          '`consortiumpartnertype_id` '
#                                                          'bigint NOT NULL,\n'
#                                                          '  `consortium_id` '
#                                                          'bigint NOT NULL,\n'
#                                                          '  PRIMARY KEY '
#                                                          '(`id`),\n'
#                                                          '  UNIQUE KEY '
#                                                          '`granter_consortiumpartne_consortiumpartnertype_id_a66088e1_uniq` '
#                                                          '(`consortiumpartnertype_id`,`consortium_id`),\n'
#                                                          '  KEY '
#                                                          '`granter_consortiumpa_consortium_id_9843551d_fk_granter_c` '
#                                                          '(`consortium_id`),\n'
#                                                          '  CONSTRAINT '
#                                                          '`granter_consortiumpa_consortium_id_9843551d_fk_granter_c` '
#                                                          'FOREIGN KEY '
#                                                          '(`consortium_id`) '
#                                                          'REFERENCES '
#                                                          '`granter_consortium` '
#                                                          '(`id`),\n'
#                                                          '  CONSTRAINT '
#                                                          '`granter_consortiumpa_consortiumpartnertyp_1bc288b1_fk_granter_c` '
#                                                          'FOREIGN KEY '
#                                                          '(`consortiumpartnertype_id`) '
#                                                          'REFERENCES '
#                                                          '`granter_consortiumpartnertype` '
#                                                          '(`id`)\n'
#                                                          ');'},
#  'granter_generalopportunityfile': {'columns': ['id',
#                                                 'created_at',
#                                                 'updated_at',
#                                                 'codename',
#                                                 'name',
#                                                 'uploaded_file'],
#                                     'foreign_keys': [],
#                                     'primary_keys': ['id'],
#                                     'raw_ddl': 'CREATE TABLE '
#                                                '`granter_generalopportunityfile` '
#                                                '(\n'
#                                                '  `id` bigint NOT NULL '
#                                                'AUTO_INCREMENT,\n'
#                                                '  `created_at` datetime(6) NOT '
#                                                'NULL,\n'
#                                                '  `updated_at` datetime(6) NOT '
#                                                'NULL,\n'
#                                                '  `codename` varchar(500) '
#                                                'DEFAULT NULL,\n'
#                                                '  `name` varchar(500) NOT '
#                                                'NULL,\n'
#                                                '  `uploaded_file` varchar(100) '
#                                                'NOT NULL,\n'
#                                                '  PRIMARY KEY (`id`)\n'
#                                                ');'},
#  'granter_generalopportunityfile_opportunities': {'columns': ['id',
#                                                               'generalopportunityfile_id',
#                                                               'opportunity_id'],
#                                                   'foreign_keys': [{'columns': ['generalopportunityfile_id'],
#                                                                     'ref_columns': ['id'],
#                                                                     'ref_table': 'granter_generalopportunityfile'},
#                                                                    {'columns': ['opportunity_id'],
#                                                                     'ref_columns': ['id'],
#                                                                     'ref_table': 'granter_opportunity'}],
#                                                   'primary_keys': ['id'],
#                                                   'raw_ddl': 'CREATE TABLE '
#                                                              '`granter_generalopportunityfile_opportunities` '
#                                                              '(\n'
#                                                              '  `id` bigint '
#                                                              'NOT NULL '
#                                                              'AUTO_INCREMENT,\n'
#                                                              '  '
#                                                              '`generalopportunityfile_id` '
#                                                              'bigint NOT '
#                                                              'NULL,\n'
#                                                              '  '
#                                                              '`opportunity_id` '
#                                                              'bigint NOT '
#                                                              'NULL,\n'
#                                                              '  PRIMARY KEY '
#                                                              '(`id`),\n'
#                                                              '  UNIQUE KEY '
#                                                              '`granter_generalopportuni_generalopportunityfile_i_3f91c4cc_uniq` '
#                                                              '(`generalopportunityfile_id`,`opportunity_id`),\n'
#                                                              '  KEY '
#                                                              '`granter_generaloppor_opportunity_id_ff1803f9_fk_granter_o` '
#                                                              '(`opportunity_id`),\n'
#                                                              '  CONSTRAINT '
#                                                              '`granter_generaloppor_generalopportunityfi_d25fa7a3_fk_granter_g` '
#                                                              'FOREIGN KEY '
#                                                              '(`generalopportunityfile_id`) '
#                                                              'REFERENCES '
#                                                              '`granter_generalopportunityfile` '
#                                                              '(`id`),\n'
#                                                              '  CONSTRAINT '
#                                                              '`granter_generaloppor_opportunity_id_ff1803f9_fk_granter_o` '
#                                                              'FOREIGN KEY '
#                                                              '(`opportunity_id`) '
#                                                              'REFERENCES '
#                                                              '`granter_opportunity` '
#                                                              '(`id`)\n'
#                                                              ');'},
#  'granter_opportunity': {'columns': ['id',
#                                      'created_at',
#                                      'updated_at',
#                                      'type',
#                                      'codename',
#                                      'state',
#                                      'name',
#                                      'fe_value',
#                                      'url',
#                                      'description',
#                                      'cover_image',
#                                      'upfront_fee',
#                                      'force_closing_soon',
#                                      'assistant_id',
#                                      'last_email_reminder',
#                                      'prep_time',
#                                      'location',
#                                      'last_email_push',
#                                      'free_applications',
#                                      'internal_submission',
#                                      'small_cover_image',
#                                      'crawler_data_id',
#                                      'expected_success_rate',
#                                      'success_fee',
#                                      'difficulty_level',
#                                      'eligibility_criteria',
#                                      'eligible_expenses',
#                                      'financial_information',
#                                      'financing_rate',
#                                      'project_duration_months',
#                                      'project_max_value',
#                                      'project_min_value',
#                                      'admissible_projects',
#                                      'form_questions',
#                                      'currency',
#                                      'difficulty_level_fundamentation',
#                                      'tags_fundamentation'],
#                          'foreign_keys': [],
#                          'primary_keys': ['id'],
#                          'raw_ddl': 'CREATE TABLE `granter_opportunity` (\n'
#                                     '  `id` bigint NOT NULL AUTO_INCREMENT,\n'
#                                     '  `created_at` datetime(6) NOT NULL,\n'
#                                     '  `updated_at` datetime(6) NOT NULL,\n'
#                                     '  `type` varchar(30) NOT NULL,\n'
#                                     '  `codename` varchar(100) NOT NULL,\n'
#                                     '  `state` varchar(30) NOT NULL,\n'
#                                     '  `name` varchar(350) NOT NULL,\n'
#                                     '  `fe_value` varchar(50) NOT NULL,\n'
#                                     '  `url` varchar(1000) NOT NULL,\n'
#                                     '  `description` longtext,\n'
#                                     '  `cover_image` varchar(100) NOT NULL,\n'
#                                     '  `upfront_fee` varchar(250) DEFAULT '
#                                     'NULL,\n'
#                                     '  `force_closing_soon` tinyint(1) NOT '
#                                     'NULL,\n'
#                                     '  `assistant_id` varchar(100) DEFAULT '
#                                     'NULL,\n'
#                                     '  `last_email_reminder` varchar(30) '
#                                     'DEFAULT NULL,\n'
#                                     '  `prep_time` varchar(50) NOT NULL,\n'
#                                     '  `location` varchar(30) NOT NULL,\n'
#                                     '  `last_email_push` datetime(6) DEFAULT '
#                                     'NULL,\n'
#                                     '  `free_applications` tinyint(1) NOT '
#                                     'NULL,\n'
#                                     '  `internal_submission` tinyint(1) NOT '
#                                     'NULL,\n'
#                                     '  `small_cover_image` varchar(100) '
#                                     'DEFAULT NULL,\n'
#                                     '  `crawler_data_id` varchar(150) DEFAULT '
#                                     'NULL,\n'
#                                     '  `expected_success_rate` smallint '
#                                     'DEFAULT NULL,\n'
#                                     '  `success_fee` varchar(250) DEFAULT '
#                                     'NULL,\n'
#                                     '  `difficulty_level` varchar(30) NOT '
#                                     'NULL,\n'
#                                     '  `eligibility_criteria` longtext,\n'
#                                     '  `eligible_expenses` longtext,\n'
#                                     '  `financial_information` longtext,\n'
#                                     '  `financing_rate` double DEFAULT NULL,\n'
#                                     '  `project_duration_months` smallint '
#                                     'DEFAULT NULL,\n'
#                                     '  `project_max_value` int unsigned '
#                                     'DEFAULT NULL,\n'
#                                     '  `project_min_value` int unsigned '
#                                     'DEFAULT NULL,\n'
#                                     '  `admissible_projects` longtext,\n'
#                                     '  `form_questions` longtext,\n'
#                                     '  `currency` varchar(10) NOT NULL,\n'
#                                     '  `difficulty_level_fundamentation` '
#                                     'longtext,\n'
#                                     '  `tags_fundamentation` longtext,\n'
#                                     '  PRIMARY KEY (`id`),\n'
#                                     '  UNIQUE KEY `codename` (`codename`),\n'
#                                     '  CONSTRAINT `granter_opportunity_chk_1` '
#                                     'CHECK ((`project_max_value` >= 0)),\n'
#                                     '  CONSTRAINT `granter_opportunity_chk_2` '
#                                     'CHECK ((`project_min_value` >= 0))\n'
#                                     ');'},
#  'granter_opportunityfile': {'columns': ['id',
#                                          'created_at',
#                                          'updated_at',
#                                          'name',
#                                          'uploaded_file',
#                                          'vector_indexed',
#                                          'opportunity_id',
#                                          'codename'],
#                              'foreign_keys': [{'columns': ['opportunity_id'],
#                                                'ref_columns': ['id'],
#                                                'ref_table': 'granter_opportunity'}],
#                              'primary_keys': ['id'],
#                              'raw_ddl': 'CREATE TABLE '
#                                         '`granter_opportunityfile` (\n'
#                                         '  `id` bigint NOT NULL '
#                                         'AUTO_INCREMENT,\n'
#                                         '  `created_at` datetime(6) NOT NULL,\n'
#                                         '  `updated_at` datetime(6) NOT NULL,\n'
#                                         '  `name` varchar(1500) NOT NULL,\n'
#                                         '  `uploaded_file` varchar(1500) NOT '
#                                         'NULL,\n'
#                                         '  `vector_indexed` tinyint(1) NOT '
#                                         'NULL,\n'
#                                         '  `opportunity_id` bigint NOT NULL,\n'
#                                         '  `codename` varchar(1500) DEFAULT '
#                                         'NULL,\n'
#                                         '  PRIMARY KEY (`id`),\n'
#                                         '  KEY '
#                                         '`granter_opportunityf_opportunity_id_43ea4ab5_fk_granter_o` '
#                                         '(`opportunity_id`),\n'
#                                         '  CONSTRAINT '
#                                         '`granter_opportunityf_opportunity_id_43ea4ab5_fk_granter_o` '
#                                         'FOREIGN KEY (`opportunity_id`) '
#                                         'REFERENCES `granter_opportunity` '
#                                         '(`id`)\n'
#                                         ');'},
#  'granter_timeline': {'columns': ['id',
#                                   'created_at',
#                                   'updated_at',
#                                   'type',
#                                   'title',
#                                   'description',
#                                   'date',
#                                   'time',
#                                   'opportunity_id',
#                                   'time_diff',
#                                   'is_prediction'],
#                       'foreign_keys': [{'columns': ['opportunity_id'],
#                                         'ref_columns': ['id'],
#                                         'ref_table': 'granter_opportunity'}],
#                       'primary_keys': ['id'],
#                       'raw_ddl': 'CREATE TABLE `granter_timeline` (\n'
#                                  '  `id` bigint NOT NULL AUTO_INCREMENT,\n'
#                                  '  `created_at` datetime(6) NOT NULL,\n'
#                                  '  `updated_at` datetime(6) NOT NULL,\n'
#                                  '  `type` varchar(30) NOT NULL,\n'
#                                  '  `title` varchar(100) NOT NULL,\n'
#                                  '  `description` varchar(500) DEFAULT NULL,\n'
#                                  '  `date` date DEFAULT NULL,\n'
#                                  '  `time` time(6) DEFAULT NULL,\n'
#                                  '  `opportunity_id` bigint NOT NULL,\n'
#                                  '  `time_diff` varchar(30) DEFAULT NULL,\n'
#                                  '  `is_prediction` tinyint(1) NOT NULL,\n'
#                                  '  PRIMARY KEY (`id`),\n'
#                                  '  KEY '
#                                  '`granter_timeline_opportunity_id_f7daba4f_fk_granter_o` '
#                                  '(`opportunity_id`),\n'
#                                  '  CONSTRAINT '
#                                  '`granter_timeline_opportunity_id_f7daba4f_fk_granter_o` '
#                                  'FOREIGN KEY (`opportunity_id`) REFERENCES '
#                                  '`granter_opportunity` (`id`)\n'
#                                  ');'}}

# %% [markdown]
# # Descriptions of the Database tables

# %%
None

# %% [markdown]
# # Pipeline

# %% [markdown]
# ## Prompt

# %%
#prompt = f"""
#    Generate ontology elements with provenance annotations for database table {data[table_name]} based on:
#
#    [CONTEXT]
#    - Database Schema of the database {data[schema_context]}
#    - Take semantics from the Relevant Documents {data[documents]}
#    - Take semantics from the Existing Ontology Knowledge {data[existing_ontology]}
#
#    [INSTRUCTIONS]
#    1. Include these elements: 
#        Classes (subclass of Thing)
#        Data properties with domain/range
#        Object properties with domain/range
#        Use only one rdfs:domain and one rdfs:range per property. If multiple options exist, select the most general or create a shared superclass.
#    3. Do not create a property named "is". Use rdf:type for instance membership, rdfs:subClassOf for class hierarchies, and owl:sameAs for instance equality.
#    4. Use this format example:
#
#    Class: {data[table_name]}
#    Annotations:
#    prov:wasDerivedFrom
#    <http://example.org/provenance/{data[table_name]}>
#
#    DataProperty:
#    has_column_name
#    domain {data[table_name]}
#    range string
#    Annotations:
#    prov:wasDerivedFrom
#    <http://example.org/provenance/{data[table_name]}/column_name>
#
#    ObjectProperty:
#    relates_to_table domain {data[table_name]}
#    range RelatedTable
#    Annotations:
#    prov:wasDerivedFrom
#    <http://example.org/provenance/{data[table_name]}/fk_column>
#
#    Only output Manchester Syntax and nothing else. [OUTPUT]
#"""

# %% [markdown]
# ## Building a delta-ontology (Iteration 01)

# %%
from langchain_ollama import OllamaLLM
llm = OllamaLLM(model="llama3.2:3b")
# Out:
# c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
with open("external_ontologies/DINGO-OWL.ttl", "r", encoding="utf-8") as f:
    external_ontology = f.read()
print(external_ontology[632:])
# Out:
# dg:Grant a rdfs:Class ;
#     rdfs:label "Grant" ;
#     rdfs:comment "The class for grant: a disbursed fund payed to a recipient or beneficiary and the process for it." ;
#     rdfs:isDefinedBy dg: ;
# 	skos:closeMatch schema:MonetaryGrant ;
# 	skos:closeMatch frapo:Funding ;
# 	skos:narrowMatch frapo:Grant ;
# 	skos:broadMatch wd:Q230788 .
#
# dg:GrantPayment a rdfs:Class ;
#     rdfs:label "GrantPayment" ;
#     rdfs:comment "The class for grant payments: a single payment to a recipient or beneficiary within a Grant." ;
#     rdfs:isDefinedBy dg: ;
# 	skos:broadMatch frapo:Payment ;
# 	skos:broadMatch wd:Q1148747 .
#
# dg:GrantShare a rdfs:Class ;
#     rdfs:label "GrantShare" ;
#     rdfs:comment "The class for grant shares: the full or proper portion or part allotted or belonging to or contributed to an individual entity within a Grant." ;
#     rdfs:isDefinedBy dg: .
#
# dg:Project a rdfs:Class ;
#     rdfs:label "Project" ;
#     rdfs:comment "The class for projects: an organised endeavour (collective or individual) planned to reach a particular aim or achieve a result." ;
#     rdfs:isDefinedBy dg: ;
# 	skos:closeMatch schema:Project ;
# 	skos:closeMatch foaf:Project ;
# 	skos:narrowMatch frapo:Project ;
# 	skos:narrowMatch frapo:Investigation ;
# 	skos:closeMatch wd:Q170584 .
#
# dg:Role a rdfs:Class ;
#     rdfs:label "Role" ;
#     rdfs:comment """The class for roles: the function assumed by or ascribed to an entity (typically person, group of persons or organisation) in a particular situation.
# It can be used to precise or represent additional information about a relationship or property such as participation or membership. The class should be only used to derive subclasses.""" ;
#     rdfs:isDefinedBy dg: ;
#     skos:closeMatch schema:Role .
#
# dg:PersonRole a rdfs:Class ;
#     rdfs:label "PersonRole" ;
#     rdfs:comment "The class for person roles: function assumed by or ascribed to a person that takes part in something." ;
#     rdfs:isDefinedBy dg: ;
#     rdfs:subClassOf dg:Role .
#
# dg:OrganisationRole a rdfs:Class ;
#     rdfs:label "OrganisationRole" ;
#     rdfs:comment "The class for organisation roles: function assumed by or ascribed to an organisation that takes part in something." ;
#     rdfs:isDefinedBy dg: ;
#     rdfs:subClassOf dg:Role .
#
# dg:Person a rdfs:Class ;
#     rdfs:label "Person" ;
#     rdfs:comment "The class for persons: alive, dead, undead, or fictional." ;
#     rdfs:isDefinedBy dg: ;
#     owl:equivalentClass schema:Person ;
# 	owl:equivalentClass foaf:Person ;
# 	skos:relatedMatch wd:Q5 ;
# 	skos:relatedMatch wd:Q215627 ;
# 	skos:closeMatch wd:Q215627 .
#
# dg:Organisation a rdfs:Class ;
#     rdfs:label "Organisation" ;
#     rdfs:comment "The class for organisations: social entities with a collective goal." ;
#     rdfs:isDefinedBy dg: ;
#     owl:equivalentClass schema:Organization ;
# 	skos:closeMatch foaf:Oranization ;
# 	owl:equivalentClass wd:Q43229 ;
# 	skos:closeMatch wd:Q43229 .
#
# dg:Company a rdfs:Class ;
#     rdfs:label "Company" ;
#     rdfs:comment "A commercial business." ;
#     rdfs:isDefinedBy dg: ;
# 	skos:closeMatch schema:Corporation ;
# 	skos:closeMatch frapo:Company ;
#     rdfs:subClassOf dg:Organisation ;
# 	skos:closeMatch wd:Q783794 .
#
# dg:ForProfitOrganisation a rdfs:Class ;
#     rdfs:label "ForProfictOrganisation" ;
#     rdfs:comment "For profit entity." ;
#     rdfs:isDefinedBy dg: ;
#     rdfs:subClassOf dg:Organisation .
#
# dg:EducationOrganisation a rdfs:Class ;
#     rdfs:label "EducationOrganisation" ;
#     rdfs:comment "Institution that provides education." ;
#     rdfs:isDefinedBy dg: ;
#     owl:equivalentClass schema:EducationalOrganization ;
#     rdfs:subClassOf dg:Organisation .
#
# dg:HigherEducationOrganisation a rdfs:Class ;
#     rdfs:label "HigherEducationOrganisation" ;
#     rdfs:comment "Place of postsecondary education (e.g., universities, vocational universities, community colleges, liberal arts colleges, institutes of technology, and others)." ;
#     rdfs:isDefinedBy dg: ;
#     rdfs:subClassOf dg:Organisation .
#
# dg:ResearchPerformingOrganisation a rdfs:Class ;
#     rdfs:label "ResearchPerformingOrganisation" ;
#     rdfs:comment "Organisations devoted to research activities." ;
#     rdfs:isDefinedBy dg: ;
# 	skos:relatedMatch frapo:ResearchInstitute ;
#     rdfs:subClassOf dg:Organisation .
#
# dg:HealthcareOrganisation a rdfs:Class ;
#     rdfs:label "HealthcareOrganisation" ;
#     rdfs:comment "Organization that provides health care and related services." ;
#     rdfs:isDefinedBy dg: ;
#     owl:equivalentClass schema:MedicalOrganization ;
#     rdfs:subClassOf dg:Organisation .
#
# dg:NonprofitOrganisation a rdfs:Class ;
#     rdfs:label "NonprofitOrganisation" ;
#     rdfs:comment "Business entity that pays no income tax, as it furthers a religious, scientific or social cause, providing a public benefit." ;
#     rdfs:isDefinedBy dg: ;
# 	skos:closeMatch frapo:NotForProfitOrganization ;
#     rdfs:subClassOf dg:Organisation .
#
# dg:FacilityOrganisation a rdfs:Class ;
#     rdfs:label "FacilityOrganisation" ;
#     rdfs:comment "A place providing for a particular purpose." ;
#     rdfs:isDefinedBy dg: ;
#     rdfs:subClassOf dg:Organisation .
#
# dg:GovernmentalOrganisation a rdfs:Class ;
#     rdfs:label "GovernmentalOrganisation" ;
#     rdfs:comment "Organisation or agency depending on a government, State or other supranational organisation and mainly operated by the government." ;
#     rdfs:isDefinedBy dg: ;
#     owl:equivalentClass schema:GovernmentOrganization ;
# 	skos:relatedMatch frapo:GovernmentOrganization ;
#     rdfs:subClassOf dg:Organisation .
#
# dg:ArchiveOrganisation a rdfs:Class ;
#     rdfs:label "ArchiveOrganisation" ;
#     rdfs:comment "Institution that holds artifacts and other objects of scientific, artistic, cultural, historical, or other importance." ;
#     rdfs:isDefinedBy dg: ;
#     rdfs:subClassOf dg:Organisation .
#
# dg:CulturalOrganisation a rdfs:Class ;
#     rdfs:label "CulturalOrganisation" ;
#     rdfs:comment "Cultural institution or cultural organization is an organization within a culture/subculture that works for the preservation or promotion of culture." ;
#     rdfs:isDefinedBy dg: ;
#     rdfs:subClassOf dg:Organisation .
#
# dg:PerformingGroup a rdfs:Class ;
#     rdfs:label "PerformingGroup" ;
#     rdfs:comment "A performance group, such as a band, an orchestra, or a circus." ;
#     rdfs:isDefinedBy dg: ;
#     owl:equivalentClass schema:PerformingGroup ;
#     rdfs:subClassOf dg:Organisation .
#
# dg:SportsOrganisation a rdfs:Class ;
#     rdfs:label "SportsOrganisation" ;
#     rdfs:comment "Represents the class of all sports organizations, including sports teams, governing bodies, and sports associations." ;
#     rdfs:isDefinedBy dg: ;
#     owl:equivalentClass schema:SportsOrganisation ;
#     rdfs:subClassOf dg:Organisation .
#
# dg:SupranationalOrganisation a rdfs:Class ;
#     rdfs:label "SupranationalOrganisation" ;
#     rdfs:comment "International organisation with power and influence in the jurisdictions of its member states. Example: European Union." ;
#     rdfs:isDefinedBy dg: ;
#     rdfs:subClassOf dg:Organisation .
#
# dg:IntergovernmentalOrganisation a rdfs:Class ;
#     rdfs:label "IntergovernmentalOrganisation" ;
#     rdfs:comment "Organization composed primarily of sovereign states. Example: United Nations." ;
#     rdfs:isDefinedBy dg: ;
#     rdfs:subClassOf dg:Organisation .
#
# dg:FundingAgency a rdfs:Class ;
#     rdfs:label "FundingAgency" ;
#     rdfs:comment "The class for funding agencies: organisations that materially disburse and administer the Grant process." ;
#     rdfs:isDefinedBy dg: ;
# 	skos:closeMatch schema:FundingAgency ;
# 	skos:closeMatch frapo:FundingAgency ;
#     rdfs:subClassOf dg:Organisation.
#
# dg:FundingScheme a rdfs:Class ;
#     rdfs:label "FundingScheme" ;
#     rdfs:comment "The class for funding schemes: plans, designs, and/or programs that determines and organizes the funding." ;
#     rdfs:isDefinedBy dg: ;
# 	skos:closeMatch frapo:FundingProgramme ;
# 	skos:closeMatch schema:FundingScheme .
#
# dg:Criterion a rdfs:Class ;
#     rdfs:label "Criterion" ;
#     rdfs:comment "Specification of Grant coverage, Grant eligibility, Grant reimbursement rates, Grant specific criteria for funding, Grant population targets, and similar features." ;
#     rdfs:isDefinedBy dg: .
#
# dg:ThematicCriterion a rdfs:Class ;
#     rdfs:label "ThematicCriterion" ;
#     rdfs:comment "Specifies that grants are awarded to projects on the basis of specified thematic/subject areas or well-defined areas of investigation indicated by the funding body." ;
#     rdfs:isDefinedBy dg: ;
#     rdfs:subClassOf dg:Criterion.
#
# dg:OrganisationalCriterion a rdfs:Class ;
#     rdfs:label "OrganisationalCriterion" ;
#     rdfs:comment "Specifies that grants are awarded on the basis of specified organisational form of the project, for instance demanding for participation of different research groups (synergy)." ;
#     rdfs:isDefinedBy dg: ;
#     rdfs:subClassOf dg:Criterion.
#
# dg:CareerPurposeCriterion a rdfs:Class ;
#     rdfs:label "CareerPurposeCriterion" ;
#     rdfs:comment "Specifies that grants are awarded on the basis of career-related goals and applicants must be at a defined career stage (defined academic degree) to be achieved." ;
#     rdfs:isDefinedBy dg: ;
#     rdfs:subClassOf dg:Criterion.
#
# dg:InfrastructurePurposeCriterion a rdfs:Class ;
#     rdfs:label "InfrastructurePurposeCriterion" ;
#     rdfs:comment "Specifies that grants are awarded to cover for the expenses of infrastructure." ;
#     rdfs:isDefinedBy dg: ;
#     rdfs:subClassOf dg:Criterion.
#
# dg:CareerStageCriterion a rdfs:Class ;
#     rdfs:label "CareerStageCriterion" ;
#     rdfs:comment "Specifies that grants are awarded to projects on the basis of career stage limits." ;
#     rdfs:isDefinedBy dg: ;
#     rdfs:subClassOf dg:Criterion.
#
# dg:EmploymentCriterion a rdfs:Class ;
#     rdfs:label "EmploymentCriterion" ;
#     rdfs:comment "Specifies that grants are awarded on the basis of employment conditions by an organisation eligible for funding at the time of applying or receiving the funds." ;
#     rdfs:isDefinedBy dg: ;
#     rdfs:subClassOf dg:Criterion.
#
# dg:AgeCriterion a rdfs:Class ;
#     rdfs:label "AgeCriterion" ;
#     rdfs:comment "Specifies that grants are awarded to projects on the basis of age limits." ;
#     rdfs:isDefinedBy dg: ;
#     rdfs:subClassOf dg:Criterion.
#
# dg:WorkingTimeCriterion a rdfs:Class ;
#     rdfs:label "WorkingTimeCriterion" ;
#     rdfs:comment "Specifies that grants are awarded to projects on the basis of percentage of work time specifically devoted to the funded research." ;
#     rdfs:isDefinedBy dg: ;
#     rdfs:subClassOf dg:Criterion.
#
# dg:GeographicCriterion a rdfs:Class ;
#     rdfs:label "GeographicCriterion" ;
#     rdfs:comment "Specifies that grants are awarded to projects on the basis of geographic areas, either where the project has to be implemented, or where the researcher must have been operating before applying for funding, or where the participants must be resident or citizens." ;
#     rdfs:isDefinedBy dg: ;
#     rdfs:subClassOf dg:Criterion.
#
# dg:BottomUpCriterion a rdfs:Class ;
#     rdfs:label "BottomUpCriterion" ;
#     rdfs:comment "Specifies that grants are awarded to projects on the basis of the research proposal itself without restriction on theme/subject or research area. The funding body does not specifies beforehand missions, targets nor topics of the research projects that can apply." ;
#     rdfs:isDefinedBy dg: ;
#     rdfs:subClassOf dg:Criterion.
#
# dg:AcademicDegree a rdfs:Class ;
#     rdfs:label "AcademicDegree" ;
#     rdfs:comment "The class for academic degrees: college or university diploma." ;
#     rdfs:isDefinedBy dg: ;
#     owl:equivalentClass wd:Q189533 .
#
# dg:Identifier a rdfs:Class ;
#     rdfs:label "Identifier" ;
#     rdfs:comment "The class for identifiers." ;
# 	skos:closeMatch wd:Q853614 ;
# 	skos:closeMatch wd:Q6545185 ;
#     rdfs:isDefinedBy dg: .
#
# dg:InformationBase a rdfs:Class ;
#     rdfs:label "InformationBase" ;
#     rdfs:comment "An organized collection of data and/or information. It can use any available technology. The temr can also indicate in general the information system built integrating such information bases." ;
#     rdfs:isDefinedBy dg: .
#
# dg:id_value a rdf:Property ;
#     rdfs:label "id_value" ;
#     rdfs:comment "String representing the identifier." ;
#     rdfs:domain dg:Identifier ;
#     rdfs:range xsd:string ;
#     rdfs:isDefinedBy dg: .
#
# dg:used_in a rdf:Property ;
#     rdfs:label "used_in" ;
#     rdfs:comment "Database or information system where the identifier is/was used." ;
#     rdfs:domain dg:Identifier ;
#     rdfs:range  dg:InformationBase ;
#     rdfs:isDefinedBy dg: .
#
# dg:id_context_agent a rdf:Property ;
#     rdfs:label "id_context_agent" ;
#     rdfs:comment "Organization, Person, Agency related to the identifiers (for instance, creator, attributor, curator, maintainer, or similar). The specific semantic should be indicated with dedicated ontologies, such as PROV-O." ;
#     rdfs:domain dg:Identifier ;
#     rdfs:range [ a owl:Class; owl:unionOf (dg:Person dg:Organisation dg:FundingAgency) ] ;
#     rdfs:isDefinedBy dg: .
#
# dg:economic_value a rdf:Property ;
#     rdfs:label "economic_value" ;
#     rdfs:comment "Amount or value expressed in a specific currency (relationship between the item and a value expressed in a currency unit)." ;
#     rdfs:range schema:MonetaryAmount ;
# 	skos:broader schema:amount ;
#     rdfs:isDefinedBy dg: .
#
# dg:implementation_of a rdf:Property ;
#     rdfs:label "implementation_of" ;
#     rdfs:comment "The relationship between the grant (subject) and the decision, plan, program (object) that the grant is the concrete realisation of." ;
#     rdfs:domain dg:Grant ;
#     rdfs:range dg:FundingScheme ;
#     owl:inverseOf dg:has_implementation ;
#     rdfs:isDefinedBy dg: .
#
# dg:has_implementation a rdf:Property ;
#     rdfs:label "has_implementation" ;
#     rdfs:comment "The relationship between the decision, plan, program (subject) and the grant (object) that the grant is the concrete realisation of." ;
#     rdfs:domain dg:FundingScheme ;
#     rdfs:range dg:Grant ;
#     owl:inverseOf dg:implementation_of ;
#     rdfs:isDefinedBy dg: .
#
# dg:implements a rdf:Property ;
#     rdfs:label "implements" ;
#     rdfs:comment "The relationship between the funding agency (subject) and the decision, plan, program (object) that the funding agency implements and administers." ;
#     rdfs:domain dg:FundingAgency ;
#     rdfs:range dg:FundingScheme ;
#     owl:inverseOf dg:implemented_by ;
#     rdfs:isDefinedBy dg: .
#
# dg:implemented_by a rdf:Property ;
#     rdfs:label "implemented_by" ;
#     rdfs:comment "The relationship between the decision, plan, program (subject) and the funding agency (object) that the funding agency implements and administers." ;
#     rdfs:domain dg:FundingScheme ;
#     rdfs:range dg:FundingAgency ;
#     owl:inverseOf dg:implements ;
#     rdfs:isDefinedBy dg: .
#
#
# dg:finances a rdf:Property ;
#     rdfs:label "finances" ;
#     rdfs:comment "The relation between the Grant (subject) and the Project (object)." ;
#     rdfs:domain dg:Grant ;
#     rdfs:range dg:Project ;
#     owl:inverseOf dg:funded_by ;
# 	skos:closeMatch p:P2770 ;
# 	skos:broadMatch frapo:funds ;
# 	skos:broadMatch frapo:supports ;
#     rdfs:isDefinedBy dg: .
#
# dg:funded_by a rdf:Property ;
#     rdfs:label "funded_by" ;
#     rdfs:comment "The relation between the Project (subject) and the Grant (object)." ;
#     rdfs:domain dg:Project ;
#     rdfs:range dg:Grant ;
#     owl:inverseOf dg:finances ;
# 	skos:broadMatch frapo:isFundedBy ;
# 	skos:broadMatch frapo:isSupportedBy ;
#     rdfs:isDefinedBy dg: .
#
# dg:budget a rdf:Property ;
#     rdfs:label "budget" ;
#     rdfs:comment "Amount of money necessary or planned for a determined project/activity." ;
#     rdfs:domain dg:Project ;
#     rdfs:range schema:MonetaryAmount ;
# 	skos:related p:P2769 ;
#     rdfs:isDefinedBy dg: .
#
# dg:beneficiary a rdf:Property ;
#     rdfs:label "beneficiary" ;
#     rdfs:comment "The relation between the Grant (subject) and a (one of the) person(s) or organisation(s) receiving benefits from it identified by his/her/its role." ;
#     rdfs:domain dg:Grant ;
#     rdfs:range dg:Role ;
#     owl:inverseOf dg:beneficiary_of ;
# 	skos:broadMatch schema:recipient ;
#     rdfs:isDefinedBy dg: .
#
# dg:recipient a rdf:Property ;
#     rdfs:label "recipient" ;
#     rdfs:comment "The receiver of a GrantPayment or receiver/beneficiary of a GrantShare." ;
#     rdfs:domain [ a owl:Class; owl:unionOf (dg:GrantPayment dg:GrantShare) ] ;
#     rdfs:range [ a owl:Class; owl:unionOf (dg:Person dg:Organisation) ] ;
# 	skos:broadMatch schema:recipient ;
#     rdfs:isDefinedBy dg: .
#
# dg:beneficiary_of a rdf:Property ;
#     rdfs:label "beneficiary_of" ;
#     rdfs:comment "The relation between a (one of the) person(s) or organisation(s) receiving benefits from a Grant identified by his/her/its role (subject), and the Grant." ;
#     rdfs:domain dg:Role ;
#     rdfs:range dg:Grant ;
#     owl:inverseOf dg:beneficiary ;
#     rdfs:isDefinedBy dg: .
#
# dg:participant a rdf:Property ;
#     rdfs:label "participant" ;
#     rdfs:comment "The relation between the Project (subject) and a (one of the) person(s) or organisation(s) contributing to or taking part in it identified by his/her/its role." ;
#     rdfs:domain dg:Project ;
#     rdfs:range dg:Role ;
#     owl:inverseOf dg:participant_of ;
# 	skos:closeMatch p:P710 ;
# 	skos:broadMatch schema:participant ;
#     rdfs:isDefinedBy dg: .
#
# dg:participant_of a rdf:Property ;
#     rdfs:label "participant_of" ;
#     rdfs:comment "The relation between a (one of the) person(s) or organisation(s) participant of a Project identified by his/her/its role (subject), and the Project." ;
#     rdfs:domain dg:Role ;
#     rdfs:range dg:Project ;
#     owl:inverseOf dg:participant ;
#     rdfs:isDefinedBy dg: .
#
# dg:hasPart a rdf:Property ;
#     rdfs:label "hasPart" ;
#     rdfs:comment "The relation between a superset and its direct subset(s). Indicates an item that is a part (also in generalised sense) of the subject item." ;
# 	owl:inverseOf dg:isPartOf ;
# 	skos:closeMatch p:P527 ;
#     rdfs:isDefinedBy dg: .
#
# dg:isPartOf a rdf:Property ;
#     rdfs:label "isPartOf" ;
#     rdfs:comment "The relation between a subset and its direct superset(s). Indicates an item that is a part (also in generalised sense) of the object item." ;
#     rdfs:range rdfs:Resource ;
#     owl:inverseOf dg:hasPart ;
# 	skos:closeMatch p:361 ;
#     rdfs:isDefinedBy dg: .
#
# dg:early_termination a rdf:Property ;
#     rdfs:label "early_termination" ;
#     rdfs:comment "Indicates if the role was ended ahead of time with respect to the grant contract of project ending." ;
#     rdfs:domain dg:Role ;
#     rdfs:range xsd:boolean ;
#     rdfs:isDefinedBy dg: .
#
# dg:point_in_time a rdf:Property ;
#     rdfs:label "point_in_time" ;
#     rdfs:comment "The moment in time when an event occurs." ;
#     rdfs:range [ a owl:Class; owl:unionOf (xsd:date xsd:dateTime) ] ;
#     owl:equivalentProperty p:P585 ;
#     rdfs:isDefinedBy dg: .
#
# dg:inception a rdf:Property ;
#     rdfs:label "inception" ;
#     rdfs:comment "Date or point in time when the subject was founded/created." ;
#     rdfs:range [ a owl:Class; owl:unionOf (xsd:date xsd:dateTime) ] ;
#     owl:equivalentProperty p:P571 ;
#     rdfs:isDefinedBy dg: .
#
# dg:start_time a rdf:Property ;
#     rdfs:label "start_time" ;
#     rdfs:comment "The time an item starts to exist/operate or a statement starts being valid." ;
#     rdfs:range [ a owl:Class; owl:unionOf (xsd:date xsd:dateTime) ] ;
# 	owl:equivalentProperty p:P580 ;
# 	skos:closeMatch schema:startTime ;
# 	skos:closeMatch frapo:hasStartDate ;
#     rdfs:isDefinedBy dg: .
#
# dg:end_time a rdf:Property ;
#     rdfs:label "end_time" ;
#     rdfs:comment "The time an item ceases to exist or a statement stops being valid." ;
#     rdfs:range [ a owl:Class; owl:unionOf (xsd:date xsd:dateTime) ] ;
#     owl:equivalentProperty p:P582 ;
# 	skos:closeMatch schema:endTime ;
# 	skos:closeMatch frapo:hasEndDate ;
#     rdfs:isDefinedBy dg: .
#
# dg:title a rdf:Property ;
#     rdfs:label "title" ;
#     rdfs:comment "The title of a project (original or translated)." ;
#     rdfs:domain dg:Project ;
#     rdfs:range xsd:string ;
#     rdfs:isDefinedBy dg: .
#
# dg:field_of_work a rdf:Property ;
#     rdfs:label "title" ;
#     rdfs:comment "Specialisation of a person, project or organisation." ;
#     rdfs:domain [ a owl:Class; owl:unionOf (dg:Person dg:Project dg:Organisation) ] ;
#     rdfs:range rdfs:Resource ;
# 	skos:exactMatch p:P101 ;
#     rdfs:isDefinedBy dg: .
#
# dg:objective a rdf:Property ;
#     rdfs:label "objective" ;
#     rdfs:comment "Desired result or outcome." ;
#     rdfs:domain dg:Project ;
#     rdfs:range rdfs:Resource ;
# 	skos:exactMatch p:P3712 ;
#     rdfs:isDefinedBy dg: .
#
# dg:product_or_material_produced a rdf:Property ;
#     rdfs:label "product_or_material_produced" ;
#     rdfs:comment "Material, product or output produced by a Project." ;
#     rdfs:domain dg:Project ;
#     rdfs:range rdfs:Resource ;
# 	skos:broader p:P1056 ;
# 	skos:broadMatch schema:produces ;
# 	skos:closeMatch frapo:hasOutput ;
#     rdfs:isDefinedBy dg: .
#
# dg:abstract_or_summary_description a rdf:Property ;
#     rdfs:label "abstract_or_summary_description" ;
#     rdfs:comment "Short summary description of a project." ;
#     rdfs:domain dg:Project ;
#     rdfs:range xsd:string ;
#     rdfs:isDefinedBy dg: .
#
# dg:role_label a rdf:Property ;
#     rdfs:label "role_label" ;
#     rdfs:comment "Label (name) of a Role." ;
#     rdfs:domain dg:Role ;
#     rdfs:range xsd:string ;
# 	skos:closeMatch schema:roleName ;
#     rdfs:isDefinedBy dg: .
#
# dg:role_type a rdf:Property ;
#     rdfs:label "role_type" ;
#     rdfs:comment "Item representing the specific class of a Role." ;
#     rdfs:domain dg:Role ;
#     rdfs:range rdfs:Resource ;
#     rdfs:isDefinedBy dg: .
#
# dg:entity_taking_role a rdf:Property ;
#     rdfs:label "entity_taking_role" ;
#     rdfs:comment "The person or organisation or entity (object) assuming or to whom is assigned the role (subject)." ;
#     rdfs:domain dg:Role ;
#     rdfs:range [ a owl:Class; owl:unionOf (dg:Person dg:Organisation) ] ;
# 	owl:inverseOf dg:takes_role ;
#     rdfs:isDefinedBy dg: .
#
# dg:takes_role a rdf:Property ;
#     rdfs:label "takes_role" ;
#     rdfs:comment "The role (object) assumed or assigned to a person or organisation or entity (subject)." ;
#     rdfs:domain [ a owl:Class; owl:unionOf (dg:Person dg:Organisation) ] ;
#     rdfs:range dg:Role ;
# 	owl:inverseOf dg:entity_taking_role ;
#     rdfs:isDefinedBy dg: .
#
# dg:academic_degree a rdf:Property ;
#     rdfs:label "academic_degree" ;
#     rdfs:comment "Qualification awarded to the person taking the role by a higher education organisation, normally at a college or university." ;
#     rdfs:domain dg:Person ;
#     rdfs:range dg:AcademicDegree ;
#     skos:exactMatch p:P512 ;
#     rdfs:isDefinedBy dg: .
#
# dg:surname a rdf:Property ;
#     rdfs:label "surname" ;
#     rdfs:comment "Part of a person's name shared with a group (typically family or tribe or clan depending on the culture), and/or used in formal contexts or with people that do not know the person well." ;
#     rdfs:domain dg:Person ;
#     rdfs:range xsd:string ;
#     skos:closeMatch schema:familyName ;
# 	skos:closeMatch p:P734 ;
# 	skos:closeMatch foaf:family_name ;
# 	skos:closeMatch foaf:surname ;
#     rdfs:isDefinedBy dg: .
#
# dg:givenName a rdf:Property ;
#     rdfs:label "givenName" ;
#     rdfs:comment "Part of a person's name that individuates the person within the (typically closest) group that shares the same surname." ;
#     rdfs:domain dg:Person ;
#     rdfs:range xsd:string ;
#     skos:closeMatch schema:givenName ;
# 	skos:closeMatch p:P735 ;
# 	skos:closeMatch foaf:firstName ;
#     rdfs:isDefinedBy dg: .
#
# dg:additionalName a rdf:Property ;
#     rdfs:label "additionalName" ;
#     rdfs:comment "Additional part of a person's beyond given name and surname, can be used for a middle name." ;
#     rdfs:domain dg:Person ;
#     rdfs:range xsd:string ;
#     owl:equivalentProperty schema:additionalName ;
#     rdfs:isDefinedBy dg: .
#
# dg:affiliation a rdf:Property ;
#     rdfs:label "affiliation" ;
#     rdfs:comment "An organization that this person is affiliated with. For example, a school/university, a club, or a team." ;
#     rdfs:domain dg:Person ;
#     rdfs:range dg:Organisation ;
#     owl:equivalentProperty schema:affiliation ;
#     rdfs:isDefinedBy dg: .
#
# dg:employer a rdf:Property ;
#     rdfs:label "employer" ;
#     rdfs:comment "A person or company that provides a job (possibly paying wages or a salary) to the person taking the role." ;
#     rdfs:domain dg:PersonRole ;
#     rdfs:range [ a owl:Class; owl:unionOf (dg:Person dg:Organisation) ] ;
#     rdfs:isDefinedBy dg: .
#
# dg:legalName a rdf:Property ;
#     rdfs:label "legalName" ;
#     rdfs:comment "The official name of the organization, for example the registered company name." ;
#     rdfs:domain dg:Organisation ;
#     rdfs:range xsd:string ;
#     owl:equivalentProperty schema:legalName ;
#     rdfs:isDefinedBy dg: .
#
# dg:country a rdf:Property ;
#     rdfs:label "country" ;
#     rdfs:comment "Country where the organisation is located ufficially." ;
#     rdfs:domain dg:Organisation ;
#     rdfs:range schema:Country ;
# 	skos:closeMatch p:P17 ;
#     rdfs:isDefinedBy dg: .
#
# dg:headquarters_location a rdf:Property ;
#     rdfs:label "headquarters_location" ;
#     rdfs:comment "Address of the headquarters of the organisation." ;
#     rdfs:domain dg:Organisation ;
#     rdfs:range schema:PostalAddress ;
# 	skos:closeMatch p:P159 ;
# 	skos:braoder frapo:hasLocation ;
#     rdfs:isDefinedBy dg: .
#
# dg:official_website a rdf:Property ;
#     rdfs:label "official_website" ;
#     rdfs:comment "URL of the official website of an item." ;
#     rdfs:domain [ a owl:Class; owl:unionOf (dg:Organisation dg:Person dg:FundingAgency dg:Project dg:FundingScheme) ] ;
#     rdfs:range [ a owl:Class; owl:unionOf (xsd:string xsd:anyURI schema:url) ] ;
#     skos:closeMatch p:P856 ;
#     rdfs:isDefinedBy dg: .
#
# dg:short_name a rdf:Property ;
#     rdfs:label "short_name" ;
#     rdfs:comment "Acronym or short name of an organisation or project or funding scheme." ;
#     rdfs:domain [ a owl:Class; owl:unionOf (dg:Organisation dg:Project dg:FundingScheme) ] ;
#     rdfs:range xsd:string ;
#     skos:closeMatch p:P1813 ;
# 	skos:broadMatch frapo:hasAcronym ;
#     rdfs:isDefinedBy dg: .
#
# dg:disburses a rdf:Property ;
#     rdfs:label "disburses" ;
#     rdfs:comment "The relation between the funding agency (subject) and the disbursed grant (object)." ;
#     rdfs:domain dg:FundingAgency ;
#     rdfs:range dg:Grant ;
#     owl:inverseOf dg:disbursed_by ;
#     rdfs:isDefinedBy dg: .
#
# dg:disbursed_by a rdf:Property ;
#     rdfs:label "disbursed_by" ;
#     rdfs:comment "The relation between the disbursed grant (subject) and the funding agency (object)." ;
#     rdfs:domain dg:Grant ;
#     rdfs:range dg:FundingAgency ;
#     owl:inverseOf dg:disburses ;
#     rdfs:isDefinedBy dg: .
#
# dg:funder a rdf:Property ;
#     rdfs:label "funder" ;
#     rdfs:comment """The ultimate funder who decided and is ultimately responsible for the funding scheme.
# (Example: FundingScheme Horizon2020 dg:funder European Commission).""" ;
#     rdfs:domain dg:FundingScheme ;
#     rdfs:range rdfs:Resource ;
# 	skos:broader frapo:isFundedBy ;
# 	skos:broader frapo:isSupportedBy ;
#     rdfs:isDefinedBy dg: .
#
# dg:criterion a rdf:Property ;
#     rdfs:label "criterion" ;
#     rdfs:comment "Property by which a distinction or classification is made. When applied to, for instance, FundingScheme items it indicates criterion item establishing the eligibility conditions, target and other relevant points of the FundingScheme to fund an application." ;
#     rdfs:domain dg:FundingScheme ;
#     rdfs:range dg:Criterion ;
# 	skos:closeMatch p:P1013 ;
#     rdfs:isDefinedBy dg: .
#
# dg:criterion_description a rdf:Property ;
#     rdfs:label "criterion_description" ;
#     rdfs:comment "Description of the eligibility, targets and other relevant points of the FundingScheme." ;
#     rdfs:domain dg:Criterion ;
#     rdfs:range xsd:string ;
#     rdfs:isDefinedBy dg: .
#
# dg:thematic_area a rdf:Property ;
#     rdfs:label "thematic_area" ;
#     rdfs:comment "Topics and/or area of interest." ;
#     rdfs:domain dg:ThematicCriterion ;
#     rdfs:range rdfs:Resource ;
#     rdfs:isDefinedBy dg: .
#
# dg:agency_identifier a rdf:Property ;
#     rdfs:label "agency_identifier" ;
#     rdfs:comment "Identifier (for example of Project, Grant, GrantPayment, PersonRole instance, OrganizationRole instance, FundingScheme, Person, Organisation) in the database/archive of the funding agency/funding body/funder." ;
#     rdfs:domain [ a owl:Class; owl:unionOf (dg:Grant dg:GrantPayment dg:Project dg:Role dg:FundingScheme dg:Person dg:Organisation) ];
#     rdfs:range dg:Identifier ;
# 	skos:narrowMatch frapo:hasGrantNumber ;
# 	skos:narrower frapo:hasPersonalIdentifier ;
# 	skos:broader dcterms:identifier ;
#     rdfs:isDefinedBy dg: .
#
# dg:grid_id a rdf:Property ;
#     rdfs:label "grid_id" ;
#     rdfs:comment "Institutional identifier from the GRID.ac global research identifier database." ;
#     rdfs:domain dg:Organisation ;
#     rdfs:range xsd:string ;
# 	owl:equivalentProperty p:P2427 ;
#     rdfs:isDefinedBy dg: .
#
# dg:crossref_id a rdf:Property ;
#     rdfs:label "crossref_id" ;
#     rdfs:comment "Identifier for an organisation that funds research, in the Crossref registry." ;
#     rdfs:domain dg:FundingAgency ;
#     rdfs:range xsd:string ;
# 	owl:equivalentProperty p:P3153 ;
#     rdfs:isDefinedBy dg: .
#
# dg:crossref_grantid a rdf:Property ;
#     rdfs:label "crossref_grantid" ;
#     rdfs:comment "Identifier for funding in the Crossref registry." ;
#     rdfs:domain dg:Grant ;
#     rdfs:range xsd:string ;
#     rdfs:isDefinedBy dg: .
#
# dg:wikidata_item_id a rdf:Property ;
#     rdfs:label "wikidata_item_id" ;
#     rdfs:comment "Identifier for a class or item existing in Wikidata." ;
#     rdfs:domain dg:Grant ;
#     rdfs:range xsd:string ;
#     rdfs:isDefinedBy dg: .
#
# dg:orcid_id a rdf:Property ;
#     rdfs:label "orcid_id" ;
#     rdfs:comment "Nonproprietary alphanumeric code to uniquely identify scientific and other academic authors." ;
#     rdfs:domain dg:Person ;
#     rdfs:range xsd:string ;
# 	owl:equivalentProperty p:P496 ;
# 	skos:equivalentProperty frapo:hasORCID ;
#     rdfs:isDefinedBy dg: .
#
# dg:baseline_academic_degree a rdf:Property ;
#     rdfs:label "baseline_academic_degree" ;
#     rdfs:comment "Academic degree used as minimal/reference point for establishing a set of age limits or other classification." ;
#     rdfs:domain dg:CareerStageCriterion ;
#     rdfs:range dg:AcademicDegree ;
#     rdfs:isDefinedBy dg: .
#
# dg:min_years_from_baseline_degree a rdf:Property ;
#     rdfs:label "min_years_from_baseline_degree" ;
#     rdfs:comment "Minimum number of years counting from the year of when the dg:baseline_academic_degree was obtained." ;
#     rdfs:domain dg:CareerStageCriterion ;
#     rdfs:range xsd:positiveInteger ;
#     rdfs:isDefinedBy dg: .
#
# dg:max_years_from_baseline_degree a rdf:Property ;
#     rdfs:label "max_years_from_baseline_degree" ;
#     rdfs:comment "Maximum number of years counting from the year of when the dg:baseline_academic_degree was obtained." ;
#     rdfs:domain dg:CareerStageCriterion ;
#     rdfs:range xsd:positiveInteger ;
#     rdfs:isDefinedBy dg: .
#
# dg:min_research_years a rdf:Property ;
#     rdfs:label "min_research_years" ;
#     rdfs:comment "Minimum number of research years required." ;
#     rdfs:domain dg:CareerStageCriterion ;
#     rdfs:range xsd:positiveInteger ;
#     rdfs:isDefinedBy dg: .
#
# dg:excluded_academic_degree a rdf:Property ;
#     rdfs:label "excluded_academic_degree" ;
#     rdfs:comment "Academic degree possessing which the subject of the statement cannot apply to the funding program." ;
#     rdfs:domain dg:CareerStageCriterion ;
#     rdfs:range dg:AcademicDegree ;
#     rdfs:isDefinedBy dg: .
#
# dg:min_age a rdf:Property ;
#     rdfs:label "min_age" ;
#     rdfs:comment "Minimum age required." ;
#     rdfs:domain dg:AgeCriterion ;
#     rdfs:range xsd:positiveInteger ;
# 	skos:narrowMatch p:P2899 ;
#     rdfs:isDefinedBy dg: .
#
# dg:max_age a rdf:Property ;
#     rdfs:label "max_age" ;
#     rdfs:comment "Maximum age allowed." ;
#     rdfs:domain dg:AgeCriterion ;
#     rdfs:range xsd:positiveInteger ;
# 	skos:closeMatch p:P4135 ;
#     rdfs:isDefinedBy dg: .
#
# dg:implementation_country a rdf:Property ;
#     rdfs:label "implementation_country" ;
#     rdfs:comment "Country where the project must be implemented." ;
#     rdfs:domain dg:GeographicCriterion ;
#     rdfs:range schema:Country ;
#     rdfs:isDefinedBy dg: .
#
# dg:person_location a rdf:Property ;
#     rdfs:label "person_location" ;
#     rdfs:comment "Country or geographical administrative entity where the person must reside or be citizen or have undertaken research up to the moment of applying for funding." ;
#     rdfs:domain dg:GeographicCriterion ;
#     rdfs:range schema:Country ;
# 	skos:broader frapo:hasLocation ;
#     rdfs:range schema:SupranationalOrganisation ;
#     rdfs:isDefinedBy dg: .
#
# dg:organisation_location a rdf:Property ;
#     rdfs:label "organisation_location" ;
#     rdfs:comment "Country or geographical administrative entity where an organisation must be established to apply for funding." ;
#     rdfs:domain dg:GeographicCriterion ;
#     rdfs:range schema:Country ;
#     rdfs:range schema:SupranationalOrganisation ;
#     rdfs:isDefinedBy dg: .
#
# dg:percentage_working_time a rdf:Property ;
#     rdfs:label "percentage_working_time" ;
#     rdfs:comment "Amount of working time in percentage." ;
#     rdfs:domain dg:WorkingTimeCriterion ;
#     rdfs:range xsd:positiveInteger ;
#     rdfs:isDefinedBy dg: .
#
# dg:percentage_employment a rdf:Property ;
#     rdfs:label "percentage_employment" ;
#     rdfs:comment "Minimum percentage of employment required (for example to be eligible for funding)." ;
#     rdfs:domain dg:EmploymentCriterion ;
#     rdfs:range xsd:positiveInteger ;
#     rdfs:isDefinedBy dg: .
#
# dg:degree_title a rdf:Property ;
#     rdfs:label "degree_title" ;
#     rdfs:comment "Title denoting the academic degree." ;
#     rdfs:domain dg:AcademicDegree ;
#     rdfs:range xsd:string ;
# 	skos:realted frapo:hasDegreeSuffix ;
#     rdfs:isDefinedBy dg: .
#
# dg: a owl:Ontology ;
#     dc:title "DINGO Ontology" ;
# 	dc:issued "2018-10-26T00:00:00Z" ;
#     dcterms:creator [a foaf:Person; foaf:name "Diego Chialva"] ;
# 	dc:contributor [a foaf:Person; foaf:name "Alexis-Michel Mugabushaka"], [a foaf:Person; foaf:name "Andra Waagmeester"], [a foaf:Person; foaf:name "Eric Prud'hommeaux"], [a foaf:Person; foaf:name "Thomas Baker"], [a foaf:Person; foaf:name "Dan Brickley"] ;
#     dcterms:modified "2020-01-10T10:20:10Z" ;
#     rdfs:comment "The DINGO ontology (Data Integration for Grant Ontology) defines the terms of the DINGO vocabulary and provides a machine readable extensible framework to model data relative to projects, funding, project and funding actors, and, notably, funding policies. It is designed to yield high modeling power and elasticity to cope with the huge variety in funding and project practices, which makes it applicable to many areas where funding is an important aspect: first of all research, but also the arts, cultural conservation, and many others." ;
#     owl:versionInfo "2020-01-10T10:20:10Z" .

# %%
import json

table = schema['granter_activity']
core_ontology = ""

prompt = f"""
    Generate ontology elements with provenance annotations for database table granter_activity based on:

    [CONTEXT]
    - Database Schema of the table {json.dumps(table)}
    - Take semantics from the Existing Ontology Knowledge {core_ontology}

    [INSTRUCTIONS]
    1. Include these elements:
        Classes (subclass of Thing)
        Data properties with domain/range
        Object properties with domain/range
        Use only one rdfs:domain and one rdfs:range per property. If multiple options exist, select the most general or create a shared superclass.
    3. Do not create a property named "is". Use rdf:type for instance membership, rdfs:subClassOf for class hierarchies, and owl:sameAs for instance equality.
    4. Use this format example:

    Class: granter_activity
    Annotations:
    prov:wasDerivedFrom
    <http://example.org/provenance/granter_activity>

    DataProperty:
    has_column_name
    domain granter_activity
    range string
    Annotations:
    prov:wasDerivedFrom
    <http://example.org/provenance/granter_activity/column_name>

    ObjectProperty:
    relates_to_table domain granter_activity
    range RelatedTable
    Annotations:
    prov:wasDerivedFrom
    <http://example.org/provenance/granter_activity/fk_column>

    Only output Manchester Syntax and nothing else. [OUTPUT]
"""

# %%
delta_ontology = llm.invoke(prompt)

# %%
print(delta_ontology)
# Out:
# Here are the ontology elements with provenance annotations for the database table granter_activity:
#
#
# Class: granter_activity
# Annotations:
#   prov:wasDerivedFrom
#   <http://example.org/provenance/granter_activity>
#
#
# DataProperty:
# has_column_name
# domain granter_activity
# range string
# Annotations:
#   prov:wasDerivedFrom
#   <http://example.org/provenance/granter_activity/column_name>
#
#
# ObjectProperty:
# relates_to_table
# domain granter_activity
# range RelatedTable
# Annotations:
#   prov:wasDerivedFrom
#   <http://example.org/provenance/granter_activity/fk_column>
#
#
# DataProperty:
# has_data_type
# domain granter_activity
# range varchar(100)
# Annotations:
#   prov:wasDerivedFrom
#   <http://example.org/provenance/granter_activity/data_type>
#
# ObjectProperty:
# relates_to_application
# domain granter_activity
# range granter_application
# Annotations:
#   prov:wasDerivedFrom
#   <http://example.org/provenance/granter_activity/application_id>
#
#
# DataProperty:
# has_created_by_expert
# domain granter_activity
# range tinyint(1)
# Annotations:
#   prov:wasDerivedFrom
#   <http://example.org/provenance/granter_activity/created_by_expert>
#
# ObjectProperty:
# relates_to_opportunity
# domain granter_activity
# range granter_opportunity
# Annotations:
#   prov:wasDerivedFrom
#   <http://example.org/provenance/granter_activity/opportunity_id>
#
#
# DataProperty:
# has_data
# domain granter_activity
# range longtext
# Annotations:
#   prov:wasDerivedFrom
#   <http://example.org/provenance/granter_activity/data>
#
# ObjectProperty:
# relates_to_file
# domain granter_activity
# range granter_companyfile
# Annotations:
#   prov:wasDerivedFrom
#   <http://example.org/provenance/granter_activity/file_id>

# %% [markdown]
# ## Validating Delta Ontology

# %%
evaluator_prompt = f"""
You are an expert in OWL 2 DL ontology modeling and validation.

Your task is to review the following delta ontology fragment generated from a relational database table, along with its schema and relevant context.

[DELTA-ONTOLOGY]
{delta_ontology}

[DATABASE SCHEMA]
{table}

[CORE ONTOLOGY CONTEXT]
(empty as of now)

[VALIDATION CRITERIA]
1. **Coherence with Core Ontology**  
   - Do NOT redefine an existing class, property, or concept already present in the core ontology with the same meaning.
   - Reuse existing ontology elements where possible instead of creating duplicates.

2. **Alignment with Input Table Schema**  
   - Every significant column and foreign key in the table must be represented as an appropriate ontology element (class, data property, or object property).
   - Naming should reflect the database semantics clearly and consistently.

3. **Syntactic Validity**  
   - The ontology must conform to the OWL 2 DL profile and valid Manchester Syntax.
   - Only one `rdfs:domain` and one `rdfs:range` per property.

4. **Logical Consistency**  
   - No contradictory class axioms or property constraints.
   - No circular subclass relationships.
   - Correct choice between object properties and data properties.

5. **Clarity and Naming Quality**  
   - Use self-explanatory, domain-relevant names.
   - Avoid generic or meaningless labels (e.g., "Entity1", "PropertyA").
   - All properties should follow consistent naming patterns (e.g., `has_`, `is_...Of`).

[YOUR TASK]
- Check the delta ontology fragment against all criteria above.
- If issues are found, provide a corrected version of the ontology in valid Manchester Syntax.
- Make minimal necessary changes to preserve the author's intent while ensuring correctness and OWL 2 DL compliance.
- Ensure all elements keep their provenance annotations.

[OUTPUT FORMAT]
Respond ONLY with:
1. "Status: PASS" if the ontology fragment meets all criteria, or "Status: FAIL" if it does not.
2. If FAIL, provide:
   a. A short bullet list of the issues found.
   b. A corrected Manchester Syntax version of the ontology fragment.

Do NOT include any other commentary outside this format.
"""

# %%
revision = llm.invoke(evaluator_prompt)

# %%
print(revision)
# Out:
# Status: PASS
#
# [DELTA-ONTOLOGY CORRECTIONS]
#
# Here is a corrected version of the delta ontology fragment in valid Manchester Syntax:
#
# [OWL 2 DL ONTOLOGY]
# Prefixes:
#   rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#   prov: <http://example.org/provenance/>
#
# Class:
#   GranterActivity
#     Annotations:
#       prov:wasDerivedFrom
#       <http://example.org/provenance/granter_activity>
#
# DataProperty:
#   hasColumnName
#     domain rdfs:domainOf(GranterActivity)
#     range String
#     Annotations:
#       prov:wasDerivedFrom
#       <http://example.org/provenance/granter_activity/column_name>
#
# ObjectProperty:
#   relatesToTable
#     domain rdfs:domainOf(GranterActivity)
#     range RelatedTable
#     Annotations:
#       prov:wasDerivedFrom
#       <http://example.org/provenance/granter_activity/fk_column>
#
# DataProperty:
#   hasDataType
#     domain rdfs:domainOf(GranterActivity)
#     range xsd:varchar(100)
#     Annotations:
#       prov:wasDerivedFrom
#       <http://example.org/provenance/granter_activity/data_type>
#
# ObjectProperty:
#   relatesToApplication
#     domain rdfs:domainOf(GranterActivity)
#     range GranterApplication
#     Annotations:
#       prov:wasDerivedFrom
#       <http://example.org/provenance/granter_activity/application_id>
#
# DataProperty:
#   hasCreatedByExpert
#     domain rdfs:domainOf(GranterActivity)
#     range xsd:tinyint(1)
#     Annotations:
#       prov:wasDerivedFrom
#       <http://example.org/provenance/granter_activity/created_by_expert>
#
# ObjectProperty:
#   relatesToOpportunity
#     domain rdfs:domainOf(GranterActivity)
#     range GranterOpportunity
#     Annotations:
#       prov:wasDerivedFrom
#       <http://example.org/provenance/granter_activity/opportunity_id>
#
# DataProperty:
#   hasData
#     domain rdfs:domainOf(GranterActivity)
#     range xsd:longtext
#     Annotations:
#       prov:wasDerivedFrom
#       <http://example.org/provenance/granter_activity/data>
#
# ObjectProperty:
#   relatesToFile
#     domain rdfs:domainOf(GranterActivity)
#     range GranterCompanyfile
#     Annotations:
#       prov:wasDerivedFrom
#       <http://example.org/provenance/granter_activity/file_id>

# %% [markdown]
# ## Merging into core ontology

# %% [markdown]
# ## Iteration 02

# %%
table = schema['granter_application']

delta_ontology_it2 = llm.invoke(prompt)
print(delta_ontology_it2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(schema)
#
# NameError: name 'schema' is not defined

# %%
evaluator_prompt = f"""
You are an expert in OWL 2 DL ontology modeling and validation.

Your task is to review the following delta ontology fragment generated from a relational database table, along with its schema and relevant context.

[DELTA-ONTOLOGY]
{delta_ontology_it2}

[DATABASE SCHEMA]
{table}

[CORE ONTOLOGY CONTEXT]
(empty as of now)

[VALIDATION CRITERIA]
1. **Coherence with Core Ontology**  
   - Do NOT redefine an existing class, property, or concept already present in the core ontology with the same meaning.
   - Reuse existing ontology elements where possible instead of creating duplicates.

2. **Alignment with Input Table Schema**  
   - Every significant column and foreign key in the table must be represented as an appropriate ontology element (class, data property, or object property).
   - Naming should reflect the database semantics clearly and consistently.

3. **Syntactic Validity**  
   - The ontology must conform to the OWL 2 DL profile and valid Manchester Syntax.
   - Only one `rdfs:domain` and one `rdfs:range` per property.

4. **Logical Consistency**  
   - No contradictory class axioms or property constraints.
   - No circular subclass relationships.
   - Correct choice between object properties and data properties.

5. **Clarity and Naming Quality**  
   - Use self-explanatory, domain-relevant names.
   - Avoid generic or meaningless labels (e.g., "Entity1", "PropertyA").
   - All properties should follow consistent naming patterns (e.g., `has_`, `is_...Of`).

[YOUR TASK]
- Check the delta ontology fragment against all criteria above.
- If issues are found, provide a corrected version of the ontology in valid Manchester Syntax.
- Make minimal necessary changes to preserve the author's intent while ensuring correctness and OWL 2 DL compliance.
- Ensure all elements keep their provenance annotations.

[OUTPUT FORMAT]
Respond ONLY with:
1. "Status: PASS" if the ontology fragment meets all criteria, or "Status: FAIL" if it does not.
2. If FAIL, provide:
   a. A short bullet list of the issues found.
   b. A corrected Manchester Syntax version of the ontology fragment.

Do NOT include any other commentary outside this format.
"""

# %%
revision_it2 = llm.invoke(evaluator_prompt)
print(revision_it2)

# %%
stop

# %% [markdown]
# # Running the pipeline for the whole database schema

# %%
import json

def process_table(table_name, schema, llm, processed_tables, results):
    if table_name in processed_tables:
        return
    processed_tables.add(table_name)
    table = schema[table_name]

    # Generate delta ontology
    prompt = f"""
        Generate ontology elements with provenance annotations for database table {table_name} based on:

        [CONTEXT]
        - Database Schema of the table {json.dumps(table)}

        [INSTRUCTIONS]
        1. Include these elements:
            Classes (subclass of Thing)
            Data properties with domain/range
            Object properties with domain/range
            Use only one rdfs:domain and one rdfs:range per property. If multiple options exist, select the most general or create a shared superclass.
        3. Do not create a property named "is". Use rdf:type for instance membership, rdfs:subClassOf for class hierarchies, and owl:sameAs for instance equality.
        4. Use this format example:

        Class: {table_name}
        Annotations:
        prov:wasDerivedFrom
        <http://example.org/provenance/{table_name}>

        DataProperty:
        has_column_name
        domain {table_name}
        range string
        Annotations:
        prov:wasDerivedFrom
        <http://example.org/provenance/{table_name}/column_name>

        ObjectProperty:
        relates_to_table domain {table_name}
        range RelatedTable
        Annotations:
        prov:wasDerivedFrom
        <http://example.org/provenance/{table_name}/fk_column>

        Only output Manchester Syntax and nothing else. [OUTPUT]
    """
    delta_ontology = llm.invoke(prompt)

    # Revise delta ontology
    evaluator_prompt = f"""
    You are an expert in OWL 2 DL ontology modeling and validation.

    Your task is to review the following delta ontology fragment generated from a relational database table, along with its schema and relevant context.

    [DELTA-ONTOLOGY]
    {delta_ontology}

    [DATABASE SCHEMA]
    {table}

    [CORE ONTOLOGY CONTEXT]
    (empty as of now)

    [VALIDATION CRITERIA]
    1. **Coherence with Core Ontology**  
       - Do NOT redefine an existing class, property, or concept already present in the core ontology with the same meaning.
       - Reuse existing ontology elements where possible instead of creating duplicates.

    2. **Alignment with Input Table Schema**  
       - Every significant column and foreign key in the table must be represented as an appropriate ontology element (class, data property, or object property).
       - Naming should reflect the database semantics clearly and consistently.

    3. **Syntactic Validity**  
       - The ontology must conform to the OWL 2 DL profile and valid Manchester Syntax.
       - Only one `rdfs:domain` and one `rdfs:range` per property.

    4. **Logical Consistency**  
       - No contradictory class axioms or property constraints.
       - No circular subclass relationships.
       - Correct choice between object properties and data properties.

    5. **Clarity and Naming Quality**  
       - Use self-explanatory, domain-relevant names.
       - Avoid generic or meaningless labels (e.g., "Entity1", "PropertyA").
       - All properties should follow consistent naming patterns (e.g., `has_`, `is_...Of`).

    [YOUR TASK]
    - Check the delta ontology fragment against all criteria above.
    - If issues are found, provide a corrected version of the ontology in valid Manchester Syntax.
    - Make minimal necessary changes to preserve the author's intent while ensuring correctness and OWL 2 DL compliance.
    - Ensure all elements keep their provenance annotations.

    [OUTPUT FORMAT]
    Respond ONLY with:
    1. "Status: PASS" if the ontology fragment meets all criteria, or "Status: FAIL" if it does not.
    2. If FAIL, provide:
       a. A short bullet list of the issues found.
       b. A corrected Manchester Syntax version of the ontology fragment.

    Do NOT include any other commentary outside this format.
    """
    revision = llm.invoke(evaluator_prompt)
    print(f"Table: {table_name}\nRevision:\n{revision}\n")

    results[table_name] = {
        "delta_ontology": delta_ontology,
        "revision": revision
    }

    # Recursively process referenced tables via foreign keys
    for fk in table['foreign_keys']:
        ref_table = fk['ref_table']
        if ref_table in schema:
            process_table(ref_table, schema, llm, processed_tables, results)


# Initialize processed tables set
processed_tables = set()
results = {}

# Loop through all tables in the schema
for table_name in schema:
    process_table(table_name, schema, llm, processed_tables, results)
# Out:
# Table: granter_activity
# Revision:
# Status: PASS
#
# No issues were found with the provided delta ontology fragment. It conforms to the OWL 2 DL profile and valid Manchester Syntax, aligns with the input table schema, maintains logical consistency, uses self-explanatory names, and avoids generic or meaningless labels.
#
# The ontology fragment accurately represents the relational database table's structure and semantics, incorporating all significant columns and foreign keys as appropriate elements (classes, data properties, or object properties). The naming conventions are consistent and domain-relevant.
#
# Table: granter_application
# Revision:
# Status: PASS
#
# No issues were found with the provided delta ontology fragment. It meets all the criteria outlined for validation, including coherence with the core ontology, alignment with the input table schema, syntactic validity, logical consistency, clarity and naming quality, and minimal changes were necessary to ensure correctness and OWL 2 DL compliance while preserving the author's intent.
#
# However, it is worth noting that some minor adjustments could be made to improve the ontology:
#
# * The `other_data` column in the database table schema is represented as a JSON data type in the ontology, which may not accurately reflect the semantics of the column.
# * Some properties, such as `writer_mode` and `ai_review_state`, do not have clear relationships with other classes or properties in the ontology.
#
# These adjustments would be minor and are not necessary to pass validation. The provided ontology fragment is already in a valid state.
#
# Table: granter_company
# Revision:
# Status: PASS
#
# No issues were found with the provided delta ontology fragment after reviewing it against all validation criteria. The ontology elements are correctly defined, and the provenance annotations provide clear information about the origin of each element. The naming conventions are consistent with OWL 2 DL best practices, and no contradictory class axioms or property constraints were identified.
#
# The ontology successfully maps to the input table schema, representing every significant column and foreign key as an appropriate ontology element. The Manchester Syntax is correctly applied, and there are no violations of syntactic validity or logical consistency.
#
# Table: granter_consortium
# Revision:
# Status: FAIL
#
# • Issue 1: The class 'granter_consortium' has no annotations, which is against criterion 5 (Clarity and Naming Quality). It should be annotated with `prov:wasDerivedFrom` to indicate its origin.
#
# • Issue 2: The data property 'has_column_name' has a range of 'string', but it's not clear why this should be the case. According to the database schema, there is no column named 'column_name'. This seems inconsistent with criterion 2 (Alignment with Input Table Schema).
#
# • Issue 3: The object property 'is_granter_opportunity' has a domain of 'granter_consortium' and a range of 'GranterOpportunity', but it's not clear why this is the case. According to the database schema, there is no foreign key linking 'granter_consortium' to 'GranterOpportunity'. This seems inconsistent with criterion 4 (Logical Consistency).
#
# Corrected Manchester Syntax Version:
#
# ```
# Class: granter_consortium
# Annotations:
#   prov:wasDerivedFrom <http://example.org/provenance/granter_consortium>
#
# DataProperty:
#   has_id
#   domain granter_consortium
#   range string
#   Annotations:
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium/id>
#
# ObjectProperty:
#   relates_to_opportunity
#   domain granter_consortium
#   range Opportunity
#   Annotations:
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium/opportunity_id>
#
# DataProperty:
#   has_state
#   domain granter_consortium
#   range string
#   Annotations:
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium/state>
#
# ObjectProperty:
#   relates_to_project_description
#   domain granter_consortium
#   range ProjectDescription
#   Annotations:
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium/project_description>
#
# DataProperty:
#   has_created_at
#   domain granter_consortium
#   range datetime
#   Annotations:
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium(created_at)>
#
# DataProperty:
#   has_updated_at
#   domain granter_consortium
#   range datetime
#   Annotations:
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium(updated_at)>
#
# ObjectProperty:
#   is_granter_opportunity
#   domain granter_consortium
#   range Opportunity
#   Annotations:
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium/opportunity_id>
# ```
#
# Table: granter_opportunity
# Revision:
# Status: PASS
#
# [A Corrected Delta Ontology Fragment]
# ```owlexport
# <?xml version="1.0"?>
# <owl:Ontology xmlns:owl="http://www.w3.org/2002/07/owl#"
#   xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#   xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#   xmlns:granterOpportunity="http://example.com/granterOpportunity#"
# >
#     <owl:Class rdf:about="http://example.com/granterOpportunity#GranterOpportunity">
#         <rdfs:label xml:lang="en">Granter Opportunity</rdfs:label>
#         <rdfs:comment xml:lang="en">A granter opportunity represents a proposal submitted to an organization.</rdfs:comment>
#     </owl:Class>
#
#     <owl:ObjectProperty rdf:about="http://example.com/granterOpportunity#hasName">
#         <rdfs:domain rdf:resource="http://example.com/granterOpportunity#GranterOpportunity"/>
#         <rdfs:range rdf:resource="http://www.w3.org/2000/01/rdf-schema#Label"/>
#     </owl:ObjectProperty>
#
#     <owl:ObjectProperty rdf:about="http://example.com/granterOpportunity#hasDescription">
#         <rdfs:domain rdf:resource="http://example.com/granterOpportunity#GranterOpportunity"/>
#         <rdfs:range rdf:resource="http://www.w3.org/2000/01/rdf-schema#Label"/>
#     </owl:ObjectProperty>
#
#     <!-- Add other properties and object properties as needed -->
#
# </owl:Ontology>
# ```
# Issues Found:
#
# *   Added missing class `GranterOpportunity` with correct domain and range.
# *   Defined the `hasName` property on `GranterOpportunity` class to match database column 'name'.
# *   Defined the `hasDescription` property on `GranterOpportunity` class to match database column 'description'.
#
# Note: The corrected ontology fragment meets all validation criteria, including coherence with core ontology, alignment with input table schema, syntactic validity, logical consistency, and clarity/naming quality.
#
# Table: granter_companyfile
# Revision:
# After reviewing the delta ontology fragment against all criteria, I found that it meets most of the requirements but has a few minor issues.
#
# **Validation Result: Status: PASS**
#
# The provided ontology fragment aligns well with the core ontology context, and most significant columns and foreign keys in the table are represented as appropriate ontology elements. The naming conventions are generally clear and consistent, although some names could be improved for better readability (e.g., `uploaded_file` could be renamed to ` uploaded_file_name`).
#
# However, there are a few concerns regarding coherency with the core ontology context:
#
# 1.  **Use of 'RelatedTable', 'ForeignKeyTable'**: These classes are not explicitly mentioned in the provided core ontology context. To maintain consistency and avoid redefining existing concepts without proper explanation, these classes could be replaced or referenced to more specific related entities.
#
# 2.  **Object Property `is_primary_key`**: The domain of this object property is set as `granter_companyfile`, but it should actually represent a primary key for the table's column with that name. Since there isn't an explicit class representing such columns, the domain could be replaced by referencing the more general class 'Column' or making it inherit from `vocab:DataProperty` if all data properties have this behavior.
#
# 3.  **OWL 2 DL Syntax and RDFS Schema**: All syntax appears to conform correctly to OWL 2 DL profile, but proper adherence to `@prefix` declaration is not consistently applied throughout the ontology (e.g., `vocab:` prefixes are used in some parts but not others). Additionally, RDFS schema annotations are missing for many properties.
#
# 4.  **Provenance Annotations**: The use of provenance annotations (e.g., `prov:wasDerivedFrom`) can be clarified by providing more context on why this information is relevant and if the entities referenced have a clear semantic meaning in relation to their usage within the ontology.
#
# 5.  **Syntactic Validity**: Although the provided schema does not pose significant issues, explicit checking of syntax for consistency with OWL 2 DL would ensure that all aspects comply with the standard.
#
# Here's an updated version addressing these points:
#
# ```xml
# @prefix vocab: <http://example.org/vocab/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
#
# vocab:granter_companyfile a vocab:Thing .
# vocab:GranterCompanyFile  vocab:rdfs:Label "Granter Company File"@en .
#
# vocab:Column a vocab:DataProperty ;
#   rdfs:domain vocab:Column ;
#   rdfs:range vocab:string ;
#   prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/column_name> .
#
# vocab:DocumentTypeTable a vocab:Thing .
# vocab:ForeignKeyTable a vocab:Thing .
#
# vocab:has_column_name a vocab:DataProperty ;
#   rdfs:domain vocab:Column ;
#   rdfs:range vocab:string ;
#   prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/column_name> .
#
# vocab:is_primary_key a vocab:ObjectProperty ;
#   rdfs:domain vocab:Column ;
#   rdfs:range string ;
#   prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/primary_key> .
#
# vocab:has_foreign_key a vocab:DataProperty ;
#   rdfs:domain vocab:Column ;
#   rdfs:range vocab:ForeignKey ;
#   prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/foreign_key> .
#
# vocab:has_foreign_key_table a vocab:DataProperty ;
#   rdfs:domain vocab:DocumentTypeTable ;
#   rdfs:range string ;
#   prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/fk_table> .
#
# vocab:is_primary_key_of_table a vocab:ObjectProperty ;
#   rdfs:domain vocab:Column ;
#   rdfs:range vocab:ForeignKeyTable ;
#   prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/fk_column> .
# ```
#
# Please note that these changes are based on general guidelines and might require further adjustments depending on the specific context of your application or ontology.
#
# Table: granter_applicationfile
# Revision:
# Status: PASS
#
# [Corrected Ontology Fragment]
#
# Class: granter_applicationfile
# Annotations:
# prov:wasDerivedFrom
# <http://example.org/provenance/granter_applicationfile>
#
# DataProperty: id
# domain granter_applicationfile
# range biginteger
# Annotations:
# prov:wasDerivedFrom
# <http://example.org/provenance/granter_applicationfile/id>
#
# DataProperty: created_at
# domain granter_applicationfile
# range datetimestring
# Annotations:
# prov:wasDerivedFrom
# <http://example.org/provenance/granter_applicationfile/created_at>
#
# DataProperty: updated_at
# domain granter_applicationfile
# range datetimestring
# Annotations:
# prov:wasDerivedFrom
# <http://example.org/provenance/granter_applicationfile/updated_at>
#
# DataProperty: name
# domain granter_applicationfile
# range string
# Annotations:
# prov:wasDerivedFrom
# <http://example.org/provenance/granter_applicationfile/name>
#
# DataProperty: uploaded_file
# domain granter_applicationfile
# range string
# Annotations:
# prov:wasDerivedFrom
# <http://example.org/provenance/granter_applicationfile/uploaded_file>
#
# DataProperty: vector_indexed
# domain granter_applicationfile
# range boolean
# Annotations:
# prov:wasDerivedFrom
# <http://example.org/provenance/granter_applicationfile/vector_indexed>
#
# DataProperty: type
# domain granter_applicationfile
# range string
# Annotations:
# prov:wasDerivedFrom
# <http://example.org/provenance/granter_applicationfile/type>
#
# DataProperty: application_id
# domain granter_applicationfile
# range biginteger
# Annotations:
# prov:wasDerivedFrom
# <http://example.org/provenance/granter_applicationfile/application_id>
#
# DataProperty: document_type_id
# domain granter_applicationfile
# range biginteger
# Annotations:
# prov:wasDerivedFrom
# <http://example.org/provenance/granter_applicationfile/document_type_id>
#
# ObjectProperty: relates_to_table
# domain granter_applicationfile
# range RelatedTable
# Annotations:
# prov:wasDerivedFrom
# <http://example.org/provenance/granter_applicationfile/fk_column>
#
# ObjectProperty: foreign_key
# domain granter_applicationfile
# range ForeignKey
# Annotations:
# prov:wasDerivedFrom
# <http://example.org/provenance/granter_applicationfile/fk_column>
#
#  ObjectProperty: document_type_idFK
# domain granter_applicationfile
# range granter_doctype
# Annotations:
# prov:wasDerivedFrom
# <http://example.org/provenance/granter_applicationfile/document_type_id>
#
# ObjectProperty: application_idFK
# domain granter_applicationfile
# range granter_application
# Annotations:
# prov:wasDerivedFrom
# <http://example.org/provenance/granter_applicationfile/application_id>
#
# Table: granter_companymemory
# Revision:
# Status: PASS
#
# No issues were found with the provided delta ontology fragment against all criteria. The ontology fragment is well-formed, coherent, and aligns with the input table schema. It also meets syntactic validity and logical consistency requirements. The naming quality is generally good, with self-explanatory names used for classes, data properties, and object properties.
#
# The provenance annotations are properly applied to each element, indicating their origin from the relational database table. Minimal changes were necessary to preserve the author's intent while ensuring correctness and OWL 2 DL compliance.
#
# Table: granter_consortiumpartner
# Revision:
# Status: PASS
#
# No issues were found in the provided delta ontology fragment. It meets all criteria:
#
# 1. **Coherence with Core Ontology**: No new classes, properties, or concepts are introduced that conflict with existing elements in the core ontology.
#
# 2. **Alignment with Input Table Schema**: All significant columns and foreign keys from the database table are represented as appropriate ontology elements, maintaining consistent naming conventions.
#
# 3. **Syntactic Validity**: The ontology conforms to OWL 2 DL profile and valid Manchester Syntax. No violations of the one `rdfs:domain` and one `rdfs:range` per property rule were found.
#
# 4. **Logical Consistency**: No contradictory class axioms or property constraints are present, and no circular subclass relationships exist. The choice between object properties and data properties is appropriate for each element.
#
# 5. **Clarity and Naming Quality**: All elements have self-explanatory, domain-relevant names, following consistent naming patterns.
#
# No further changes were necessary to maintain the author's intent while ensuring correctness and OWL 2 DL compliance.
#
# Table: granter_consortiumpartnertype
# Revision:
# Status: PASS
#
# Corrected Manchester Syntax Version:
#
# [DELTA-ONTOLOGY]
# Here are the ontology elements with provenance annotations for the database table `granter_consortiumpartnertype`:
#
# Class:
#   granter_consortiumpartnertype
#   Annotations:
#     prov:wasDerivedFrom
#     <http://example.org/provenance/granter_consortiumpartnertype>
#
# DataProperty:
#   has_column_name
#   domain granter_consortiumpartnertype
#   range string
#   Annotations:
#     prov:wasDerivedFrom
#     <http://example.org/provenance/granter_consortiumpartnertype/column_name>
#
# ObjectProperty:
#   relates_to_table
#   domain granter_consortiumpartnertype
#   range RelatedTable
#   Annotations:
#     prov:wasDerivedFrom
#     <http://example.org/provenance/granter_consortiumpartnertype/fk_column>
#
# DataProperty:
#   has_description
#   domain granter_consertiumpartnertype
#   range string
#   Annotations:
#     prov:wasDerivedFrom
#     <http://example.org/provenance/granter_consertiumpartnertype/description>
#
# ObjectProperty:
#   relates_to_row
#   domain granter_consertiumpartnertype
#   range Row
#   Annotations:
#     prov:wasDerivedFrom
#     <http://example.org/provenance/granter_consertiumpartnertype/row>
#
# DataProperty:
#   has_title
#   domain granter_consertiumpartnertype
#   range string
#   Annotations:
#     prov:wasDerivedFrom
#     <http://example.org/provenance/granter_consertiumpartnertype/title>
#
# ObjectProperty:
#   relates_to_column
#   domain granter_consertiumpartnertype
#   range Column
#   Annotations:
#     prov:wasDerivedFrom
#     <http://example.org/provenance/granter_consertiumpartnertype/col>
#
# [DATABASE SCHEMA]
# {'raw_ddl': 'CREATE TABLE `granter_consortiumpartnertype` (\n  `id` bigint NOT NULL AUTO_INCREMENT,\n  `created_at` datetime(6) NOT NULL,\n  `updated_at` datetime(6) NOT NULL,\n  `codename` varchar(60) NOT NULL,\n  `description` longtext,\n  `description_en` longtext,\n  `description_pt` longtext,\n  `title` varchar(100) NOT NULL,\n  `title_en` varchar(100) DEFAULT NULL,\n  `title_pt` varchar(100) DEFAULT NULL,\n  `type` varchar(50) NOT NULL,\n  `description_es` longtext,\n  `description_it` longtext,\n  `description_pl` longtext,\n  `title_es` varchar(100) DEFAULT NULL,\n  `title_it` varchar(100) DEFAULT NULL,\n  `title_pl` varchar(100) DEFAULT NULL,\n  PRIMARY KEY (`id`),\n  UNIQUE KEY `codename` (`codename`)\n);', 'columns': ['id', 'created_at', 'updated_at', 'codename', 'description', 'description_en', 'description_pt', 'title', 'title_en', 'title_pt', 'type', 'description_es', 'description_it', 'description_pl', 'title_es', 'title_it', 'title_pl'], 'primary_keys': ['id'], 'foreign_keys': []}
#
# [CORE ONTOLOGY CONTEXT]
# (empty as of now)
#
# [VALIDATION CRITERIA]
#
# The provided delta ontology fragment meets all criteria:
#
# 1. **Coherence with Core Ontology**: The new elements are not redefining existing classes, properties, or concepts in the core ontology.
# 2. **Alignment with Input Table Schema**: All significant columns and foreign keys in the table are represented as appropriate ontology elements.
# 3. **Syntactic Validity**: The ontology conforms to the OWL 2 DL profile and valid Manchester Syntax.
# 4. **Logical Consistency**: There are no contradictory class axioms or property constraints, no circular subclass relationships, and correct choices between object properties and data properties.
# 5. **Clarity and Naming Quality**: The names of all elements follow self-explanatory, domain-relevant patterns, and are consistent with the provided context.
#
# Table: granter_consortiumpartnertype_consortium
# Revision:
# Status: PASS
#
# No issues were found with the provided delta ontology fragment. It meets all validation criteria:
#
# 1. Coherence with Core Ontology:
#    - No existing classes, properties, or concepts in the core ontology are redefined with the same meaning as in the delta ontology.
#
# 2. Alignment with Input Table Schema:
#    - All significant columns and foreign keys from the table schema are represented as appropriate ontology elements.
#    - Names reflect database semantics clearly and consistently.
#
# 3. Syntactic Validity:
#    - The ontology conforms to the OWL 2 DL profile and valid Manchester Syntax.
#    - There is only one `rdfs:domain` and one `rdfs:range` per property.
#
# 4. Logical Consistency:
#    - No contradictory class axioms or property constraints were found.
#    - No circular subclass relationships are present.
#    - Correct choices between object properties and data properties have been made.
#
# 5. Clarity and Naming Quality:
#    - All ontology elements use self-explanatory, domain-relevant names.
#    - No generic or meaningless labels are used.
#    - Properties follow consistent naming patterns (e.g., `has_`, `is_...Of`).
#
# Table: granter_generalopportunityfile
# Revision:
# Status: PASS
#
# Table: granter_generalopportunityfile_opportunities
# Revision:
# Status: PASS
#
# Table: granter_opportunityfile
# Revision:
# Status: FAIL
#
# • Issue 1: The `codename` data property has an incorrect range annotation, which does not match the database schema specification (`varchar(1500)`).
#
# • Issue 2: The `relates_to_table` object property is missing a domain annotation, which should be explicitly stated as `granter_opportunityfile`.
#
# • Issue 3: The `has_foreign_key_column` object property has an incorrect range annotation, which does not match the database schema specification (`string`, but it seems there's no column with that name).
#
# Here is a corrected version of the ontology fragment in valid Manchester Syntax:
#
# [DELTA-ONTOLOGY]
# Class: granter_opportunityfile
# Annotations:
#   prov:wasDerivedFrom
#   <http://example.org/provenance/granter_opportunityfile>
#
# DataProperty: id
# domain granter_opportunityfile
# range bigint
# Annotations:
#   prov:wasDerivedFrom
#   <http://example.org/provenance/granter_opportunityfile/id>
#
# DataProperty: created_at
# domain granter_opportunityfile
# range datetime(6)
# Annotations:
#   prov:wasDerivedFrom
#   <http://example.org/provenance/granter_opportunityfile/created_at>
#
# DataProperty: updated_at
# domain granter_opportunityfile
# range datetime(6)
# Annotations:
#   prov:wasDerivedFrom
#   <http://example.org/provenance/granter_opportunityfile/updated_at>
#
# DataProperty: name
# domain granter_opportunityfile
# range varchar(1500)
# Annotations:
#   prov:wasDerivedFrom
#   <http://example.org/provenance/granter_opportunityfile/name>
#
# DataProperty: uploaded_file
# domain granter_opportunityfile
# range varchar(1500)
# Annotations:
#   prov:wasDerivedFrom
#   <http://example.org/provenance/granter_opportunityfile/uploaded_file>
#
# DataProperty: vector_indexed
# domain granter_opportunityfile
# range tinyint(1)
# Annotations:
#   prov:wasDerivedFrom
#   <http://example.org/provenance/granter_opportunityfile/vector_indexed>
#
# DataProperty: opportunity_id
# domain granter_opportunityfile
# range bigint
# Annotations:
#   prov:wasDerivedFrom
#   <http://example.org/provenance/granter_opportunityfile/opportunity_id>
#
# ObjectProperty: relates_to_table
# domain granter_opportunityfile
# range RelatedTable
# Annotations:
#   prov:wasDerivedFrom
#   <http://example.org/provenance/granter_opportunityfile/fk_column>
# rdfs:domain granter_opportunityfile
#
# ObjectProperty: has_foreign_key_column
# domain granter_opportunityfile
# range string
# Annotations:
#   prov:wasDerivedFrom
#   <http://example.org/provenance/granter_opportunityfile/fk_column>
# rdfs:domain granter_opportunityfile
#
# Table: granter_timeline
# Revision:
# Status: PASS
#
# No issues were found with the delta ontology fragment. The provided schema and context align with the validation criteria, and all elements meet the requirements for coherence with the core ontology, alignment with the input table schema, syntactic validity, logical consistency, clarity, and naming quality.
#
# All annotations have been preserved, and the changes made to ensure compliance with OWL 2 DL profile while preserving the author's intent are minimal. The delta ontology fragment is in valid Manchester Syntax, adhering to the guidelines outlined in the validation criteria.

# %%
pprint(results)
# Out:
# {'granter_activity': {'delta_ontology': 'Here is the generated ontology in '
#                                         'Manchester Syntax:\n'
#                                         '\n'
#                                         'Class: granter_activity\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity>\n'
#                                         '\n'
#                                         'DataProperty:\n'
#                                         'has_column_name\n'
#                                         'domain granter_activity\n'
#                                         'range string\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity/column_name>\n'
#                                         '\n'
#                                         'ObjectProperty:\n'
#                                         'relates_to_table domain '
#                                         'granter_activity\n'
#                                         'range RelatedTable\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity/fk_column>\n'
#                                         '\n'
#                                         'DataProperty:\n'
#                                         'has_type\n'
#                                         'domain granter_activity\n'
#                                         'range string\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity/type>\n'
#                                         '\n'
#                                         'ObjectProperty:\n'
#                                         'relates_to_application domain '
#                                         'granter_activity\n'
#                                         'range GranterApplication\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity/application_id>\n'
#                                         '\n'
#                                         'ObjectProperty:\n'
#                                         'relates_to_company domain '
#                                         'granter_activity\n'
#                                         'range GranterCompany\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity/company_id>\n'
#                                         '\n'
#                                         'ObjectProperty:\n'
#                                         'relates_to_file domain '
#                                         'granter_activity\n'
#                                         'range GranterCompanyfile\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity/file_id>\n'
#                                         '\n'
#                                         'ObjectProperty:\n'
#                                         'relates_to_profile domain '
#                                         'granter_activity\n'
#                                         'range GranterProfile\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity/profile_id>\n'
#                                         '\n'
#                                         'ObjectProperty:\n'
#                                         'relates_to_opportunity domain '
#                                         'granter_activity\n'
#                                         'range GranterOpportunity\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity/opportunity_id>\n'
#                                         '\n'
#                                         'DataProperty:\n'
#                                         'has_created_by_expert\n'
#                                         'domain granter_activity\n'
#                                         'range tinyint\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity(created_by_expert)> \n'
#                                         '\n'
#                                         'DataProperty:\n'
#                                         'has_description\n'
#                                         'domain granter_activity\n'
#                                         'range longtext\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity(description)> \n'
#                                         '\n'
#                                         'DataProperty:\n'
#                                         'has_data_type\n'
#                                         'domain granter_activity\n'
#                                         'range string\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity(data_type)>',
#                       'revision': 'Status: PASS\n'
#                                   '\n'
#                                   'No issues were found with the provided '
#                                   'delta ontology fragment. It conforms to the '
#                                   'OWL 2 DL profile and valid Manchester '
#                                   'Syntax, aligns with the input table schema, '
#                                   'maintains logical consistency, uses '
#                                   'self-explanatory names, and avoids generic '
#                                   'or meaningless labels.\n'
#                                   '\n'
#                                   'The ontology fragment accurately represents '
#                                   "the relational database table's structure "
#                                   'and semantics, incorporating all '
#                                   'significant columns and foreign keys as '
#                                   'appropriate elements (classes, data '
#                                   'properties, or object properties). The '
#                                   'naming conventions are consistent and '
#                                   'domain-relevant.'},
#  'granter_application': {'delta_ontology': 'Here is the ontology generated '
#                                            'based on the provided database '
#                                            'table schema with provenance '
#                                            'annotations:\n'
#                                            '\n'
#                                            'Class: granter_application\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_column_name\n'
#                                            'domain granter_application\n'
#                                            'range string\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/column_name>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_data_type\n'
#                                            'domain granter_application\n'
#                                            'range datatype(string)\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/data_type>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'relates_to_table\n'
#                                            'domain granter_application\n'
#                                            'range RelatedTable\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/fk_column>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_domain\n'
#                                            'domain granter_application\n'
#                                            'range Resource\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/domain>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'relates_to_ref_table\n'
#                                            'domain granter_application\n'
#                                            'range URI\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/ref_table>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_range\n'
#                                            'domain granter_application\n'
#                                            'range string\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/range>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'relates_to_ref_columns\n'
#                                            'domain granter_application\n'
#                                            'range URI\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/ref_columns>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_foreign_key\n'
#                                            'domain granter_application\n'
#                                            'range ForeignKey\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/fk>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'relates_to_ref_table_name\n'
#                                            'domain granter_application\n'
#                                            'range String\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/ref_table_name>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_foreign_key_columns\n'
#                                            'domain granter_application\n'
#                                            'range List<String>\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/fk_columns>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'relates_to_ref_column_names\n'
#                                            'domain granter_application\n'
#                                            'range List<String>\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/ref_column_names>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_cardinality\n'
#                                            'domain granter_application\n'
#                                            'range Cardinality\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/cardinality>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'relates_to_cardinality\n'
#                                            'domain granter_application\n'
#                                            'range Cardinality\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/cardinality>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_type\n'
#                                            'domain granter_application\n'
#                                            'range datatype(string)\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/type>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'relates_to_table_name\n'
#                                            'domain granter_application\n'
#                                            'range String\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/table_name>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_cardinality_domain\n'
#                                            'domain granter_application\n'
#                                            'range Cardinality\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/cardinality_domain>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'relates_to_cardinality_range\n'
#                                            'domain granter_application\n'
#                                            'range Cardinality\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/cardinality_range>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_cardinality_type\n'
#                                            'domain granter_application\n'
#                                            'range datatype(Cardinality)\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/cardinality_type>',
#                          'revision': 'Status: PASS\n'
#                                      '\n'
#                                      'No issues were found with the provided '
#                                      'delta ontology fragment. It meets all '
#                                      'the criteria outlined for validation, '
#                                      'including coherence with the core '
#                                      'ontology, alignment with the input table '
#                                      'schema, syntactic validity, logical '
#                                      'consistency, clarity and naming quality, '
#                                      'and minimal changes were necessary to '
#                                      'ensure correctness and OWL 2 DL '
#                                      "compliance while preserving the author's "
#                                      'intent.\n'
#                                      '\n'
#                                      'However, it is worth noting that some '
#                                      'minor adjustments could be made to '
#                                      'improve the ontology:\n'
#                                      '\n'
#                                      '* The `other_data` column in the '
#                                      'database table schema is represented as '
#                                      'a JSON data type in the ontology, which '
#                                      'may not accurately reflect the semantics '
#                                      'of the column.\n'
#                                      '* Some properties, such as `writer_mode` '
#                                      'and `ai_review_state`, do not have clear '
#                                      'relationships with other classes or '
#                                      'properties in the ontology.\n'
#                                      '\n'
#                                      'These adjustments would be minor and are '
#                                      'not necessary to pass validation. The '
#                                      'provided ontology fragment is already in '
#                                      'a valid state.'},
#  'granter_applicationfile': {'delta_ontology': 'Here is the ontology elements '
#                                                'with provenance annotations '
#                                                'for database table '
#                                                'granter_applicationfile in '
#                                                'Manchester Syntax:\n'
#                                                '\n'
#                                                'Class: '
#                                                'granter_applicationfile\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile>\n'
#                                                '\n'
#                                                'DataProperty: id\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range biginteger\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/id>\n'
#                                                '\n'
#                                                'DataProperty: created_at\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range datetimestring\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/created_at>\n'
#                                                '\n'
#                                                'DataProperty: updated_at\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range datetimestring\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/updated_at>\n'
#                                                '\n'
#                                                'DataProperty: name\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range string\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/name>\n'
#                                                '\n'
#                                                'DataProperty: uploaded_file\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range string\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/uploaded_file>\n'
#                                                '\n'
#                                                'DataProperty: vector_indexed\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range boolean\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/vector_indexed>\n'
#                                                '\n'
#                                                'DataProperty: type\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range string\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/type>\n'
#                                                '\n'
#                                                'DataProperty: application_id\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range biginteger\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/application_id>\n'
#                                                '\n'
#                                                'DataProperty: '
#                                                'document_type_id\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range biginteger\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/document_type_id>\n'
#                                                '\n'
#                                                'ObjectProperty: '
#                                                'relates_to_table\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range RelatedTable\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/fk_column>\n'
#                                                '\n'
#                                                'ObjectProperty: foreign_key\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range ForeignKey\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/fk_column>',
#                              'revision': 'Status: PASS\n'
#                                          '\n'
#                                          '[Corrected Ontology Fragment]\n'
#                                          '\n'
#                                          'Class: granter_applicationfile\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile>\n'
#                                          '\n'
#                                          'DataProperty: id\n'
#                                          'domain granter_applicationfile\n'
#                                          'range biginteger\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/id>\n'
#                                          '\n'
#                                          'DataProperty: created_at\n'
#                                          'domain granter_applicationfile\n'
#                                          'range datetimestring\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/created_at>\n'
#                                          '\n'
#                                          'DataProperty: updated_at\n'
#                                          'domain granter_applicationfile\n'
#                                          'range datetimestring\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/updated_at>\n'
#                                          '\n'
#                                          'DataProperty: name\n'
#                                          'domain granter_applicationfile\n'
#                                          'range string\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/name>\n'
#                                          '\n'
#                                          'DataProperty: uploaded_file\n'
#                                          'domain granter_applicationfile\n'
#                                          'range string\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/uploaded_file>\n'
#                                          '\n'
#                                          'DataProperty: vector_indexed\n'
#                                          'domain granter_applicationfile\n'
#                                          'range boolean\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/vector_indexed>\n'
#                                          '\n'
#                                          'DataProperty: type\n'
#                                          'domain granter_applicationfile\n'
#                                          'range string\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/type>\n'
#                                          '\n'
#                                          'DataProperty: application_id\n'
#                                          'domain granter_applicationfile\n'
#                                          'range biginteger\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/application_id>\n'
#                                          '\n'
#                                          'DataProperty: document_type_id\n'
#                                          'domain granter_applicationfile\n'
#                                          'range biginteger\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/document_type_id>\n'
#                                          '\n'
#                                          'ObjectProperty: relates_to_table\n'
#                                          'domain granter_applicationfile\n'
#                                          'range RelatedTable\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/fk_column>\n'
#                                          '\n'
#                                          'ObjectProperty: foreign_key\n'
#                                          'domain granter_applicationfile\n'
#                                          'range ForeignKey\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/fk_column>\n'
#                                          '\n'
#                                          ' ObjectProperty: document_type_idFK\n'
#                                          'domain granter_applicationfile\n'
#                                          'range granter_doctype\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/document_type_id>\n'
#                                          '\n'
#                                          'ObjectProperty: application_idFK\n'
#                                          'domain granter_applicationfile\n'
#                                          'range granter_application\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/application_id>'},
#  'granter_company': {'delta_ontology': 'Here is the ontology elements with '
#                                        'provenance annotations for database '
#                                        'table granter_company:\n'
#                                        '\n'
#                                        'Class: granter_company\n'
#                                        'Annotations:\n'
#                                        'prov:wasDerivedFrom\n'
#                                        '<http://example.org/provenance/granter_company>\n'
#                                        '\n'
#                                        'DataProperty:\n'
#                                        'has_column_name\n'
#                                        'domain granter_company\n'
#                                        'range string\n'
#                                        'Annotations:\n'
#                                        'prov:wasDerivedFrom\n'
#                                        '<http://example.org/provenance/granter_company/column_name>\n'
#                                        '\n'
#                                        'ObjectProperty:\n'
#                                        'relates_to_table\n'
#                                        'domain granter_company\n'
#                                        'range RelatedTable\n'
#                                        'Annotations:\n'
#                                        'prov:wasDerivedFrom\n'
#                                        '<http://example.org/provenance/granter_company/fk_column>\n'
#                                        '\n'
#                                        'DataProperty:\n'
#                                        'has_data_type\n'
#                                        'domain granter_company\n'
#                                        'range string\n'
#                                        'Annotations:\n'
#                                        'prov:wasDerivedFrom\n'
#                                        '<http://example.org/provenance/granter_company/data_type>\n'
#                                        '\n'
#                                        'ObjectProperty:\n'
#                                        'relates_to_column\n'
#                                        'domain granter_company\n'
#                                        'range Column\n'
#                                        'Annotations:\n'
#                                        'prov:wasDerivedFrom\n'
#                                        '<http://example.org/provenance/granter_company/fk_column>\n'
#                                        '\n'
#                                        'ObjectProperty:\n'
#                                        'is_primary_key\n'
#                                        'domain granter_company\n'
#                                        'range boolean\n'
#                                        'Annotations:\n'
#                                        'prov:wasDerivedFrom\n'
#                                        '<http://example.org/provenance/granter_company/primary_key>\n'
#                                        '\n'
#                                        'DataProperty:\n'
#                                        'has_description\n'
#                                        'domain granter_company\n'
#                                        'range string\n'
#                                        'Annotations:\n'
#                                        'prov:wasDerivedFrom\n'
#                                        '<http://example.org/provenance/granter_company/description>\n'
#                                        '\n'
#                                        'ObjectProperty:\n'
#                                        'is ForeignKey\n'
#                                        'domain granter_company\n'
#                                        'range ForeignKey\n'
#                                        'Annotations:\n'
#                                        'prov:wasDerivedFrom\n'
#                                        '<http://example.org/provenance/granter_company/foreign_key>\n'
#                                        '\n'
#                                        'DataProperty:\n'
#                                        'has_cardinality\n'
#                                        'domain granter_company\n'
#                                        'range int\n'
#                                        'Annotations:\n'
#                                        'prov:wasDerivedFrom\n'
#                                        '<http://example.org/provenance/granter_company/cardinality>\n'
#                                        '\n'
#                                        'ObjectProperty:\n'
#                                        'is Constraint\n'
#                                        'domain granter_company\n'
#                                        'range Constraint\n'
#                                        'Annotations:\n'
#                                        'prov:wasDerivedFrom\n'
#                                        '<http://example.org/provenance/granter_company/constraint>',
#                      'revision': 'Status: PASS\n'
#                                  '\n'
#                                  'No issues were found with the provided delta '
#                                  'ontology fragment after reviewing it against '
#                                  'all validation criteria. The ontology '
#                                  'elements are correctly defined, and the '
#                                  'provenance annotations provide clear '
#                                  'information about the origin of each '
#                                  'element. The naming conventions are '
#                                  'consistent with OWL 2 DL best practices, and '
#                                  'no contradictory class axioms or property '
#                                  'constraints were identified.\n'
#                                  '\n'
#                                  'The ontology successfully maps to the input '
#                                  'table schema, representing every significant '
#                                  'column and foreign key as an appropriate '
#                                  'ontology element. The Manchester Syntax is '
#                                  'correctly applied, and there are no '
#                                  'violations of syntactic validity or logical '
#                                  'consistency.'},
#  'granter_companyfile': {'delta_ontology': 'Here is the ontology elements with '
#                                            'provenance annotations for the '
#                                            'database table '
#                                            'granter_companyfile:\n'
#                                            '\n'
#                                            'Class: granter_companyfile\n'
#                                            'Annotations:\n'
#                                            '  prov:wasDerivedFrom\n'
#                                            '  '
#                                            '<http://example.org/provenance/granter_companyfile>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_column_name\n'
#                                            'domain granter_companyfile\n'
#                                            'range string\n'
#                                            'Annotations:\n'
#                                            '  prov:wasDerivedFrom\n'
#                                            '  '
#                                            '<http://example.org/provenance/granter_companyfile/column_name>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_data_type\n'
#                                            'domain granter_companyfile\n'
#                                            'range string\n'
#                                            'Annotations:\n'
#                                            '  prov:wasDerivedFrom\n'
#                                            '  '
#                                            '<http://example.org/provenance/granter_companyfile/data_type>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'relates_to_table\n'
#                                            'domain granter_companyfile\n'
#                                            'range RelatedTable\n'
#                                            'Annotations:\n'
#                                            '  prov:wasDerivedFrom\n'
#                                            '  '
#                                            '<http://example.org/provenance/granter_companyfile/fk_column>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_foreign_key\n'
#                                            'domain granter_companyfile\n'
#                                            'range ForeignKey\n'
#                                            'Annotations:\n'
#                                            '  prov:wasDerivedFrom\n'
#                                            '  '
#                                            '<http://example.org/provenance/granter_companyfile/foreign_key>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'is_primary_key\n'
#                                            'domain granter_companyfile\n'
#                                            'range string\n'
#                                            'Annotations:\n'
#                                            '  prov:wasDerivedFrom\n'
#                                            '  '
#                                            '<http://example.org/provenance/granter_companyfile/primary_key>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_foreign_key_table\n'
#                                            'domain granter_companyfile\n'
#                                            'range string\n'
#                                            'Annotations:\n'
#                                            '  prov:wasDerivedFrom\n'
#                                            '  '
#                                            '<http://example.org/provenance/granter_companyfile/fk_table>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'relates_to_foreign_key\n'
#                                            'domain granter_companyfile\n'
#                                            'range ForeignKeyTable\n'
#                                            'Annotations:\n'
#                                            '  prov:wasDerivedFrom\n'
#                                            '  '
#                                            '<http://example.org/provenance/granter_companyfile/fk_column>\n'
#                                            '\n'
#                                            'Here is the complete ontology in '
#                                            'Manchester Syntax:\n'
#                                            '\n'
#                                            '```xml\n'
#                                            '@prefix rdfs: '
#                                            '<http://www.w3.org/2000/01/rdf-schema#> '
#                                            '.\n'
#                                            '@prefix owl: '
#                                            '<http://www.w3.org/2002/07/owl#> '
#                                            '.\n'
#                                            '@prefix prov: '
#                                            '<http://www.w3.org/ns/prov#> .\n'
#                                            '@prefix vocab: '
#                                            '<http://example.org/vocab/> .\n'
#                                            '\n'
#                                            'vocab:granter_companyfile a '
#                                            'vocab:Thing .\n'
#                                            '\n'
#                                            'vocab:has_column_name a '
#                                            'vocab:DataProperty ;\n'
#                                            '  rdfs:domain '
#                                            'vocab:granter_companyfile ;\n'
#                                            '  rdfs:range vocab:string ;\n'
#                                            '\n'
# ...
#                                                'domain '
#                                                'granter_opportunityfile\n'
#                                                'range RelatedTable\n'
#                                                'Annotations:\n'
#                                                '  prov:wasDerivedFrom\n'
#                                                '  '
#                                                '<http://example.org/provenance/granter_opportunityfile/fk_column>\n'
#                                                '\n'
#                                                'ObjectProperty: '
#                                                'has_foreign_key_column\n'
#                                                'domain '
#                                                'granter_opportunityfile\n'
#                                                'range string\n'
#                                                'Annotations:\n'
#                                                '  prov:wasDerivedFrom\n'
#                                                '  '
#                                                '<http://example.org/provenance/granter_opportunityfile/fk_column>',
#                              'revision': 'Status: FAIL\n'
#                                          '\n'
#                                          '• Issue 1: The `codename` data '
#                                          'property has an incorrect range '
#                                          'annotation, which does not match the '
#                                          'database schema specification '
#                                          '(`varchar(1500)`).\n'
#                                          '\n'
#                                          '• Issue 2: The `relates_to_table` '
#                                          'object property is missing a domain '
#                                          'annotation, which should be '
#                                          'explicitly stated as '
#                                          '`granter_opportunityfile`.\n'
#                                          '\n'
#                                          '• Issue 3: The '
#                                          '`has_foreign_key_column` object '
#                                          'property has an incorrect range '
#                                          'annotation, which does not match the '
#                                          'database schema specification '
#                                          "(`string`, but it seems there's no "
#                                          'column with that name).\n'
#                                          '\n'
#                                          'Here is a corrected version of the '
#                                          'ontology fragment in valid '
#                                          'Manchester Syntax:\n'
#                                          '\n'
#                                          '[DELTA-ONTOLOGY]\n'
#                                          'Class: granter_opportunityfile\n'
#                                          'Annotations:\n'
#                                          '  prov:wasDerivedFrom\n'
#                                          '  '
#                                          '<http://example.org/provenance/granter_opportunityfile>\n'
#                                          '\n'
#                                          'DataProperty: id\n'
#                                          'domain granter_opportunityfile\n'
#                                          'range bigint\n'
#                                          'Annotations:\n'
#                                          '  prov:wasDerivedFrom\n'
#                                          '  '
#                                          '<http://example.org/provenance/granter_opportunityfile/id>\n'
#                                          '\n'
#                                          'DataProperty: created_at\n'
#                                          'domain granter_opportunityfile\n'
#                                          'range datetime(6)\n'
#                                          'Annotations:\n'
#                                          '  prov:wasDerivedFrom\n'
#                                          '  '
#                                          '<http://example.org/provenance/granter_opportunityfile/created_at>\n'
#                                          '\n'
#                                          'DataProperty: updated_at\n'
#                                          'domain granter_opportunityfile\n'
#                                          'range datetime(6)\n'
#                                          'Annotations:\n'
#                                          '  prov:wasDerivedFrom\n'
#                                          '  '
#                                          '<http://example.org/provenance/granter_opportunityfile/updated_at>\n'
#                                          '\n'
#                                          'DataProperty: name\n'
#                                          'domain granter_opportunityfile\n'
#                                          'range varchar(1500)\n'
#                                          'Annotations:\n'
#                                          '  prov:wasDerivedFrom\n'
#                                          '  '
#                                          '<http://example.org/provenance/granter_opportunityfile/name>\n'
#                                          '\n'
#                                          'DataProperty: uploaded_file\n'
#                                          'domain granter_opportunityfile\n'
#                                          'range varchar(1500)\n'
#                                          'Annotations:\n'
#                                          '  prov:wasDerivedFrom\n'
#                                          '  '
#                                          '<http://example.org/provenance/granter_opportunityfile/uploaded_file>\n'
#                                          '\n'
#                                          'DataProperty: vector_indexed\n'
#                                          'domain granter_opportunityfile\n'
#                                          'range tinyint(1)\n'
#                                          'Annotations:\n'
#                                          '  prov:wasDerivedFrom\n'
#                                          '  '
#                                          '<http://example.org/provenance/granter_opportunityfile/vector_indexed>\n'
#                                          '\n'
#                                          'DataProperty: opportunity_id\n'
#                                          'domain granter_opportunityfile\n'
#                                          'range bigint\n'
#                                          'Annotations:\n'
#                                          '  prov:wasDerivedFrom\n'
#                                          '  '
#                                          '<http://example.org/provenance/granter_opportunityfile/opportunity_id>\n'
#                                          '\n'
#                                          'ObjectProperty: relates_to_table\n'
#                                          'domain granter_opportunityfile\n'
#                                          'range RelatedTable\n'
#                                          'Annotations:\n'
#                                          '  prov:wasDerivedFrom\n'
#                                          '  '
#                                          '<http://example.org/provenance/granter_opportunityfile/fk_column>\n'
#                                          'rdfs:domain granter_opportunityfile\n'
#                                          '\n'
#                                          'ObjectProperty: '
#                                          'has_foreign_key_column\n'
#                                          'domain granter_opportunityfile\n'
#                                          'range string\n'
#                                          'Annotations:\n'
#                                          '  prov:wasDerivedFrom\n'
#                                          '  '
#                                          '<http://example.org/provenance/granter_opportunityfile/fk_column>\n'
#                                          'rdfs:domain granter_opportunityfile'},
#  'granter_timeline': {'delta_ontology': 'Below are the generated ontology '
#                                         'elements in Manchester syntax, along '
#                                         'with provenance annotations:\n'
#                                         '\n'
#                                         'Class: granter_timeline\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline>\n'
#                                         '\n'
#                                         'DataProperty: created_at\n'
#                                         'domain granter_timeline\n'
#                                         'range DateTime\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/created_at>\n'
#                                         '\n'
#                                         'DataProperty: updated_at\n'
#                                         'domain granter_timeline\n'
#                                         'range DateTime\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/updated_at>\n'
#                                         '\n'
#                                         'DataProperty: type\n'
#                                         'domain granter_timeline\n'
#                                         'range string\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/type>\n'
#                                         '\n'
#                                         'DataProperty: title\n'
#                                         'domain granter_timeline\n'
#                                         'range string\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/title>\n'
#                                         '\n'
#                                         'DataProperty: description\n'
#                                         'domain granter_timeline\n'
#                                         'range string\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/description>\n'
#                                         '\n'
#                                         'DataProperty: date\n'
#                                         'domain granter_timeline\n'
#                                         'range Date\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/date>\n'
#                                         '\n'
#                                         'DataProperty: time\n'
#                                         'domain granter_timeline\n'
#                                         'range Time\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/time>\n'
#                                         '\n'
#                                         'DataProperty: opportunity_id\n'
#                                         'domain granter_timeline\n'
#                                         'range Bigint\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/opportunity_id>\n'
#                                         '\n'
#                                         'DataProperty: time_diff\n'
#                                         'domain granter_timeline\n'
#                                         'range string\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/time_diff>\n'
#                                         '\n'
#                                         'ObjectProperty: relates_to_table\n'
#                                         'domain granter_timeline\n'
#                                         'range RelatedTable\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/foreign_key_column>\n'
#                                         '\n'
#                                         'ObjectProperty: '
#                                         'foreign_key_opportunity_id\n'
#                                         'domain granter_timeline\n'
#                                         'range GranterOpportunity\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/fk_granter_opportunity>\n'
#                                         '\n'
#                                         'Note that the rdfs:domain and '
#                                         'rdfs:range are combined to ensure '
#                                         'only one instance per property. The '
#                                         'owl:sameAs is not explicitly '
#                                         'mentioned, but it can be inferred as '
#                                         'part of the general understanding of '
#                                         'the annotations.',
#                       'revision': 'Status: PASS\n'
#                                   '\n'
#                                   'No issues were found with the delta '
#                                   'ontology fragment. The provided schema and '
#                                   'context align with the validation criteria, '
#                                   'and all elements meet the requirements for '
#                                   'coherence with the core ontology, alignment '
#                                   'with the input table schema, syntactic '
#                                   'validity, logical consistency, clarity, and '
#                                   'naming quality.\n'
#                                   '\n'
#                                   'All annotations have been preserved, and '
#                                   'the changes made to ensure compliance with '
#                                   'OWL 2 DL profile while preserving the '
#                                   "author's intent are minimal. The delta "
#                                   'ontology fragment is in valid Manchester '
#                                   'Syntax, adhering to the guidelines outlined '
#                                   'in the validation criteria.'}}

# %%
with open("delta_ontologies_results.json", "w", encoding="utf-8") as f:
    json.dump(results, f, ensure_ascii=False, indent=2)

# %% [markdown]
# ## Merging the delta ontologies

# %%
import json
from pprint import pprint
with open('delta_ontologies_results.json', 'r') as file:
    results = json.load(file)

pprint(results)
# Out:
# {'granter_activity': {'delta_ontology': 'Here is the generated ontology in '
#                                         'Manchester Syntax:\n'
#                                         '\n'
#                                         'Class: granter_activity\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity>\n'
#                                         '\n'
#                                         'DataProperty:\n'
#                                         'has_column_name\n'
#                                         'domain granter_activity\n'
#                                         'range string\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity/column_name>\n'
#                                         '\n'
#                                         'ObjectProperty:\n'
#                                         'relates_to_table domain '
#                                         'granter_activity\n'
#                                         'range RelatedTable\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity/fk_column>\n'
#                                         '\n'
#                                         'DataProperty:\n'
#                                         'has_type\n'
#                                         'domain granter_activity\n'
#                                         'range string\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity/type>\n'
#                                         '\n'
#                                         'ObjectProperty:\n'
#                                         'relates_to_application domain '
#                                         'granter_activity\n'
#                                         'range GranterApplication\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity/application_id>\n'
#                                         '\n'
#                                         'ObjectProperty:\n'
#                                         'relates_to_company domain '
#                                         'granter_activity\n'
#                                         'range GranterCompany\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity/company_id>\n'
#                                         '\n'
#                                         'ObjectProperty:\n'
#                                         'relates_to_file domain '
#                                         'granter_activity\n'
#                                         'range GranterCompanyfile\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity/file_id>\n'
#                                         '\n'
#                                         'ObjectProperty:\n'
#                                         'relates_to_profile domain '
#                                         'granter_activity\n'
#                                         'range GranterProfile\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity/profile_id>\n'
#                                         '\n'
#                                         'ObjectProperty:\n'
#                                         'relates_to_opportunity domain '
#                                         'granter_activity\n'
#                                         'range GranterOpportunity\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity/opportunity_id>\n'
#                                         '\n'
#                                         'DataProperty:\n'
#                                         'has_created_by_expert\n'
#                                         'domain granter_activity\n'
#                                         'range tinyint\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity(created_by_expert)> \n'
#                                         '\n'
#                                         'DataProperty:\n'
#                                         'has_description\n'
#                                         'domain granter_activity\n'
#                                         'range longtext\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity(description)> \n'
#                                         '\n'
#                                         'DataProperty:\n'
#                                         'has_data_type\n'
#                                         'domain granter_activity\n'
#                                         'range string\n'
#                                         'Annotations:\n'
#                                         '  prov:wasDerivedFrom\n'
#                                         '  '
#                                         '<http://example.org/provenance/granter_activity(data_type)>',
#                       'revision': 'Status: PASS\n'
#                                   '\n'
#                                   'No issues were found with the provided '
#                                   'delta ontology fragment. It conforms to the '
#                                   'OWL 2 DL profile and valid Manchester '
#                                   'Syntax, aligns with the input table schema, '
#                                   'maintains logical consistency, uses '
#                                   'self-explanatory names, and avoids generic '
#                                   'or meaningless labels.\n'
#                                   '\n'
#                                   'The ontology fragment accurately represents '
#                                   "the relational database table's structure "
#                                   'and semantics, incorporating all '
#                                   'significant columns and foreign keys as '
#                                   'appropriate elements (classes, data '
#                                   'properties, or object properties). The '
#                                   'naming conventions are consistent and '
#                                   'domain-relevant.'},
#  'granter_application': {'delta_ontology': 'Here is the ontology generated '
#                                            'based on the provided database '
#                                            'table schema with provenance '
#                                            'annotations:\n'
#                                            '\n'
#                                            'Class: granter_application\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_column_name\n'
#                                            'domain granter_application\n'
#                                            'range string\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/column_name>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_data_type\n'
#                                            'domain granter_application\n'
#                                            'range datatype(string)\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/data_type>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'relates_to_table\n'
#                                            'domain granter_application\n'
#                                            'range RelatedTable\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/fk_column>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_domain\n'
#                                            'domain granter_application\n'
#                                            'range Resource\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/domain>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'relates_to_ref_table\n'
#                                            'domain granter_application\n'
#                                            'range URI\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/ref_table>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_range\n'
#                                            'domain granter_application\n'
#                                            'range string\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/range>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'relates_to_ref_columns\n'
#                                            'domain granter_application\n'
#                                            'range URI\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/ref_columns>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_foreign_key\n'
#                                            'domain granter_application\n'
#                                            'range ForeignKey\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/fk>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'relates_to_ref_table_name\n'
#                                            'domain granter_application\n'
#                                            'range String\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/ref_table_name>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_foreign_key_columns\n'
#                                            'domain granter_application\n'
#                                            'range List<String>\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/fk_columns>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'relates_to_ref_column_names\n'
#                                            'domain granter_application\n'
#                                            'range List<String>\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/ref_column_names>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_cardinality\n'
#                                            'domain granter_application\n'
#                                            'range Cardinality\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/cardinality>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'relates_to_cardinality\n'
#                                            'domain granter_application\n'
#                                            'range Cardinality\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/cardinality>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_type\n'
#                                            'domain granter_application\n'
#                                            'range datatype(string)\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/type>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'relates_to_table_name\n'
#                                            'domain granter_application\n'
#                                            'range String\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/table_name>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_cardinality_domain\n'
#                                            'domain granter_application\n'
#                                            'range Cardinality\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/cardinality_domain>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'relates_to_cardinality_range\n'
#                                            'domain granter_application\n'
#                                            'range Cardinality\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/cardinality_range>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_cardinality_type\n'
#                                            'domain granter_application\n'
#                                            'range datatype(Cardinality)\n'
#                                            'Annotations:\n'
#                                            'prov:wasDerivedFrom\n'
#                                            '<http://example.org/provenance/granter_application/cardinality_type>',
#                          'revision': 'Status: PASS\n'
#                                      '\n'
#                                      'No issues were found with the provided '
#                                      'delta ontology fragment. It meets all '
#                                      'the criteria outlined for validation, '
#                                      'including coherence with the core '
#                                      'ontology, alignment with the input table '
#                                      'schema, syntactic validity, logical '
#                                      'consistency, clarity and naming quality, '
#                                      'and minimal changes were necessary to '
#                                      'ensure correctness and OWL 2 DL '
#                                      "compliance while preserving the author's "
#                                      'intent.\n'
#                                      '\n'
#                                      'However, it is worth noting that some '
#                                      'minor adjustments could be made to '
#                                      'improve the ontology:\n'
#                                      '\n'
#                                      '* The `other_data` column in the '
#                                      'database table schema is represented as '
#                                      'a JSON data type in the ontology, which '
#                                      'may not accurately reflect the semantics '
#                                      'of the column.\n'
#                                      '* Some properties, such as `writer_mode` '
#                                      'and `ai_review_state`, do not have clear '
#                                      'relationships with other classes or '
#                                      'properties in the ontology.\n'
#                                      '\n'
#                                      'These adjustments would be minor and are '
#                                      'not necessary to pass validation. The '
#                                      'provided ontology fragment is already in '
#                                      'a valid state.'},
#  'granter_applicationfile': {'delta_ontology': 'Here is the ontology elements '
#                                                'with provenance annotations '
#                                                'for database table '
#                                                'granter_applicationfile in '
#                                                'Manchester Syntax:\n'
#                                                '\n'
#                                                'Class: '
#                                                'granter_applicationfile\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile>\n'
#                                                '\n'
#                                                'DataProperty: id\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range biginteger\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/id>\n'
#                                                '\n'
#                                                'DataProperty: created_at\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range datetimestring\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/created_at>\n'
#                                                '\n'
#                                                'DataProperty: updated_at\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range datetimestring\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/updated_at>\n'
#                                                '\n'
#                                                'DataProperty: name\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range string\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/name>\n'
#                                                '\n'
#                                                'DataProperty: uploaded_file\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range string\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/uploaded_file>\n'
#                                                '\n'
#                                                'DataProperty: vector_indexed\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range boolean\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/vector_indexed>\n'
#                                                '\n'
#                                                'DataProperty: type\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range string\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/type>\n'
#                                                '\n'
#                                                'DataProperty: application_id\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range biginteger\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/application_id>\n'
#                                                '\n'
#                                                'DataProperty: '
#                                                'document_type_id\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range biginteger\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/document_type_id>\n'
#                                                '\n'
#                                                'ObjectProperty: '
#                                                'relates_to_table\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range RelatedTable\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/fk_column>\n'
#                                                '\n'
#                                                'ObjectProperty: foreign_key\n'
#                                                'domain '
#                                                'granter_applicationfile\n'
#                                                'range ForeignKey\n'
#                                                'Annotations:\n'
#                                                'prov:wasDerivedFrom\n'
#                                                '<http://example.org/provenance/granter_applicationfile/fk_column>',
#                              'revision': 'Status: PASS\n'
#                                          '\n'
#                                          '[Corrected Ontology Fragment]\n'
#                                          '\n'
#                                          'Class: granter_applicationfile\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile>\n'
#                                          '\n'
#                                          'DataProperty: id\n'
#                                          'domain granter_applicationfile\n'
#                                          'range biginteger\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/id>\n'
#                                          '\n'
#                                          'DataProperty: created_at\n'
#                                          'domain granter_applicationfile\n'
#                                          'range datetimestring\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/created_at>\n'
#                                          '\n'
#                                          'DataProperty: updated_at\n'
#                                          'domain granter_applicationfile\n'
#                                          'range datetimestring\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/updated_at>\n'
#                                          '\n'
#                                          'DataProperty: name\n'
#                                          'domain granter_applicationfile\n'
#                                          'range string\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/name>\n'
#                                          '\n'
#                                          'DataProperty: uploaded_file\n'
#                                          'domain granter_applicationfile\n'
#                                          'range string\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/uploaded_file>\n'
#                                          '\n'
#                                          'DataProperty: vector_indexed\n'
#                                          'domain granter_applicationfile\n'
#                                          'range boolean\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/vector_indexed>\n'
#                                          '\n'
#                                          'DataProperty: type\n'
#                                          'domain granter_applicationfile\n'
#                                          'range string\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/type>\n'
#                                          '\n'
#                                          'DataProperty: application_id\n'
#                                          'domain granter_applicationfile\n'
#                                          'range biginteger\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/application_id>\n'
#                                          '\n'
#                                          'DataProperty: document_type_id\n'
#                                          'domain granter_applicationfile\n'
#                                          'range biginteger\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/document_type_id>\n'
#                                          '\n'
#                                          'ObjectProperty: relates_to_table\n'
#                                          'domain granter_applicationfile\n'
#                                          'range RelatedTable\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/fk_column>\n'
#                                          '\n'
#                                          'ObjectProperty: foreign_key\n'
#                                          'domain granter_applicationfile\n'
#                                          'range ForeignKey\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/fk_column>\n'
#                                          '\n'
#                                          ' ObjectProperty: document_type_idFK\n'
#                                          'domain granter_applicationfile\n'
#                                          'range granter_doctype\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/document_type_id>\n'
#                                          '\n'
#                                          'ObjectProperty: application_idFK\n'
#                                          'domain granter_applicationfile\n'
#                                          'range granter_application\n'
#                                          'Annotations:\n'
#                                          'prov:wasDerivedFrom\n'
#                                          '<http://example.org/provenance/granter_applicationfile/application_id>'},
#  'granter_company': {'delta_ontology': 'Here is the ontology elements with '
#                                        'provenance annotations for database '
#                                        'table granter_company:\n'
#                                        '\n'
#                                        'Class: granter_company\n'
#                                        'Annotations:\n'
#                                        'prov:wasDerivedFrom\n'
#                                        '<http://example.org/provenance/granter_company>\n'
#                                        '\n'
#                                        'DataProperty:\n'
#                                        'has_column_name\n'
#                                        'domain granter_company\n'
#                                        'range string\n'
#                                        'Annotations:\n'
#                                        'prov:wasDerivedFrom\n'
#                                        '<http://example.org/provenance/granter_company/column_name>\n'
#                                        '\n'
#                                        'ObjectProperty:\n'
#                                        'relates_to_table\n'
#                                        'domain granter_company\n'
#                                        'range RelatedTable\n'
#                                        'Annotations:\n'
#                                        'prov:wasDerivedFrom\n'
#                                        '<http://example.org/provenance/granter_company/fk_column>\n'
#                                        '\n'
#                                        'DataProperty:\n'
#                                        'has_data_type\n'
#                                        'domain granter_company\n'
#                                        'range string\n'
#                                        'Annotations:\n'
#                                        'prov:wasDerivedFrom\n'
#                                        '<http://example.org/provenance/granter_company/data_type>\n'
#                                        '\n'
#                                        'ObjectProperty:\n'
#                                        'relates_to_column\n'
#                                        'domain granter_company\n'
#                                        'range Column\n'
#                                        'Annotations:\n'
#                                        'prov:wasDerivedFrom\n'
#                                        '<http://example.org/provenance/granter_company/fk_column>\n'
#                                        '\n'
#                                        'ObjectProperty:\n'
#                                        'is_primary_key\n'
#                                        'domain granter_company\n'
#                                        'range boolean\n'
#                                        'Annotations:\n'
#                                        'prov:wasDerivedFrom\n'
#                                        '<http://example.org/provenance/granter_company/primary_key>\n'
#                                        '\n'
#                                        'DataProperty:\n'
#                                        'has_description\n'
#                                        'domain granter_company\n'
#                                        'range string\n'
#                                        'Annotations:\n'
#                                        'prov:wasDerivedFrom\n'
#                                        '<http://example.org/provenance/granter_company/description>\n'
#                                        '\n'
#                                        'ObjectProperty:\n'
#                                        'is ForeignKey\n'
#                                        'domain granter_company\n'
#                                        'range ForeignKey\n'
#                                        'Annotations:\n'
#                                        'prov:wasDerivedFrom\n'
#                                        '<http://example.org/provenance/granter_company/foreign_key>\n'
#                                        '\n'
#                                        'DataProperty:\n'
#                                        'has_cardinality\n'
#                                        'domain granter_company\n'
#                                        'range int\n'
#                                        'Annotations:\n'
#                                        'prov:wasDerivedFrom\n'
#                                        '<http://example.org/provenance/granter_company/cardinality>\n'
#                                        '\n'
#                                        'ObjectProperty:\n'
#                                        'is Constraint\n'
#                                        'domain granter_company\n'
#                                        'range Constraint\n'
#                                        'Annotations:\n'
#                                        'prov:wasDerivedFrom\n'
#                                        '<http://example.org/provenance/granter_company/constraint>',
#                      'revision': 'Status: PASS\n'
#                                  '\n'
#                                  'No issues were found with the provided delta '
#                                  'ontology fragment after reviewing it against '
#                                  'all validation criteria. The ontology '
#                                  'elements are correctly defined, and the '
#                                  'provenance annotations provide clear '
#                                  'information about the origin of each '
#                                  'element. The naming conventions are '
#                                  'consistent with OWL 2 DL best practices, and '
#                                  'no contradictory class axioms or property '
#                                  'constraints were identified.\n'
#                                  '\n'
#                                  'The ontology successfully maps to the input '
#                                  'table schema, representing every significant '
#                                  'column and foreign key as an appropriate '
#                                  'ontology element. The Manchester Syntax is '
#                                  'correctly applied, and there are no '
#                                  'violations of syntactic validity or logical '
#                                  'consistency.'},
#  'granter_companyfile': {'delta_ontology': 'Here is the ontology elements with '
#                                            'provenance annotations for the '
#                                            'database table '
#                                            'granter_companyfile:\n'
#                                            '\n'
#                                            'Class: granter_companyfile\n'
#                                            'Annotations:\n'
#                                            '  prov:wasDerivedFrom\n'
#                                            '  '
#                                            '<http://example.org/provenance/granter_companyfile>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_column_name\n'
#                                            'domain granter_companyfile\n'
#                                            'range string\n'
#                                            'Annotations:\n'
#                                            '  prov:wasDerivedFrom\n'
#                                            '  '
#                                            '<http://example.org/provenance/granter_companyfile/column_name>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_data_type\n'
#                                            'domain granter_companyfile\n'
#                                            'range string\n'
#                                            'Annotations:\n'
#                                            '  prov:wasDerivedFrom\n'
#                                            '  '
#                                            '<http://example.org/provenance/granter_companyfile/data_type>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'relates_to_table\n'
#                                            'domain granter_companyfile\n'
#                                            'range RelatedTable\n'
#                                            'Annotations:\n'
#                                            '  prov:wasDerivedFrom\n'
#                                            '  '
#                                            '<http://example.org/provenance/granter_companyfile/fk_column>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_foreign_key\n'
#                                            'domain granter_companyfile\n'
#                                            'range ForeignKey\n'
#                                            'Annotations:\n'
#                                            '  prov:wasDerivedFrom\n'
#                                            '  '
#                                            '<http://example.org/provenance/granter_companyfile/foreign_key>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'is_primary_key\n'
#                                            'domain granter_companyfile\n'
#                                            'range string\n'
#                                            'Annotations:\n'
#                                            '  prov:wasDerivedFrom\n'
#                                            '  '
#                                            '<http://example.org/provenance/granter_companyfile/primary_key>\n'
#                                            '\n'
#                                            'DataProperty:\n'
#                                            'has_foreign_key_table\n'
#                                            'domain granter_companyfile\n'
#                                            'range string\n'
#                                            'Annotations:\n'
#                                            '  prov:wasDerivedFrom\n'
#                                            '  '
#                                            '<http://example.org/provenance/granter_companyfile/fk_table>\n'
#                                            '\n'
#                                            'ObjectProperty:\n'
#                                            'relates_to_foreign_key\n'
#                                            'domain granter_companyfile\n'
#                                            'range ForeignKeyTable\n'
#                                            'Annotations:\n'
#                                            '  prov:wasDerivedFrom\n'
#                                            '  '
#                                            '<http://example.org/provenance/granter_companyfile/fk_column>\n'
#                                            '\n'
#                                            'Here is the complete ontology in '
#                                            'Manchester Syntax:\n'
#                                            '\n'
#                                            '```xml\n'
#                                            '@prefix rdfs: '
#                                            '<http://www.w3.org/2000/01/rdf-schema#> '
#                                            '.\n'
#                                            '@prefix owl: '
#                                            '<http://www.w3.org/2002/07/owl#> '
#                                            '.\n'
#                                            '@prefix prov: '
#                                            '<http://www.w3.org/ns/prov#> .\n'
#                                            '@prefix vocab: '
#                                            '<http://example.org/vocab/> .\n'
#                                            '\n'
#                                            'vocab:granter_companyfile a '
#                                            'vocab:Thing .\n'
#                                            '\n'
#                                            'vocab:has_column_name a '
#                                            'vocab:DataProperty ;\n'
#                                            '  rdfs:domain '
#                                            'vocab:granter_companyfile ;\n'
#                                            '  rdfs:range vocab:string ;\n'
#                                            '\n'
# ...
#                                                'domain '
#                                                'granter_opportunityfile\n'
#                                                'range RelatedTable\n'
#                                                'Annotations:\n'
#                                                '  prov:wasDerivedFrom\n'
#                                                '  '
#                                                '<http://example.org/provenance/granter_opportunityfile/fk_column>\n'
#                                                '\n'
#                                                'ObjectProperty: '
#                                                'has_foreign_key_column\n'
#                                                'domain '
#                                                'granter_opportunityfile\n'
#                                                'range string\n'
#                                                'Annotations:\n'
#                                                '  prov:wasDerivedFrom\n'
#                                                '  '
#                                                '<http://example.org/provenance/granter_opportunityfile/fk_column>',
#                              'revision': 'Status: FAIL\n'
#                                          '\n'
#                                          '• Issue 1: The `codename` data '
#                                          'property has an incorrect range '
#                                          'annotation, which does not match the '
#                                          'database schema specification '
#                                          '(`varchar(1500)`).\n'
#                                          '\n'
#                                          '• Issue 2: The `relates_to_table` '
#                                          'object property is missing a domain '
#                                          'annotation, which should be '
#                                          'explicitly stated as '
#                                          '`granter_opportunityfile`.\n'
#                                          '\n'
#                                          '• Issue 3: The '
#                                          '`has_foreign_key_column` object '
#                                          'property has an incorrect range '
#                                          'annotation, which does not match the '
#                                          'database schema specification '
#                                          "(`string`, but it seems there's no "
#                                          'column with that name).\n'
#                                          '\n'
#                                          'Here is a corrected version of the '
#                                          'ontology fragment in valid '
#                                          'Manchester Syntax:\n'
#                                          '\n'
#                                          '[DELTA-ONTOLOGY]\n'
#                                          'Class: granter_opportunityfile\n'
#                                          'Annotations:\n'
#                                          '  prov:wasDerivedFrom\n'
#                                          '  '
#                                          '<http://example.org/provenance/granter_opportunityfile>\n'
#                                          '\n'
#                                          'DataProperty: id\n'
#                                          'domain granter_opportunityfile\n'
#                                          'range bigint\n'
#                                          'Annotations:\n'
#                                          '  prov:wasDerivedFrom\n'
#                                          '  '
#                                          '<http://example.org/provenance/granter_opportunityfile/id>\n'
#                                          '\n'
#                                          'DataProperty: created_at\n'
#                                          'domain granter_opportunityfile\n'
#                                          'range datetime(6)\n'
#                                          'Annotations:\n'
#                                          '  prov:wasDerivedFrom\n'
#                                          '  '
#                                          '<http://example.org/provenance/granter_opportunityfile/created_at>\n'
#                                          '\n'
#                                          'DataProperty: updated_at\n'
#                                          'domain granter_opportunityfile\n'
#                                          'range datetime(6)\n'
#                                          'Annotations:\n'
#                                          '  prov:wasDerivedFrom\n'
#                                          '  '
#                                          '<http://example.org/provenance/granter_opportunityfile/updated_at>\n'
#                                          '\n'
#                                          'DataProperty: name\n'
#                                          'domain granter_opportunityfile\n'
#                                          'range varchar(1500)\n'
#                                          'Annotations:\n'
#                                          '  prov:wasDerivedFrom\n'
#                                          '  '
#                                          '<http://example.org/provenance/granter_opportunityfile/name>\n'
#                                          '\n'
#                                          'DataProperty: uploaded_file\n'
#                                          'domain granter_opportunityfile\n'
#                                          'range varchar(1500)\n'
#                                          'Annotations:\n'
#                                          '  prov:wasDerivedFrom\n'
#                                          '  '
#                                          '<http://example.org/provenance/granter_opportunityfile/uploaded_file>\n'
#                                          '\n'
#                                          'DataProperty: vector_indexed\n'
#                                          'domain granter_opportunityfile\n'
#                                          'range tinyint(1)\n'
#                                          'Annotations:\n'
#                                          '  prov:wasDerivedFrom\n'
#                                          '  '
#                                          '<http://example.org/provenance/granter_opportunityfile/vector_indexed>\n'
#                                          '\n'
#                                          'DataProperty: opportunity_id\n'
#                                          'domain granter_opportunityfile\n'
#                                          'range bigint\n'
#                                          'Annotations:\n'
#                                          '  prov:wasDerivedFrom\n'
#                                          '  '
#                                          '<http://example.org/provenance/granter_opportunityfile/opportunity_id>\n'
#                                          '\n'
#                                          'ObjectProperty: relates_to_table\n'
#                                          'domain granter_opportunityfile\n'
#                                          'range RelatedTable\n'
#                                          'Annotations:\n'
#                                          '  prov:wasDerivedFrom\n'
#                                          '  '
#                                          '<http://example.org/provenance/granter_opportunityfile/fk_column>\n'
#                                          'rdfs:domain granter_opportunityfile\n'
#                                          '\n'
#                                          'ObjectProperty: '
#                                          'has_foreign_key_column\n'
#                                          'domain granter_opportunityfile\n'
#                                          'range string\n'
#                                          'Annotations:\n'
#                                          '  prov:wasDerivedFrom\n'
#                                          '  '
#                                          '<http://example.org/provenance/granter_opportunityfile/fk_column>\n'
#                                          'rdfs:domain granter_opportunityfile'},
#  'granter_timeline': {'delta_ontology': 'Below are the generated ontology '
#                                         'elements in Manchester syntax, along '
#                                         'with provenance annotations:\n'
#                                         '\n'
#                                         'Class: granter_timeline\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline>\n'
#                                         '\n'
#                                         'DataProperty: created_at\n'
#                                         'domain granter_timeline\n'
#                                         'range DateTime\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/created_at>\n'
#                                         '\n'
#                                         'DataProperty: updated_at\n'
#                                         'domain granter_timeline\n'
#                                         'range DateTime\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/updated_at>\n'
#                                         '\n'
#                                         'DataProperty: type\n'
#                                         'domain granter_timeline\n'
#                                         'range string\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/type>\n'
#                                         '\n'
#                                         'DataProperty: title\n'
#                                         'domain granter_timeline\n'
#                                         'range string\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/title>\n'
#                                         '\n'
#                                         'DataProperty: description\n'
#                                         'domain granter_timeline\n'
#                                         'range string\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/description>\n'
#                                         '\n'
#                                         'DataProperty: date\n'
#                                         'domain granter_timeline\n'
#                                         'range Date\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/date>\n'
#                                         '\n'
#                                         'DataProperty: time\n'
#                                         'domain granter_timeline\n'
#                                         'range Time\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/time>\n'
#                                         '\n'
#                                         'DataProperty: opportunity_id\n'
#                                         'domain granter_timeline\n'
#                                         'range Bigint\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/opportunity_id>\n'
#                                         '\n'
#                                         'DataProperty: time_diff\n'
#                                         'domain granter_timeline\n'
#                                         'range string\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/time_diff>\n'
#                                         '\n'
#                                         'ObjectProperty: relates_to_table\n'
#                                         'domain granter_timeline\n'
#                                         'range RelatedTable\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/foreign_key_column>\n'
#                                         '\n'
#                                         'ObjectProperty: '
#                                         'foreign_key_opportunity_id\n'
#                                         'domain granter_timeline\n'
#                                         'range GranterOpportunity\n'
#                                         'Annotations:\n'
#                                         'prov:wasDerivedFrom\n'
#                                         '<http://example.org/provenance/granter_timeline/fk_granter_opportunity>\n'
#                                         '\n'
#                                         'Note that the rdfs:domain and '
#                                         'rdfs:range are combined to ensure '
#                                         'only one instance per property. The '
#                                         'owl:sameAs is not explicitly '
#                                         'mentioned, but it can be inferred as '
#                                         'part of the general understanding of '
#                                         'the annotations.',
#                       'revision': 'Status: PASS\n'
#                                   '\n'
#                                   'No issues were found with the delta '
#                                   'ontology fragment. The provided schema and '
#                                   'context align with the validation criteria, '
#                                   'and all elements meet the requirements for '
#                                   'coherence with the core ontology, alignment '
#                                   'with the input table schema, syntactic '
#                                   'validity, logical consistency, clarity, and '
#                                   'naming quality.\n'
#                                   '\n'
#                                   'All annotations have been preserved, and '
#                                   'the changes made to ensure compliance with '
#                                   'OWL 2 DL profile while preserving the '
#                                   "author's intent are minimal. The delta "
#                                   'ontology fragment is in valid Manchester '
#                                   'Syntax, adhering to the guidelines outlined '
#                                   'in the validation criteria.'}}
