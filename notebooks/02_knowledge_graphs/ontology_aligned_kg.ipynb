# %% [markdown]
# # LLMs

# %%
from langchain_openai import AzureChatOpenAI
import os
from dotenv import load_dotenv
load_dotenv()
AZURE_OPENAI_API_KEY = os.getenv("AZURE_OPENAI_API_KEY")
AZURE_OPENAI_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
AZURE_OPENAI_API_VERSION = os.getenv("AZURE_OPENAI_API_VERSION")

AZURE_DEPLOYMENT_GPT41 = os.getenv("AZURE_DEPLOYMENT_GPT41")
AZURE_DEPLOYMENT_GPT41_NANO = os.getenv("AZURE_DEPLOYMENT_GPT41_NANO")

gpt41_nano = AzureChatOpenAI(
    azure_deployment=AZURE_DEPLOYMENT_GPT41_NANO,
    api_version=AZURE_OPENAI_API_VERSION,
    azure_endpoint=AZURE_OPENAI_ENDPOINT,
    api_key=AZURE_OPENAI_API_KEY
)
# Out:
# c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
from dotenv import load_dotenv
load_dotenv()
GROQ_API_KEY = os.getenv("GROQ_API_KEY")

from langchain_groq import ChatGroq

groqllm = ChatGroq(
    model="llama-3.1-8b-instant",
    api_key=GROQ_API_KEY
)

# %% [markdown]
# # Ontology Rules

# %%
import re
def extract_ontology_lexical_view(ontology_path: str) -> list:
    """
    Returns format: ['label: comment', 'label2: comment2']
    Pairs labels with their corresponding comments
    """
    with open(ontology_path, 'r', encoding='utf-8') as f:
        content = f.read()
        
    lexical_view = []
    
    # Find all rdfs:label and rdfs:comment matches with their positions
    label_pattern = r'rdfs:label\s+"([^"]+)"'
    comment_pattern = r'rdfs:comment\s+"([^"]+)"'
    
    # Get all matches in order
    labels = [match.group(1).replace(" ", "") for match in re.finditer(label_pattern, content)]
    comments = [match.group(1) for match in re.finditer(comment_pattern, content)]

    # Pair them sequentially (comment[i] goes with label[i])
    for i in range(len(labels)):
        if i < len(comments):
            lexical_view.append(f"{labels[i]}: {comments[i]}")
        else:
            lexical_view.append(f"{labels[i]}: ")
    
    return lexical_view

# %%
extract_ontology_lexical_view('../../output/ontologies/rdb/rigor_ontology_few_fixes.ttl')
# Out:
# ['ActivityDate: Date when the company commenced operations or activity.',
#  'Address: Physical address of the company.',
#  'AgentLanguage: Preferred language of the agent or representative.',
#  'AIReviewState: State of AI-based review process for the application.',
#  'AnnualRevenue: Total annual revenue of the company.',
#  'ApplicationIdentifier: Unique identifier for the granter application.',
#  'ApplicationState: Current state of the application (e.g., submitted, under review, approved).',
#  'ApprovedGrantAmount: The amount of grant approved for the application.',
#  'CAE: Custom attribute or code related to the company.',
#  'City: City where the company is located.',
#  'CodeName: Internal code name for the application.',
#  'Company: Identifier linking to internal or external company references.',
#  'Consortium: Associated consortium for the application, if any.',
#  'Country: Country where the company is registered or located.',
#  'CoverImage: URL to an image representing the company.',
#  'CreationTimestamp: Timestamp when the application was created.',
#  "Description: Brief description of the company's activities or profile.",
#  "DigitalComponent: Information about the company's digital infrastructure or components.",
#  'NumberofEmployees: Total number of employees in the company.',
#  'ExtraInformation: Additional information about the company.',
#  'FutureGoalsHR: Future plans related to human resources.',
#  "FutureGoalsInfrastructure: Company's future plans related to infrastructure development.",
#  "FutureGoalsInternationalization: Company's future plans for international expansion.",
#  'FutureGoalsMachineryandEquipments: Plans related to machinery and equipment upgrades or acquisitions.',
#  "FutureGoalsMarketing: Company's future marketing strategies or goals.",
#  'FutureGoalsR&D: Research and Development future plans.',
#  'GeographicCriterion: A class representing geographic constraints or locations relevant to data.',
#  'GrantPayment: A class representing a payment made as part of a grant.',
#  'GreenComponent: Environmental or sustainability initiatives.',
#  'InitialSummary: Summary provided at the initial stage of application.',
#  'IsSME: Indicates whether the company qualifies as a Small and Medium Enterprise.',
#  'LegalForm: Legal structure or form of the company (e.g., LLC, Corporation).',
#  'LegalName: Legal registered name of the company.',
#  'MatchesGenerating: Indicates if the company is generating matches.',
#  'MatchingOrder: Order or priority for matching processes.',
#  'Name: Official name of the granter company.',
#  'OnboardingState: Current onboarding or registration status.',
#  'Opportunity: The funding opportunity for which the application was submitted.',
#  'AdditionalData: Additional miscellaneous data.',
#  'Owner: Reference to the owner profile of the company.',
#  'PersonLocation: A class representing geographic location information for persons.',
#  "PostCode: Postal code of the company's address.",
#  'PricingOption: Selected pricing option for the application.',
#  'ProfileCreator: The profile of the person who created the application.',
#  'RelatedOperations: Information about operations related to the company.',
#  'SaleConfirmed: Indicates whether the sale has been confirmed.',
#  "Shareholders: Information about the company's shareholders.",
#  'SocialSecurityID: Social security identifier associated with the company.',
#  'Source: Origin or source of the data.',
#  'StripeCustomerID: Stripe payment platform customer identifier.',
#  "SubscriptionID: Identifier for the company's subscription.",
#  'SuccessFee: Fee earned upon successful grant disbursement.',
#  'SuccessPaymentAmount: Amount paid upon successful grant.',
#  'TaxID: Tax identification number of the company.',
#  "TeamDescription: Description of the company's team or organizational structure.",
#  'Title: Title of the application.',
#  'LastUpdatedTimestamp: Timestamp when the application was last updated.',
#  'UpfrontPaymentAmount: Initial payment amount for the application.',
#  'WebsiteURL: Official website URL of the company.',
#  'Userless: Indicates if the company record is userless.',
#  "WebsiteData: Additional data or metadata from the company's website.",
#  'WhiteLabelID: Identifier for white-label configurations.',
#  'WriterMode: Mode of writing or submission for the application.',
#  'AdmissibleProjects: Types of projects eligible.',
#  'AgencyIdentifier: Identifier of the funding agency or body in the database.',
#  'AssistantID: Identifier for the assistant managing the record.',
#  'belongstoapplication: Associates the file with a specific granter application.',
#  'belongsToCompany: Associates a matchcheck with a specific granter company.',
#  "belongsToCompanyMemory: Associates an opportunity with a granter company's memory snippets.",
#  'belongstoeligibilitycriteria: Associates a matchcheck with a specific eligibility criteria.',
#  'BelongsToOpportunity: Associates a consortium with a specific opportunity.',
#  'belongstoProfile: Relationship linking the company to its owner profile.',
#  'belongstoSubscription: Relationship linking the company to its subscription.',
#  'belongstoWhitelabel: Relationship linking the company to its whitelabel configuration.',
#  'CodeName: A short code or abbreviation representing the file.',
#  'CompanyID: Foreign key linking to the granter company.',
#  'Content: Small text snippet stored as a vector for semantic context.',
#  'CoverImage: URL to the cover image associated with the record.',
#  'CrawlerDataID: Identifier for crawler data associated with the record.',
#  'CreatedAt: Timestamp indicating when the file was created.',
#  'CreatedByID: Identifier of the user or profile that created the record.',
#  'Currency: Currency used for financial figures.',
#  'EventDate: The date on which the timeline event occurs.',
#  'Description: Description of the partner type in default language.',
#  'EnglishDescription: Description of the partner type in English.',
#  'PortugueseDescription: Description of the partner type in Portuguese.',
#  'DifficultyLevel: Difficulty level of the opportunity.',
#  'DifficultyLevelFundamentation: Explanation of the difficulty level.',
#  'EligibilityCriteria: Criteria to determine eligibility.',
#  'EligibleExpenses: Expenses eligible for funding.',
#  'ExpectedSuccessRate: Projected success rate percentage.',
#  'FEValue: Financial or feature value associated with the record.',
#  'FinancialInformation: Financial details related to the opportunity.',
#  'FinancingRate: Interest or financing rate applicable.',
#  'ForceClosingSoon: Indicates if the opportunity is closing soon.',
#  'FormQuestions: Questions included in application forms.',
#  'FreeApplications: Number of free applications allowed.',
#  'fundamentation: Indicates the fundamentation or basis for the record.',
#  'fundedBy: Relation indicating that a project is funded by a specific grant.',
#  'ProvenanceforGranterOpportunity: Metadata describing the origin and history of the granter opportunity data.',
#  'belongstomatchgroup: Associates a granter matchcheck with its parent granter matchgroup.',
#  'GRIDID: Institutional identifier from the GRID.ac database.',
#  'activitydate: Date of activity related to the opportunity.',
#  'hasApplication: Links a company or consortium to its application.',
#  'hasAssociatedFile: Links an application or opportunity to its related files.',
#  'Column: Name of a column in the database table.',
#  'ColumnName: Name of a column in the database table.',
#  'CompanyID: Foreign key linking to the company involved.',
#  'ConsortiumID: Foreign key linking to the associated consortium.',
#  'CreatedAt: Timestamp when the record or file was created.',
#  'Description: Description of the database table or entity.',
#  'FileName: Name or identifier of the general opportunity file.',
#  'hasforeignkey: Foreign key relation associated with the table.',
#  'ForeignKeyRelation: Relation describing foreign key constraints for the table.',
#  'GeneralOpportunityFileID: References the associated Granter General Opportunity File.',
#  'hasgrant: Associates an opportunity with a specific grant.',
#  'hasgrantshare: Associates a project with its grant shares.',
#  'ID: Unique identifier for the Granter General Opportunity File Opportunities record.',
#  'haslegalform: Legal form of the company, e.g., LLC, Corporation.',
#  'haslegalname: Legal name of the granter company.',
#  'hasMemorySnippet: Associates a granter company with its semantic memory snippets.',
#  'hasname: Name of the database table or entity.',
#  'hasopportunityfile: Links an opportunity to its associated files.',
#  'OpportunityID: Foreign key referencing the associated opportunity.',
#  'hasPartner: Associates a consortium with its individual partners.',
#  "PartnerDescription: Description of the partner's role or attributes within the consortium.",
#  'PartnerTypeID: Foreign key indicating the type of partner role.',
#  'hasprimarykey: Primary key column(s) of the table.',
#  'hasProjectDescription: Description of the project associated with the consortium.',
#  'hasProjectDurationMonths: Duration of the project in months.',
#  'hasProjectMaxValue: Maximum project funding value.',
#  'hasProjectMinValue: Minimum project funding value.',
#  'hasProvenance: Associates a database table with its provenance information.',
#  'ProvenanceDetails: Details describing the provenance of the data.',
#  'HasProvenanceInfo: Associates provenance information with the general opportunity file for traceability.',
#  'hasrecipient: Associates a grant share with its recipient.',
#  'ReferenceColumn: Name of the referenced column in the foreign key relationship.',
#  'ReferenceTable: Name of the referenced table in a foreign key relationship.',
#  'hasState: Current state or status of the record.',
#  'Table: Name of the database table.',
#  'hasTimeline: Associates a consortium with its timeline information.',
#  'hastype: The type or category of the file.',
#  'UpdatedAt: Timestamp when the record or file was last updated.',
#  'hasuploadedfile: The file content or reference to the uploaded file.',
#  'hasvectorindexed: Indicates whether the file has been processed for vector indexing.',
#  'includesPartner: Associates a consortium with its partner companies.',
#  'InternalSubmission: Indicates if internal submission is permitted.',
#  'IsPrediction: Indicates whether the timeline event is a forecast or prediction.',
#  'LastEmailPush: Timestamp of the last email push.',
#  'LastEmailReminder: Timestamp of the last email reminder sent.',
#  'Location: Geographical location related to the opportunity.',
#  'Name: Human-readable name of the file.',
#  'Opportunity: Foreign key linking to the granter opportunity.',
#  'PreparationTime: Estimated preparation time in days.',
#  'ProjectDuration(Months): Duration of the project in months.',
#  'ProjectMaxValue: Maximum project funding value.',
#  'ProjectMinValue: Minimum project funding value.',
#  'ProvenanceInformation: Represents provenance annotations for tracking the origin and history of data elements.',
#  'recipient: The company or entity that receives a grant share.',
#  'relatesTo: Generic relation between database tables or entities.',
#  'relatestoCompany: Indicates a relation between an opportunity and a company.',
#  'relatestoConsortium: Links a partner to its consortium.',
#  'relatesToOpportunity: Indicates relationships between different funding opportunities.',
#  'relatestotable: Indicates the table that is referenced by the foreign key.',
#  'SmallCoverImage: URL to a smaller version of the cover image.',
#  'State: Current state or status of the record.',
#  'status: Status of the record, e.g., active, inactive.',
#  'SuccessFee: Fee payable upon successful grant acquisition.',
#  'TagsFundamentation: Explanation of associated tags.',
#  'EventTime: The specific time of the timeline event, if applicable.',
#  'TimeDifference: Duration or difference relative to a reference point, e.g., days until deadline.',
#  'Title: Title or name of the partner type in default language.',
#  'EnglishTitle: Title of the partner type in English.',
#  'PortugueseTitle: Title of the partner type in Portuguese.',
#  'Type: Semantic type or category of the partner type.',
#  'LastUpdatedTimestamp: Timestamp indicating the last time the file was updated.',
#  'UpfrontFee: Fee payable upfront for the opportunity.',
#  'uploadedfile: The actual file content or reference to the uploaded file.',
#  'URL: Link to related web resource.',
#  'VectorIndexed: Indicates whether the memory snippet is indexed as a vector.',
#  'wasDerivedFrom: Indicates the source from which the data element was derived.',
#  'Recipient: The receiver of a GrantPayment or receiver/beneficiary of a GrantShare.',
#  'GranterMatchGroup: The overall eligibility evaluation of a company for an opportunity, grouping multiple granter matchchecks.',
#  'GranterApplicationFile: Files associated with a specific granter application, providing contextual documentation.',
#  'Grant: A class representing a grant, funding, or financial support opportunity.',
#  'GrantShare: A class representing a portion or share of a grant allocated to an entity.',
#  'GranterGeneralOpportunityFileOpportunities: A class representing the association between opportunity files and specific opportunities.',
#  'GranterMatchcheck: Represents the eligibility result of a single company against a single eligibility criteria, belonging to a granter company and criteria, grouped into a granter matchgroup.',
#  'GranterOpportunityFile: Files associated with granter opportunities, providing contextual information.',
#  'Opportunity: A class representing a funding, tax incentive, investment, or loan opportunity.',
#  'ForeignKeyRelation: A class representing a foreign key relationship between database tables.',
#  'ProvenanceInfo: A class capturing provenance metadata for data elements.',
#  'GranterCompanyMemory: A class representing small text snippets stored as vectors for semantic context related to a company.',
#  'GranterConsortium: A class representing a consortium of companies or entities involved in grants.',
#  'GranterConsortiumPartner: A class representing a partner within a grant consortium.',
#  'GranterConsortiumPartnerType: A class representing the type or role of a partner within a consortium.',
#  'GranterOpportunity: Represents a funding opportunity such as a grant, tax incentive, investment, or loan.',
#  'GranterTimeline: Represents important dates and deadlines for an opportunity.',
#  'GranterGeneralOpportunityFile: A class representing files associated with funding opportunities.',
#  'GranterApplication: A class representing an application submitted for a funding opportunity.',
#  'GranterCompany: A commercial business entity that grants funding, grants, or other resources.',
#  'DatabaseTable: A class representing a database table in the schema.']

# %%
from rdflib import Graph, RDF, OWL

def extract_local_names(ttl_file_path):
    """
    Extract ontology elements (local names without full URIs).
    Returns:
        - class_names: ontology classes (entities)
        - object_property_names: ontology object properties (relationships)
        - datatype_property_names: ontology datatype properties (attributes)
    """
    g = Graph()
    g.parse(ttl_file_path, format="turtle")
    
    def get_local_name(uri):
        uri_str = str(uri)
        if '#' in uri_str: 
            return uri_str.split('#')[-1]
        return uri_str.split('/')[-1]
    
    # Classes
    class_uris = [s for s, _, _ in g.triples((None, RDF.type, OWL.Class))]
    class_names = [get_local_name(uri) for uri in class_uris]
    
    # Object properties
    object_prop_uris = [s for s, _, _ in g.triples((None, RDF.type, OWL.ObjectProperty))]
    object_property_names = [get_local_name(uri) for uri in object_prop_uris]
    
    # Datatype properties
    data_prop_uris = [s for s, _, _ in g.triples((None, RDF.type, OWL.DatatypeProperty))]
    datatype_property_names = [get_local_name(uri) for uri in data_prop_uris]
    
    return (
        sorted(class_names),
        sorted(object_property_names),
        sorted(datatype_property_names),
    )

# Usage
classes, relations, attributes = extract_local_names('../../output/ontologies/rdb/rigor_ontology_few_fixes.ttl')

print(f"Found {len(classes)} classes, {len(relations)} object properties, {len(attributes)} datatype properties")
print("\nClass names:", classes)
print("\nObject properties (relations):", relations)
print("\nDatatype properties (attributes):", attributes)
# Out:
# Found 26 classes, 43 object properties, 137 datatype properties
#
# Class names: ['DatabaseTable', 'ForeignKeyRelation', 'GeographicCriterion', 'Grant', 'GrantPayment', 'GrantShare', 'GranterApplication', 'GranterCompany', 'GranterCompanyMemory', 'GranterConsortium', 'GranterConsortiumPartner', 'GranterConsortiumPartnerType', 'GranterGeneralOpportunityFile', 'GranterGeneralOpportunityFileOpportunities', 'GranterMatchcheck', 'GranterMatchgroup', 'GranterOpportunity', 'GranterOpportunityFile', 'GranterTimeline', 'GrantersApplicationFile', 'Opportunity', 'PersonLocation', 'ProvenanceInfo', 'Recipient', 'granterCompanyMemory', 'provenanceInfo']
#
# Object properties (relations): ['CompanyId', 'ConsortiumId', 'OpportunityId', 'OwnerId', 'ProfileCreatorId', 'belongsToApplication', 'belongsToCompany', 'belongsToCompanyMemory', 'belongsToEligibilityCriteria', 'belongsToOpportunity', 'belongsToProfile', 'belongsToSubscription', 'belongsToWhitelabel', 'companyId', 'fundedBy', 'granter_matchgroup', 'hasApplication', 'hasAssociatedFile', 'hasCompanyId', 'hasConsortiumId', 'hasForeignKey', 'hasForeignKeyRelation', 'hasGeneralOpportunityFileId', 'hasGrant', 'hasGrantShare', 'hasMemorySnippet', 'hasOpportunityFile', 'hasOpportunityId', 'hasPartner', 'hasPartnerTypeId', 'hasProvenance', 'hasProvenanceInfo', 'hasRecipient', 'hasTimeline', 'includesPartner', 'opportunityId', 'recipient', 'relatesTo', 'relatesToCompany', 'relatesToConsortium', 'relatesToOpportunity', 'relatesToTable', 'wasDerivedFrom']
#
# Datatype properties (attributes): ['ActivityDate', 'Address', 'AgentLanguage', 'AiReviewState', 'AnnualRevenue', 'ApplicationId', 'ApplicationState', 'ApprovedGrantAmount', 'Cae', 'City', 'CodeName', 'CompanyId', 'Country', 'CoverImage', 'CreatedAt', 'Description', 'DigitalComponent', 'EmployeesNumber', 'ExtraInformation', 'FutureGoalsHr', 'FutureGoalsInfrastructure', 'FutureGoalsInternationalization', 'FutureGoalsMachineryAndEquipments', 'FutureGoalsMarketing', 'FutureGoalsRd', 'GreenComponent', 'InitialSummary', 'IsSme', 'LegalForm', 'LegalName', 'MatchesGenerating', 'MatchingOrder', 'Name', 'OnboardingState', 'OtherData', 'PostCode', 'PricingOption', 'RelatedOperations', 'SaleConfirmed', 'Shareholders', 'SocialSecurityId', 'Source', 'StripeCustomerId', 'SubscriptionId', 'SuccessFee', 'SuccessPaymentAmount', 'TaxId', 'TeamDescription', 'Title', 'UpdatedAt', 'UpfrontPaymentAmount', 'Url', 'Userless', 'WebsiteData', 'WhitelabelId', 'WriterMode', 'admissibleProjects', 'agencyIdentifier', 'assistantId', 'codename', 'companyId', 'content', 'coverImage', 'crawlerDataId', 'createdAt', 'createdById', 'currency', 'date', 'description', 'descriptionEn', 'descriptionPt', 'difficultyLevel', 'difficultyLevelFundamentation', 'eligibilityCriteria', 'eligibleExpenses', 'expectedSuccessRate', 'feValue', 'financialInformation', 'financingRate', 'forceClosingSoon', 'formQuestions', 'freeApplications', 'fundamentation', 'gridId', 'hasActivityDate', 'hasColumn', 'hasColumnName', 'hasContent', 'hasCreatedAt', 'hasDescription', 'hasFileName', 'hasId', 'hasLegalForm', 'hasLegalName', 'hasName', 'hasOpportunityId', 'hasPartnerDescription', 'hasPrimaryKey', 'hasProjectDescription', 'hasProjectDurationMonths', 'hasProjectMaxValue', 'hasProjectMinValue', 'hasProvenanceDetails', 'hasRefColumn', 'hasRefTable', 'hasState', 'hasTable', 'hasType', 'hasUpdatedAt', 'hasUploadedFile', 'hasVectorIndexed', 'internalSubmission', 'isPrediction', 'lastEmailPush', 'lastEmailReminder', 'location', 'name', 'prepTime', 'projectDurationMonths', 'projectMaxValue', 'projectMinValue', 'smallCoverImage', 'state', 'status', 'successFee', 'tagsFundamentation', 'time', 'timeDiff', 'title', 'titleEn', 'titlePt', 'type', 'updatedAt', 'upfrontFee', 'uploadedFile', 'url', 'vectorIndexed']

# %%
classes
# Out:
# ['DatabaseTable',
#  'ForeignKeyRelation',
#  'GeographicCriterion',
#  'Grant',
#  'GrantPayment',
#  'GrantShare',
#  'GranterApplication',
#  'GranterCompany',
#  'GranterCompanyMemory',
#  'GranterConsortium',
#  'GranterConsortiumPartner',
#  'GranterConsortiumPartnerType',
#  'GranterGeneralOpportunityFile',
#  'GranterGeneralOpportunityFileOpportunities',
#  'GranterMatchcheck',
#  'GranterMatchgroup',
#  'GranterOpportunity',
#  'GranterOpportunityFile',
#  'GranterTimeline',
#  'GrantersApplicationFile',
#  'Opportunity',
#  'PersonLocation',
#  'ProvenanceInfo',
#  'Recipient',
#  'granterCompanyMemory',
#  'provenanceInfo']

# %%
relations
# Out:
# ['CompanyId',
#  'ConsortiumId',
#  'OpportunityId',
#  'OwnerId',
#  'ProfileCreatorId',
#  'belongsToApplication',
#  'belongsToCompany',
#  'belongsToCompanyMemory',
#  'belongsToEligibilityCriteria',
#  'belongsToOpportunity',
#  'belongsToProfile',
#  'belongsToSubscription',
#  'belongsToWhitelabel',
#  'companyId',
#  'fundedBy',
#  'granter_matchgroup',
#  'hasApplication',
#  'hasAssociatedFile',
#  'hasCompanyId',
#  'hasConsortiumId',
#  'hasForeignKey',
#  'hasForeignKeyRelation',
#  'hasGeneralOpportunityFileId',
#  'hasGrant',
#  'hasGrantShare',
#  'hasMemorySnippet',
#  'hasOpportunityFile',
#  'hasOpportunityId',
#  'hasPartner',
#  'hasPartnerTypeId',
#  'hasProvenance',
#  'hasProvenanceInfo',
#  'hasRecipient',
#  'hasTimeline',
#  'includesPartner',
#  'opportunityId',
#  'recipient',
#  'relatesTo',
#  'relatesToCompany',
#  'relatesToConsortium',
#  'relatesToOpportunity',
#  'relatesToTable',
#  'wasDerivedFrom']

# %%
relations.remove('relatesToTable')
relations
# Out:
# ['CompanyId',
#  'ConsortiumId',
#  'OpportunityId',
#  'OwnerId',
#  'ProfileCreatorId',
#  'belongsToApplication',
#  'belongsToCompany',
#  'belongsToCompanyMemory',
#  'belongsToEligibilityCriteria',
#  'belongsToOpportunity',
#  'belongsToProfile',
#  'belongsToSubscription',
#  'belongsToWhitelabel',
#  'companyId',
#  'fundedBy',
#  'granter_matchgroup',
#  'hasApplication',
#  'hasAssociatedFile',
#  'hasCompanyId',
#  'hasConsortiumId',
#  'hasForeignKey',
#  'hasForeignKeyRelation',
#  'hasGeneralOpportunityFileId',
#  'hasGrant',
#  'hasGrantShare',
#  'hasMemorySnippet',
#  'hasOpportunityFile',
#  'hasOpportunityId',
#  'hasPartner',
#  'hasPartnerTypeId',
#  'hasProvenance',
#  'hasProvenanceInfo',
#  'hasRecipient',
#  'hasTimeline',
#  'includesPartner',
#  'opportunityId',
#  'recipient',
#  'relatesTo',
#  'relatesToCompany',
#  'relatesToConsortium',
#  'relatesToOpportunity',
#  'wasDerivedFrom']

# %% [markdown]
# # Input text

# %%
from langchain_core.documents import Document
import os

input_txt_folder = "data/texts"

# Import opportunity file 
for filename in os.listdir(input_txt_folder):
    if filename.endswith('opportunity_example.txt'):
        file_path = os.path.join(input_txt_folder, filename)
        print(f"Processing {filename}...")

        try:
            with open(file_path, 'r', encoding='utf-8') as file:
                content = file.read()
                print(type(content))
        except Exception as e:
            print(f"Error processing {filename}: {e}")

document = Document(page_content=content)
print(document)
# Out:
# Processing opportunity_example.txt...
# <class 'str'>
# page_content='Os Fundos Europeus mais próximos de si.
#
#
#           1/23
# Aviso para apresentação de  candidaturas
# Código do aviso   MAR2030 -2023 -22
# Data de publicação  14/11 /2023
# Natureza do aviso   Concurso
# Âmbito de atuação:  Operações
# Aprovado pelo SRMAR a 25/07/2023
#
#
# Designação do  aviso
# Transformação  de Produtos da Pesca e da Aquicultura no Domínio dos Investimentos Produtivos -  Região
# Autónoma da Madeira
#
# Apoio para
# Promover a comercialização, a qualidade, o valor acrescentado dos produtos da pesca e da aquicultura, assim
# como a transformação destes produtos .
# Ações abrangidas por este aviso
# São abrangidas pelo presente aviso as ações, promovidas por empresas, previstas no artigo 50.º da Portaria n.º
# 559/2023, de 25 de julho , relativas a :
# a) Investimentos produtivos bem como investimentos que promovam a descarbonização, o uso de energias
# renováveis e a eficiência energética, a economia circular, a digitalização e a internacionalização,
# b) Investimentos que promovam o empreendedorismo através do apoio à criação e desenvolvimento de start -
# ups e de spin -offs;
# c) Investimentos na certificação e na promoção de produtos da pesca e da aquicultura sustentáveis, incluindo
# os processos que culminam no registo de marcas ou de patentes;
# d) Investimentos que reduzam o impacto da atividade no ambiente;
# e) Desenvolvimento de estratégias de comercialização e internacionalização, incluindo as ações promocionais
# ou de prospeção e desenvolvimento de produto, que não se integram em ações organizadas pelas
# associações e organizações de produtores;  Os Fundos Europeus mais próximos de si.
#
#
#           2/23
# f) Inovação de marketing , que passe pela implementação de um novo método de marketing  com mudanças
# significativas no design do produto ou na sua embalagem, ou na sua promoção e distribuição;
# g) Iniciativas que promovam a diversificação do consumo, através da transformação de produtos de pesca
# relativos a espécies mais abundantes e com menor valor comercial;
# h) Promoção dos circuitos curtos de distribuição e comercialização.
# Podem ainda ser apoiados projetos em inovação em copromoção, desde que liderados por uma empresa, na
# aceção da al c) do nº.2 do artigo 23.º do DL 20 -A/2023 sendo:
# i) projetos desenvolvidos entre duas ou mais entidades independentes, que cooperam de forma estratégica
# e efetiva numa lógica de médio e longo prazo, partilhando infraestruturas, competências e recursos,
# incluindo recursos humanos, em função dos contributos específicos para os objetivos do projeto, visando
# o desenvolvimento das ações que integram o plano de atividades comum e a concretização das realizações
# e resul tados;
# ii) em que a empresa assume a função de entidade líder, sendo responsável por assegurar a coordenação
# geral do projeto e a interlocução com os vários copromotores e entre estes e a autoridade de gestão, no
# que diz respeito à gestão técnica, administrativa e fi nanceira do projeto;
# iii) em que deve ser estabelecido um acordo escrito, subscrito por todas as entidades que participam no
# projeto, que explicite o âmbito da cooperação entre as entidades envolvidas, a identificação da entidade
# líder, a responsabilidade conjunta entre as partes, o contributo individual de cada entidade para a
# concretização do projeto, assim como os termos da partilha de custos, riscos e resultados;
# iv) em que todas as entidades que integram o projeto são consideradas beneficiários, pelo que devem
# cumprir todos os requisitos de elegibilidade, obrigações e impedimentos dos beneficiários;
# e
# v) sendo os pagamentos realizados a todos os copromotores, ficando estes individualmente responsáveis
# pelas restituições dos apoios que tenham recebido e solidariamente responsáveis pela prossecução dos
# objetivos do projeto, bem como pelo cumprimento dos resultados .
#
# Entidades que se podem candidatar
# Podem beneficiar dos apoios previstos no presente aviso as PME cuja atividade se enquadre nas subclasses da
# CAE previstas no n.º 1 do artigo 52.º da Portaria n.º 559/2023, de 25 de julho :
# a) 10201 «Preparação de produtos da pesca e da aquicultura»;
# b) 10202 «Congelação de produtos da pesca e da aquicultura»;
# c) 10203 «Conservação de produtos da pesca e da aquicultura em azeite e outros óleos vegetais e outros molhos»;
# d) 10204 «Salga, secagem e outras atividades de transformação de produtos da pesca e da aquicultura»;
# e) 10411 «Produção de óleos e gorduras animais brutos, se relativa a produtos da pesca e da aquicultura»; e
# f) 10850 «Fabricação de refeições e pratos pré -cozinhados, se relativa a produtos da pesca e da aquicultura».
# No caso de operações realizadas em co -promoção, lideradas por uma PME, podem ainda ser beneficiárias as
# entidades identificadas no n.º 2 do artigo 52.º da Portaria n.º 559/2023, de 25 de julho : Os Fundos Europeus mais próximos de si.
#
#
#           3/23
# a) Instituições do ensino superior, seus institutos e unidades de I&D;
# b) Laboratórios do Estado ou internacionais com sede ou representação permanente em Portugal;
# c) Instituições privadas sem fins lucrativos que tenham como objeto principal atividades de I&D;
# d) Outras instituições públicas e privadas, sem fins lucrativos, que desenvolvam ou participem em atividades
# de investigação científica.
#
# Área geográfica abrangida
# Região Autónoma da Madeira
# Período de candidaturas
# De 14/11/ 2023 a 30/12/2027
# Dotação fundo  indicativa  disponível
#  neste avis o  Fundo e Taxa máxima de
# cofinanciamento
# 770 000 € FEAMPA (*)  70 %
# Programa financiador
# Programa MAR 2030
# Entidade gestora do apoio /Organismo Interm édio
# Coordenador Regional do Mar 2030 - Região Autónoma da Madeira
#
# Contactos para mais informações
# Linha dos Fundos 800 10 35 10 (09:00 -18:00h - gratuito)
# Correio eletrónico: linhadosfundos@linhadosfundos.pt
#
# Programa MAR 2030
# Telefone: + 351 291 203 250
# Correio eletrónico: drp@madeira.gov.pt   Os Fundos Europeus mais próximos de si.
#
#
#           4/23
# Finalidades e objetivos
# Promover a comercialização, a qualidade, o valor acrescentado dos produtos da pesca e da aquicultura, assim
# como a transformação destes produtos .
# Dotação
# Programa  Mar 2030
# Prioridade do
# Programa  2 - Fomentar atividades de aquicultura sustentáveis e a transformação e comercialização de
# produtos da pesca e da aquicultura, contribuindo assim para a segurança alimentar da União
# Objetivos
# específicos  FSO2.2 - Promover a comercialização, a qualidade e o valor acrescentado dos produtos da
# pesca e da aquicultura, assim como a transformação destes produtos
# Tipologia de
# ação  FSO2.2 -01-Investimentos produtivos na transformação
# FSO2.2.02 - Investimentos em eficiência energética, a economia circular, a digitalização e a
# internacionalização
# Tipologia de
# intervenção  FSO2.2 -01-01-Investimentos produtivos na transformação
# FSO2.2.02 -01 - Investimentos em eficiência energética, a economia circular, a digitalização e a
# internacionalização
# Tipologia de
# operação  8503 - Investimento na redução do consumo de energia e na eficiência energética
# 8504 - Investimento em sistemas de energias renováveis
# 8515 – Investimentos de apoio ao desenvolvimento de empresas (desenvolvimento de
# estratégias, administração, equipamento)
# 8517 - Desenvolvimento da inovação comercial
# 8518 - Desenvolvimento da inovação de processos
# 8519 - Desenvolvimento da inovação do produto
# 8510 – Utilização de capturas indesejadas
# 8548 – Consumo de água e melhoria da qualidade da água
# 8512 - Qualidade dos alimentos, segurança e higiene
# 8546 - Atividades de comercialização
# 8513 - Investimentos nas condições de trabalho
# Fundo  Dotação Fundo  Taxa Máxima  Dotação Nacional  Fonte de Financiamento
# Nacional disponível
# FEAMPA  770 000 € 100 % (*)  330 000 € Orçamento de
# Investimento
# Dotação Global  770 000 €  330 000 €
# (*) A taxa de apoio público é determinada de acordo com o estabelecido no artigo 56.º da Portaria n.º 559/2023, de 25 de julho.
#
# Enquadramento em instrumentos territoriais
# Não aplicável.
#
# Legislação nacional
# Tem política pública regulada ou contribui para uma Agenda ou Estratégia Nacional?
# ☐ Não
# ☒ Sim. Qual?  Os objetivos específicos prosseguidos são enformados pela Política Comum de Pescas e/ou pela Política Marítima integrada da União Europeia
#  Os Fundos Europeus mais próximos de si.
#
#
#           5/23
# Tem regulamento específico?
# ☐ Não
# ☒ Sim. Qual?  Portaria n.º 559/2023, de 25 de julho
#
# Ações elegíveis
# São elegíveis ao presente aviso as ações previstas no artigo 50 .º da Portaria n.º 559/2023, de 25 de julho :
# a) Investimentos produtivos bem como investimentos que promovam a descarbonização, o uso de energias
# renováveis e a eficiência energética, a economia circular, a digitalização e a internacionalização, incluindo
# os que:
# i) Melhorem o desempenho ambiental e climático;
# ii) Reforcem a segurança alimentar;
# iii) Promovam a introdução de novas espécies no mercado, designadamente através da valorização de
# pescado com menor valor comercial;
# iv) Promovam a transformação de subprodutos resultantes das principais atividades de transformação;
# v) Promovam a valorização de produtos da aquicultura;
# vi) Sendo inovadores, sejam promovidos por empresas ou em copromoção com universidades ou centros
# de investigação, desde que liderados pela empresa;
# vii) Promovam o uso de energias renováveis e a melhoria do desempenho energético, a otimização do uso
# dos recursos hídricos;
# viii) Promovam a utilização de embalagens de base biológica, biodegradável ou reciclável, ou outras
# iniciativas que reduzam a utilização de papel ou de plástico;
# ix) Contribuam para a redução do desperdício de alimentos, através da introdução de soluções inovadoras
# ao nível do processamento e comercialização do pescado;
# b) Promoção do empreendedorismo através do apoio à criação e desenvolvimento de start- ups e de spin -offs;
# c) Investimentos na certificação e na promoção de produtos da pesca e da aquicultura sustentáveis, incluindo
# os processos que culminam no registo de marcas ou de patentes;
# d) Investimentos que reduzam o impacto da atividade no ambiente;
# e) Desenvolvimento de estratégias de comercialização e internacionalização, incluindo as ações promocionais
# ou de prospeção e desenvolvimento de produto, que não se integram em ações organizadas pelas
# associações e organizações de produtores;
# f) Inovação de marketing, que passe pela implementação de um novo método de marketing com mudanças
# significativas no design do produto ou na sua embalagem, ou na sua promoção e distribuição;
# g) Iniciativas que promovam a diversificação do consumo, através da transformação de produtos de pesca
# relativos a espécies mais abundantes e com menor valor comercial;
# h) Promoção dos circuitos curtos de distribuição e comercialização .
#  Os Fundos Europeus mais próximos de si.
#
#
#           6/23
#
#
# Entidades beneficiárias  (incluindo destinatários, quando relevante)
# Podem ser beneficiárias dos apoios previstos no presente aviso as PME cuja atividade se enquadre nas subclasses
# da CAE previstas no número 1 do artigo 52 .º da Portaria n.º 559/2023, de 25 de julho :
# a) 10201 «Preparação de produtos da pesca e da aquicultura»;
# b) 10202 «Congelação de produtos da pesca e da aquicultura»;
# c) 10203 «Conservação de produtos da pesca e da aquicultura em azeite e outros óleos vegetais e outros
# molhos»;
# d) 10204 «Salga, secagem e outras atividades de transformação de produtos da pesca e da aquicultura»;
# e) 10411 «Produção de óleos e gorduras animais brutos, se relativa a produtos da pesca e da aquicultura»; e
# f) 10850 «Fabricação de refeições e pratos pré - cozinhados, se relativa a produtos da pesca e da aquicultura». .
# No caso de operações de inovação lideradas por uma PME e realizadas em copromoção, podem ainda ser
# beneficiários as entidades identificadas no n.º 2 do artigo 52. º da Portaria n.º 559/2023, de 25 de julho:
# a) Instituições do ensino superior, seus institutos e unidades de I&D;
# b) Laboratórios do Estado ou internacionais com sede ou representação permanente em Portugal;
# c) Instituições privadas sem fins lucrativos que tenham como objeto principal atividades de I&D;
# d) Outras instituições públicas e privadas, sem fins lucrativos, que desenvolvam ou participem em atividades
# de investigação científica .
#
# Condições específicas ou normas técnicas a observar pelos beneficiários ou operações
# No que se refere a beneficiários, sem prejuízo dos critérios de elegibilidade previstos no artigo 14 .º do Decreto -
# Lei n.º 20 -A/2023, de 22 de março , que estabelece o regime geral de aplicação dos fundos europeus do Portugal
# 2030 e dos critérios gerais definidos no artigo 5.º da Portaria n.º 559/2023, de 25 de julho , os beneficiários do
# presente aviso devem ainda cumprir os requisitos previstos no artigo 53.º da mesma Portaria .
# a) Serem detentores do estatuto de PME, com base em certificação do IAPMEI;
# b) Deterem autorização de instalação, no caso de construção de novos estabelecimentos;
# c) Possuírem licença de exploração e número de controlo veterinário, quando se trate da modernização de
# estabelecimentos existentes;
# d) Deterem autorização para alterações dos estabelecimentos que exijam licenciamento, nos casos aplicáveis;
# e) Apresentarem uma situação económico -financeira equilibrada.
# Para o efeito, considera -se existir uma situação económica e financeira equilibrada quando a autonomia
# financeira pré  -projeto seja igual ou superior a 15 %, tendo por base o último exercício encerrado à data da
# apresentação da candidatura.  Os Fundos Europeus mais próximos de si.
#
#
#           7/23
# A autonomia financeira é calculada a partir da seguinte fórmula:
# Autonomia financeira = CP / AT × 100
# em que:
# CP — capitais próprios da empresa, incluindo os suprimentos e ou empréstimos de sócios ou acionistas, desde
# que estes venham a ser incorporados em capital próprio até à data do primeiro pedido de pagamento;
# AT — ativo total da empresa.
# Relativamente aos beneficiários que, à data de apresentação da candidatura, não tenham desenvolvido qualquer
# atividade, ou não tenha ainda decorrido o prazo legal de apresentação do balanço e contas, bem como aos
# empresários em nome individual sem contabil idade organizada considera - se que possuem uma situação
# financeira equilibrada se suportarem com capitais próprios pelo menos 20 % do custo total do investimento.
# Os beneficiários podem comprovar os indicadores de autonomia financeira com informação mais recente, devendo para o efeito apresentar os respetivos balanços e demonstrações de resultados devidamente
# certificados por contabilista certificado.
# No que se refere a operações, sem prejuízo dos critérios de elegibilidade previstos no artigo 19.º do
# Decreto -Lei
# n.º 20 -A/2023, de 22 de março , e no artigo 6.º da Portaria n.º 559/2023, de 25 de julho , a elegibilidade das
# operações ao presente aviso está também sujeita ao cumprimento dos requisitos estabelecidos no artigo 51º da
# Portaria n.º 559/2023, de 25 de julho , devendo :
# a) Ser sustentadas por uma análise estratégica da empresa que identifique as áreas de competitividade críticas
# para o negócio em que se insere, diagnostique a situação da empresa nestas áreas críticas e fundamente as
# opções de investimento consideradas na candidatura;
# b) Ter um investimento elegível de valor igual ou superior a 10 000 euros, e um investimento total máximo de
# 20 milhões de euros ou de 4 milhões de euros no caso de estabelecimentos localizados na NUTS II Algarve;
# c) Demonstrar a viabilidade económico -financeira do projeto, sustentada em plano empresarial e, quando o
# investimento seja superior a 50 000 euros, num estudo de viabilidade;
# d) Demonstrar que se encontram asseguradas as fontes de financiamento, incluindo o financiamento por
# empréstimo bancário, quando necessário, devendo ser garantido um mínimo de 20 % de capitais próprios,
# que pode incluir novas entradas de capital, nomeadamente  capital social, incorporação de suprimentos e
# prestações suplementares de capital, desde que venham a ser incorporados em capital próprio ao longo da
# concretização do projeto e até à sua conclusão material e financeira;
# e) Demonstrar a existência de perspetivas sustentáveis para comercialização do produto no mercado,
# mediante relatório de comercialização independente, no caso de empresas com menos de um ano de
# atividade, ou, para as restantes empresas, com base na análise hi stórica dos clientes da empresa e da sua
# projeção após realização do projeto .
# Os beneficiários comprovam as informações contabilísticas com base no último exercício encerrado à data de
# apresentação da candidatura, podendo ser usada informação mais recente, devendo para o efeito apresentar os
# respetivos balanços e demonstrações de re sultados devidamente certificados por um contabilista certificado.
# Considera -se que se encontram asseguradas as fontes de financiamento nas operações apresentadas pelas
# entidades que participam nos projetos em copromoção, que não as empresas, quando o valor do investimento
# se encontre previsto em orçamento ou quando exist a declaração emitida pelo beneficiário da sua inscrição em
# anos futuros .  Os Fundos Europeus mais próximos de si.
#
#
#           8/23
#
# Modalidade de apresentação
# de candidaturas  Número máximo
# de candidaturas  Duração
# das operações
# Individualmente ou em
# copromoção  Uma por operador económico  2 anos
#
# Condições de atribuição de financiamento da operação
# A taxa de apoio público para as operações é de até :
# a) 75 % no caso de start -ups e spin-offs ou em projetos em copromoção  destinados a introduzir produtos,
# processos ou equipamentos inovadores na empresa;
# b) 100 % das despesas elegíveis, no caso de operações em que o beneficiário é um organismo público;
# c) 50 % das despesas elegíveis, nos demais casos .
# Sempre que uma operação possa ser enquadrada em mais do que uma das alíneas do número anterior, aplica -se
# a taxa máxima de apoio mais elevada.
# Devem ser cumpridas as condições fixadas relativas ao enquadramento do beneficiário e da candidatura no
# âmbito do presente Aviso bem como as obrigações e as condições gerais e específicas de elegibilidade do beneficiário e das operações, definidas na legis lação em vigor, nomeadamente, no Regulamento (UE) 2021/1060
# do Parlamento Europeu e do Conselho, de 24 de junho, no Decreto -Lei nº 20 -A/2023. de 22 de março, que
# estabelece o regime geral de aplicação dos fundos europeus do Portugal 2030 e na Portaria n.º 559/2023, de 25 de julho , que adota o Regulamento específico das medidas de apoio do Programa Mar 2030  na Região Autónoma
# da Madeira.
#
#
# Auxílios de Estado
# ☐ Aplicável?  Enquadrar:                       ☐ Regulamento Geral de Isenção de Categoria
#   ☐ Auxílio s de minimis
#   ☐ Notificação à Comissão Europeia
#   ☐ Serviço de Interesse Econ ómico Geral
#
# ☒
#  Não Aplicável?  Fundamentar:
# Excecionado ao abrigo do disposto no n.º 2 do art.º 10º Regulamento (UE) n.º
# 1139/2021 do Parlamento Europeu e do Conselho de 7/07/2021
# Formas de apoios
# ☒ Subvenção  Os Fundos Europeus mais próximos de si.
#
#
#           9/23
#  ☒ Custos reais
#
#  ☐ Custos Unitários  ☐ Em programa  Data da decisão  00-00-0000
#    ☐ Nacional  Deliberação CIC nº  XXXXXX
#
#  ☐ Montantes Fixos  ☐ Em programa  Data da decisão  00-00-0000
#    ☐ Nacional  Deliberação CIC nº  XXXXXX
#
#  ☒ Taxa Fixa  40 % da taxa  Artigo  56.º RDC
#
#  ☐ Financiamento não associado a custos  Data da decisão  00-00-0000
#
# ☐ Instrumento financeiro
#
# Custos elegíveis
# Sem prejuízo do disposto no artigo 20.º do Decreto -Lei n.º 20 -A/2023, de 22 de março  e do disposto no artigo 8.º
# da Portaria n.º 559/2023, de 25 de julho , são elegíveis para efeitos de apoio público ao presente aviso, as despesas
# diretamente relacionadas com a atividade apoiada, identificadas no artigo 54 .º da mesma Portaria :
# a) Construção, modernização ou adaptação de edifícios e instalações;
# b) Aquisição de edifícios ou instalações, com exceção do valor correspondente ao terreno;
# c) Vedações e preparação de terrenos;
# d) Sistemas e equipamentos necessários ao processo de preparação, transformação, tratamento,
# conservação, acondicionamento e embalagem, armazenagem, comercialização, rastreabilidade e rotulagem de produtos da pesca e da aquicultura;
# e) Equipamentos e meios para movimentação interna e pesagem;
# f) Sistemas e equipamentos para o fabrico e silagem de gelo, destinado ao uso exclusivo da atividade do estabelecimento;
# g) Sistemas e equipamentos destinados à verificação, controlo e certificação da qualidade e rastreabilidade
# dos produtos da pesca e da aquicultura;
# h) Sistemas ou equipamentos destinados ao armazenamento, transformação e comercialização de
# subprodutos e de desperdícios dos produtos da pesca e da aquicultura;
# i) Sistemas ou equipamentos para deteção ou extração de substâncias perigosas para a saúde, da farinha de peixe ou do óleo de peixe, mesmo que os produtos finais sejam utilizados para outros fins que não o
# consumo humano;
# j) Sistemas e equipamentos de sinalização, segurança, deteção e combate a incêndios, gestão informatizada
# da atividade produtiva, bem como equipamento telemático;
# k) Sistemas e equipamentos de redes de água salubre, saneamento, comunicações, eletricidade e combustíveis;  Os Fundos Europeus mais próximos de si.
#
#
#           10/23
# l) Automatização de sistemas ou equipamentos já existentes no estabelecimento, ou adoção de aplicações
# que restrinjam a utilização de papel ou de plástico, sendo também elegíveis as auditorias de gestão realizadas com esta finalidade;
# m) Aquisição de equipamentos e sistemas informáticos e telemáticos, incluindo a adoção de Enterprise Resources Planning (ERP) ;
# n) Construção de estações de pré -tratamento de águas residuais (EPTAR) ou de estações de tratamento de
# águas residuais (ETAR), bem como instalação dos respetivos sistemas e equipamentos;
# o) Despesas relativas ao desenvolvimento de aplicações dirigidas à realização de vendas on -line, bem como
# relativas à aquisição do hardware  e software informático que se revelem adequadas a esta finalidade;
# p) Apenas no caso da construção de novos estabelecimentos produtivos, instalações e equipamentos sociais que melhorem a qualidade das condições de trabalho das instalações;
# q) Aquisição de veículos aprovados e certificados nos termos do Acordo Internacional de Transporte de
# Produtos Perecíveis sob Temperatura Dirigida, e aquisição de veículos comerciais ligeiros de emissões nulas,
# equipados com contentores isotérmicos para trans porte e armazenamento de pescado;
# r) Conceção e registo de marcas incluindo a criação de marcas próprias, a melhoria de design na apresentação e embalagem dos produtos;
# s) Aquisição de equipamentos ou sistemas para acondicionamento e embalagem;
# t) Despesas de auditoria e consultoria especializada, de consultoria e elaboração ou de acompanhamento da candidatura, a fiscalização de obras, desde que realizada por uma entidade externa ao beneficiário e ao
# construtor, as despesas de preparação do licencia mento, nas quais se incluem estudos e projetos técnico -
# económicos ou de impacte ambiental, excluindo -se destes, o pagamento de escrituras, taxas ou
# emolumentos;
# u) Custo com a contratação de um máximo de dois novos quadros técnicos por micro ou pequena empresa,
# com nível de qualificação igual ou superior a 6, correspondente a licenciatura, nos termos definidos na Portaria n.º 782/2009, de 23 de julho, na medida em qu e sejam utilizados no projeto;
# v) Despesas com formação profissional diretamente relacionadas com o objeto e os objetivos da operação.
# Nas operações realizadas em co -promoção, as despesas elegíveis relativas aos beneficiários parceiros previstos
# no n.º 2 do artigo 52.º da Portaria n.º 559/2023, de 25 de julho
# , são as que se encontram identificadas na alínea
# b) do n.º 2 do artigo 55.º da mesma Portaria, isto é os custos diretos com pessoal, a que acresce uma taxa fixa de
# 40 % dos custos elegíveis diretos com pessoal, para cobrir todos os restantes custos elegívei s da operação. Os
# custos diretos com pessoal são financiados com  recurso a uma taxa horária calculada para cada operação, de
# forma objetiva, dividindo os custos anuais brutos do trabalho registados no ano civil anterior ao do pedido de
# apoio por 1720 horas, de acordo com as seguintes regras:
# 1) Os custos anuais são documentados com base numa relação dos trabalhadores da entidade beneficiária, organizada por categoria profissional/perfil funcional, com referência de remuneração base, subsídio de férias, subsídio de Natal, aos quais se aplica o lim ite correspondente ao valor das remunerações definido na
# tabela remuneratória aplicada à Administração Pública, acrescido de subsídio de refeição e contribuições
# obrigatórias;
# 2) Uma vez obtida a taxa horária para cada categoria profissional/perfil funcional de recurso humano afeto
# pelo beneficiário à operação, a mesma é multiplicada pelo número de horas correspondentes a essa
# afetação, obtendo - se assim o custo elegível para fins de cofinanciamento.
#  Os Fundos Europeus mais próximos de si.
#
#
#           11/23
#
# Regras ou limites específicos à elegibilidade de despesa (Quando aplicável)
# 1. A elegibilidade das despesas tem início a partir de 1 de janeiro de 2021, conforme exceção prevista na alínea
# a) do n.º 2 do artigo 8.º da Portaria n.º 559/2023, de 25 de julho .
# 2. Os custos elegíveis com a contratação de até dois novos quadros técnicos, aplicável às micro e pequenas empresas apoiadas e previstos na alínea u) do artigo 54.º da Portaria n.º 559/2023, de 25 de julho
# , são
# determinados de acordo com os requisitos estabelecidos no ponto 2 do mesmo artigo 54.º, estabelecendo -se
# como limite máximo para efeitos do presente aviso, um salário base de 1.600 € (mil e seiscentos euros) .
# 3. Para efeitos de cumprimento da condição prevista na alínea e) do n.º 2 do Artigo 54.º da Portaria n.º 559/2023,
# de 25 de julho , considera -se criação líquida de postos de trabalho a aumento líquido do número de
# trabalhadores diretamente empregados na entidade beneficiária, calculado pela diferença entre o número de trabalhadores no momento da apresentação do último pedido de pagamento e a média mensal do número de trabalhadores nos seis meses anteriores à data da apresentação da candidatura, a demonstrar através dos mapas de remunerações da segurança social, e desde que reúna cumulativamente as seguintes condições :
# i) Ter por base a celebração de contrato de trabalho escrito entre a entidade beneficiária e o trabalhador;
# ii) Os trabalhadores a contratar não terem tido vínculo laboral com a entidade beneficiária ou entidades parceiras ou associadas destas, durante os 12 meses anteriores à data de apresentação da candidatura;
# iii) Não corresponder a postos de trabalho de gerentes, administradores e ou sócios da entidade beneficiária ;
# iv) Os postos de trabalho criados estarem diretamente associados ao desenvolvimento da operação objeto de apoio.
# 4. As despesas previstas na alínea q) do n.º 1 do artigo 54.º da Portaria n.º 559/2023, de 25 de julho
# , relativas a
# aquisição de veículos, estão limitadas a 20% das restantes despesas elegíveis ;
# 5. As despesas previstas na alínea t) do n.º 1 do artigo 54.º da  Portaria n.º 559/2023, de 25 de julho , relativas a
# auditoria e consultoria especializada, de consultoria e elaboração ou de acompanhamento da candidatura, de fiscalização de obras, as
#  despesas de preparação do licenciamento, nas quais se incluem estudos e projetos
# técnico -económicos ou de impacte ambiental, estão limitadas a 6% das restantes despesas elegíveis ;
# 6. Nas operações realizadas em co -promoção, as despesas realizadas pelas entidades parceiras estão limitadas
# aos custos unitários e taxas fixas apurados de acordo com o estabelecido na alínea b) do número 2 do artigo 55.º da  Portaria n.º 559/2023, de 25 de julho
# .
# Formas de pagamento  ☒ Adiantamentos %  ☒ Reembolso  ☒ Contra fatura
# Os pagamentos ao projeto são efetuados de acordo com o estabelecido no artigo 10.º da Portaria n.º 559/2023,
# de 25 de julho .
# No presente Aviso, os pagamentos aos beneficiários são efetuados a título de adiantamento (adiantamento
# inicial até 10%, adiantamento contra fatura e adiantamento contragarantia), reembolso e/ou pagamento final).
# O pedido de pagamento final, não pode ser inferior a 5% do valor do apoio aprovado e deve ser apresentado à respetiva Autoridade de Gestão até 90 dias úteis a contar da data da conclusão da operação, podendo este prazo ser prorrogado mediante justificação fundamentada a apresentar à Autoridade de Gestão ou Organismo
# Intermédio com funções de gestão atribuídas .
#  Os Fundos Europeus mais próximos de si.
#
#
#           12/23
#
# Indicadores de realização
# Programa  MAR 2030
# Tipologia de  intervenção  FSO2.2 -01-01-Investimentos produtivos na transformação
# FSO2.2.02 -01 - Investimentos em eficiência energética, a economia circular, a
# digitalização e a internacionalização
# Tipologia de  operação  8503 - Investimento na redução do consumo de energia e na eficiência energética
# 8504 - Investimento em sistemas de energias renováveis
# 8515 – Investimentos de apoio ao desenvolvimento de empresas (desenvolvimento
# de estratégias, administração, equipamento)
# 8517 - Desenvolvimento da inovação comercial
# 8518 - Desenvolvimento da inovação de processos
# 8519 - Desenvolvimento da inovação do produto
# 8510 – Utilização de capturas indesejadas
# 8548 – Consumo de água e melhoria da qualidade da água
# 8512 - Qualidade dos alimentos, segurança e higiene
# 8546 - Atividades de comercialização
# 8513 - Investimentos nas condições de trabalho
# Código  do indicador  Designação  do indicador  Unidade
# CO01  Operações aprovadas  N.º
# Descrição  O indicador reporta a quantificação das operações que contribuem para o alcance da
# tipologia de intervenção
# Método de cálculo  Somatório simples
#
# Indicadores de resultado
# Program a MAR 2030
# Tipologia de  intervenção  FSO2.2 -01-01-Investimentos produtivos na transformação
# FSO2.2.02 -01 - Investimentos em eficiência energética, a economia circular, a
# digitalização e a internacionalização
# Tipologia de  operação  8503 - Investimento na redução do consumo de energia e na eficiência energética
# 8504 - Investimento em sistemas de energias renováveis
# 8515 – Investimentos de apoio ao desenvolvimento de empresas (desenvolvimento de
# estratégias, administração, equipamento)
# 8517 - Desenvolvimento da inovação comercial
# 8518 - Desenvolvimento da inovação de processos
# 8519 - Desenvolvimento da inovação do produto
# 8510 – Utilização de capturas indesejadas
# 8548 – Consumo de água e melhoria da qualidade da água
# 8512 - Qualidade dos alimentos, segurança e higiene
# 8546 - Atividades de comercialização
# 8513 - Investimentos nas condições de trabalho
# Código  do indicador  Designação  do indicador  Unidade
# CR14  Inovações possibilitadas  N.º de inovações  Os Fundos Europeus mais próximos de si.
#
#
#           13/23
# Descrição  Número de inovações implementadas ou testadas para novos produtos, serviços,
# processos , modelos de negócio  ou métodos de produção.
# Método de cálculo  O beneficiário deverá identificar na candidatura o número de inovações a gerar pela
# realização da operação , desagregando o n.º de novos produtos, o n.º de novos
# processos, n .º de novos modelos de negócio  ou n .º de novos métodos de produção
# Resultado a ser verificado em sede de avaliação no final da operação .
#
# Program a Mar 2030
# Tipologia de  intervenção  FSO2.2 -01-01-Investimentos produtivos na transformação
# FSO2.2.02 -01 - Investimentos em eficiência energética, a economia circular, a
# digitalização e a internacionalização
# Tipologia de  operação  8503 - Investimento na redução do consumo de energia e na eficiência energética
# 8504 - Investimento em sistemas de energias renováveis
# 8515 – Investimentos de apoio ao desenvolvimento de empresas (desenvolvimento de
# estratégias, administração, equipamento)
# 8517 - Desenvolvimento da inovação comercial
# 8518 - Desenvolvimento da inovação de processos
# 8519 - Desenvolvimento da inovação do produto
# 8510 – Utilização de capturas indesejadas
# 8548 – Consumo de água e melhoria da qualidade da água
# 8512 - Qualidade dos alimentos, segurança e higiene
# 8546 - Atividades de comercialização
# 8513 - Investimentos nas condições de trabalho
# Código  do indicador  Designação  do indicador  Unidade
# CR17  Entidades que melhorem a eficiência dos recursos na
# produção e/ou na transformação  N.º
# Descrição  Número de operadores ou empresas que introduzam tecnologias ou processos que
# poupem recursos, incluindo a conversão para energias renováveis ou o aumento da
# eficiência através da redução do consumo de água, isolamento térmico ou reutilização
# de matérias anteriorment e consideradas como desperdício .
# Método de cálculo  Identificação por parte do beneficiário no âmbito do formulário da sua candidatura de
# que a operação irá resultar num aumento da eficiência, identificando as áreas onde se perspetivam melhorias de eficiência de recursos (por exemplo energia, água,
# emissões, resíduos, outros a especificar). Resultado a ser verificado em sede de
# avaliação no final da operação .
#
#
# Program a Mar 2030
# Tipologia de  intervenção  FSO2.2 -01-01-Investimentos produtivos na transformação
# Tipologia de  operação  8510 – Utilização de capturas indesejadas
# 8512 - Qualidade dos alimentos, segurança e higiene
# 8546 - Atividades de comercialização
# 8513 - Investimentos nas condições de trabalho
# Código  do indicador  Designação  do indicador  Unidade  Os Fundos Europeus mais próximos de si.
#
#
#           14/23
# CR04    Empresas com volume de negócios mais elevado  N.º empresas
# Descrição  O indicador recolhe o volume de negócios antes da realização do projeto e o volume
# de negócios previsto após a realização do projeto /ano cruzeiro .
# Método de cálculo  O beneficiário identifica na candidatura o volume de negócios antes da realização do
# projeto e o volume de negócios previsto após a realização do projeto/ano cruzeiro
# Esta previsão é verificada e avaliada no final da operação/ano cruzeiro .
#
# Program a Mar 2030
# Tipologia de  intervenção  FSO2.2.02 -01 - Investimentos em eficiência energética, a economia circular, a
# digitalização e a internacionalização
# Tipologia de  operação  8503 - Investimento na redução do consumo de energia e na eficiência energética
# 8504 - Investimento em sistemas de energias renováveis
# 8517 - Desenvolvimento da inovação comercial
# 8548 – Consumo de água e melhoria da qualidade da água
# Código  do indicador  Designação  do indicador  Unidade
# CR18.1 Consumo de energia conducente à redução das emissões de
# CO2  kWh por tonelada
# produzida
# Descrição  Considerando o objetivo de r edução das emissões de CO2 , este indicador mede o
# consumo de energia por tonelada produzida antes e depois da realização do
# investimento.
# Método de cálculo  O beneficiário identifica na  candidatura o consumo em kWh por tonelada produzida ,
# para a mesma capacidade produtiva, existente antes e após a realização dos
# investimentos que visem a eficiência energética  e a economia circular . Os valores
# estimados em candidatura serão analisados e m sede de avaliação no final da
# operação .
#
# Consequências do incumprimento dos indicadores
# A execução parcial da operação face aos objetivos e resultados aprovados, aferida pelo não alcance das metas
# definidas na decisão de aprovação do apoio público para os indicadores de resultados do projeto, constitui
# fundamento para redução do apoio público exceto quando esse incumprimento decorra de factos não imputáveis
# ao beneficiário.
# Consideram -se cumpridos os indicadores de resultado contratualizados na aprovação do Financiamento, quando
# a percentagem de cumprimento for igual ou superior a 70 % do contratualizado.
# Abaixo desse limiar será aplicada uma redução no apoio publico proporcional à percentagem de incumprimento,
# de acordo com o seguinte :
# • Aplicação de uma penalização de 0,5 p.p na taxa de apoio público, por cada ponto percentual abaixo do
# limiar do cumprimento de cada um dos indicadores contratualizados;
# • A redução da taxa de apoio publico resultante da aplicação da penalização referida no ponto anterior, para
# a totalidade dos indicadores que incumpriram, está limitada a 5 p.p.  Os Fundos Europeus mais próximos de si.
#
#
#           15/23
# Sem prejuízo das penalizações na taxa de apoio público decorrentes do incumprimento dos resultados
# contratualizados, as operações que não atinjam os objetivos essenciais previstos na aprovação do Financiamento,
# pondo em causa as finalidades que determinara m a sua aprovação, podem ser objeto de revogação nos termos
# da alínea b) do n.º 4 do artigo 33.º do  Decreto -Lei n.º 20 -A/2023, de 22 de março .
# Nos termos do n.º 3 do artigo 57 .º da Portaria n.º 559/2023, de 25 de julho , no caso de operações enquadráveis
# na tipologia de copromoção, os beneficiários parceiros devem a presentar, no pedido de pagamento de saldo
# final, uma autoavaliação qualitativa das realizações e resultados atingidos, nos termos do disposto no n.º 2 do
# artigo 22.º do Decreto -Lei n.º 20 -A/2023, de 22 de março .
#
# Mecanismos de bonificação (Quando aplicável)
# Não Aplicável
# Critérios de seleção das operações aprovados em : 21/03/2023
#
# Obrigações dos beneficiários em matéria de notoriedade, transparência e comunicação
# Constituem obrigações dos beneficiários dar a conhecer o apoio do FEAMPA às operações , nos seguintes termos :
# Para todas as operações :
# 1. nos sítios na internet e nas redes sociais dos Beneficiários, através dos emblemas financiadores – do
# Programa, do PT 2030 e da União Europeia - , que devem encontrar -se permanentemente visíveis na página
# de abertura, devendo ainda ser assegurada a disponibilização da descrição da operação apoiada, com
# elementos audiovisuais de apoio;
# 2. nos edificados, equipamentos ou ações imateriais: aposição dos emblemas financiadores nos próprios equipamento ou materiais impressos, com visibilidade e legibilidade adequadas;
# Para operações:
# 1. cujo custo elegível financiado seja superior a 500 mil €: realização de um vídeo, com duração não inferior a um minuto, para apresentação da operação, seus objetivos e resultados, com cedência de direitos de autor à autoridade de gestão, podendo a reali zação do vídeo ser elegível em moldes a definir em sede de
# aviso para a apresentação da candidatura;
# 2. superiores a 10 milhões de € ou consideradas de importância estratégica, deve ser organizada pelo
# Beneficiário uma atividade de comunicação: organização de uma atividade de comunicação.
#
#
# Outras e ntidades que intervêm no processo
# Direção Regional de Pescas (DRP), da Região Autónoma da Madeira, no âmbito das suas competências enquanto
# organismo intermédio do Programa Mar 2030
# Instituto de Financiamento da Agricultura e Pescas, IP
#  Os Fundos Europeus mais próximos de si.
#
#
#           16/23
# Processo de admissão e seleção das candidaturas
# Aprese ntação
# Como se apresentam
# As candidaturas são apresentadas:
# • online no Balcão dos Fundos em balcaofundosue.pt
# Vai precisar de preencher o formulário de candidatura e entregar os documentos listados em Anexo A
# – Candidatura > Documentos necessários para apresentar uma candidatura
#
# Quais são os critérios de seleção
# As candidaturas são selecionadas com base numa avaliação de mérito do projeto (MP), que resulta da aplicação
# da seguinte fórmula :
# MP = 0,4 x AT + 0,6 x AE
# Em que:
# MP = pontuação final; AT = apreciação técnica; AE = apreciação estratégica
# Na AT é avaliada a valia financeira do investimento a realizar, através do valor da Taxa Interna de Rendibilidade em relação à REFI.
# Na AE é avaliado o mérito da operação através de pontuação dos efeitos esperados do projeto na
# competitividade da empresa, na eficiência e descarbonização e na economia nacional.
# A pontuação da AT e da AE pode atingir um máximo de 100 pontos .
# A AT é pontuada de 0 a 100 pontos de acordo com a taxa interna de rendibilidade (TIR) da operação sendo
# pontuada de acordo com a seguinte tabela :
# TIR Pontuação
# TIR < REFI  0
# TIR = REFI  50
# REFI < TIR ≤ REFI + 2  65
# REFI + 2 < TIR ≤ REFI + 4  80
# TIR > REFI + 4  100
# A REFI é a taxa de refinanciamento do Banco Central Europeu em vigor no 1.º dia útil de cada mês
# correspondente à apresentação ou reformulação da candidatura
# A AE é efetuada de acordo com as seguintes alíneas, podendo atingir um máximo de 100 pontos:
# a) Pontuação relativa à dimensão da empresa
# Start up ou spin -off - 50 pontos;
# Micro e pequena empresa - 40 pontos;
# Média empresa -  30 pontos.
# b) À pontuação prevista na alínea anterior acrescem as seguintes majorações que são atribuídas sempre que a operação preveja intervenções relacionadas com o parâmetro em causa:  Os Fundos Europeus mais próximos de si.
#
#
#           17/23
# Efeito do
# projeto
# na Parâmetros  10 pontos  6 pontos
# Competitividade
# da empresa  Diversificação da oferta  O projeto dá lugar à criação de
# pelo menos um novo produto
# com utilização de uma nova
# espécie de peixe  O projeto dá lugar à criação
# de um novo produto ou de
# produto(s) melhorado(s) a partir das espécies de peixe já utilizadas pela empresa
# ou de novas formas de
# apresentação dos produtos
# Qualificação da
# gestão  O projeto prevê a realização de
# ações de formação dirigidas à
# melhoria das competências
# profissionais em matéria de
# gestão empresarial  O projeto prevê a
# realização de investimentos que melhorem as condições de trabalho dos
# seus profissionais
# (investimentos em áreas sociais - dentro da unidade
# produtiva -, em
# climatização, ou na mecanização de processos
# manuais)
# Eficiência e descarbonização  Eficiência no uso de recursos  O projeto prevê investimentos relativos à reutilização de desperdícios gerados na própria
# empresa  O projeto prevê
# investimentos que reduzem
# os impactes negativos no ambiente gerados pela
# atividade
# O projeto prevê investimentos
# que aumentem a eficiência no uso de recursos naturais (ex. a água)
# ou que reduzam a poluição
# Digitalização  O projeto prevê investimentos
# relativos à digitalização do processo produtivo (entendendo -
# se a produção como incluindo a comercialização, podendo
# envolver quer os fornecedores
# quer os clientes através do
# comércio on -line)  O projeto prevê investimentos relativos à digitalização em qualquer uma das restantes áreas da empresa
# Descarbonização  O projeto prevê investimentos
# que tenham por objetivo a
# descarbonização  O projeto prevê outros
# investimentos que
# aumentem a eficiência no
# uso de energias renováveis
# (ex. painéis solares)
# Economia  Reforço da segurança alimentar  Aumento em 20% ou mais da capacidade de produção da empresa no pré -projeto
# Aumento em mais de 10% e
# menos de 20% da capacidade de produção no
# pré-projeto  Os Fundos Europeus mais próximos de si.
#
#
#           18/23
# Efeito do
# projeto
# na Parâmetros  10 pontos  6 pontos
# Impacto noutras
# PME do sector da pesca  Valorização de produtos da pesca
# de baixo valor comercial
# ou
# Valorização de produtos da
# aquicultura
# Dinamização das exportações  Após a realização do projeto a produção global prevista destina -
# se em 40%, ou mais, à exportação  Após a realização do
# projeto a produção global prevista destina -se pelo
# menos em 10% até 40%, à
# exportação
# Diversificação dos
# mercados
# internacionais  Diversificação dos mercados
# internacionais de destino (mais de um novo país de destino no
# mercado internacional ou um país
# de destino que não integre a lista dos principais países de destino
# das exportações portuguesas) *  Diversificação dos mercados internacionais de
# destino (um novo país de
# destino no mercado internacional)
# À pontuação desta tabela acrescem 10 p.p. caso se trate de introduzir inovação a nível da empresa
# * aferido com base no Relatório Anual do INE -  Estatísticas da Pesca –  disponível em
# www.ine.pt/xportal/xmain?xpid=INE&xpgid=ine_publicacoes&PUBLICACOEStipo=ea&PUBLICACOEScoleccao=10
# 7656&selTab=tab0&xlang=pt
# Não podem ser objeto de seleção as operações cuja classificação final do Mérito do projeto seja inferior a 50
# pontos. Adicionalmente, são excluídas as candidaturas que não obtenham no mínimo 50 pontos em cada uma
# das Apreciações técnica e estratégica.
# Caso exista uma insuficiente dotação fixada no Aviso de abertura de candidaturas, face aos pedidos de apoio, as
# candidaturas são ainda avaliadas de acordo com o seu mérito relativo, que resulta da comparação entre o mérito
# da operação e o mérito das demais  operações candidatas na mesma fase de decisão, com hierarquização final
# das candidaturas avaliadas, para efeitos de decisão de financiamento.
# Em caso de igualdade pontual, o critério de desempate é o da pontuação obtida no critério de seleção relativo à
# Apreciação Estratégica. Mantendo -se o empate, na pontuação obtida, é, então, utilizada a data de apresentação
# da candidatura prevalecendo as que  tenham sido primeiramente apresentadas .
#
#   Os Fundos Europeus mais próximos de si.
#
#
#           19/23
# Como funciona o processo de análise e decisão das candidaturas
#
# Calendário de candidaturas
#
# Abertura  14-11-2023
# Fecho  30-12-2027
# Analise  60 dias após receção candidatura
# Data Limite para a comunicação da decisão aos candidatos  65 dias após a apresentação da
# candidatura  (*)
# (*) não inclui o prazo legalmente previsto para audiência de interessados
#
# Processo de análise e decisão
# O processo de decisão das candidaturas integra quatro fases:
# i) Verificação das condições de elegibilidade dos beneficiários previstas na regulamentação aplicável aos
# Fundos Europeus e no presente aviso.
# ii) Verificação dos critérios de elegibilidade definidos para a operação pela Autoridade de Gestão do Programa
# em conformidade com o texto do respetivo Programa e da regulamentação geral e específica dos Fundos
# Europeus e no presente aviso;
# iii) Avaliação do mérito do projeto, com base na metodologia e nos critérios de seleção aprovados pelo Comité de Acompanhamento do Programa;
# iv) Decisão do Coordenador Regional da Madeira sobre o financiamento dos projetos em conformidade com
# as regras de elegibilidade definidas e tendo em conta as disponibilidades financeiras.
# A análise da candidatura, desenvolvida de acordo com as fases referidas nas alíneas i), ii) e iii), será desenvolvida pela Estrutura de Apoio Técnico do FEAMPA (EAT -FEAMPA) do Coordenador Regional da Madeira, sendo sujeita
# a controlo de qualidade pela Coor denação Regional da Madeira do MAR 2030, com a finalidade de garantir o
# cumprimento da plenitude dos normativos aplicáveis e a harmonização das apreciações desenvolvidas, bem como
# a avaliar a correlação entre as propostas de sentido favorável e a dotação f inanceira disponível.
#
#
# Decisão sobre as candidatura s
# A análise das candidaturas é efetuada de acordo com a informação constante do formulário de candidatura e documentos anexos.
# Sob pena de caducidade imediata da candidatura, os elementos solicitados em sede de análise das candidaturas devem ser remetidos no prazo fixado pela autoridade gestão, num máximo de 10 dias úteis contados da receção
# do pedido de elementos, salvo se o candidato apresentar justificação e a mesma venha a ser aceite pela
# autoridade de gestão.  Os Fundos Europeus mais próximos de si.
#
#
#           20/23
# A decisão fundamentada é proferida no prazo de 60 dias úteis, contados a partir da data de apresentação da
# candidatura e notificada ao candidato no prazo máximo de 5 dias, a contar da data da sua emissão, conjuntamente com o respetivo termo de aceitação.
# Este prazo não inclui o prazo legalmente previsto para audiência de interessados
# e pode ser alargado por até mais 30 dias:
# a) Em caso de apresentação de alegações em sede de audiência de interessados; ou
# b) Em situações excecionais devidamente fundamentadas, designadamente quando se registe uma elevada procura, devendo o novo prazo ser publicitado na primeira metade do prazo para decisão definido no aviso para apresentação de candidaturas
#
# Onde são comunicadas as decisões às entidades candidatas
# As entidades que se candidatam ao apoio recebem as notificações da proposta de decisão e da decisão final na sua área reservada no Balcão.
#
# Aceitação ou não aceitação da decisã o
# A notificação às entidades que se candidataram inclui a decisão final sobre a sua candidatura, que pode ser de aprovação, total ou parcial, não aprovação ou aprovação condicionada.
# A aceitação da decisão de aprovação da candidatura é feita pelo beneficiário, no prazo de 30 dias úteis, no sistema de informação do IFAP, I.P. mediante assinatura do termo de aceitação, através de assinatura digital qualificada, com atributos profissionai s suficientes para o ato, que comprove os poderes de representação do beneficiário
# pelo subscritor.
#
# Onde são publicadas as  listas das candidaturas aprovadas
# • No site do Programa MAR 2030
# • No site do Portugal 2030.
#
# Pedidos de alteração à candidatura
# Alterações aos elementos constantes do termo de aceitação estão sujeitas a nova decisão do Coordenador Regional da Madeira do MAR 2030.
# É necessária a assinatura de um novo termo de aceitação, caso se trate de alterações aos elementos de identificação dos beneficiários e seus representantes legais, à identificação do programa, do fundo, da prioridade,
# do objetivo específico, da tipologia d e intervenção e/ou operação ou, ainda, alterações ao montante do apoio
# público e a respetiva taxa de cofinanciamento, com explicitação das fontes de financiamento europeu e nacional
# ou aos indicadores de realização e resultado e as metas a atingir.
#
#
#   Os Fundos Europeus mais próximos de si.
#
#
#           21/23
# Anexos
#
# Anexo A - Candidatura
# Documentos necessários para apresentar uma candidatura ao abrigo da Medida
# Transformação de Produtos da Pesca e da Aquicultura no Domínio dos Investimentos
# Produtivos
#
#
# Anexo B – Legislação aplicável a este Aviso
#
#   Os Fundos Europeus mais próximos de si.
#
#
#           22/23
#
# Anexo  A - Documentos necessários para apresentar uma candidatura
#
# • Apresentar uma análise estratégica da empresa que identifique as áreas de competitividade críticas
# para o negócio em que se insere, diagnostique a situação da empresa nestas áreas críticas e
# fundamente as opções de investimento consideradas na candidatura
# • Caso se trate de pessoa coletiva: contrato da sociedade, estatutos e certidão permanente atualizados, ou acesso a código para consulta
# • Memória descritiva e justificativa da operação a desenvolver
# • Caso inclua instalações em terra, documento que habilite a realização de intervenções no espaço (caderneta predial demonstrando a propriedade do espaço, ou contrato de arrendamento ou autorização da entidade pública competente)
# • Caso inclua a modernização de instalações, número de controlo veterinário
# • Caso respeite a nova empresa, relatório de comercialização independente
# • Orçamentos e catálogos relativos a todos os bens e serviços compreendidos na proposta, em número mínimo de três, com vista a que possa ser aferida a razoabilidade dos custos apresentados
# • Plano empresarial que permita aferir a viabilidade económico financeira do projeto e, quando o investimento seja superior a 50 mil euros, estudo de viabilidade
# • Elementos que demonstrem que se encontram asseguradas as fontes de financiamento, incluindo o financiamento por empréstimo bancário, quando necessário, e por um mínimo de 20% de capitais próprios, podendo para o efeito incluir novas entradas de capital, no meadamente capital
# social, incorporação de suprimentos e prestações suplementares de capital, desde que venham a ser incorporados em capital próprio ao longo da concretização do projeto e até à sua conclusão material e financeira
# • Informação Económica Simplificada relativa ao último exercício encerrado à data da submissão da candidatura que evidencie uma situação económico -financeira equilibrada (autonomia financeira
# pré-projeto igual ou superior a 15 %), sem prejuízo das situações previstas no n.º 4 do artigo 53.º
# da Portaria n.º 559/2023, de 25 de julho , em que a existência de situação económico -financeira
# equilibrada fica demonstrada quando os capitais próprios suportarem pelo menos 20% do custo
# total do investimento.
# • Caso se pretenda que, para este efeito, seja usada informação mais recente, poderá apresentar os respetivos balanços e demonstrações de resultados, devidamente certificados por contabilista
# certificado.
# • Caso a candidatura seja apresentada em copromoção e preveja a elegibilidade de custos com
# pessoal na entidade parceira: relação dos trabalhadores da entidade beneficiária, organizada por categoria profissional/perfil funcional, com referência de remuneraçã o base (vencimento bruto),
# subsídios de férias, Natal e refeição e contribuições obrigatórias (patronais).
#  Os Fundos Europeus mais próximos de si.
#
#
#           23/23
#
#
#
#
# Anexo  B – Legislação aplicável a este aviso
#
# Europeia
# • Regulamento FEAMPA -  Regulamento (UE) 2021/1139 do Parlamento Europeu e do Conselho, de 7 de
# julho;
# • Regulamento das Disposições Comuns (RDC) -  Regulamento (UE) 2021/1060 do Parlamento Europeu e
# do Conselho, de 24 de junho ;
#
# Nacional
# • Decreto -Lei n.º 20 -A/2023, de 22 de março ;
# • Portaria n.º 559/2023, de 25 de julh o, da Secretaria Regional de Mar e Pescas .
#
#  '

# %% [markdown]
# ## Chunking it

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

def chunk_document(document, chunk_size=3000, chunk_overlap=50):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap
    )
    return text_splitter.split_documents([document])

chunks = chunk_document(document)
print(chunks[0].page_content)
# Out:
# Os Fundos Europeus mais próximos de si.
#
#
#           1/23
# Aviso para apresentação de  candidaturas
# Código do aviso   MAR2030 -2023 -22
# Data de publicação  14/11 /2023
# Natureza do aviso   Concurso
# Âmbito de atuação:  Operações
# Aprovado pelo SRMAR a 25/07/2023
#
#
# Designação do  aviso
# Transformação  de Produtos da Pesca e da Aquicultura no Domínio dos Investimentos Produtivos -  Região
# Autónoma da Madeira
#
# Apoio para
# Promover a comercialização, a qualidade, o valor acrescentado dos produtos da pesca e da aquicultura, assim
# como a transformação destes produtos .
# Ações abrangidas por este aviso
# São abrangidas pelo presente aviso as ações, promovidas por empresas, previstas no artigo 50.º da Portaria n.º
# 559/2023, de 25 de julho , relativas a :
# a) Investimentos produtivos bem como investimentos que promovam a descarbonização, o uso de energias
# renováveis e a eficiência energética, a economia circular, a digitalização e a internacionalização,
# b) Investimentos que promovam o empreendedorismo através do apoio à criação e desenvolvimento de start -
# ups e de spin -offs;
# c) Investimentos na certificação e na promoção de produtos da pesca e da aquicultura sustentáveis, incluindo
# os processos que culminam no registo de marcas ou de patentes;
# d) Investimentos que reduzam o impacto da atividade no ambiente;
# e) Desenvolvimento de estratégias de comercialização e internacionalização, incluindo as ações promocionais
# ou de prospeção e desenvolvimento de produto, que não se integram em ações organizadas pelas
# associações e organizações de produtores;  Os Fundos Europeus mais próximos de si.
#
#
#           2/23
# f) Inovação de marketing , que passe pela implementação de um novo método de marketing  com mudanças
# significativas no design do produto ou na sua embalagem, ou na sua promoção e distribuição;
# g) Iniciativas que promovam a diversificação do consumo, através da transformação de produtos de pesca
# relativos a espécies mais abundantes e com menor valor comercial;
# h) Promoção dos circuitos curtos de distribuição e comercialização.
# Podem ainda ser apoiados projetos em inovação em copromoção, desde que liderados por uma empresa, na
# aceção da al c) do nº.2 do artigo 23.º do DL 20 -A/2023 sendo:
# i) projetos desenvolvidos entre duas ou mais entidades independentes, que cooperam de forma estratégica
# e efetiva numa lógica de médio e longo prazo, partilhando infraestruturas, competências e recursos,
# incluindo recursos humanos, em função dos contributos específicos para os objetivos do projeto, visando
# o desenvolvimento das ações que integram o plano de atividades comum e a concretização das realizações
# e resul tados;
# ii) em que a empresa assume a função de entidade líder, sendo responsável por assegurar a coordenação
# geral do projeto e a interlocução com os vários copromotores e entre estes e a autoridade de gestão, no

# %% [markdown]
# # Prompt

# %%
test_sentence = chunks[0].page_content
print(test_sentence)
# Out:
# European Funds closer to you.
#
#
#           1/23
# Call for applications
# Call code   MAR2030 -2023 -22
# Date of publication  14/11/2023
# Nature of the notice   Tender
# Scope of action:  Operations
# Approved by SRMAR on 25/07/2023
#
#
# Name of the  notice
# Processing  of Fishery and Aquaculture Products in the Field of Productive Investments -  Autonomous Region
# of Madeira
#
# Support to
# promote the marketing, quality, and added value of fishery and aquaculture products, as well as
# the processing of these products .
# Actions covered by this notice
# This notice covers actions promoted by companies, as provided for in Article 50 of Ordinance No.
# 559/2023 of July 25, relating to:
# a) Productive investments as well as investments that promote decarbonization, the use of renewable energy
# and energy efficiency, the circular economy, digitization, and internationalization,
# b) Investments that promote entrepreneurship by supporting the creation and development of start-ups
# and spin-offs;
# c) Investments in the certification and promotion of sustainable fisheries and aquaculture products, including
# the processes leading to the registration of trademarks or patents;
# d) Investments that reduce the impact of the activity on the environment;
# e) Development of marketing and internationalization strategies, including promotional
# or prospecting and product development actions that are not part of actions organized by
# producers' associations and organizations;  The European Funds closest to you.
#
#
#           2/23
# f) Marketing innovation , involving the implementation of a new marketing method  with significant changes
# in product design or packaging, or in its promotion and distribution;
# g) Initiatives that promote consumption diversification through the processing of fishery products
# relating to more abundant species with lower commercial value;
# h) Promotion of short distribution and marketing circuits.
# Projects in co-promotion innovation may also be supported, provided they are led by a company, within the
# meaning of Article 23(2)(c) of DL 20-A/2023, namely:
# i) projects developed between two or more independent entities that cooperate strategically
# and effectively in the medium and long term, sharing infrastructure, skills, and resources,
# including human resources, according to their specific contributions to the project's objectives, with a view to
# developing the actions that make up the common activity plan and achieving the objectives
# and results;
# ii) in which the company assumes the role of lead entity, being responsible for ensuring the overall coordination
# of the project and the dialogue with the various co-promoters and between them and the managing authority, with
# regard to the technical, administrative, and financial management of the project;
# iii) in which a written agreement must be established, signed by all entities participating in the

# %%
examples = [
    {'sentence': '<id> The technology company submitted their grant application for AI research projects.', 
    'answer': '(technology company, appliedFor, grant application)'},

    {'sentence': '<id> The granter opportunity requires applicants to meet the organisational criterion of having at least 50 employees.', 
    'answer': '(granter opportunity, requires, organisational criterion)\n(applicants, hasEligibility, organisational criterion)'},

    {'sentence': '<id> The healthcare company applied for a grant that offers payments of up to $500,000.', 
    'answer': '(healthcare company, appliesFor, grant)\n(grant, offers, grant payment)'},

    {'sentence': '<id> The environmental grant has a deadline of September 30 for all project submissions.', 
    'answer': '(environmental grant, hasDeadline, September 30)\n(environmental grant, requires, project submissions)'},

    {'sentence': '<id> The granter application file was evaluated by an AI review state before final approval.', 
    'answer': '(AI review state, hasEvaluates, granter application file)\n(granter application file, aiReviewState, AI review state)'},
]

# %%
# - Allowed Attributes (datatype properties): {attributes_str}
# - Attribute triple: (entity, attribute, literal_value)

def generate_prompt(concepts, relations, attributes, examples, test_sentence):
    """
    Build an ontology-guided extraction prompt for LLMs.
    
    Args:
        concepts (list[str]): Ontology classes (entities).
        relations (list[str]): Ontology object properties (relationships).
        attributes (list[str]): Ontology datatype properties (attributes).
        examples (list[dict]): Few-shot examples with keys {"sentence": str, "answer": str}.
        test_sentence (str): The new sentence to extract triples from.
    
    Returns:
        str: The formatted LLM prompt.
    """
    # Format ontology context
    concepts_str = ", ".join(concepts)
    relations_str = ", ".join(relations)
    attributes_str = ", ".join(attributes)

    # Format examples
    examples_str = "\n\n".join([
        f"Example sentence: {ex['sentence']}\nExample answer: {ex['answer']}"
        for ex in examples
    ])
    
    # Build complete prompt
    return f"""Given the following ontology and sentence, please extract the triples from the sentence according to the relations in the ontology.
In the output, only include the triples in the given output format

Context:
- Ontology Entities (classes): {concepts_str}
- Ontology Relations (object properties): {relations_str}

For each input sentence, output triples in the following formats:
- Relationship triple: (subject_entity, relationship, object_entity)

{examples_str}

Given these examples, give the correct answer for the following sentence:
Test sentence:\n{test_sentence}\n
Test answer:"""

print(generate_prompt(classes, relations, attributes, examples, test_sentence))
# Out:
# Given the following ontology and sentence, please extract the triples from the sentence according to the relations in the ontology.
# In the output, only include the triples in the given output format
#
# Context:
# - Ontology Entities (classes): DatabaseTable, ForeignKeyRelation, GeographicCriterion, Grant, GrantPayment, GrantShare, GranterApplication, GranterCompany, GranterCompanyMemory, GranterConsortium, GranterConsortiumPartner, GranterConsortiumPartnerType, GranterGeneralOpportunityFile, GranterGeneralOpportunityFileOpportunities, GranterMatchcheck, GranterMatchgroup, GranterOpportunity, GranterOpportunityFile, GranterTimeline, GrantersApplicationFile, Opportunity, PersonLocation, ProvenanceInfo, Recipient, granterCompanyMemory, provenanceInfo
# - Ontology Relations (object properties): CompanyId, ConsortiumId, OpportunityId, OwnerId, ProfileCreatorId, belongsToApplication, belongsToCompany, belongsToCompanyMemory, belongsToEligibilityCriteria, belongsToOpportunity, belongsToProfile, belongsToSubscription, belongsToWhitelabel, companyId, fundedBy, granter_matchgroup, hasApplication, hasAssociatedFile, hasCompanyId, hasConsortiumId, hasForeignKey, hasForeignKeyRelation, hasGeneralOpportunityFileId, hasGrant, hasGrantShare, hasMemorySnippet, hasOpportunityFile, hasOpportunityId, hasPartner, hasPartnerTypeId, hasProvenance, hasProvenanceInfo, hasRecipient, hasTimeline, includesPartner, opportunityId, recipient, relatesTo, relatesToCompany, relatesToConsortium, relatesToOpportunity, relatesToTable, wasDerivedFrom
#
# For each input sentence, output triples in the following formats:
# - Relationship triple: (subject_entity, relationship, object_entity)
#
# Example sentence: <id> The technology company submitted their grant application for AI research projects.
# Example answer: (technology company, appliedFor, grant application)
#
# Example sentence: <id> The granter opportunity requires applicants to meet the organisational criterion of having at least 50 employees.
# Example answer: (granter opportunity, requires, organisational criterion)
# (applicants, hasEligibility, organisational criterion)
#
# Example sentence: <id> The healthcare company applied for a grant that offers payments of up to $500,000.
# Example answer: (healthcare company, appliesFor, grant)
# (grant, offers, grant payment)
#
# Example sentence: <id> The environmental grant has a deadline of September 30 for all project submissions.
# Example answer: (environmental grant, hasDeadline, September 30)
# (environmental grant, requires, project submissions)
#
# Example sentence: <id> The granter application file was evaluated by an AI review state before final approval.
# Example answer: (AI review state, hasEvaluates, granter application file)
# (granter application file, aiReviewState, AI review state)
#
# Given these examples, give the correct answer for the following sentence:
# Test sentence:
# European Funds closer to you.
#
#
#           1/23
# Call for applications
# Call code   MAR2030 -2023 -22
# Date of publication  14/11/2023
# Nature of the notice   Tender
# Scope of action:  Operations
# Approved by SRMAR on 25/07/2023
#
#
# Name of the  notice
# Processing  of Fishery and Aquaculture Products in the Field of Productive Investments -  Autonomous Region
# of Madeira
#
# Support to
# promote the marketing, quality, and added value of fishery and aquaculture products, as well as
# the processing of these products .
# Actions covered by this notice
# This notice covers actions promoted by companies, as provided for in Article 50 of Ordinance No.
# 559/2023 of July 25, relating to:
# a) Productive investments as well as investments that promote decarbonization, the use of renewable energy
# and energy efficiency, the circular economy, digitization, and internationalization,
# b) Investments that promote entrepreneurship by supporting the creation and development of start-ups
# and spin-offs;
# c) Investments in the certification and promotion of sustainable fisheries and aquaculture products, including
# the processes leading to the registration of trademarks or patents;
# d) Investments that reduce the impact of the activity on the environment;
# e) Development of marketing and internationalization strategies, including promotional
# or prospecting and product development actions that are not part of actions organized by
# producers' associations and organizations;  The European Funds closest to you.
#
#
#           2/23
# f) Marketing innovation , involving the implementation of a new marketing method  with significant changes
# in product design or packaging, or in its promotion and distribution;
# g) Initiatives that promote consumption diversification through the processing of fishery products
# relating to more abundant species with lower commercial value;
# h) Promotion of short distribution and marketing circuits.
# Projects in co-promotion innovation may also be supported, provided they are led by a company, within the
# meaning of Article 23(2)(c) of DL 20-A/2023, namely:
# i) projects developed between two or more independent entities that cooperate strategically
# and effectively in the medium and long term, sharing infrastructure, skills, and resources,
# including human resources, according to their specific contributions to the project's objectives, with a view to
# developing the actions that make up the common activity plan and achieving the objectives
# and results;
# ii) in which the company assumes the role of lead entity, being responsible for ensuring the overall coordination
# of the project and the dialogue with the various co-promoters and between them and the managing authority, with
# regard to the technical, administrative, and financial management of the project;
# iii) in which a written agreement must be established, signed by all entities participating in the
#
# Test answer:

# %% [markdown]
# # Trying without structured output

# %%
answer = gpt41_nano.invoke(generate_prompt(classes, relations, attributes, examples, test_sentence))

# %%
print(answer.content)
# Out:
# (points to note: The sentence is about "European Funds" which are not explicitly linked to specific entities in the ontology, but the context suggests a funding source. Since the ontology includes the relation "fundedBy," and "European Funds" implies a funding entity, the relevant triple would link the funding source to the related project or entity. However, the sentence doesn't specify a project or entity explicitly. Given the data, the best extraction is that "European Funds" fund some activity or project related to the notice about fishery and aquaculture products and investments.)
#
# *(European Funds, fundedBy, project or activity related to fishery and aquaculture investments)*
#
# But since no specific entity in the ontology directly corresponds to "European Funds," and no explicit project or activity is named, a minimal valid triple based on the context is:
#
# (European Funds, hasScope, closer to you)
#
# or more precisely, considering the sentence's emphasis:
#
# (European Funds, relatesTo, fishery and aquaculture projects)
#
# However, since the instructions specify extracting triples according to the relations in the ontology and only include triples in the given format, the most appropriate extraction is:
#
# (European Funds, hasScope, closer to you)

# %% [markdown]
# # With LLMGraphTransformer

# %%
from langchain_experimental.graph_transformers import LLMGraphTransformer
graph_transformer = LLMGraphTransformer(llm = gpt41_nano,
                                        allowed_nodes = classes,
                                        allowed_relationships = relations)

# %%
graph_documents = await graph_transformer.aconvert_to_graph_documents(chunks)

# %%
graph_documents
# Out:
# [GraphDocument(nodes=[Node(id='Mar2030-2023-22', type='Grant', properties={}), Node(id='Transformação De Produtos Da Pesca E Da Aquicultura No Domínio Dos Investimentos Produtivos - Região Autónoma Da Madeira', type='Grant', properties={}), Node(id='14/11/2023', type='Provenanceinfo', properties={}), Node(id='Operações', type='Geographiccriterion', properties={}), Node(id='Aviso Para Apresentação De Candidaturas', type='Granterapplication', properties={})], relationships=[Relationship(source=Node(id='Mar2030-2023-22', type='Grant', properties={}), target=Node(id='Aviso Para Apresentação De Candidaturas', type='Granterapplication', properties={}), type='HASAPPLICATION', properties={}), Relationship(source=Node(id='Aviso Para Apresentação De Candidaturas', type='Granterapplication', properties={}), target=Node(id='Transformação De Produtos Da Pesca E Da Aquicultura No Domínio Dos Investimentos Produtivos - Região Autónoma Da Madeira', type='Grant', properties={}), type='BELONGSTOAPPLICATION', properties={}), Relationship(source=Node(id='14/11/2023', type='Provenanceinfo', properties={}), target=Node(id='Aviso Para Apresentação De Candidaturas', type='Granterapplication', properties={}), type='HASPROVENANCE', properties={}), Relationship(source=Node(id='Operações', type='Geographiccriterion', properties={}), target=Node(id='Transformação De Produtos Da Pesca E Da Aquicultura No Domínio Dos Investimentos Produtivos - Região Autónoma Da Madeira', type='Grant', properties={}), type='RELATESTO', properties={})], source=Document(metadata={}, page_content='Os Fundos Europeus mais próximos de si.  \n           \n \n          1/23 \nAviso para apresentação de  candidaturas  \nCódigo do aviso   MAR2030 -2023 -22 \nData de publicação  14/11 /2023  \nNatureza do aviso   Concurso  \nÂmbito de atuação:  Operações  \nAprovado pelo SRMAR a 25/07/2023  \n \n \nDesignação do  aviso  \nTransformação  de Produtos da Pesca e da Aquicultura no Domínio dos Investimentos Produtivos -  Região \nAutónoma da Madeira  \n \nApoio para  \nPromover a comercialização, a qualidade, o valor acrescentado dos produtos da pesca e da aquicultura, assim \ncomo a transformação destes produtos . \nAções abrangidas por este aviso  \nSão abrangidas pelo presente aviso as ações, promovidas por empresas, previstas no artigo 50.º da Portaria n.º \n559/2023, de 25 de julho , relativas a : \na) Investimentos produtivos bem como investimentos que promovam a descarbonização, o uso de energias \nrenováveis e a eficiência energética, a economia circular, a digitalização e a internacionalização,  \nb) Investimentos que promovam o empreendedorismo através do apoio à criação e desenvolvimento de start -\nups e de spin -offs; \nc) Investimentos na certificação e na promoção de produtos da pesca e da aquicultura sustentáveis, incluindo \nos processos que culminam no registo de marcas ou de patentes;  \nd) Investimentos que reduzam o impacto da atividade no ambiente;  \ne) Desenvolvimento de estratégias de comercialização e internacionalização, incluindo as ações promocionais \nou de prospeção e desenvolvimento de produto, que não se integram em ações organizadas pelas \nassociações e organizações de produtores;  Os Fundos Europeus mais próximos de si.  \n           \n \n          2/23 \nf) Inovação de marketing , que passe pela implementação de um novo método de marketing  com mudanças \nsignificativas no design do produto ou na sua embalagem, ou na sua promoção e distribuição;  \ng) Iniciativas que promovam a diversificação do consumo, através da transformação de produtos de pesca \nrelativos a espécies mais abundantes e com menor valor comercial;  \nh) Promoção dos circuitos curtos de distribuição e comercialização.  \nPodem ainda ser apoiados projetos em inovação em copromoção, desde que liderados por uma empresa, na \naceção da al c) do nº.2 do artigo 23.º do DL 20 -A/2023 sendo:  \ni) projetos desenvolvidos entre duas ou mais entidades independentes, que cooperam de forma estraté ...
#  GraphDocument(nodes=[Node(id='Região_Autónoma_Da_Madeira', type='Geographiccriterion', properties={})], relationships=[], source=Document(metadata={}, page_content='que diz respeito à gestão técnica, administrativa e fi nanceira do projeto;  \niii) em que deve ser estabelecido um acordo escrito, subscrito por todas as entidades que participam no \nprojeto, que explicite o âmbito da cooperação entre as entidades envolvidas, a identificação da entidade \nlíder, a responsabilidade conjunta entre as partes, o contributo individual de cada entidade para a \nconcretização do projeto, assim como os termos da partilha de custos, riscos e resultados;  \niv) em que todas as entidades que integram o projeto são consideradas beneficiários, pelo que devem \ncumprir todos os requisitos de elegibilidade, obrigações e impedimentos dos beneficiários;  \ne \nv) sendo os pagamentos realizados a todos os copromotores, ficando estes individualmente responsáveis \npelas restituições dos apoios que tenham recebido e solidariamente responsáveis pela prossecução dos \nobjetivos do projeto, bem como pelo cumprimento dos resultados . \n \nEntidades que se podem candidatar  \nPodem beneficiar dos apoios previstos no presente aviso as PME cuja atividade se enquadre nas subclasses da \nCAE previstas no n.º 1 do artigo 52.º da Portaria n.º 559/2023, de 25 de julho : \na) 10201 «Preparação de produtos da pesca e da aquicultura»;  \nb) 10202 «Congelação de produtos da pesca e da aquicultura»;  \nc) 10203 «Conservação de produtos da pesca e da aquicultura em azeite e outros óleos vegetais e outros molhos»;  \nd) 10204 «Salga, secagem e outras atividades de transformação de produtos da pesca e da aquicultura»;  \ne) 10411 «Produção de óleos e gorduras animais brutos, se relativa a produtos da pesca e da aquicultura»; e  \nf) 10850 «Fabricação de refeições e pratos pré -cozinhados, se relativa a produtos da pesca e da aquicultura».  \nNo caso de operações realizadas em co -promoção, lideradas por uma PME, podem ainda ser beneficiárias as \nentidades identificadas no n.º 2 do artigo 52.º da Portaria n.º 559/2023, de 25 de julho : Os Fundos Europeus mais próximos de si.  \n           \n \n          3/23 \na) Instituições do ensino superior, seus institutos e unidades de I&D;  \nb) Laboratórios do Estado ou internacionais com sede ou representação permanente em Portugal;  \nc) Instituições privadas sem fins lucrativos que tenham como objeto principal atividades de I&D;  \nd) Outras instituições públicas e privadas, sem fins lucrativos, que desenvolvam ou participem em atividades \nde investigação científica.  \n \nÁrea geográfica abrangida  \nRegião Autónoma da Madeira  \nPeríodo de candidaturas  \nDe 14/11/ 2023 a 30/12/2027  \nDotação fundo  indicativa  disponível  \n neste avis o  Fundo e Taxa máxima de \ncofinanciamento   \n770 000 € FEAMPA (*)  70 % \nPrograma financiador  \nPrograma MAR 2030  \nEntidade gestora do apoio /Organismo Interm édio \nCoordenador Regional do Mar 2030 - Região Autónoma da Madeira  \n \nContactos para mais informações  \nLinha dos Fundos 800 10 35 10 (09:00 -18:00h - gratuito)  \nCorreio eletrónico: linhadosfundos@linhadosfundos.pt  \n \nPrograma MAR 2030')),
#  GraphDocument(nodes=[Node(id='Programa Mar 2030', type='Grant', properties={}), Node(id='+ 351 291 203 250', type='Personlocation', properties={}), Node(id='Drp@Madeira.Gov.Pt', type='Personlocation', properties={}), Node(id='Fundos Europeus Mais Próximos De Si', type='Grant', properties={}), Node(id='Promover A Comercialização, A Qualidade, O Valor Acrescentado Dos Produtos Da Pesca E Da Aquicultura, Assim Como A Transformação Destes Produtos', type='Grant', properties={}), Node(id='Programa  Mar 2030', type='Grant', properties={}), Node(id='2 - Fomentar Atividades De Aquicultura Sustentáveis E A Transformação E Comercialização De Produtos Da Pesca E Da Aquicultura, Contribuindo Assim Para A Segurança Alimentar Da União', type='Grant', properties={}), Node(id='Fso2.2 - Promover A Comercialização, A Qualidade E O Valor Acrescentado Dos Produtos Da Pesca E Da Aquicultura, Assim Como A Transformação Destes Produtos', type='Grant', properties={}), Node(id='Fso2.2 -01-Investimentos Produtivos Na Transformação', type='Grant', properties={}), Node(id='Fso2.2.02 - Investimentos Em Eficiência Energética, A Economia Circular, A Digitalização E A Internacionalização', type='Grant', properties={}), Node(id='Fso2.2 -01-01-Investimentos Produtivos Na Transformação', type='Grant', properties={}), Node(id='Fso2.2.02 -01 - Investimentos Em Eficiência Energética, A Economia Circular, A Digitalização E A Internacionalização', type='Grant', properties={}), Node(id='8503 - Investimento Na Redução Do Consumo De Energia E Na Eficiência Energética', type='Grant', properties={}), Node(id='8504 - Investimento Em Sistemas De Energias Renováveis', type='Grant', properties={}), Node(id='8515 – Investimentos De Apoio Ao Desenvolvimento De Empresas (Desenvolvimento De Estratégias, Administração, Equipamento)', type='Grant', properties={}), Node(id='8517 - Desenvolvimento Da Inovação Comercial', type='Grant', properties={}), Node(id='8518 - Desenvolvimento Da Inovação De Processos', type='Grant', properties={}), Node(id='8519 - Desenvolvimento Da Inovação Do Produto', type='Grant', properties={}), Node(id='8510 – Utilização De Capturas Indesejadas', type='Grant', properties={}), Node(id='8548 – Consumo De Água E Melhoria Da Qualidade Da Água', type='Grant', properties={}), Node(id='8512 - Qualidade Dos Alimentos, Segurança E Higiene', type='Grant', properties={}), Node(id='8546 - Atividades De Comercialização', type='Grant', properties={}), Node(id='8513 - Investimentos Nas Condições De Trabalho', type='Grant', properties={}), Node(id='Feampa', type='Grant', properties={}), Node(id='770 000 €', type='Grant', properties={}), Node(id='330 000 €', type='Grant', properties={}), Node(id='Fonte De Financiamento', type='Grant', properties={}), Node(id='Dotação Global', type='Grant', properties={})], relationships=[Relationship(source=Node(id='Programa Mar 2030', type='Grant', properties={}), target=Node(id='Fundos Europeus Mais Próximos De Si', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Programa Mar 2030', type='Grant', properties={}), target=Node(id='Promover A Comercialização, A Qualidade, O Valor Acrescentado Dos Produtos Da Pesca E Da Aquicultura, Assim Como A Transformação Destes Produtos', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Programa Mar 2030', type='Grant', properties={}), target=Node(id='2 - Fomentar Atividades De Aquicultura Sustentáveis E A Transformação E Comercialização De Produtos Da Pesca E Da Aquicultura, Contribuindo Assim Para A Segurança Alimentar Da União', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Fso2.2 - Promover A Comercialização, A Qualidade E O Valor Acrescentado Dos Produtos Da Pesca E Da Aquicultura, Assim Como A Transformação Destes Produtos', type='Grant', properties={}), target=Node(id='Fso2.2 -01-Investimentos Produtivos Na Transformação', type='Grant', properties={}), type='RE ...
#  GraphDocument(nodes=[], relationships=[], source=Document(metadata={}, page_content='renováveis e a eficiência energética, a economia circular, a digitalização e a internacionalização, incluindo \nos que:  \ni) Melhorem o desempenho ambiental e climático;  \nii) Reforcem a segurança alimentar;  \niii) Promovam a introdução de novas espécies no mercado, designadamente através da valorização de \npescado com menor valor comercial;  \niv) Promovam a transformação de subprodutos resultantes das principais atividades de transformação;  \nv) Promovam a valorização de produtos da aquicultura;  \nvi) Sendo inovadores, sejam promovidos por empresas ou em copromoção com universidades ou centros \nde investigação, desde que liderados pela empresa;  \nvii) Promovam o uso de energias renováveis e a melhoria do desempenho energético, a otimização do uso \ndos recursos hídricos;  \nviii) Promovam a utilização de embalagens de base biológica, biodegradável ou reciclável, ou outras \niniciativas que reduzam a utilização de papel ou de plástico;  \nix) Contribuam para a redução do desperdício de alimentos, através da introdução de soluções inovadoras \nao nível do processamento e comercialização do pescado;  \nb) Promoção do empreendedorismo através do apoio à criação e desenvolvimento de start- ups e de spin -offs;  \nc) Investimentos na certificação e na promoção de produtos da pesca e da aquicultura sustentáveis, incluindo \nos processos que culminam no registo de marcas ou de patentes;  \nd) Investimentos que reduzam o impacto da atividade no ambiente;  \ne) Desenvolvimento de estratégias de comercialização e internacionalização, incluindo as ações promocionais \nou de prospeção e desenvolvimento de produto, que não se integram em ações organizadas pelas \nassociações e organizações de produtores;  \nf) Inovação de marketing, que passe pela implementação de um novo método de marketing com mudanças \nsignificativas no design do produto ou na sua embalagem, ou na sua promoção e distribuição;  \ng) Iniciativas que promovam a diversificação do consumo, através da transformação de produtos de pesca \nrelativos a espécies mais abundantes e com menor valor comercial;  \nh) Promoção dos circuitos curtos de distribuição e comercialização . \n Os Fundos Europeus mais próximos de si.  \n           \n \n          6/23 \n \n \nEntidades beneficiárias  (incluindo destinatários, quando relevante)  \nPodem ser beneficiárias dos apoios previstos no presente aviso as PME cuja atividade se enquadre nas subclasses \nda CAE previstas no número 1 do artigo 52 .º da Portaria n.º 559/2023, de 25 de julho : \na) 10201 «Preparação de produtos da pesca e da aquicultura»;  \nb) 10202 «Congelação de produtos da pesca e da aquicultura»;  \nc) 10203 «Conservação de produtos da pesca e da aquicultura em azeite e outros óleos vegetais e outros \nmolhos»;  \nd) 10204 «Salga, secagem e outras atividades de transformação de produtos da pesca e da aquicultura»;  \ne) 10411 «Produção de óleos e gorduras animais brutos, se relativa a produtos da pesca e da aquicultura»; e')),
#  GraphDocument(nodes=[Node(id='10850', type='Databasetable', properties={})], relationships=[], source=Document(metadata={}, page_content='f) 10850 «Fabricação de refeições e pratos pré - cozinhados, se relativa a produtos da pesca e da aquicultura». . \nNo caso de operações de inovação lideradas por uma PME e realizadas em copromoção, podem ainda ser \nbeneficiários as entidades identificadas no n.º 2 do artigo 52. º da Portaria n.º 559/2023, de 25 de julho:  \na) Instituições do ensino superior, seus institutos e unidades de I&D;  \nb) Laboratórios do Estado ou internacionais com sede ou representação permanente em Portugal;  \nc) Instituições privadas sem fins lucrativos que tenham como objeto principal atividades de I&D;  \nd) Outras instituições públicas e privadas, sem fins lucrativos, que desenvolvam ou participem em atividades \nde investigação científica . \n \nCondições específicas ou normas técnicas a observar pelos beneficiários ou operações  \nNo que se refere a beneficiários, sem prejuízo dos critérios de elegibilidade previstos no artigo 14 .º do Decreto -\nLei n.º 20 -A/2023, de 22 de março , que estabelece o regime geral de aplicação dos fundos europeus do Portugal \n2030 e dos critérios gerais definidos no artigo 5.º da Portaria n.º 559/2023, de 25 de julho , os beneficiários do \npresente aviso devem ainda cumprir os requisitos previstos no artigo 53.º da mesma Portaria . \na) Serem detentores do estatuto de PME, com base em certificação do IAPMEI;  \nb) Deterem autorização de instalação, no caso de construção de novos estabelecimentos;  \nc) Possuírem licença de exploração e número de controlo veterinário, quando se trate da modernização de \nestabelecimentos existentes;  \nd) Deterem autorização para alterações dos estabelecimentos que exijam licenciamento, nos casos aplicáveis;  \ne) Apresentarem uma situação económico -financeira equilibrada.  \nPara o efeito, considera -se existir uma situação económica e financeira equilibrada quando a autonomia \nfinanceira pré  -projeto seja igual ou superior a 15 %, tendo por base o último exercício encerrado à data da \napresentação da candidatura.  Os Fundos Europeus mais próximos de si.  \n           \n \n          7/23 \nA autonomia financeira é calculada a partir da seguinte fórmula:  \nAutonomia financeira = CP / AT × 100  \nem que:  \nCP — capitais próprios da empresa, incluindo os suprimentos e ou empréstimos de sócios ou acionistas, desde \nque estes venham a ser incorporados em capital próprio até à data do primeiro pedido de pagamento;  \nAT — ativo total da empresa.  \nRelativamente aos beneficiários que, à data de apresentação da candidatura, não tenham desenvolvido qualquer \natividade, ou não tenha ainda decorrido o prazo legal de apresentação do balanço e contas, bem como aos \nempresários em nome individual sem contabil idade organizada considera - se que possuem uma situação \nfinanceira equilibrada se suportarem com capitais próprios pelo menos 20 % do custo total do investimento.')),
#  GraphDocument(nodes=[], relationships=[], source=Document(metadata={}, page_content='Os beneficiários podem comprovar os indicadores de autonomia financeira com informação mais recente, devendo para o efeito apresentar os respetivos balanços e demonstrações de resultados devidamente \ncertificados por contabilista certificado.  \nNo que se refere a operações, sem prejuízo dos critérios de elegibilidade previstos no artigo 19.º do \nDecreto -Lei \nn.º 20 -A/2023, de 22 de março , e no artigo 6.º da Portaria n.º 559/2023, de 25 de julho , a elegibilidade das \noperações ao presente aviso está também sujeita ao cumprimento dos requisitos estabelecidos no artigo 51º da \nPortaria n.º 559/2023, de 25 de julho , devendo : \na) Ser sustentadas por uma análise estratégica da empresa que identifique as áreas de competitividade críticas \npara o negócio em que se insere, diagnostique a situação da empresa nestas áreas críticas e fundamente as \nopções de investimento consideradas na candidatura;  \nb) Ter um investimento elegível de valor igual ou superior a 10 000 euros, e um investimento total máximo de \n20 milhões de euros ou de 4 milhões de euros no caso de estabelecimentos localizados na NUTS II Algarve;  \nc) Demonstrar a viabilidade económico -financeira do projeto, sustentada em plano empresarial e, quando o \ninvestimento seja superior a 50 000 euros, num estudo de viabilidade;  \nd) Demonstrar que se encontram asseguradas as fontes de financiamento, incluindo o financiamento por \nempréstimo bancário, quando necessário, devendo ser garantido um mínimo de 20 % de capitais próprios, \nque pode incluir novas entradas de capital, nomeadamente  capital social, incorporação de suprimentos e \nprestações suplementares de capital, desde que venham a ser incorporados em capital próprio ao longo da \nconcretização do projeto e até à sua conclusão material e financeira;  \ne) Demonstrar a existência de perspetivas sustentáveis para comercialização do produto no mercado, \nmediante relatório de comercialização independente, no caso de empresas com menos de um ano de \natividade, ou, para as restantes empresas, com base na análise hi stórica dos clientes da empresa e da sua \nprojeção após realização do projeto . \nOs beneficiários comprovam as informações contabilísticas com base no último exercício encerrado à data de \napresentação da candidatura, podendo ser usada informação mais recente, devendo para o efeito apresentar os \nrespetivos balanços e demonstrações de re sultados devidamente certificados por um contabilista certificado.  \nConsidera -se que se encontram asseguradas as fontes de financiamento nas operações apresentadas pelas \nentidades que participam nos projetos em copromoção, que não as empresas, quando o valor do investimento \nse encontre previsto em orçamento ou quando exist a declaração emitida pelo beneficiário da sua inscrição em \nanos futuros .  Os Fundos Europeus mais próximos de si.  \n           \n \n          8/23 \n \nModalidade de apresentação  \nde candidaturas  Número máximo  \nde candidaturas  Duração  \ndas operações')),
#  GraphDocument(nodes=[Node(id='Duração_Das_Operacoes', type='Databasetable', properties={}), Node(id='Individualmente_Ou_Em_Copromoção', type='Databasetable', properties={}), Node(id='Ano_Duração', type='Databasetable', properties={}), Node(id='Condições_De_Atribuição_De_Financiamento_Da_Operacao', type='Databasetable', properties={}), Node(id='Taxa_De_Apoio_Publico', type='Databasetable', properties={}), Node(id='Start_Ups_E_Spin_Offs', type='Databasetable', properties={}), Node(id='Organismo_Publico', type='Databasetable', properties={}), Node(id='Demais_Casos', type='Databasetable', properties={}), Node(id='Legislacao_Em_Vigor', type='Databasetable', properties={}), Node(id='Regulamento_Ue_2021_1060', type='Databasetable', properties={}), Node(id='Decretolei_20A_2023', type='Databasetable', properties={}), Node(id='Portaria_559_2023', type='Databasetable', properties={}), Node(id='Auxilios_De_Estado', type='Databasetable', properties={}), Node(id='Aplicavel', type='Databasetable', properties={}), Node(id='Fundamentar', type='Databasetable', properties={}), Node(id='Excecionado_Obrigatorio', type='Databasetable', properties={}), Node(id='Formas_De_Apoios', type='Databasetable', properties={}), Node(id='Subvencao', type='Databasetable', properties={}), Node(id='Custos_Reais', type='Databasetable', properties={}), Node(id='Custos_Unitarios', type='Databasetable', properties={}), Node(id='Em_Programa', type='Databasetable', properties={}), Node(id='Data_Da_Decisao', type='Databasetable', properties={}), Node(id='Deliberacao_Cic', type='Databasetable', properties={}), Node(id='Montantes_Fixos', type='Databasetable', properties={}), Node(id='Taxa_Fixa', type='Databasetable', properties={}), Node(id='Financiamento_Nao_Associado_A_Custos', type='Databasetable', properties={}), Node(id='Instrumento_Financeiro', type='Databasetable', properties={}), Node(id='Custos_Elegiveis', type='Databasetable', properties={}), Node(id='Construção_E_Modernização', type='Databasetable', properties={}), Node(id='Aquisição_De_Edificios_Outros', type='Databasetable', properties={}), Node(id='Vedações_Preparação_De_Terrenos', type='Databasetable', properties={}), Node(id='Sistemas_E_Equipamentos', type='Databasetable', properties={})], relationships=[], source=Document(metadata={}, page_content='de candidaturas  Duração  \ndas operações  \nIndividualmente ou em \ncopromoção  Uma por operador económico  2 anos  \n \nCondições de atribuição de financiamento da operação  \nA taxa de apoio público para as operações é de até : \na) 75 % no caso de start -ups e spin-offs ou em projetos em copromoção  destinados a introduzir produtos, \nprocessos ou equipamentos inovadores na empresa;  \nb) 100 % das despesas elegíveis, no caso de operações em que o beneficiário é um organismo público;  \nc) 50 % das despesas elegíveis, nos demais casos . \nSempre que uma operação possa ser enquadrada em mais do que uma das alíneas do número anterior, aplica -se \na taxa máxima de apoio mais elevada.  \nDevem ser cumpridas as condições fixadas relativas ao enquadramento do beneficiário e da candidatura no \nâmbito do presente Aviso bem como as obrigações e as condições gerais e específicas de elegibilidade do beneficiário e das operações, definidas na legis lação em vigor, nomeadamente, no Regulamento (UE) 2021/1060 \ndo Parlamento Europeu e do Conselho, de 24 de junho, no Decreto -Lei nº 20 -A/2023. de 22 de março, que \nestabelece o regime geral de aplicação dos fundos europeus do Portugal 2030 e na Portaria n.º 559/2023, de 25 de julho , que adota o Regulamento específico das medidas de apoio do Programa Mar 2030  na Região Autónoma \nda Madeira.\n \n \nAuxílios de Estado  \n☐ Aplicável?  Enquadrar:                       ☐ Regulamento Geral de Isenção de Categoria  \n  ☐ Auxílio s de minimis  \n  ☐ Notificação à Comissão Europeia  \n  ☐ Serviço de Interesse Econ ómico Geral  \n  \n☒ \n Não Aplicável?  Fundamentar:  \nExcecionado ao abrigo do disposto no n.º 2 do art.º 10º  ...
#  GraphDocument(nodes=[Node(id='Pesca_E_Aquicultura', type='Geographiccriterion', properties={})], relationships=[], source=Document(metadata={}, page_content='conservação, acondicionamento e embalagem, armazenagem, comercialização, rastreabilidade e rotulagem de produtos da pesca e da aquicultura;  \ne) Equipamentos e meios para movimentação interna e pesagem;  \nf) Sistemas e equipamentos para o fabrico e silagem de gelo, destinado ao uso exclusivo da atividade do estabelecimento;  \ng) Sistemas e equipamentos destinados à verificação, controlo e certificação da qualidade e rastreabilidade \ndos produtos da pesca e da aquicultura;  \nh) Sistemas ou equipamentos destinados ao armazenamento, transformação e comercialização de \nsubprodutos e de desperdícios dos produtos da pesca e da aquicultura;  \ni) Sistemas ou equipamentos para deteção ou extração de substâncias perigosas para a saúde, da farinha de peixe ou do óleo de peixe, mesmo que os produtos finais sejam utilizados para outros fins que não o \nconsumo humano;  \nj) Sistemas e equipamentos de sinalização, segurança, deteção e combate a incêndios, gestão informatizada \nda atividade produtiva, bem como equipamento telemático;  \nk) Sistemas e equipamentos de redes de água salubre, saneamento, comunicações, eletricidade e combustíveis;  Os Fundos Europeus mais próximos de si.  \n           \n \n          10/23 \nl) Automatização de sistemas ou equipamentos já existentes no estabelecimento, ou adoção de aplicações \nque restrinjam a utilização de papel ou de plástico, sendo também elegíveis as auditorias de gestão realizadas com esta finalidade;  \nm) Aquisição de equipamentos e sistemas informáticos e telemáticos, incluindo a adoção de Enterprise Resources Planning (ERP) ; \nn) Construção de estações de pré -tratamento de águas residuais (EPTAR) ou de estações de tratamento de \náguas residuais (ETAR), bem como instalação dos respetivos sistemas e equipamentos;  \no) Despesas relativas ao desenvolvimento de aplicações dirigidas à realização de vendas on -line, bem como \nrelativas à aquisição do hardware  e software informático que se revelem adequadas a esta finalidade;  \np) Apenas no caso da construção de novos estabelecimentos produtivos, instalações e equipamentos sociais que melhorem a qualidade das condições de trabalho das instalações;  \nq) Aquisição de veículos aprovados e certificados nos termos do Acordo Internacional de Transporte de \nProdutos Perecíveis sob Temperatura Dirigida, e aquisição de veículos comerciais ligeiros de emissões nulas, \nequipados com contentores isotérmicos para trans porte e armazenamento de pescado;  \nr) Conceção e registo de marcas incluindo a criação de marcas próprias, a melhoria de design na apresentação e embalagem dos produtos;  \ns) Aquisição de equipamentos ou sistemas para acondicionamento e embalagem;  \nt) Despesas de auditoria e consultoria especializada, de consultoria e elaboração ou de acompanhamento da candidatura, a fiscalização de obras, desde que realizada por uma entidade externa ao beneficiário e ao \nconstrutor, as despesas de preparação do licencia mento, nas quais se incluem estudos e projetos técnico -')),
#  GraphDocument(nodes=[], relationships=[], source=Document(metadata={}, page_content='económicos ou de impacte ambiental, excluindo -se destes, o pagamento de escrituras, taxas ou \nemolumentos;  \nu) Custo com a contratação de um máximo de dois novos quadros técnicos por micro ou pequena empresa, \ncom nível de qualificação igual ou superior a 6, correspondente a licenciatura, nos termos definidos na Portaria n.º 782/2009, de 23 de julho, na medida em qu e sejam utilizados no projeto;  \nv) Despesas com formação profissional diretamente relacionadas com o objeto e os objetivos da operação.  \nNas operações realizadas em co -promoção, as despesas elegíveis relativas aos beneficiários parceiros previstos \nno n.º 2 do artigo 52.º da Portaria n.º 559/2023, de 25 de julho\n, são as que se encontram identificadas na alínea \nb) do n.º 2 do artigo 55.º da mesma Portaria, isto é os custos diretos com pessoal, a que acresce uma taxa fixa de \n40 % dos custos elegíveis diretos com pessoal, para cobrir todos os restantes custos elegívei s da operação. Os \ncustos diretos com pessoal são financiados com  recurso a uma taxa horária calculada para cada operação, de \nforma objetiva, dividindo os custos anuais brutos do trabalho registados no ano civil anterior ao do pedido de \napoio por 1720 horas, de acordo com as seguintes regras:  \n1) Os custos anuais são documentados com base numa relação dos trabalhadores da entidade beneficiária, organizada por categoria profissional/perfil funcional, com referência de remuneração base, subsídio de férias, subsídio de Natal, aos quais se aplica o lim ite correspondente ao valor das remunerações definido na \ntabela remuneratória aplicada à Administração Pública, acrescido de subsídio de refeição e contribuições \nobrigatórias;  \n2) Uma vez obtida a taxa horária para cada categoria profissional/perfil funcional de recurso humano afeto \npelo beneficiário à operação, a mesma é multiplicada pelo número de horas correspondentes a essa \nafetação, obtendo - se assim o custo elegível para fins de cofinanciamento.\n Os Fundos Europeus mais próximos de si.  \n           \n \n          11/23 \n \nRegras ou limites específicos à elegibilidade de despesa (Quando aplicável)  \n1. A elegibilidade das despesas tem início a partir de 1 de janeiro de 2021, conforme exceção prevista na alínea \na) do n.º 2 do artigo 8.º da Portaria n.º 559/2023, de 25 de julho . \n2. Os custos elegíveis com a contratação de até dois novos quadros técnicos, aplicável às micro e pequenas empresas apoiadas e previstos na alínea u) do artigo 54.º da Portaria n.º 559/2023, de 25 de julho\n, são \ndeterminados de acordo com os requisitos estabelecidos no ponto 2 do mesmo artigo 54.º, estabelecendo -se \ncomo limite máximo para efeitos do presente aviso, um salário base de 1.600 € (mil e seiscentos euros) . \n3. Para efeitos de cumprimento da condição prevista na alínea e) do n.º 2 do Artigo 54.º da Portaria n.º 559/2023, \nde 25 de julho , considera -se criação líquida de postos de trabalho a aumento líquido do número de')),
#  GraphDocument(nodes=[Node(id='Mapas_De_Remunerações', type='Geographiccriterion', properties={}), Node(id='Seguranca_Social', type='Geographiccriterion', properties={}), Node(id='Contrato_De_Trabalho', type='Geographiccriterion', properties={}), Node(id='Postos_De_Trabalho', type='Geographiccriterion', properties={}), Node(id='Despesas_Em_Veículos', type='Grant', properties={}), Node(id='Despesas_Com_Auditoria_E_Consultoria', type='Grant', properties={}), Node(id='Despesas_Em_Co_Promoção', type='Grant', properties={})], relationships=[Relationship(source=Node(id='Mapas_De_Remunerações', type='Geographiccriterion', properties={}), target=Node(id='Seguranca_Social', type='Geographiccriterion', properties={}), type='RELATESTO', properties={})], source=Document(metadata={}, page_content='trabalhadores diretamente empregados na entidade beneficiária, calculado pela diferença entre o número de trabalhadores no momento da apresentação do último pedido de pagamento e a média mensal do número de trabalhadores nos seis meses anteriores à data da apresentação da candidatura, a demonstrar através dos mapas de remunerações da segurança social, e desde que reúna cumulativamente as seguintes condições : \ni) Ter por base a celebração de contrato de trabalho escrito entre a entidade beneficiária e o trabalhador;  \nii) Os trabalhadores a contratar não terem tido vínculo laboral com a entidade beneficiária ou entidades parceiras ou associadas destas, durante os 12 meses anteriores à data de apresentação da candidatura;  \niii) Não corresponder a postos de trabalho de gerentes, administradores e ou sócios da entidade beneficiária ; \niv) Os postos de trabalho criados estarem diretamente associados ao desenvolvimento da operação objeto de apoio.  \n4. As despesas previstas na alínea q) do n.º 1 do artigo 54.º da Portaria n.º 559/2023, de 25 de julho\n, relativas a \naquisição de veículos, estão limitadas a 20% das restantes despesas elegíveis ; \n5. As despesas previstas na alínea t) do n.º 1 do artigo 54.º da  Portaria n.º 559/2023, de 25 de julho , relativas a \nauditoria e consultoria especializada, de consultoria e elaboração ou de acompanhamento da candidatura, de fiscalização de obras, as\n despesas de preparação do licenciamento, nas quais se incluem estudos e projetos \ntécnico -económicos ou de impacte ambiental, estão limitadas a 6% das restantes despesas elegíveis ; \n6. Nas operações realizadas em co -promoção, as despesas realizadas pelas entidades parceiras estão limitadas \naos custos unitários e taxas fixas apurados de acordo com o estabelecido na alínea b) do número 2 do artigo 55.º da  Portaria n.º 559/2023, de 25 de julho\n. \nFormas de pagamento  ☒ Adiantamentos %  ☒ Reembolso  ☒ Contra fatura  \nOs pagamentos ao projeto são efetuados de acordo com o estabelecido no artigo 10.º da Portaria n.º 559/2023, \nde 25 de julho . \nNo presente Aviso, os pagamentos aos beneficiários são efetuados a título de adiantamento (adiantamento \ninicial até 10%, adiantamento contra fatura e adiantamento contragarantia), reembolso e/ou pagamento final).  \nO pedido de pagamento final, não pode ser inferior a 5% do valor do apoio aprovado e deve ser apresentado à respetiva Autoridade de Gestão até 90 dias úteis a contar da data da conclusão da operação, podendo este prazo ser prorrogado mediante justificação fundamentada a apresentar à Autoridade de Gestão ou Organismo \nIntermédio com funções de gestão atribuídas . \n Os Fundos Europeus mais próximos de si.  \n           \n \n          12/23 \n \nIndicadores de realização  \nPrograma  MAR 2030  \nTipologia de  intervenção  FSO2.2 -01-01-Investimentos produtivos na transformação  \nFSO2.2.02 -01 - Investimentos em eficiência energética, a economia circular, a \ndigitalização e a internacionalização')),
#  GraphDocument(nodes=[], relationships=[], source=Document(metadata={}, page_content='digitalização e a internacionalização  \nTipologia de  operação  8503 - Investimento na redução do consumo de energia e na eficiência energética  \n8504 - Investimento em sistemas de energias renováveis  \n8515 – Investimentos de apoio ao desenvolvimento de empresas (desenvolvimento \nde estratégias, administração, equipamento)  \n8517 - Desenvolvimento da inovação comercial  \n8518 - Desenvolvimento da inovação de processos  \n8519 - Desenvolvimento da inovação do produto  \n8510 – Utilização de capturas indesejadas  \n8548 – Consumo de água e melhoria da qualidade da água  \n8512 - Qualidade dos alimentos, segurança e higiene  \n8546 - Atividades de comercialização  \n8513 - Investimentos nas condições de trabalho  \nCódigo  do indicador  Designação  do indicador  Unidade  \nCO01  Operações aprovadas  N.º \nDescrição  O indicador reporta a quantificação das operações que contribuem para o alcance da \ntipologia de intervenção  \nMétodo de cálculo  Somatório simples  \n \nIndicadores de resultado  \nProgram a MAR 2030  \nTipologia de  intervenção  FSO2.2 -01-01-Investimentos produtivos na transformação  \nFSO2.2.02 -01 - Investimentos em eficiência energética, a economia circular, a \ndigitalização e a internacionalização  \nTipologia de  operação  8503 - Investimento na redução do consumo de energia e na eficiência energética  \n8504 - Investimento em sistemas de energias renováveis  \n8515 – Investimentos de apoio ao desenvolvimento de empresas (desenvolvimento de \nestratégias, administração, equipamento)  \n8517 - Desenvolvimento da inovação comercial  \n8518 - Desenvolvimento da inovação de processos  \n8519 - Desenvolvimento da inovação do produto  \n8510 – Utilização de capturas indesejadas  \n8548 – Consumo de água e melhoria da qualidade da água  \n8512 - Qualidade dos alimentos, segurança e higiene  \n8546 - Atividades de comercialização  \n8513 - Investimentos nas condições de trabalho  \nCódigo  do indicador  Designação  do indicador  Unidade  \nCR14  Inovações possibilitadas  N.º de inovações  Os Fundos Europeus mais próximos de si.  \n           \n \n          13/23 \nDescrição  Número de inovações implementadas ou testadas para novos produtos, serviços, \nprocessos , modelos de negócio  ou métodos de produção.  \nMétodo de cálculo  O beneficiário deverá identificar na candidatura o número de inovações a gerar pela \nrealização da operação , desagregando o n.º de novos produtos, o n.º de novos \nprocessos, n .º de novos modelos de negócio  ou n .º de novos métodos de produção  \nResultado a ser verificado em sede de avaliação no final da operação . \n \nProgram a Mar 2030  \nTipologia de  intervenção  FSO2.2 -01-01-Investimentos produtivos na transformação  \nFSO2.2.02 -01 - Investimentos em eficiência energética, a economia circular, a \ndigitalização e a internacionalização  \nTipologia de  operação  8503 - Investimento na redução do consumo de energia e na eficiência energética  \n8504 - Investimento em sistemas de energias renováveis')),
#  GraphDocument(nodes=[Node(id='8515', type='Databasetable', properties={}), Node(id='8517', type='Databasetable', properties={}), Node(id='8518', type='Databasetable', properties={}), Node(id='8519', type='Databasetable', properties={}), Node(id='8510', type='Databasetable', properties={}), Node(id='8548', type='Databasetable', properties={}), Node(id='8512', type='Databasetable', properties={}), Node(id='8546', type='Databasetable', properties={}), Node(id='8513', type='Databasetable', properties={}), Node(id='Cr17', type='Databasetable', properties={}), Node(id='Cr04', type='Databasetable', properties={}), Node(id='Cr18.1', type='Databasetable', properties={}), Node(id='Investimentos De Apoio Ao Desenvolvimento De Empresas', type='Grant', properties={}), Node(id='Desenvolvimento Da Inovação Comercial', type='Grant', properties={}), Node(id='Desenvolvimento Da Inovação De Processos', type='Grant', properties={}), Node(id='Desenvolvimento Da Inovação Do Produto', type='Grant', properties={}), Node(id='Utilização De Capturas Indesejadas', type='Grant', properties={}), Node(id='Consumo De Água E Melhoria Da Qualidade Da Água', type='Grant', properties={}), Node(id='Qualidade Dos Alimentos, Segurança E Higiene', type='Grant', properties={}), Node(id='Atividades De Comercialização', type='Grant', properties={}), Node(id='Investimentos Nas Condições De Trabalho', type='Grant', properties={}), Node(id='Entidades Que Melhorem A Eficiência Dos Recursos Na Produção E/Ou Na Transformação', type='Grant', properties={}), Node(id='Volume De Negócios Antes Do Projeto', type='Grant', properties={}), Node(id='Volume De Negócios Previsto Após O Projeto', type='Grant', properties={}), Node(id='Empresa Com Volume De Negócios Mais Elevado', type='Grant', properties={})], relationships=[Relationship(source=Node(id='8515', type='Databasetable', properties={}), target=Node(id='Investimentos De Apoio Ao Desenvolvimento De Empresas', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='8517', type='Databasetable', properties={}), target=Node(id='Desenvolvimento Da Inovação Comercial', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='8518', type='Databasetable', properties={}), target=Node(id='Desenvolvimento Da Inovação De Processos', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='8519', type='Databasetable', properties={}), target=Node(id='Desenvolvimento Da Inovação Do Produto', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='8510', type='Databasetable', properties={}), target=Node(id='Utilização De Capturas Indesejadas', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='8548', type='Databasetable', properties={}), target=Node(id='Consumo De Água E Melhoria Da Qualidade Da Água', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='8512', type='Databasetable', properties={}), target=Node(id='Qualidade Dos Alimentos, Segurança E Higiene', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='8546', type='Databasetable', properties={}), target=Node(id='Atividades De Comercialização', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='8513', type='Databasetable', properties={}), target=Node(id='Investimentos Nas Condições De Trabalho', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Cr17', type='Databasetable', properties={}), target=Node(id='Entidades Que Melhorem A Eficiência Dos Recursos Na Produção E/Ou Na Transformação', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Cr04', type='Databasetable', properties={}), target=Node(id='Empresa Com Volume De Negócios Mais Elevado', type='Grant', properties={}), type='RELATESTO', proper ...
#  GraphDocument(nodes=[], relationships=[], source=Document(metadata={}, page_content='consumo de energia por tonelada produzida antes e depois da realização do \ninvestimento.  \nMétodo de cálculo  O beneficiário identifica na  candidatura o consumo em kWh por tonelada produzida , \npara a mesma capacidade produtiva, existente antes e após a realização dos \ninvestimentos que visem a eficiência energética  e a economia circular . Os valores \nestimados em candidatura serão analisados e m sede de avaliação no final da \noperação . \n \nConsequências do incumprimento dos indicadores  \nA execução parcial da operação face aos objetivos e resultados aprovados, aferida pelo não alcance das metas \ndefinidas na decisão de aprovação do apoio público para os indicadores de resultados do projeto, constitui \nfundamento para redução do apoio público exceto quando esse incumprimento decorra de factos não imputáveis \nao beneficiário.  \nConsideram -se cumpridos os indicadores de resultado contratualizados na aprovação do Financiamento, quando \na percentagem de cumprimento for igual ou superior a 70 % do contratualizado.  \nAbaixo desse limiar será aplicada uma redução no apoio publico proporcional à percentagem de incumprimento, \nde acordo com o seguinte : \n• Aplicação de uma penalização de 0,5 p.p na taxa de apoio público, por cada ponto percentual abaixo do \nlimiar do cumprimento de cada um dos indicadores contratualizados;  \n• A redução da taxa de apoio publico resultante da aplicação da penalização referida no ponto anterior, para \na totalidade dos indicadores que incumpriram, está limitada a 5 p.p.  Os Fundos Europeus mais próximos de si.  \n           \n \n          15/23 \nSem prejuízo das penalizações na taxa de apoio público decorrentes do incumprimento dos resultados \ncontratualizados, as operações que não atinjam os objetivos essenciais previstos na aprovação do Financiamento, \npondo em causa as finalidades que determinara m a sua aprovação, podem ser objeto de revogação nos termos \nda alínea b) do n.º 4 do artigo 33.º do  Decreto -Lei n.º 20 -A/2023, de 22 de março . \nNos termos do n.º 3 do artigo 57 .º da Portaria n.º 559/2023, de 25 de julho , no caso de operações enquadráveis \nna tipologia de copromoção, os beneficiários parceiros devem a presentar, no pedido de pagamento de saldo \nfinal, uma autoavaliação qualitativa das realizações e resultados atingidos, nos termos do disposto no n.º 2 do \nartigo 22.º do Decreto -Lei n.º 20 -A/2023, de 22 de março . \n \nMecanismos de bonificação (Quando aplicável)   \nNão Aplicável  \nCritérios de seleção das operações aprovados em : 21/03/2023  \n \nObrigações dos beneficiários em matéria de notoriedade, transparência e comunicação  \nConstituem obrigações dos beneficiários dar a conhecer o apoio do FEAMPA às operações , nos seguintes termos : \nPara todas as operações : \n1. nos sítios na internet e nas redes sociais dos Beneficiários, através dos emblemas financiadores – do \nPrograma, do PT 2030 e da União Europeia - , que devem encontrar -se permanentemente visíveis na página')),
#  GraphDocument(nodes=[Node(id='Deabertura', type='Provenanceinfo', properties={}), Node(id='Descriçãooperacao', type='Provenanceinfo', properties={}), Node(id='Elementosapoioaudiovisual', type='Provenanceinfo', properties={}), Node(id='Emblemasfinanciadores', type='Provenanceinfo', properties={}), Node(id='Operacao', type='Grant', properties={}), Node(id='Operacaovalor', type='Grant', properties={}), Node(id='Operacaovideo', type='Grant', properties={}), Node(id='Operacaoatendimento', type='Grant', properties={}), Node(id='Candidaturaonline', type='Provenanceinfo', properties={}), Node(id='Formulariocandidatura', type='Grant', properties={}), Node(id='Documentosanexoa', type='Grant', properties={}), Node(id='Criteriosselecao', type='Provenanceinfo', properties={}), Node(id='Pontuacaofinal', type='Grant', properties={}), Node(id='Apreciacaotecnica', type='Grant', properties={}), Node(id='Apreciacaoestrategica', type='Grant', properties={}), Node(id='Tir', type='Grant', properties={}), Node(id='Refi', type='Grant', properties={})], relationships=[Relationship(source=Node(id='Descriçãooperacao', type='Provenanceinfo', properties={}), target=Node(id='Deabertura', type='Provenanceinfo', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Descriçãooperacao', type='Provenanceinfo', properties={}), target=Node(id='Elementosapoioaudiovisual', type='Provenanceinfo', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Descriçãooperacao', type='Provenanceinfo', properties={}), target=Node(id='Emblemasfinanciadores', type='Provenanceinfo', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Operacao', type='Grant', properties={}), target=Node(id='Operacaovalor', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Operacao', type='Grant', properties={}), target=Node(id='Operacaovideo', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Operacao', type='Grant', properties={}), target=Node(id='Operacaoatendimento', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Formulariocandidatura', type='Grant', properties={}), target=Node(id='Documentosanexoa', type='Grant', properties={}), type='HASAPPLICATION', properties={}), Relationship(source=Node(id='Criteriosselecao', type='Provenanceinfo', properties={}), target=Node(id='Pontuacaofinal', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Pontuacaofinal', type='Grant', properties={}), target=Node(id='Apreciacaotecnica', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Pontuacaofinal', type='Grant', properties={}), target=Node(id='Apreciacaoestrategica', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Apreciacaotecnica', type='Grant', properties={}), target=Node(id='Tir', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Apreciacaotecnica', type='Grant', properties={}), target=Node(id='Refi', type='Grant', properties={}), type='RELATESTO', properties={})], source=Document(metadata={}, page_content='de abertura, devendo ainda ser assegurada a disponibilização da descrição da operação apoiada, com \nelementos audiovisuais de apoio;  \n2. nos edificados, equipamentos ou ações imateriais: aposição dos emblemas financiadores nos próprios equipamento ou materiais impressos, com visibilidade e legibilidade adequadas;  \nPara operações:  \n1. cujo custo elegível financiado seja superior a 500 mil €: realização de um vídeo, com duração não inferior a um minuto, para apresentação da operação, seus objetivos e resultados, com cedência de direitos de autor à autoridade de gestão, podendo a reali zação do vídeo ser elegível em moldes a definir em sede de \naviso para a apresentação da candidatura;  \n2. superiores a 10 milhões de € ou ...
#  GraphDocument(nodes=[Node(id='30 Pontos', type='Grant', properties={}), Node(id='Fundos Europeus', type='Grant', properties={})], relationships=[], source=Document(metadata={}, page_content='Média empresa -  30 pontos.  \nb) À pontuação prevista na alínea anterior acrescem as seguintes majorações que são atribuídas sempre que a operação preveja intervenções relacionadas com o parâmetro em causa:  Os Fundos Europeus mais próximos de si.  \n           \n \n          17/23 \nEfeito do \nprojeto  \nna Parâmetros  10 pontos  6 pontos  \nCompetitividade \nda empresa  Diversificação da oferta  O projeto dá lugar à criação de \npelo menos um novo produto \ncom utilização de uma nova \nespécie de peixe  O projeto dá lugar à criação \nde um novo produto ou de \nproduto(s) melhorado(s) a partir das espécies de peixe já utilizadas pela empresa \nou de novas formas de \napresentação dos produtos  \nQualificação da \ngestão  O projeto prevê a realização de \nações de formação dirigidas à \nmelhoria das competências \nprofissionais em matéria de \ngestão empresarial  O projeto prevê a \nrealização de investimentos que melhorem as condições de trabalho dos \nseus profissionais \n(investimentos em áreas sociais - dentro da unidade \nprodutiva -, em \nclimatização, ou na mecanização de processos \nmanuais)  \nEficiência e descarbonização  Eficiência no uso de recursos  O projeto prevê investimentos relativos à reutilização de desperdícios gerados na própria \nempresa  O projeto prevê \ninvestimentos que reduzem \nos impactes negativos no ambiente gerados pela \natividade  \nO projeto prevê investimentos \nque aumentem a eficiência no uso de recursos naturais (ex. a água) \nou que reduzam a poluição   \nDigitalização  O projeto prevê investimentos \nrelativos à digitalização do processo produtivo (entendendo -\nse a produção como incluindo a comercialização, podendo \nenvolver quer os fornecedores \nquer os clientes através do \ncomércio on -line)  O projeto prevê investimentos relativos à digitalização em qualquer uma das restantes áreas da empresa  \nDescarbonização  O projeto prevê investimentos \nque tenham por objetivo a \ndescarbonização  O projeto prevê outros \ninvestimentos que \naumentem a eficiência no \nuso de energias renováveis \n(ex. painéis solares)  \nEconomia  Reforço da segurança alimentar  Aumento em 20% ou mais da capacidade de produção da empresa no pré -projeto  \nAumento em mais de 10% e \nmenos de 20% da capacidade de produção no \npré-projeto  Os Fundos Europeus mais próximos de si.  \n           \n \n          18/23 \nEfeito do \nprojeto  \nna Parâmetros  10 pontos  6 pontos  \nImpacto noutras \nPME do sector da pesca  Valorização de produtos da pesca \nde baixo valor comercial  \nou \nValorização de produtos da \naquicultura   \nDinamização das exportações  Após a realização do projeto a produção global prevista destina -\nse em 40%, ou mais, à exportação  Após a realização do \nprojeto a produção global prevista destina -se pelo \nmenos em 10% até 40%, à \nexportação  \nDiversificação dos \nmercados \ninternacionais  Diversificação dos mercados \ninternacionais de destino (mais de um novo país de destino no \nmercado internacional ou um país')),
#  GraphDocument(nodes=[Node(id='Mercado_Internacional', type='Geographiccriterion', properties={}), Node(id='País_Destino', type='Geographiccriterion', properties={}), Node(id='Lista_Principais_Países_Destino', type='Databasetable', properties={}), Node(id='Exportações_Portuguesas', type='Databasetable', properties={}), Node(id='Novo_País_Destino', type='Geographiccriterion', properties={}), Node(id='Relatório_Anual_Do_Ine', type='Grant', properties={}), Node(id='Estatísticas_Da_Pesca', type='Grant', properties={}), Node(id='Www.Ine.Pt/Xportal/Xmain?Xpid=Ine&Xpgid=Ine_Publicacoes&Publicacoestipo=Ea&Publicacoescoleccao=107656&Seltab=Tab0&Xlang=Pt', type='Geographiccriterion', properties={}), Node(id='Classificação_Final_Do_Mérito', type='Databasetable', properties={}), Node(id='Pontuação_Merito_Projeto', type='Databasetable', properties={}), Node(id='Operacão', type='Databasetable', properties={}), Node(id='Avaliação_Técnica_E_Estratégica', type='Databasetable', properties={}), Node(id='Fundos_Europeus', type='Grant', properties={})], relationships=[Relationship(source=Node(id='Mercado_Internacional', type='Geographiccriterion', properties={}), target=Node(id='Lista_Principais_Países_Destino', type='Databasetable', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='País_Destino', type='Geographiccriterion', properties={}), target=Node(id='Novo_País_Destino', type='Geographiccriterion', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Relatório_Anual_Do_Ine', type='Grant', properties={}), target=Node(id='Estatísticas_Da_Pesca', type='Grant', properties={}), type='HASAPPLICATION', properties={}), Relationship(source=Node(id='Classificação_Final_Do_Mérito', type='Databasetable', properties={}), target=Node(id='Pontuação_Merito_Projeto', type='Databasetable', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Operacão', type='Databasetable', properties={}), target=Node(id='Avaliação_Técnica_E_Estratégica', type='Databasetable', properties={}), type='RELATESTO', properties={})], source=Document(metadata={}, page_content='mercado internacional ou um país \nde destino que não integre a lista dos principais países de destino \ndas exportações portuguesas) *  Diversificação dos mercados internacionais de \ndestino (um novo país de \ndestino no mercado internacional)  \nÀ pontuação desta tabela acrescem 10 p.p. caso se trate de introduzir inovação a nível da empresa  \n* aferido com base no Relatório Anual do INE -  Estatísticas da Pesca –  disponível em  \nwww.ine.pt/xportal/xmain?xpid=INE&xpgid=ine_publicacoes&PUBLICACOEStipo=ea&PUBLICACOEScoleccao=10\n7656&selTab=tab0&xlang=pt   \nNão podem ser objeto de seleção as operações cuja classificação final do Mérito do projeto seja inferior a 50 \npontos. Adicionalmente, são excluídas as candidaturas que não obtenham no mínimo 50 pontos em cada uma \ndas Apreciações técnica e estratégica.  \nCaso exista uma insuficiente dotação fixada no Aviso de abertura de candidaturas, face aos pedidos de apoio, as \ncandidaturas são ainda avaliadas de acordo com o seu mérito relativo, que resulta da comparação entre o mérito \nda operação e o mérito das demais  operações candidatas na mesma fase de decisão, com hierarquização final \ndas candidaturas avaliadas, para efeitos de decisão de financiamento.  \nEm caso de igualdade pontual, o critério de desempate é o da pontuação obtida no critério de seleção relativo à \nApreciação Estratégica. Mantendo -se o empate, na pontuação obtida, é, então, utilizada a data de apresentação \nda candidatura prevalecendo as que  tenham sido primeiramente apresentadas . \n \n  Os Fundos Europeus mais próximos de si.  \n           \n \n          19/23 \nComo funciona o processo de análise e decisão das candidaturas  \n \nCalendário de candidaturas  \n \nAbertura  14-11-2023  \nFecho  30-12-2027  \nAnalise  60 dias após receção candidatura  \nData Limite para a comunicação da decisão aos c ...
#  GraphDocument(nodes=[], relationships=[], source=Document(metadata={}, page_content='A análise da candidatura, desenvolvida de acordo com as fases referidas nas alíneas i), ii) e iii), será desenvolvida pela Estrutura de Apoio Técnico do FEAMPA (EAT -FEAMPA) do Coordenador Regional da Madeira, sendo sujeita \na controlo de qualidade pela Coor denação Regional da Madeira do MAR 2030, com a finalidade de garantir o \ncumprimento da plenitude dos normativos aplicáveis e a harmonização das apreciações desenvolvidas, bem como \na avaliar a correlação entre as propostas de sentido favorável e a dotação f inanceira disponível.  \n \n \nDecisão sobre as candidatura s \nA análise das candidaturas é efetuada de acordo com a informação constante do formulário de candidatura e documentos anexos.  \nSob pena de caducidade imediata da candidatura, os elementos solicitados em sede de análise das candidaturas devem ser remetidos no prazo fixado pela autoridade gestão, num máximo de 10 dias úteis contados da receção \ndo pedido de elementos, salvo se o candidato apresentar justificação e a mesma venha a ser aceite pela \nautoridade de gestão.  Os Fundos Europeus mais próximos de si.  \n           \n \n          20/23 \nA decisão fundamentada é proferida no prazo de 60 dias úteis, contados a partir da data de apresentação da \ncandidatura e notificada ao candidato no prazo máximo de 5 dias, a contar da data da sua emissão, conjuntamente com o respetivo termo de aceitação.  \nEste prazo não inclui o prazo legalmente previsto para audiência de interessados  \ne pode ser alargado por até mais 30 dias:  \na) Em caso de apresentação de alegações em sede de audiência de interessados; ou  \nb) Em situações excecionais devidamente fundamentadas, designadamente quando se registe uma elevada procura, devendo o novo prazo ser publicitado na primeira metade do prazo para decisão definido no aviso para apresentação de candidaturas  \n \nOnde são comunicadas as decisões às entidades candidatas  \nAs entidades que se candidatam ao apoio recebem as notificações da proposta de decisão e da decisão final na sua área reservada no Balcão.  \n \nAceitação ou não aceitação da decisã o \nA notificação às entidades que se candidataram inclui a decisão final sobre a sua candidatura, que pode ser de aprovação, total ou parcial, não aprovação ou aprovação condicionada.  \nA aceitação da decisão de aprovação da candidatura é feita pelo beneficiário, no prazo de 30 dias úteis, no sistema de informação do IFAP, I.P. mediante assinatura do termo de aceitação, através de assinatura digital qualificada, com atributos profissionai s suficientes para o ato, que comprove os poderes de representação do beneficiário \npelo subscritor.  \n \nOnde são publicadas as  listas das candidaturas aprovadas  \n• No site do Programa MAR 2030  \n• No site do Portugal 2030.  \n \nPedidos de alteração à candidatura  \nAlterações aos elementos constantes do termo de aceitação estão sujeitas a nova decisão do Coordenador Regional da Madeira do MAR 2030.')),
#  GraphDocument(nodes=[], relationships=[], source=Document(metadata={}, page_content='É necessária a assinatura de um novo termo de aceitação, caso se trate de alterações aos elementos de identificação dos beneficiários e seus representantes legais, à identificação do programa, do fundo, da prioridade, \ndo objetivo específico, da tipologia d e intervenção e/ou operação ou, ainda, alterações ao montante do apoio \npúblico e a respetiva taxa de cofinanciamento, com explicitação das fontes de financiamento europeu e nacional \nou aos indicadores de realização e resultado e as metas a atingir.\n \n \n  Os Fundos Europeus mais próximos de si.  \n           \n \n          21/23 \nAnexos  \n \nAnexo A - Candidatura  \nDocumentos necessários para apresentar uma candidatura ao abrigo da Medida \nTransformação de Produtos da Pesca e da Aquicultura no Domínio dos Investimentos \nProdutivos  \n \n \nAnexo B – Legislação aplicável a este Aviso  \n \n  Os Fundos Europeus mais próximos de si.  \n           \n \n          22/23 \n \nAnexo  A - Documentos necessários para apresentar uma candidatura  \n \n• Apresentar uma análise estratégica da empresa que identifique as áreas de competitividade críticas \npara o negócio em que se insere, diagnostique a situação da empresa nestas áreas críticas e \nfundamente as opções de investimento consideradas na candidatura  \n• Caso se trate de pessoa coletiva: contrato da sociedade, estatutos e certidão permanente atualizados, ou acesso a código para consulta  \n• Memória descritiva e justificativa da operação a desenvolver  \n• Caso inclua instalações em terra, documento que habilite a realização de intervenções no espaço (caderneta predial demonstrando a propriedade do espaço, ou contrato de arrendamento ou autorização da entidade pública competente)  \n• Caso inclua a modernização de instalações, número de controlo veterinário  \n• Caso respeite a nova empresa, relatório de comercialização independente  \n• Orçamentos e catálogos relativos a todos os bens e serviços compreendidos na proposta, em número mínimo de três, com vista a que possa ser aferida a razoabilidade dos custos apresentados  \n• Plano empresarial que permita aferir a viabilidade económico financeira do projeto e, quando o investimento seja superior a 50 mil euros, estudo de viabilidade  \n• Elementos que demonstrem que se encontram asseguradas as fontes de financiamento, incluindo o financiamento por empréstimo bancário, quando necessário, e por um mínimo de 20% de capitais próprios, podendo para o efeito incluir novas entradas de capital, no meadamente capital \nsocial, incorporação de suprimentos e prestações suplementares de capital, desde que venham a ser incorporados em capital próprio ao longo da concretização do projeto e até à sua conclusão material e financeira  \n• Informação Económica Simplificada relativa ao último exercício encerrado à data da submissão da candidatura que evidencie uma situação económico -financeira equilibrada (autonomia financeira \npré-projeto igual ou superior a 15 %), sem prejuízo das situações previstas no n.º 4 do artigo 53.º')),
#  GraphDocument(nodes=[], relationships=[], source=Document(metadata={}, page_content='da Portaria n.º 559/2023, de 25 de julho , em que a existência de situação económico -financeira \nequilibrada fica demonstrada quando os capitais próprios suportarem pelo menos 20% do custo \ntotal do investimento.  \n• Caso se pretenda que, para este efeito, seja usada informação mais recente, poderá apresentar os respetivos balanços e demonstrações de resultados, devidamente certificados por contabilista \ncertificado.  \n• Caso a candidatura seja apresentada em copromoção e preveja a elegibilidade de custos com \npessoal na entidade parceira: relação dos trabalhadores da entidade beneficiária, organizada por categoria profissional/perfil funcional, com referência de remuneraçã o base (vencimento bruto), \nsubsídios de férias, Natal e refeição e contribuições obrigatórias (patronais).  \n Os Fundos Europeus mais próximos de si.  \n           \n \n          23/23 \n \n \n \n \nAnexo  B – Legislação aplicável a este aviso  \n \nEuropeia  \n• Regulamento FEAMPA -  Regulamento (UE) 2021/1139 do Parlamento Europeu e do Conselho, de 7 de \njulho;  \n• Regulamento das Disposições Comuns (RDC) -  Regulamento (UE) 2021/1060 do Parlamento Europeu e \ndo Conselho, de 24 de junho ; \n \nNacional  \n• Decreto -Lei n.º 20 -A/2023, de 22 de março ; \n• Portaria n.º 559/2023, de 25 de julh o, da Secretaria Regional de Mar e Pescas .'))]

# %%
print(f"Nodes:{graph_documents[0].nodes}")
print(f"Relationships:{graph_documents[0].relationships}")
# Out:
# Nodes:[Node(id='Mar2030-2023-22', type='Grant', properties={}), Node(id='Transformação De Produtos Da Pesca E Da Aquicultura No Domínio Dos Investimentos Produtivos - Região Autónoma Da Madeira', type='Grant', properties={}), Node(id='14/11/2023', type='Provenanceinfo', properties={}), Node(id='Operações', type='Geographiccriterion', properties={}), Node(id='Aviso Para Apresentação De Candidaturas', type='Granterapplication', properties={})]
# Relationships:[Relationship(source=Node(id='Mar2030-2023-22', type='Grant', properties={}), target=Node(id='Aviso Para Apresentação De Candidaturas', type='Granterapplication', properties={}), type='HASAPPLICATION', properties={}), Relationship(source=Node(id='Aviso Para Apresentação De Candidaturas', type='Granterapplication', properties={}), target=Node(id='Transformação De Produtos Da Pesca E Da Aquicultura No Domínio Dos Investimentos Produtivos - Região Autónoma Da Madeira', type='Grant', properties={}), type='BELONGSTOAPPLICATION', properties={}), Relationship(source=Node(id='14/11/2023', type='Provenanceinfo', properties={}), target=Node(id='Aviso Para Apresentação De Candidaturas', type='Granterapplication', properties={}), type='HASPROVENANCE', properties={}), Relationship(source=Node(id='Operações', type='Geographiccriterion', properties={}), target=Node(id='Transformação De Produtos Da Pesca E Da Aquicultura No Domínio Dos Investimentos Produtivos - Região Autónoma Da Madeira', type='Grant', properties={}), type='RELATESTO', properties={})]

# %%
def merge_graph_documents(graph_documents):
    """Simple function to merge all nodes and relationships from graph documents."""
    all_nodes = []
    all_relationships = []
    
    # Collect everything
    for doc in graph_documents:
        all_nodes.extend(doc.nodes)
        all_relationships.extend(doc.relationships)
    
    # Remove duplicate nodes by ID
    seen_nodes = set()
    unique_nodes = []
    for node in all_nodes:
        if node.id not in seen_nodes:
            seen_nodes.add(node.id)
            unique_nodes.append(node)
    
    # Remove duplicate relationships
    seen_rels = set()
    unique_relationships = []
    for rel in all_relationships:
        rel_key = (rel.source.id, rel.target.id, rel.type)
        if rel_key not in seen_rels:
            seen_rels.add(rel_key)
            unique_relationships.append(rel)
    
    # Create merged document
    merged_doc = type(graph_documents[0])(
        nodes=unique_nodes,
        relationships=unique_relationships,
        source=graph_documents[0].source
    )
    
    print(f"Merged: {len(unique_nodes)} nodes, {len(unique_relationships)} relationships")
    return [merged_doc]

# Use it
graph_documents = merge_graph_documents(graph_documents)
graph_documents
# Out:
# Merged: 132 nodes, 43 relationships
# [GraphDocument(nodes=[Node(id='Mar2030-2023-22', type='Grant', properties={}), Node(id='Transformação De Produtos Da Pesca E Da Aquicultura No Domínio Dos Investimentos Produtivos - Região Autónoma Da Madeira', type='Grant', properties={}), Node(id='14/11/2023', type='Provenanceinfo', properties={}), Node(id='Operações', type='Geographiccriterion', properties={}), Node(id='Aviso Para Apresentação De Candidaturas', type='Granterapplication', properties={}), Node(id='Região_Autónoma_Da_Madeira', type='Geographiccriterion', properties={}), Node(id='Programa Mar 2030', type='Grant', properties={}), Node(id='+ 351 291 203 250', type='Personlocation', properties={}), Node(id='Drp@Madeira.Gov.Pt', type='Personlocation', properties={}), Node(id='Fundos Europeus Mais Próximos De Si', type='Grant', properties={}), Node(id='Promover A Comercialização, A Qualidade, O Valor Acrescentado Dos Produtos Da Pesca E Da Aquicultura, Assim Como A Transformação Destes Produtos', type='Grant', properties={}), Node(id='Programa  Mar 2030', type='Grant', properties={}), Node(id='2 - Fomentar Atividades De Aquicultura Sustentáveis E A Transformação E Comercialização De Produtos Da Pesca E Da Aquicultura, Contribuindo Assim Para A Segurança Alimentar Da União', type='Grant', properties={}), Node(id='Fso2.2 - Promover A Comercialização, A Qualidade E O Valor Acrescentado Dos Produtos Da Pesca E Da Aquicultura, Assim Como A Transformação Destes Produtos', type='Grant', properties={}), Node(id='Fso2.2 -01-Investimentos Produtivos Na Transformação', type='Grant', properties={}), Node(id='Fso2.2.02 - Investimentos Em Eficiência Energética, A Economia Circular, A Digitalização E A Internacionalização', type='Grant', properties={}), Node(id='Fso2.2 -01-01-Investimentos Produtivos Na Transformação', type='Grant', properties={}), Node(id='Fso2.2.02 -01 - Investimentos Em Eficiência Energética, A Economia Circular, A Digitalização E A Internacionalização', type='Grant', properties={}), Node(id='8503 - Investimento Na Redução Do Consumo De Energia E Na Eficiência Energética', type='Grant', properties={}), Node(id='8504 - Investimento Em Sistemas De Energias Renováveis', type='Grant', properties={}), Node(id='8515 – Investimentos De Apoio Ao Desenvolvimento De Empresas (Desenvolvimento De Estratégias, Administração, Equipamento)', type='Grant', properties={}), Node(id='8517 - Desenvolvimento Da Inovação Comercial', type='Grant', properties={}), Node(id='8518 - Desenvolvimento Da Inovação De Processos', type='Grant', properties={}), Node(id='8519 - Desenvolvimento Da Inovação Do Produto', type='Grant', properties={}), Node(id='8510 – Utilização De Capturas Indesejadas', type='Grant', properties={}), Node(id='8548 – Consumo De Água E Melhoria Da Qualidade Da Água', type='Grant', properties={}), Node(id='8512 - Qualidade Dos Alimentos, Segurança E Higiene', type='Grant', properties={}), Node(id='8546 - Atividades De Comercialização', type='Grant', properties={}), Node(id='8513 - Investimentos Nas Condições De Trabalho', type='Grant', properties={}), Node(id='Feampa', type='Grant', properties={}), Node(id='770 000 €', type='Grant', properties={}), Node(id='330 000 €', type='Grant', properties={}), Node(id='Fonte De Financiamento', type='Grant', properties={}), Node(id='Dotação Global', type='Grant', properties={}), Node(id='10850', type='Databasetable', properties={}), Node(id='Duração_Das_Operacoes', type='Databasetable', properties={}), Node(id='Individualmente_Ou_Em_Copromoção', type='Databasetable', properties={}), Node(id='Ano_Duração', type='Databasetable', properties={}), Node(id='Condições_De_Atribuição_De_Financiamento_Da_Operacao', type='Databasetable', properties={}), Node(id='Taxa_De_Apoio_Publico', type='Databasetable', properties={}), Node(id='Start_Ups_E_Spin_Offs', type='Databasetable', properties={}), Node(id='Organismo_Publico', type='Databasetable', properties={}), Node(id='Demais_Casos', type='Databasetable', properties={}), Node(id='Legislacao_Em_V ...

# %%
print(f"Nodes:{graph_documents[0].nodes}")
print(f"Relationships:{graph_documents[0].relationships}")
# Out:
# Nodes:[Node(id='Mar2030-2023-22', type='Grant', properties={}), Node(id='Transformação De Produtos Da Pesca E Da Aquicultura No Domínio Dos Investimentos Produtivos - Região Autónoma Da Madeira', type='Grant', properties={}), Node(id='14/11/2023', type='Provenanceinfo', properties={}), Node(id='Operações', type='Geographiccriterion', properties={}), Node(id='Aviso Para Apresentação De Candidaturas', type='Granterapplication', properties={}), Node(id='Região_Autónoma_Da_Madeira', type='Geographiccriterion', properties={}), Node(id='Programa Mar 2030', type='Grant', properties={}), Node(id='+ 351 291 203 250', type='Personlocation', properties={}), Node(id='Drp@Madeira.Gov.Pt', type='Personlocation', properties={}), Node(id='Fundos Europeus Mais Próximos De Si', type='Grant', properties={}), Node(id='Promover A Comercialização, A Qualidade, O Valor Acrescentado Dos Produtos Da Pesca E Da Aquicultura, Assim Como A Transformação Destes Produtos', type='Grant', properties={}), Node(id='Programa  Mar 2030', type='Grant', properties={}), Node(id='2 - Fomentar Atividades De Aquicultura Sustentáveis E A Transformação E Comercialização De Produtos Da Pesca E Da Aquicultura, Contribuindo Assim Para A Segurança Alimentar Da União', type='Grant', properties={}), Node(id='Fso2.2 - Promover A Comercialização, A Qualidade E O Valor Acrescentado Dos Produtos Da Pesca E Da Aquicultura, Assim Como A Transformação Destes Produtos', type='Grant', properties={}), Node(id='Fso2.2 -01-Investimentos Produtivos Na Transformação', type='Grant', properties={}), Node(id='Fso2.2.02 - Investimentos Em Eficiência Energética, A Economia Circular, A Digitalização E A Internacionalização', type='Grant', properties={}), Node(id='Fso2.2 -01-01-Investimentos Produtivos Na Transformação', type='Grant', properties={}), Node(id='Fso2.2.02 -01 - Investimentos Em Eficiência Energética, A Economia Circular, A Digitalização E A Internacionalização', type='Grant', properties={}), Node(id='8503 - Investimento Na Redução Do Consumo De Energia E Na Eficiência Energética', type='Grant', properties={}), Node(id='8504 - Investimento Em Sistemas De Energias Renováveis', type='Grant', properties={}), Node(id='8515 – Investimentos De Apoio Ao Desenvolvimento De Empresas (Desenvolvimento De Estratégias, Administração, Equipamento)', type='Grant', properties={}), Node(id='8517 - Desenvolvimento Da Inovação Comercial', type='Grant', properties={}), Node(id='8518 - Desenvolvimento Da Inovação De Processos', type='Grant', properties={}), Node(id='8519 - Desenvolvimento Da Inovação Do Produto', type='Grant', properties={}), Node(id='8510 – Utilização De Capturas Indesejadas', type='Grant', properties={}), Node(id='8548 – Consumo De Água E Melhoria Da Qualidade Da Água', type='Grant', properties={}), Node(id='8512 - Qualidade Dos Alimentos, Segurança E Higiene', type='Grant', properties={}), Node(id='8546 - Atividades De Comercialização', type='Grant', properties={}), Node(id='8513 - Investimentos Nas Condições De Trabalho', type='Grant', properties={}), Node(id='Feampa', type='Grant', properties={}), Node(id='770 000 €', type='Grant', properties={}), Node(id='330 000 €', type='Grant', properties={}), Node(id='Fonte De Financiamento', type='Grant', properties={}), Node(id='Dotação Global', type='Grant', properties={}), Node(id='10850', type='Databasetable', properties={}), Node(id='Duração_Das_Operacoes', type='Databasetable', properties={}), Node(id='Individualmente_Ou_Em_Copromoção', type='Databasetable', properties={}), Node(id='Ano_Duração', type='Databasetable', properties={}), Node(id='Condições_De_Atribuição_De_Financiamento_Da_Operacao', type='Databasetable', properties={}), Node(id='Taxa_De_Apoio_Publico', type='Databasetable', properties={}), Node(id='Start_Ups_E_Spin_Offs', type='Databasetable', properties={}), Node(id='Organismo_Publico', type='Databasetable', properties={}), Node(id='Demais_Casos', type='Databasetable', properties={}), Node(id='Legislacao_Em_Vigor', type='Da ...
# Relationships:[Relationship(source=Node(id='Mar2030-2023-22', type='Grant', properties={}), target=Node(id='Aviso Para Apresentação De Candidaturas', type='Granterapplication', properties={}), type='HASAPPLICATION', properties={}), Relationship(source=Node(id='Aviso Para Apresentação De Candidaturas', type='Granterapplication', properties={}), target=Node(id='Transformação De Produtos Da Pesca E Da Aquicultura No Domínio Dos Investimentos Produtivos - Região Autónoma Da Madeira', type='Grant', properties={}), type='BELONGSTOAPPLICATION', properties={}), Relationship(source=Node(id='14/11/2023', type='Provenanceinfo', properties={}), target=Node(id='Aviso Para Apresentação De Candidaturas', type='Granterapplication', properties={}), type='HASPROVENANCE', properties={}), Relationship(source=Node(id='Operações', type='Geographiccriterion', properties={}), target=Node(id='Transformação De Produtos Da Pesca E Da Aquicultura No Domínio Dos Investimentos Produtivos - Região Autónoma Da Madeira', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Programa Mar 2030', type='Grant', properties={}), target=Node(id='Fundos Europeus Mais Próximos De Si', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Programa Mar 2030', type='Grant', properties={}), target=Node(id='Promover A Comercialização, A Qualidade, O Valor Acrescentado Dos Produtos Da Pesca E Da Aquicultura, Assim Como A Transformação Destes Produtos', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Programa Mar 2030', type='Grant', properties={}), target=Node(id='2 - Fomentar Atividades De Aquicultura Sustentáveis E A Transformação E Comercialização De Produtos Da Pesca E Da Aquicultura, Contribuindo Assim Para A Segurança Alimentar Da União', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Fso2.2 - Promover A Comercialização, A Qualidade E O Valor Acrescentado Dos Produtos Da Pesca E Da Aquicultura, Assim Como A Transformação Destes Produtos', type='Grant', properties={}), target=Node(id='Fso2.2 -01-Investimentos Produtivos Na Transformação', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Fso2.2 -01-Investimentos Produtivos Na Transformação', type='Grant', properties={}), target=Node(id='Fso2.2.02 - Investimentos Em Eficiência Energética, A Economia Circular, A Digitalização E A Internacionalização', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Fso2.2 -01-01-Investimentos Produtivos Na Transformação', type='Grant', properties={}), target=Node(id='8503 - Investimento Na Redução Do Consumo De Energia E Na Eficiência Energética', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Fso2.2.02 -01 - Investimentos Em Eficiência Energética, A Economia Circular, A Digitalização E A Internacionalização', type='Grant', properties={}), target=Node(id='8504 - Investimento Em Sistemas De Energias Renováveis', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Feamp', type='Grant', properties={}), target=Node(id='770 000 €', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Feamp', type='Grant', properties={}), target=Node(id='330 000 €', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='Mapas_De_Remunerações', type='Geographiccriterion', properties={}), target=Node(id='Seguranca_Social', type='Geographiccriterion', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='8515', type='Databasetable', properties={}), target=Node(id='Investimentos De Apoio Ao Desenvolvimento De Empresas', type='Grant', properties={}), type='RELATESTO', properties={}), Relationship(source=Node(id='8517', type='Databasetable', properties={}), target=Node(id='Dese ...

# %% [markdown]
# ## Visualize

# %%
from pyvis.network import Network

def visualize_graph(graph_documents):

    # Create network
    net = Network(height="1200px", width="100%", directed=True,
                      notebook=False, bgcolor="#222222", font_color="white")
    
    nodes = graph_documents[0].nodes
    relationships = graph_documents[0].relationships

    # Build lookup for valid nodes
    node_dict = {node.id: node for node in nodes}
    
    # Filter out invalid edges and collect valid node IDs
    valid_edges = []
    valid_node_ids = set()
    for rel in relationships:
        if rel.source.id in node_dict and rel.target.id in node_dict:
            valid_edges.append(rel)
            valid_node_ids.update([rel.source.id, rel.target.id])


    # Track which nodes are part of any relationship
    connected_node_ids = set()
    for rel in relationships:
        connected_node_ids.add(rel.source.id)
        connected_node_ids.add(rel.target.id)

    # Add valid nodes
    for node_id in valid_node_ids:
        node = node_dict[node_id]
        try:
            net.add_node(node.id, label=node.id, title=node.type, group=node.type)
        except:
            continue  # skip if error

    # Add valid edges
    for rel in valid_edges:
        try:
            net.add_edge(rel.source.id, rel.target.id, label=rel.type.lower())
        except:
            continue  # skip if error

    # Configure physics
    net.set_options("""
            {
                "physics": {
                    "forceAtlas2Based": {
                        "gravitationalConstant": -100,
                        "centralGravity": 0.01,
                        "springLength": 200,
                        "springConstant": 0.08
                    },
                    "minVelocity": 0.75,
                    "solver": "forceAtlas2Based"
                }
            }
            """)
        
    output_file = "knowledge_graph.html"
    net.save_graph(output_file)
    print(f"Graph saved to {os.path.abspath(output_file)}")

    # Try to open in browser
    try:
        import webbrowser
        webbrowser.open(f"file://{os.path.abspath(output_file)}")
    except:
        print("Could not open browser automatically")
        
# Run the function
visualize_graph(graph_documents)
# Out:
# Graph saved to c:\Users\tiago\Documents\Granter Ai Internship\Implementation\KGs_for_Vertical_AI\knowledge_graph.html

# %% [markdown]
# # Saving to csv

# %%
import re
from rdflib import Graph, RDF, OWL
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from langchain_experimental.graph_transformers import LLMGraphTransformer
from pyvis.network import Network
import pandas as pd

import asyncio

from langchain_openai import AzureChatOpenAI
import os
from dotenv import load_dotenv
load_dotenv()
AZURE_OPENAI_API_KEY = os.getenv("AZURE_OPENAI_API_KEY")
AZURE_OPENAI_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
AZURE_OPENAI_API_VERSION = os.getenv("AZURE_OPENAI_API_VERSION")

AZURE_DEPLOYMENT_GPT41 = os.getenv("AZURE_DEPLOYMENT_GPT41")
AZURE_DEPLOYMENT_GPT41_NANO = os.getenv("AZURE_DEPLOYMENT_GPT41_NANO")

gpt41_nano = AzureChatOpenAI(
    azure_deployment=AZURE_DEPLOYMENT_GPT41_NANO,
    api_version=AZURE_OPENAI_API_VERSION,
    azure_endpoint=AZURE_OPENAI_ENDPOINT,
    api_key=AZURE_OPENAI_API_KEY,
    temperature = 0.0
)


# ---------------------------------- TOOLS ----------------------------------


def extract_ontology_lexical_view(ontology_path: str) -> list:
    """
    Returns format: ['label: comment', 'label2: comment2']
    Pairs labels with their corresponding comments
    """
    with open(ontology_path, 'r', encoding='utf-8') as f:
        content = f.read()
        
    lexical_view = []
    
    # Find all rdfs:label and rdfs:comment matches with their positions
    label_pattern = r'rdfs:label\s+"([^"]+)"'
    comment_pattern = r'rdfs:comment\s+"([^"]+)"'
    
    # Get all matches in order
    labels = [match.group(1).replace(" ", "") for match in re.finditer(label_pattern, content)]
    comments = [match.group(1) for match in re.finditer(comment_pattern, content)]

    # Pair them sequentially (comment[i] goes with label[i])
    for i in range(len(labels)):
        if i < len(comments):
            lexical_view.append(f"{labels[i]}: {comments[i]}")
        else:
            lexical_view.append(f"{labels[i]}: ")
    
    return lexical_view




def extract_local_names(ttl_file_path):
    """
    Extract ontology elements (local names without full URIs).
    Returns:
        - class_names: ontology classes (entities)
        - object_property_names: ontology object properties (relationships)
        - datatype_property_names: ontology datatype properties (attributes)
    """
    g = Graph()
    g.parse(ttl_file_path, format="turtle")
    
    def get_local_name(uri):
        uri_str = str(uri)
        if '#' in uri_str: 
            return uri_str.split('#')[-1]
        return uri_str.split('/')[-1]
    
    # Classes
    class_uris = [s for s, _, _ in g.triples((None, RDF.type, OWL.Class))]
    class_names = [get_local_name(uri) for uri in class_uris]
    
    # Object properties
    object_prop_uris = [s for s, _, _ in g.triples((None, RDF.type, OWL.ObjectProperty))]
    object_property_names = [get_local_name(uri) for uri in object_prop_uris]
    
    # Datatype properties
    data_prop_uris = [s for s, _, _ in g.triples((None, RDF.type, OWL.DatatypeProperty))]
    datatype_property_names = [get_local_name(uri) for uri in data_prop_uris]
    
    return (
        sorted(class_names),
        sorted(object_property_names),
        sorted(datatype_property_names),
    )




def chunk_document(document, chunk_size=3000, chunk_overlap=50):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap
    )
    return text_splitter.split_documents([document])




def merge_graph_documents(graph_documents):
    """Simple function to merge all nodes and relationships from graph documents."""

    all_nodes = []
    all_relationships = []
    
    # Collect everything
    for doc in graph_documents:
        all_nodes.extend(doc.nodes)
        all_relationships.extend(doc.relationships)
    
    # Remove duplicate nodes by ID
    seen_nodes = set()
    unique_nodes = []
    for node in all_nodes:
        if node.id not in seen_nodes:
            seen_nodes.add(node.id)
            unique_nodes.append(node)
    
    # Remove duplicate relationships
    seen_rels = set()
    unique_relationships = []
    for rel in all_relationships:
        rel_key = (rel.source.id, rel.target.id, rel.type)
        if rel_key not in seen_rels:
            seen_rels.add(rel_key)
            unique_relationships.append(rel)
    
    # Create merged document
    merged_doc = type(graph_documents[0])(
        nodes=unique_nodes,
        relationships=unique_relationships,
        source=graph_documents[0].source
    )
    
    print(f"Merged: {len(unique_nodes)} nodes, {len(unique_relationships)} relationships")
    return [merged_doc]




def visualize_graph(graph_documents):
    """
    Code from https://github.com/thu-vu92/knowledge-graph-llms/tree/main
    """

    # Create network
    net = Network(height="1200px", width="100%", directed=True,
                      notebook=False, bgcolor="#222222", font_color="white")
    
    nodes = graph_documents[0].nodes
    relationships = graph_documents[0].relationships

    # Build lookup for valid nodes
    node_dict = {node.id: node for node in nodes}
    
    # Filter out invalid edges and collect valid node IDs
    valid_edges = []
    valid_node_ids = set()
    for rel in relationships:
        if rel.source.id in node_dict and rel.target.id in node_dict:
            valid_edges.append(rel)
            valid_node_ids.update([rel.source.id, rel.target.id])


    # Track which nodes are part of any relationship
    connected_node_ids = set()
    for rel in relationships:
        connected_node_ids.add(rel.source.id)
        connected_node_ids.add(rel.target.id)

    # Add valid nodes
    for node_id in valid_node_ids:
        node = node_dict[node_id]
        try:
            net.add_node(node.id, label=node.id, title=node.type, group=node.type)
        except:
            continue  # skip if error

    # Add valid edges
    for rel in valid_edges:
        try:
            net.add_edge(rel.source.id, rel.target.id, label=rel.type.lower())
        except:
            continue  # skip if error

    # Configure physics
    net.set_options("""
            {
                "physics": {
                    "forceAtlas2Based": {
                        "gravitationalConstant": -100,
                        "centralGravity": 0.01,
                        "springLength": 200,
                        "springConstant": 0.08
                    },
                    "minVelocity": 0.75,
                    "solver": "forceAtlas2Based"
                }
            }
            """)
        
    output_file = "knowledge_graph.html"
    net.save_graph(output_file)
    print(f"Graph saved to {os.path.abspath(output_file)}")

    # Try to open in browser
    try:
        import webbrowser
        webbrowser.open(f"file://{os.path.abspath(output_file)}")
    except:
        print("Could not open browser automatically")




def save_graph_to_csv(graph_documents, output_file="knowledge_graph.csv"):
    """
    Save the knowledge graph to CSV format with structure (object, relation, subject).
    
    Args:
        graph_documents: The graph documents from LLMGraphTransformer
        output_file: Output CSV filename
    """
    relationships = graph_documents[0].relationships
    
    # Extract triples in (object, relation, subject) format
    triples = []
    for rel in relationships:
        triple = {
            'object': rel.source.id,      # source node as object
            'relation': rel.type,         # relationship type
            'subject': rel.target.id      # target node as subject
        }
        triples.append(triple)
    
    # Create DataFrame and save to CSV
    df = pd.DataFrame(triples)
    df.to_csv(output_file, index=False)
    
    print(f"Graph saved to CSV: {os.path.abspath(output_file)}")
    print(f"Total triples: {len(triples)}")


# ---------------------------------- RUNNING ----------------------------------


classes, relations, attributes = extract_local_names('results/ontologies/rdb/rigor_ontology_few_fixes.ttl')

input_txt_folder = "data/texts"
for filename in os.listdir(input_txt_folder):
    if filename.endswith('opportunity_example_eng.txt'):
        file_path = os.path.join(input_txt_folder, filename)
        print(f"Processing {filename}...")

        try:
            with open(file_path, 'r', encoding='utf-8') as file:
                content = file.read()
        except Exception as e:
            print(f"Error processing {filename}: {e}")


document = Document(page_content=content)
chunks = chunk_document(document)

graph_transformer = LLMGraphTransformer(llm = gpt41_nano,
                                    allowed_nodes = classes,
                                    allowed_relationships=relations)


graph_documents = await graph_transformer.aconvert_to_graph_documents(chunks)

graph_documents = merge_graph_documents(graph_documents)
# Out:
# Processing opportunity_example_eng.txt...
# Merged: 81 nodes, 65 relationships

# %%
visualize_graph(graph_documents)
# Out:
# Graph saved to c:\Users\tiago\Documents\Granter Ai Internship\Implementation\KGs_for_Vertical_AI\approaches\02_knowledge_graphs\knowledge_graph.html

# %%
def save_graph(graph_documents, output_file="graph.csv"):
    nodes = graph_documents[0].nodes
    relationships = graph_documents[0].relationships
    
    # Create a mapping from node IDs to sequential integers
    node_id_mapping = {}
    sequential_id = 1
    
    for node in nodes:
        if node.id not in node_id_mapping:
            node_id_mapping[node.id] = sequential_id
            sequential_id += 1
    
    # Prepare data for CSV
    csv_data = []
    
    # Add header for nodes section
    csv_data.append("node_id,node_attr")
    
    # Add nodes with their attributes
    for node in nodes:
        node_id = node_id_mapping[node.id]
        # Format: "Type: NodeName" or just "NodeName" if no type
        if hasattr(node, 'type') and node.type:
            node_attr = f"{node.type}: {node.id}"
        else:
            node_attr = node.id
        
        csv_data.append(f'{node_id},"{node_attr}"')
    
    # Add empty line separator
    csv_data.append("")
    
    # Add header for edges section
    csv_data.append("src,edge_attr,dst")
    
    # Add edges
    for rel in relationships:
        src_id = node_id_mapping.get(rel.source.id)
        dst_id = node_id_mapping.get(rel.target.id)
        
        # Skip if either node ID is not found
        if src_id is None or dst_id is None:
            continue
            
        edge_attr = rel.type
        csv_data.append(f'{src_id},"{edge_attr}",{dst_id}')
    
    # Write to file
    with open(output_file, 'w', encoding='utf-8') as f:
        f.write('\n'.join(csv_data))
    
    print(f"Graph saved to: {os.path.abspath(output_file)}")
    print(f"Total nodes: {len(nodes)}")
    print(f"Total edges: {len(relationships)}")
    print(f"Node ID mapping: {node_id_mapping}")
    
    return node_id_mapping

# %%
save_graph(graph_documents)
# Out:
# Graph saved to: c:\Users\tiago\Documents\Granter Ai Internship\Implementation\KGs_for_Vertical_AI\approaches\02_knowledge_graphs\gretriever_graph.csv
# Total nodes: 93
# Total edges: 70
# Node ID mapping: {'Mar2030 -2023 -22': 1, 'Transformação De Produtos Da Pesca E Da Aquicultura Na Região Autónoma Da Madeira': 2, '14/11/2023': 3, 'Concurso': 4, 'Operações': 5, 'Srmar': 6, '25/07/2023': 7, 'Article 50.º Da Portaria N.º 559/2023': 8, 'Região Autónoma Da Madeira': 9, 'Programa Mar 2030': 10, '+ 351 291 203 250': 11, 'Drp@Madeira.Gov.Pt': 12, 'Fundos Europeus Mais Próximos De Si.': 13, 'Promover A Comercialização, A Qualidade, O Valor Acrescentado Dos Produtos Da Pesca E Da Aquicultura, Assim Como A Transformação Destes Produtos.': 14, 'Programa  Mar 2030': 15, '2 - Fomentar Atividades De Aquicultura Sustentáveis E A Transformação E Comercialização De Produtos Da Pesca E Da Aquicultura, Contribuindo Assim Para A Segurança Alimentar Da União': 16, 'Fso2.2': 17, 'Fso2.2 -01-Investimentos Produtivos Na Transformação': 18, 'Fso2.2.02 - Investimentos Em Eficiência Energética, A Economia Circular, A Digitalização E A Internacionalização': 19, 'Fso2.2 -01-01-Investimentos Produtivos Na Transformação': 20, 'Fso2.2.02 -01 - Investimentos Em Eficiência Energética, A Economia Circular, A Digitalização E A Internacionalização': 21, '8503': 22, 'Investimento Na Redução Do Consumo De Energia E Na Eficiência Energética': 23, '8504': 24, 'Investimento Em Sistemas De Energias Renováveis': 25, '8515': 26, 'Investimentos De Apoio Ao Desenvolvimento De Empresas (Desenvolvimento De Estratégias, Administração, Equipamento)': 27, '8517': 28, 'Desenvolvimento Da Inovação Comercial': 29, '8518': 30, 'Desenvolvimento Da Inovação De Processos': 31, '8519': 32, 'Desenvolvimento Da Inovação Do Produto': 33, '8510': 34, 'Utilização De Capturas Indesejadas': 35, '8548': 36, 'Consumo De Água E Melhoria Da Qualidade Da Água': 37, '8512': 38, 'Qualidade Dos Alimentos, Segurança E Higiene': 39, '8546': 40, 'Atividades De Comercialização': 41, '8513': 42, 'Investimentos Nas Condições De Trabalho': 43, 'Feampa': 44, '770 000 €': 45, '330 000 € Orçamento De Investimento': 46, 'Dotação Global': 47, 'Regulamento Específico': 48, '10850': 49, 'Escrituras_Taxes_Emolumentos': 50, 'Contratacao_Quadros_Tecnicos': 51, 'Despesas_Formacao_Profissional': 52, 'Beneficiarios_Parceiros': 53, 'Co-Promocao_Operacoes': 54, 'Custos_Diretos_Pessoal': 55, 'Taxa_Fixa_40_Por_Cento': 56, 'Social_Security_Maps': 57, 'Co01': 58, 'Operações Aprovadas': 59, 'Indicador': 60, 'N.º': 61, 'Somatório Simples': 62, 'Program A Mar 2030': 63, 'Fso2.2.2-01-01-Investimentos Produtivos Na Transformação': 64, 'Fso2.2.02-01-Investimentos Em Eficiência Energética, A Economia Circular, A Digitalização E A Internacionalização': 65, 'Cr14': 66, 'Inovações Possibilitadas': 67, 'N.º De Inovações': 68, 'Número De Inovações Implementadas Ou Testadas Para Novos Produtos, Serviços, Processos , Modelos De Negócio Ou Métodos De Produção': 69, 'Cr17': 70, 'Cr04': 71, 'Cr18.1': 72, 'Consumo De Energia Por Tonelada Produzida Antes Do Investimento': 73, 'Consumo De Energia Por Tonelada Produzida Após O Investimento': 74, 'Candidatura': 75, 'Metodologia De Cálculo': 76, 'Alterations_To_Identification_Elements': 77, 'Beneficiaries': 78, 'Legal_Representatives': 79, 'Program': 80, 'Fund': 81, 'Priority': 82, 'Specific_Objective': 83, 'Intervention_Type': 84, 'Operation': 85, 'Support_Amount': 86, 'Cofunding_Rate': 87, 'Financing_Sources': 88, 'European_Financing_Sources': 89, 'National_Financing_Sources': 90, 'Performance_Indicators': 91, 'Performance_Results': 92, 'Goals': 93}
# {'Mar2030 -2023 -22': 1,
#  'Transformação De Produtos Da Pesca E Da Aquicultura Na Região Autónoma Da Madeira': 2,
#  '14/11/2023': 3,
#  'Concurso': 4,
#  'Operações': 5,
#  'Srmar': 6,
#  '25/07/2023': 7,
#  'Article 50.º Da Portaria N.º 559/2023': 8,
#  'Região Autónoma Da Madeira': 9,
#  'Programa Mar 2030': 10,
#  '+ 351 291 203 250': 11,
#  'Drp@Madeira.Gov.Pt': 12,
#  'Fundos Europeus Mais Próximos De Si.': 13,
#  'Promover A Comercialização, A Qualidade, O Valor Acrescentado Dos Produtos Da Pesca E Da Aquicultura, Assim Como A Transformação Destes Produtos.': 14,
#  'Programa  Mar 2030': 15,
#  '2 - Fomentar Atividades De Aquicultura Sustentáveis E A Transformação E Comercialização De Produtos Da Pesca E Da Aquicultura, Contribuindo Assim Para A Segurança Alimentar Da União': 16,
#  'Fso2.2': 17,
#  'Fso2.2 -01-Investimentos Produtivos Na Transformação': 18,
#  'Fso2.2.02 - Investimentos Em Eficiência Energética, A Economia Circular, A Digitalização E A Internacionalização': 19,
#  'Fso2.2 -01-01-Investimentos Produtivos Na Transformação': 20,
#  'Fso2.2.02 -01 - Investimentos Em Eficiência Energética, A Economia Circular, A Digitalização E A Internacionalização': 21,
#  '8503': 22,
#  'Investimento Na Redução Do Consumo De Energia E Na Eficiência Energética': 23,
#  '8504': 24,
#  'Investimento Em Sistemas De Energias Renováveis': 25,
#  '8515': 26,
#  'Investimentos De Apoio Ao Desenvolvimento De Empresas (Desenvolvimento De Estratégias, Administração, Equipamento)': 27,
#  '8517': 28,
#  'Desenvolvimento Da Inovação Comercial': 29,
#  '8518': 30,
#  'Desenvolvimento Da Inovação De Processos': 31,
#  '8519': 32,
#  'Desenvolvimento Da Inovação Do Produto': 33,
#  '8510': 34,
#  'Utilização De Capturas Indesejadas': 35,
#  '8548': 36,
#  'Consumo De Água E Melhoria Da Qualidade Da Água': 37,
#  '8512': 38,
#  'Qualidade Dos Alimentos, Segurança E Higiene': 39,
#  '8546': 40,
#  'Atividades De Comercialização': 41,
#  '8513': 42,
#  'Investimentos Nas Condições De Trabalho': 43,
#  'Feampa': 44,
#  '770 000 €': 45,
#  '330 000 € Orçamento De Investimento': 46,
#  'Dotação Global': 47,
#  'Regulamento Específico': 48,
#  '10850': 49,
#  'Escrituras_Taxes_Emolumentos': 50,
#  'Contratacao_Quadros_Tecnicos': 51,
#  'Despesas_Formacao_Profissional': 52,
#  'Beneficiarios_Parceiros': 53,
#  'Co-Promocao_Operacoes': 54,
#  'Custos_Diretos_Pessoal': 55,
#  'Taxa_Fixa_40_Por_Cento': 56,
#  'Social_Security_Maps': 57,
#  'Co01': 58,
#  'Operações Aprovadas': 59,
#  'Indicador': 60,
#  'N.º': 61,
#  'Somatório Simples': 62,
#  'Program A Mar 2030': 63,
#  'Fso2.2.2-01-01-Investimentos Produtivos Na Transformação': 64,
#  'Fso2.2.02-01-Investimentos Em Eficiência Energética, A Economia Circular, A Digitalização E A Internacionalização': 65,
#  'Cr14': 66,
#  'Inovações Possibilitadas': 67,
#  'N.º De Inovações': 68,
#  'Número De Inovações Implementadas Ou Testadas Para Novos Produtos, Serviços, Processos , Modelos De Negócio Ou Métodos De Produção': 69,
#  'Cr17': 70,
#  'Cr04': 71,
#  'Cr18.1': 72,
#  'Consumo De Energia Por Tonelada Produzida Antes Do Investimento': 73,
#  'Consumo De Energia Por Tonelada Produzida Após O Investimento': 74,
#  'Candidatura': 75,
#  'Metodologia De Cálculo': 76,
#  'Alterations_To_Identification_Elements': 77,
#  'Beneficiaries': 78,
#  'Legal_Representatives': 79,
#  'Program': 80,
#  'Fund': 81,
#  'Priority': 82,
#  'Specific_Objective': 83,
#  'Intervention_Type': 84,
#  'Operation': 85,
#  'Support_Amount': 86,
#  'Cofunding_Rate': 87,
#  'Financing_Sources': 88,
#  'European_Financing_Sources': 89,
#  'National_Financing_Sources': 90,
#  'Performance_Indicators': 91,
#  'Performance_Results': 92,
#  'Goals': 93}
