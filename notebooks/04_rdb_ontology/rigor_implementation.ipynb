# %% [markdown]
# # Setup and imports

# %%
import re
from pprint import pprint
import json
from langchain_ollama import OllamaLLM, OllamaEmbeddings
import os # remove from here

from langchain_community.vectorstores import FAISS
from langchain.schema import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter

llama32 = OllamaLLM(model="llama3.2:3b", temperature=0)
embedding = OllamaEmbeddings(model="nomic-embed-text:v1.5")

# %%
from langchain_openai import AzureChatOpenAI
import os
from dotenv import load_dotenv
load_dotenv()
AZURE_OPENAI_API_KEY = os.getenv("AZURE_OPENAI_API_KEY")
AZURE_OPENAI_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
AZURE_OPENAI_API_VERSION = os.getenv("AZURE_OPENAI_API_VERSION")

AZURE_DEPLOYMENT_GPT41 = os.getenv("AZURE_DEPLOYMENT_GPT41")
AZURE_DEPLOYMENT_GPT41_NANO = os.getenv("AZURE_DEPLOYMENT_GPT41_NANO")

gpt41_nano = AzureChatOpenAI(
    azure_deployment=AZURE_DEPLOYMENT_GPT41_NANO,
    api_version=AZURE_OPENAI_API_VERSION,
    azure_endpoint=AZURE_OPENAI_ENDPOINT,
    api_key=AZURE_OPENAI_API_KEY,
    temperature=0.0
)

# %% [markdown]
# # Data Structures

# %% [markdown]
# ## Database Schema

# %%
def parse_mysql_ddl_file(filepath):
    with open(filepath, 'r', encoding='utf-8') as f:
        ddl = f.read()

    # Remove comments and MySQL directives
    ddl = re.sub(r'/\*.*?\*/', '', ddl, flags=re.DOTALL)
    ddl = re.sub(r'--.*?$', '', ddl, flags=re.MULTILINE)
    ddl = re.sub(r'/\!.*?\*/;', '', ddl, flags=re.DOTALL)
    ddl = re.sub(r'/\!.*?\*/', '', ddl, flags=re.DOTALL)

    # Find all CREATE TABLE statements (handles backticks and multiline)
    table_regex = re.compile(
        r'CREATE TABLE\s+`?(\w+)`?\s*\((.*?)\)\s*ENGINE=.*?;',
        re.DOTALL | re.IGNORECASE
    )
    tables = table_regex.findall(ddl)
    result = {}

    for table_name, table_body in tables:
        # Raw DDL - not used anymore
        raw_ddl = f"CREATE TABLE `{table_name}` ({table_body});"

        # Split lines, remove empty and trailing commas
        lines = [line.strip().rstrip(',') for line in table_body.splitlines() if line.strip()]
        columns = []
        primary_keys = []
        foreign_keys = []

        for line in lines:
            # Column definition (starts with backtick or word, not constraint)
            if re.match(r'^`?\w+`?\s', line) and not line.upper().startswith(('PRIMARY KEY', 'FOREIGN KEY', 'CONSTRAINT', 'UNIQUE', 'KEY')):
                col_name = re.match(r'^`?(\w+)`?', line).group(1)
                columns.append(col_name)
            # Primary key
            elif line.upper().startswith('PRIMARY KEY'):
                pk_match = re.search(r'\((.*?)\)', line)
                if pk_match:
                    pk_cols = [col.strip(' `') for col in pk_match.group(1).split(',')]
                    primary_keys.extend(pk_cols)
            # Foreign key
            elif line.upper().startswith('CONSTRAINT') and 'FOREIGN KEY' in line.upper():
                fk_match = re.search(r'FOREIGN KEY\s*\((.*?)\)\s*REFERENCES\s*`?(\w+)`?\s*\((.*?)\)', line, re.IGNORECASE)
                if fk_match:
                    fk_cols = [col.strip(' `') for col in fk_match.group(1).split(',')]
                    ref_table = fk_match.group(2)
                    ref_cols = [col.strip(' `') for col in fk_match.group(3).split(',')]
                    foreign_keys.append({
                        'columns': fk_cols,
                        'ref_table': ref_table,
                        'ref_columns': ref_cols
                    })

        result[table_name] = {
            'columns': columns,
            'primary_keys': primary_keys,
            'foreign_keys': foreign_keys
        }

    return result

# %%
schema = parse_mysql_ddl_file('../../database/schema/usable_schema.sql')
pprint(schema)
# Out:
# {'granter_application': {'columns': ['id',
#                                      'created_at',
#                                      'updated_at',
#                                      'state',
#                                      'codename',
#                                      'title',
#                                      'other_data',
#                                      'company_id',
#                                      'opportunity_id',
#                                      'profile_creator_id',
#                                      'pricing_option',
#                                      'ai_review_state',
#                                      'consortium_id',
#                                      'sale_confirmed',
#                                      'approved_grant_amount',
#                                      'success_fee',
#                                      'success_payment_amount',
#                                      'upfront_payment_amount',
#                                      'initial_summary',
#                                      'writer_mode'],
#                          'foreign_keys': [{'columns': ['company_id'],
#                                            'ref_columns': ['id'],
#                                            'ref_table': 'granter_company'},
#                                           {'columns': ['consortium_id'],
#                                            'ref_columns': ['id'],
#                                            'ref_table': 'granter_consortium'},
#                                           {'columns': ['opportunity_id'],
#                                            'ref_columns': ['id'],
#                                            'ref_table': 'granter_opportunity'},
#                                           {'columns': ['profile_creator_id'],
#                                            'ref_columns': ['id'],
#                                            'ref_table': 'granter_profile'}],
#                          'primary_keys': ['id']},
#  'granter_applicationfile': {'columns': ['id',
#                                          'created_at',
#                                          'updated_at',
#                                          'name',
#                                          'uploaded_file',
#                                          'vector_indexed',
#                                          'type',
#                                          'application_id',
#                                          'document_type_id'],
#                              'foreign_keys': [{'columns': ['application_id'],
#                                                'ref_columns': ['id'],
#                                                'ref_table': 'granter_application'},
#                                               {'columns': ['document_type_id'],
#                                                'ref_columns': ['id'],
#                                                'ref_table': 'granter_doctype'}],
#                              'primary_keys': ['id']},
#  'granter_company': {'columns': ['id',
#                                  'created_at',
#                                  'updated_at',
#                                  'name',
#                                  'legal_name',
#                                  'address',
#                                  'post_code',
#                                  'city',
#                                  'country',
#                                  'url',
#                                  'legal_form',
#                                  'activity_date',
#                                  'company_id',
#                                  'tax_id',
#                                  'social_security_id',
#                                  'is_sme',
#                                  'employees_n',
#                                  'annual_revenue',
#                                  'description',
#                                  'cover_image',
#                                  'website_data',
#                                  'owner_id',
#                                  'stripe_customer_id',
#                                  'digital_component',
#                                  'future_goals_infrastructure',
#                                  'future_goals_internationalization',
#                                  'future_goals_machinery_and_equipments',
#                                  'future_goals_marketing',
#                                  'future_goals_rd',
#                                  'green_component',
#                                  'team_description',
#                                  'future_goals_hr',
#                                  'onboarding_state',
#                                  'matches_generating',
#                                  'userless',
#                                  'cae',
#                                  'whitelabel_id',
#                                  'related_operations',
#                                  'shareholders',
#                                  'other_data',
#                                  'source',
#                                  'subscription_id',
#                                  'extra_information',
#                                  'matching_order',
#                                  'agent_language'],
#                      'foreign_keys': [{'columns': ['owner_id'],
#                                        'ref_columns': ['id'],
#                                        'ref_table': 'granter_profile'},
#                                       {'columns': ['subscription_id'],
#                                        'ref_columns': ['id'],
#                                        'ref_table': 'granter_subscription'},
#                                       {'columns': ['whitelabel_id'],
#                                        'ref_columns': ['id'],
#                                        'ref_table': 'granter_whitelabel'}],
#                      'primary_keys': ['id']},
#  'granter_companyfile': {'columns': ['id',
#                                      'created_at',
#                                      'updated_at',
#                                      'name',
#                                      'uploaded_file',
#                                      'company_id',
#                                      'document_type_id',
#                                      'vector_indexed',
#                                      'codename',
#                                      'type',
#                                      'uploaded_by_id'],
#                          'foreign_keys': [{'columns': ['company_id'],
#                                            'ref_columns': ['id'],
#                                            'ref_table': 'granter_company'},
#                                           {'columns': ['document_type_id'],
#                                            'ref_columns': ['id'],
#                                            'ref_table': 'granter_doctype'},
#                                           {'columns': ['uploaded_by_id'],
#                                            'ref_columns': ['id'],
#                                            'ref_table': 'granter_profile'}],
#                          'primary_keys': ['id']},
#  'granter_companymemory': {'columns': ['id',
#                                        'created_at',
#                                        'updated_at',
#                                        'content',
#                                        'vector_indexed',
#                                        'company_id',
#                                        'created_by_id',
#                                        'type'],
#                            'foreign_keys': [{'columns': ['created_by_id'],
#                                              'ref_columns': ['id'],
#                                              'ref_table': 'granter_profile'},
#                                             {'columns': ['company_id'],
#                                              'ref_columns': ['id'],
#                                              'ref_table': 'granter_company'}],
#                            'primary_keys': ['id']},
#  'granter_consortium': {'columns': ['id',
#                                     'created_at',
#                                     'updated_at',
#                                     'opportunity_id',
#                                     'project_description',
#                                     'state'],
#                         'foreign_keys': [{'columns': ['opportunity_id'],
#                                           'ref_columns': ['id'],
#                                           'ref_table': 'granter_opportunity'}],
#                         'primary_keys': ['id']},
#  'granter_consortiumpartner': {'columns': ['id',
#                                            'created_at',
#                                            'updated_at',
#                                            'partner_description',
#                                            'company_id',
#                                            'consortium_id',
#                                            'partner_type_id'],
#                                'foreign_keys': [{'columns': ['company_id'],
#                                                  'ref_columns': ['id'],
#                                                  'ref_table': 'granter_company'},
#                                                 {'columns': ['consortium_id'],
#                                                  'ref_columns': ['id'],
#                                                  'ref_table': 'granter_consortium'},
#                                                 {'columns': ['partner_type_id'],
#                                                  'ref_columns': ['id'],
#                                                  'ref_table': 'granter_consortiumpartnertype'}],
#                                'primary_keys': ['id']},
#  'granter_consortiumpartnertype': {'columns': ['id',
#                                                'created_at',
#                                                'updated_at',
#                                                'codename',
#                                                'description',
#                                                'description_en',
#                                                'description_pt',
#                                                'title',
#                                                'title_en',
#                                                'title_pt',
#                                                'type',
#                                                'description_es',
#                                                'description_it',
#                                                'description_pl',
#                                                'title_es',
#                                                'title_it',
#                                                'title_pl'],
#                                    'foreign_keys': [],
#                                    'primary_keys': ['id']},
#  'granter_consortiumpartnertype_consortium': {'columns': ['id',
#                                                           'consortiumpartnertype_id',
#                                                           'consortium_id'],
#                                               'foreign_keys': [{'columns': ['consortium_id'],
#                                                                 'ref_columns': ['id'],
#                                                                 'ref_table': 'granter_consortium'},
#                                                                {'columns': ['consortiumpartnertype_id'],
#                                                                 'ref_columns': ['id'],
#                                                                 'ref_table': 'granter_consortiumpartnertype'}],
#                                               'primary_keys': ['id']},
#  'granter_eligibilitycriteria': {'columns': ['id',
#                                              'title',
#                                              'description',
#                                              'opportunity_id'],
#                                  'foreign_keys': [{'columns': ['opportunity_id'],
#                                                    'ref_columns': ['id'],
#                                                    'ref_table': 'granter_opportunity'}],
#                                  'primary_keys': ['id']},
#  'granter_generalopportunityfile': {'columns': ['id',
#                                                 'created_at',
#                                                 'updated_at',
#                                                 'codename',
#                                                 'name',
#                                                 'uploaded_file'],
#                                     'foreign_keys': [],
#                                     'primary_keys': ['id']},
#  'granter_generalopportunityfile_opportunities': {'columns': ['id',
#                                                               'generalopportunityfile_id',
#                                                               'opportunity_id'],
#                                                   'foreign_keys': [{'columns': ['generalopportunityfile_id'],
#                                                                     'ref_columns': ['id'],
#                                                                     'ref_table': 'granter_generalopportunityfile'},
#                                                                    {'columns': ['opportunity_id'],
#                                                                     'ref_columns': ['id'],
#                                                                     'ref_table': 'granter_opportunity'}],
#                                                   'primary_keys': ['id']},
#  'granter_matchgroup': {'columns': ['id',
#                                     'created_at',
#                                     'updated_at',
#                                     'status',
#                                     'fundamentation',
#                                     'company_id',
#                                     'opportunity_id'],
#                         'foreign_keys': [{'columns': ['company_id'],
#                                           'ref_columns': ['id'],
#                                           'ref_table': 'granter_company'},
#                                          {'columns': ['opportunity_id'],
#                                           'ref_columns': ['id'],
#                                           'ref_table': 'granter_opportunity'}],
#                         'primary_keys': ['id']},
#  'granter_opportunity': {'columns': ['id',
#                                      'created_at',
#                                      'updated_at',
#                                      'type',
#                                      'codename',
#                                      'state',
#                                      'name',
#                                      'fe_value',
#                                      'url',
#                                      'description',
#                                      'cover_image',
#                                      'upfront_fee',
#                                      'force_closing_soon',
#                                      'assistant_id',
#                                      'last_email_reminder',
#                                      'prep_time',
#                                      'location',
#                                      'last_email_push',
#                                      'free_applications',
#                                      'internal_submission',
#                                      'small_cover_image',
#                                      'crawler_data_id',
#                                      'expected_success_rate',
#                                      'success_fee',
#                                      'difficulty_level',
#                                      'eligibility_criteria',
#                                      'eligible_expenses',
#                                      'financial_information',
#                                      'financing_rate',
#                                      'project_duration_months',
#                                      'project_max_value',
#                                      'project_min_value',
#                                      'admissible_projects',
#                                      'form_questions',
#                                      'currency',
#                                      'difficulty_level_fundamentation',
#                                      'tags_fundamentation'],
#                          'foreign_keys': [],
#                          'primary_keys': ['id']},
#  'granter_opportunityfile': {'columns': ['id',
#                                          'created_at',
#                                          'updated_at',
#                                          'name',
#                                          'uploaded_file',
#                                          'vector_indexed',
#                                          'opportunity_id',
#                                          'codename'],
#                              'foreign_keys': [{'columns': ['opportunity_id'],
#                                                'ref_columns': ['id'],
#                                                'ref_table': 'granter_opportunity'}],
#                              'primary_keys': ['id']},
#  'granter_timeline': {'columns': ['id',
#                                   'created_at',
#                                   'updated_at',
#                                   'type',
#                                   'title',
#                                   'description',
#                                   'date',
#                                   'time',
#                                   'opportunity_id',
#                                   'time_diff',
#                                   'is_prediction'],
#                       'foreign_keys': [{'columns': ['opportunity_id'],
#                                         'ref_columns': ['id'],
#                                         'ref_table': 'granter_opportunity'}],
#                       'primary_keys': ['id']}}

# %% [markdown]
# ## Descriptions of Database tables

# %%
with open('../../database/README.md', 'r', encoding='utf-8') as f:
    readme_database_content = f.read()

print(readme_database_content)
# Out:
# # Granter Database Schema
# This document explains the relationships between the main tables used in **Granter**, the AI-powered grant application platform.
# ---
# ## Tables and Relationships
# ### **granter_company**
# - Represents a company that applies to funding opportunities.
# - **Relations:**
#   - Can create **granter_applications** for opportunities.
#   - Has associated **granter_companyfiles** for company-related context.
#   - Has associated **granter_companymemories** (vectorized text snippets for RAG).
# ---
# ### **granter_application**
# - An application generated for a specific **company** and a specific **opportunity**.
# - **Relations:**
#   - Belongs to a **granter_company**.
#   - Belongs to a **granter_opportunity**.
#   - Has associated **granter_applicationfiles** (files relevant to this application).
# ---
# ### **granter_applicationfile**
# - Files tied to a specific **application**.
# - Usually provide company or project-specific context for that application.
# - **Relations:**
#   - Belongs to a **granter_application**.
# ---
# ### **granter_companyfile**
# - Files that contain general company context (used for RAG purposes).
# - **Relations:**
#   - Belongs to a **granter_company**.
# ---
# ### **granter_companymemory**
# - Small text snippets stored as vectors for RAG purposes.
# - Help provide semantic context when drafting applications.
# - **Relations:**
#   - Belongs to a **granter_company**.
# ---
# ### **granter_opportunity**
# - Represents a funding opportunity (grant, tax incentive, investment, or loan).
# - **Relations:**
#   - Can have multiple **granter_applications** from different companies.
#   - Has associated **granter_opportunityfiles**.
#   - Has associated **granter_timelines** (opening dates, deadlines, etc.).
#   - Has associated **granter_eligibilitycriterias** (eligibility requirements to apply).
# ---
# ### **granter_opportunityfile**
# - Files linked to a specific **opportunity**.
# - Provide contextual information for RAG when drafting or evaluating applications.
# - **Relations:**
#   - Belongs to a **granter_opportunity**.
# ---
# ### **granter_generalopportunityfile**
# - Files that are not tied to a single opportunity.
# - Provide context across **multiple opportunities**.
# ---
# ### **granter_timeline**
# - Represents important dates for an **opportunity** (opening, submission deadlines, evaluations, etc.).
# - **Relations:**
#   - Belongs to a **granter_opportunity**.
# ---
# ### **granter_consortium**
# - Represents a consortium formed by multiple companies.
# - Used to apply to opportunities jointly.
# - **Relations:**
#   - Can include multiple **granter_consortiumpartners**.
#   - Can be linked to **granter_applications** when a consortium applies instead of a single company.
# ---
# ### **granter_consortiumpartner**
# - Represents a company persona or role within a **consortium** (e.g., lead applicant, research partner, SME partner).
# - **Relations:**
#   - Belongs to a **granter_consortium**.
#   - Each partner is typically a **granter_company**.
# ---
# ### **granter_eligibilitycriteria**
# - Defines the eligibility criteria for an **opportunity**.
# - Examples: financial status, company size, sector, geographic location.
# - **Relations:**
#   - Belongs to a **granter_opportunity**.
#   - Has multiple **granter_matchchecks** for individual companies.
# ---
# ### **granter_matchcheck**
# - Represents the eligibility result of a single **company** against a single **eligibility criteria**.
# - **Relations:**
#   - Belongs to a **granter_company**.
#   - Belongs to a **granter_eligibilitycriteria**.
#   - Is grouped into a **granter_matchgroup**.
# ---
# ### **granter_matchgroup**
# - The overall eligibility evaluation of a **company** for an **opportunity**.
# - Includes all individual **granter_matchchecks** for that company and opportunity.
# - **Relations:**
#   - Belongs to a **granter_company**.
#   - Belongs to a **granter_opportunity**.
#   - Aggregates multiple **granter_matchchecks**.
# ---
# ## Summary
# - **Companies** apply to **opportunities** by creating **applications**.
# - **Files and memories** enrich both companies and opportunities with context for AI-driven drafting (RAG).
# - **Eligibility criteria** determine whether a company qualifies for an opportunity:
#   - Individual checks are stored in **matchchecks**.
#   - The grouped decision is stored in a **matchgroup**.
# - **Consortiums** allow multiple companies to join forces and apply together.
# - **Timelines** define key dates for opportunities.
# This schema ensures that Granter can handle complex funding scenarios, provide accurate context for AI agents, and streamline the grant application process

# %% [markdown]
# ## External Ontologies

# %%
with open("external_ontologies/DINGO-Manchester.omn", "r", encoding="utf-8") as f:
    external_ontology = f.read()
print(external_ontology)
# Out:
# Prefix: owl: <http://www.w3.org/2002/07/owl#>
# Prefix: rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# Prefix: rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# Prefix: xml: <http://www.w3.org/XML/1998/namespace>
# Prefix: xsd: <http://www.w3.org/2001/XMLSchema#>
#
#
#
# Ontology: <https://w3id.org/dingo#>
#
#
# Annotations:
#     <http://purl.org/dc/elements/1.1/contributor> _:0,
#     <http://purl.org/dc/elements/1.1/contributor> _:1,
#     <http://purl.org/dc/elements/1.1/contributor> _:2,
#     <http://purl.org/dc/elements/1.1/contributor> _:4,
#     <http://purl.org/dc/elements/1.1/contributor> _:5,
#     <http://purl.org/dc/elements/1.1/issued> "2018-10-26T00:00:00Z",
#     <http://purl.org/dc/elements/1.1/title> "DINGO Ontology",
#     <http://purl.org/dc/terms/creator> _:3,
#     <http://purl.org/dc/terms/modified> "2020-01-10T10:20:10Z",
#     rdfs:comment "The DINGO ontology (Data Integration for Grant Ontology) defines the terms of the DINGO vocabulary and provides a machine readable extensible framework to model data relative to projects, funding, project and funding actors, and, notably, funding policies. It is designed to yield high modeling power and elasticity to cope with the huge variety in funding and project practices, which makes it applicable to many areas where funding is an important aspect: first of all research, but also the arts, cultural conservation, and many others.",
#     owl:versionInfo "2020-01-10T10:20:10Z"
#
# AnnotationProperty: <http://purl.org/dc/elements/1.1/contributor>
#
#
# AnnotationProperty: <http://purl.org/dc/elements/1.1/issued>
#
#
# AnnotationProperty: <http://purl.org/dc/elements/1.1/title>
#
#
# AnnotationProperty: <http://purl.org/dc/terms/creator>
#
#
# AnnotationProperty: <http://purl.org/dc/terms/modified>
#
#
# AnnotationProperty: <http://www.w3.org/2004/02/skos/core#braoder>
#
#
# AnnotationProperty: <http://www.w3.org/2004/02/skos/core#broadMatch>
#
#
# AnnotationProperty: <http://www.w3.org/2004/02/skos/core#broader>
#
#
# AnnotationProperty: <http://www.w3.org/2004/02/skos/core#closeMatch>
#
#
# AnnotationProperty: <http://www.w3.org/2004/02/skos/core#equivalentProperty>
#
#
# AnnotationProperty: <http://www.w3.org/2004/02/skos/core#exactMatch>
#
#
# AnnotationProperty: <http://www.w3.org/2004/02/skos/core#narrowMatch>
#
#
# AnnotationProperty: <http://www.w3.org/2004/02/skos/core#narrower>
#
#
# AnnotationProperty: <http://www.w3.org/2004/02/skos/core#realted>
#
#
# AnnotationProperty: <http://www.w3.org/2004/02/skos/core#related>
#
#
# AnnotationProperty: <http://www.w3.org/2004/02/skos/core#relatedMatch>
#
#
# AnnotationProperty: <http://xmlns.com/foaf/0.1/name>
#
#
# AnnotationProperty: owl:versionInfo
#
#
# AnnotationProperty: rdfs:comment
#
#
# AnnotationProperty: rdfs:isDefinedBy
#
#
# AnnotationProperty: rdfs:label
#
#
# Datatype: rdf:PlainLiteral
#
#
# Datatype: xsd:boolean
#
#
# Datatype: xsd:positiveInteger
#
#
# Datatype: xsd:string
#
#
# ObjectProperty: <https://w3id.org/dingo#academic_degree>
#
#     Annotations:
#         rdfs:comment "Qualification awarded to the person taking the role by a higher education organisation, normally at a college or university.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "academic_degree",
#         <http://www.w3.org/2004/02/skos/core#exactMatch> <http://www.wikidata.org/prop/P512>
#
#     Domain:
#         <https://w3id.org/dingo#Person>
#
#     Range:
#         <https://w3id.org/dingo#AcademicDegree>
#
#
# ObjectProperty: <https://w3id.org/dingo#affiliation>
#
#     Annotations:
#         rdfs:comment "An organization that this person is affiliated with. For example, a school/university, a club, or a team.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "affiliation"
#
#     Domain:
#         <https://w3id.org/dingo#Person>
#
#     Range:
#         <https://w3id.org/dingo#Organisation>
#
#
# ObjectProperty: <https://w3id.org/dingo#agency_identifier>
#
#     Annotations:
#         rdfs:comment "Identifier (for example of Project, Grant, GrantPayment, PersonRole instance, OrganizationRole instance, FundingScheme, Person, Organisation) in the database/archive of the funding agency/funding body/funder.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "agency_identifier",
#         <http://www.w3.org/2004/02/skos/core#broader> <http://purl.org/dc/terms/identifier>,
#         <http://www.w3.org/2004/02/skos/core#narrowMatch> <http://purl.org/cerif/frapo/hasGrantNumber>,
#         <http://www.w3.org/2004/02/skos/core#narrower> <http://purl.org/cerif/frapo/hasPersonalIdentifier>
#
#     Domain:
#         <https://w3id.org/dingo#FundingScheme> or <https://w3id.org/dingo#Grant> or <https://w3id.org/dingo#GrantPayment> or <https://w3id.org/dingo#Organisation> or <https://w3id.org/dingo#Person> or <https://w3id.org/dingo#Project> or <https://w3id.org/dingo#Role>
#
#     Range:
#         <https://w3id.org/dingo#Identifier>
#
#
# ObjectProperty: <https://w3id.org/dingo#baseline_academic_degree>
#
#     Annotations:
#         rdfs:comment "Academic degree used as minimal/reference point for establishing a set of age limits or other classification.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "baseline_academic_degree"
#
#     Domain:
#         <https://w3id.org/dingo#CareerStageCriterion>
#
#     Range:
#         <https://w3id.org/dingo#AcademicDegree>
#
#
# ObjectProperty: <https://w3id.org/dingo#beneficiary>
#
#     Annotations:
#         rdfs:comment "The relation between the Grant (subject) and a (one of the) person(s) or organisation(s) receiving benefits from it identified by his/her/its role.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "beneficiary",
#         <http://www.w3.org/2004/02/skos/core#broadMatch> <http://schema.org/recipient>
#
#     Domain:
#         <https://w3id.org/dingo#Grant>
#
#     Range:
#         <https://w3id.org/dingo#Role>
#
#     InverseOf:
#         <https://w3id.org/dingo#beneficiary_of>
#
#
# ObjectProperty: <https://w3id.org/dingo#beneficiary_of>
#
#     Annotations:
#         rdfs:comment "The relation between a (one of the) person(s) or organisation(s) receiving benefits from a Grant identified by his/her/its role (subject), and the Grant.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "beneficiary_of"
#
#     Domain:
#         <https://w3id.org/dingo#Role>
#
#     Range:
#         <https://w3id.org/dingo#Grant>
#
#     InverseOf:
#         <https://w3id.org/dingo#beneficiary>
#
#
# ObjectProperty: <https://w3id.org/dingo#budget>
#
#     Annotations:
#         rdfs:comment "Amount of money necessary or planned for a determined project/activity.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "budget",
#         <http://www.w3.org/2004/02/skos/core#related> <http://www.wikidata.org/prop/P2769>
#
#     Domain:
#         <https://w3id.org/dingo#Project>
#
#     Range:
#         <http://schema.org/MonetaryAmount>
#
#
# ObjectProperty: <https://w3id.org/dingo#country>
#
#     Annotations:
#         rdfs:comment "Country where the organisation is located ufficially.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "country",
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://www.wikidata.org/prop/P17>
#
#     Domain:
#         <https://w3id.org/dingo#Organisation>
#
#     Range:
#         <http://schema.org/Country>
#
#
# ObjectProperty: <https://w3id.org/dingo#criterion>
#
#     Annotations:
#         rdfs:comment "Property by which a distinction or classification is made. When applied to, for instance, FundingScheme items it indicates criterion item establishing the eligibility conditions, target and other relevant points of the FundingScheme to fund an application.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "criterion",
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://www.wikidata.org/prop/P1013>
#
#     Domain:
#         <https://w3id.org/dingo#FundingScheme>
#
#     Range:
#         <https://w3id.org/dingo#Criterion>
#
#
# ObjectProperty: <https://w3id.org/dingo#disbursed_by>
#
#     Annotations:
#         rdfs:comment "The relation between the disbursed grant (subject) and the funding agency (object).",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "disbursed_by"
#
#     Domain:
#         <https://w3id.org/dingo#Grant>
#
#     Range:
#         <https://w3id.org/dingo#FundingAgency>
#
#     InverseOf:
#         <https://w3id.org/dingo#disburses>
#
#
# ObjectProperty: <https://w3id.org/dingo#disburses>
#
#     Annotations:
#         rdfs:comment "The relation between the funding agency (subject) and the disbursed grant (object).",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "disburses"
#
#     Domain:
#         <https://w3id.org/dingo#FundingAgency>
#
#     Range:
#         <https://w3id.org/dingo#Grant>
#
#     InverseOf:
#         <https://w3id.org/dingo#disbursed_by>
#
#
# ObjectProperty: <https://w3id.org/dingo#economic_value>
#
#     Annotations:
#         rdfs:comment "Amount or value expressed in a specific currency (relationship between the item and a value expressed in a currency unit).",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "economic_value",
#         <http://www.w3.org/2004/02/skos/core#broader> <http://schema.org/amount>
#
#     Range:
#         <http://schema.org/MonetaryAmount>
#
#
# ObjectProperty: <https://w3id.org/dingo#employer>
#
#     Annotations:
#         rdfs:comment "A person or company that provides a job (possibly paying wages or a salary) to the person taking the role.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "employer"
#
#     Domain:
#         <https://w3id.org/dingo#PersonRole>
#
#     Range:
#         <https://w3id.org/dingo#Organisation> or <https://w3id.org/dingo#Person>
#
#
# ObjectProperty: <https://w3id.org/dingo#end_time>
#
#     Annotations:
#         rdfs:comment "The time an item ceases to exist or a statement stops being valid.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "end_time",
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://purl.org/cerif/frapo/hasEndDate>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://schema.org/endTime>
#
#     Range:
#         xsd:date or xsd:dateTime
#
#
# ObjectProperty: <https://w3id.org/dingo#entity_taking_role>
#
#     Annotations:
#         rdfs:comment "The person or organisation or entity (object) assuming or to whom is assigned the role (subject).",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "entity_taking_role"
#
#     Domain:
#         <https://w3id.org/dingo#Role>
#
#     Range:
#         <https://w3id.org/dingo#Organisation> or <https://w3id.org/dingo#Person>
#
#     InverseOf:
#         <https://w3id.org/dingo#takes_role>
#
#
# ObjectProperty: <https://w3id.org/dingo#excluded_academic_degree>
#
#     Annotations:
#         rdfs:comment "Academic degree possessing which the subject of the statement cannot apply to the funding program.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "excluded_academic_degree"
#
#     Domain:
#         <https://w3id.org/dingo#CareerStageCriterion>
#
#     Range:
#         <https://w3id.org/dingo#AcademicDegree>
#
#
# ObjectProperty: <https://w3id.org/dingo#field_of_work>
#
#     Annotations:
#         rdfs:comment "Specialisation of a person, project or organisation.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "title",
#         <http://www.w3.org/2004/02/skos/core#exactMatch> <http://www.wikidata.org/prop/P101>
#
#     Domain:
#         <https://w3id.org/dingo#Organisation> or <https://w3id.org/dingo#Person> or <https://w3id.org/dingo#Project>
#
#     Range:
#         rdfs:Resource
#
#
# ObjectProperty: <https://w3id.org/dingo#finances>
#
#     Annotations:
#         rdfs:comment "The relation between the Grant (subject) and the Project (object).",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "finances",
#         <http://www.w3.org/2004/02/skos/core#broadMatch> <http://purl.org/cerif/frapo/funds>,
#         <http://www.w3.org/2004/02/skos/core#broadMatch> <http://purl.org/cerif/frapo/supports>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://www.wikidata.org/prop/P2770>
#
#     Domain:
#         <https://w3id.org/dingo#Grant>
#
#     Range:
#         <https://w3id.org/dingo#Project>
#
#     InverseOf:
#         <https://w3id.org/dingo#funded_by>
#
#
# ObjectProperty: <https://w3id.org/dingo#funded_by>
#
#     Annotations:
#         rdfs:comment "The relation between the Project (subject) and the Grant (object).",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "funded_by",
#         <http://www.w3.org/2004/02/skos/core#broadMatch> <http://purl.org/cerif/frapo/isFundedBy>,
#         <http://www.w3.org/2004/02/skos/core#broadMatch> <http://purl.org/cerif/frapo/isSupportedBy>
#
#     Domain:
#         <https://w3id.org/dingo#Project>
#
#     Range:
#         <https://w3id.org/dingo#Grant>
#
#     InverseOf:
#         <https://w3id.org/dingo#finances>
#
#
# ObjectProperty: <https://w3id.org/dingo#funder>
#
#     Annotations:
#         rdfs:comment "The ultimate funder who decided and is ultimately responsible for the funding scheme.
# (Example: FundingScheme Horizon2020 dg:funder European Commission).",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "funder",
#         <http://www.w3.org/2004/02/skos/core#broader> <http://purl.org/cerif/frapo/isFundedBy>,
#         <http://www.w3.org/2004/02/skos/core#broader> <http://purl.org/cerif/frapo/isSupportedBy>
#
#     Domain:
#         <https://w3id.org/dingo#FundingScheme>
#
#     Range:
#         rdfs:Resource
#
#
# ObjectProperty: <https://w3id.org/dingo#grid_id>
#
#     Annotations:
#         rdfs:comment "Institutional identifier from the GRID.ac global research identifier database.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "grid_id"
#
#     Domain:
#         <https://w3id.org/dingo#Organisation>
#
#     Range:
#         xsd:string
#
#
# ObjectProperty: <https://w3id.org/dingo#hasPart>
#
#     Annotations:
#         rdfs:comment "The relation between a superset and its direct subset(s). Indicates an item that is a part (also in generalised sense) of the subject item.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "hasPart",
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://www.wikidata.org/prop/P527>
#
#     InverseOf:
#         <https://w3id.org/dingo#isPartOf>
#
#
# ObjectProperty: <https://w3id.org/dingo#has_implementation>
#
#     Annotations:
#         rdfs:comment "The relationship between the decision, plan, program (subject) and the grant (object) that the grant is the concrete realisation of.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "has_implementation"
#
#     Domain:
#         <https://w3id.org/dingo#FundingScheme>
#
#     Range:
#         <https://w3id.org/dingo#Grant>
#
#     InverseOf:
#         <https://w3id.org/dingo#implementation_of>
#
#
# ObjectProperty: <https://w3id.org/dingo#headquarters_location>
#
#     Annotations:
#         rdfs:comment "Address of the headquarters of the organisation.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "headquarters_location",
#         <http://www.w3.org/2004/02/skos/core#braoder> <http://purl.org/cerif/frapo/hasLocation>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://www.wikidata.org/prop/P159>
#
#     Domain:
#         <https://w3id.org/dingo#Organisation>
#
#     Range:
#         <http://schema.org/PostalAddress>
#
#
# ObjectProperty: <https://w3id.org/dingo#id_context_agent>
#
#     Annotations:
#         rdfs:comment "Organization, Person, Agency related to the identifiers (for instance, creator, attributor, curator, maintainer, or similar). The specific semantic should be indicated with dedicated ontologies, such as PROV-O.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "id_context_agent"
#
#     Domain:
#         <https://w3id.org/dingo#Identifier>
#
#     Range:
#         <https://w3id.org/dingo#FundingAgency> or <https://w3id.org/dingo#Organisation> or <https://w3id.org/dingo#Person>
#
#
# ObjectProperty: <https://w3id.org/dingo#implementation_country>
#
#     Annotations:
#         rdfs:comment "Country where the project must be implemented.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "implementation_country"
#
#     Domain:
#         <https://w3id.org/dingo#GeographicCriterion>
#
#     Range:
#         <http://schema.org/Country>
#
#
# ObjectProperty: <https://w3id.org/dingo#implementation_of>
#
#     Annotations:
#         rdfs:comment "The relationship between the grant (subject) and the decision, plan, program (object) that the grant is the concrete realisation of.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "implementation_of"
#
#     Domain:
#         <https://w3id.org/dingo#Grant>
#
#     Range:
#         <https://w3id.org/dingo#FundingScheme>
#
#     InverseOf:
#         <https://w3id.org/dingo#has_implementation>
#
#
# ObjectProperty: <https://w3id.org/dingo#implemented_by>
#
#     Annotations:
#         rdfs:comment "The relationship between the decision, plan, program (subject) and the funding agency (object) that the funding agency implements and administers.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "implemented_by"
#
#     Domain:
#         <https://w3id.org/dingo#FundingScheme>
#
#     Range:
#         <https://w3id.org/dingo#FundingAgency>
#
#     InverseOf:
#         <https://w3id.org/dingo#implements>
#
#
# ObjectProperty: <https://w3id.org/dingo#implements>
#
#     Annotations:
#         rdfs:comment "The relationship between the funding agency (subject) and the decision, plan, program (object) that the funding agency implements and administers.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "implements"
#
#     Domain:
#         <https://w3id.org/dingo#FundingAgency>
#
#     Range:
#         <https://w3id.org/dingo#FundingScheme>
#
#     InverseOf:
#         <https://w3id.org/dingo#implemented_by>
#
#
# ObjectProperty: <https://w3id.org/dingo#inception>
#
#     Annotations:
#         rdfs:comment "Date or point in time when the subject was founded/created.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "inception"
#
#     Range:
#         xsd:date or xsd:dateTime
#
#
# ObjectProperty: <https://w3id.org/dingo#isPartOf>
#
#     Annotations:
#         rdfs:comment "The relation between a subset and its direct superset(s). Indicates an item that is a part (also in generalised sense) of the object item.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "isPartOf",
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://www.wikidata.org/prop/361>
#
#     Range:
#         rdfs:Resource
#
#     InverseOf:
#         <https://w3id.org/dingo#hasPart>
#
#
# ObjectProperty: <https://w3id.org/dingo#legalName>
#
#     Annotations:
#         rdfs:comment "The official name of the organization, for example the registered company name.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "legalName"
#
#     Domain:
#         <https://w3id.org/dingo#Organisation>
#
#     Range:
#         xsd:string
#
#
# ObjectProperty: <https://w3id.org/dingo#objective>
#
#     Annotations:
#         rdfs:comment "Desired result or outcome.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "objective",
#         <http://www.w3.org/2004/02/skos/core#exactMatch> <http://www.wikidata.org/prop/P3712>
#
#     Domain:
#         <https://w3id.org/dingo#Project>
#
#     Range:
#         rdfs:Resource
#
#
# ObjectProperty: <https://w3id.org/dingo#official_website>
#
#     Annotations:
#         rdfs:comment "URL of the official website of an item.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "official_website",
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://www.wikidata.org/prop/P856>
#
#     Domain:
#         <https://w3id.org/dingo#FundingAgency> or <https://w3id.org/dingo#FundingScheme> or <https://w3id.org/dingo#Organisation> or <https://w3id.org/dingo#Person> or <https://w3id.org/dingo#Project>
#
#     Range:
#         <http://schema.org/url> or xsd:anyURI or xsd:string
#
#
# ObjectProperty: <https://w3id.org/dingo#organisation_location>
#
#     Annotations:
#         rdfs:comment "Country or geographical administrative entity where an organisation must be established to apply for funding.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "organisation_location"
#
#     Domain:
#         <https://w3id.org/dingo#GeographicCriterion>
#
#     Range:
#         <http://schema.org/Country>,
#         <http://schema.org/SupranationalOrganisation>
#
#
# ObjectProperty: <https://w3id.org/dingo#participant>
#
#     Annotations:
#         rdfs:comment "The relation between the Project (subject) and a (one of the) person(s) or organisation(s) contributing to or taking part in it identified by his/her/its role.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "participant",
#         <http://www.w3.org/2004/02/skos/core#broadMatch> <http://schema.org/participant>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://www.wikidata.org/prop/P710>
#
#     Domain:
#         <https://w3id.org/dingo#Project>
#
#     Range:
#         <https://w3id.org/dingo#Role>
#
#     InverseOf:
#         <https://w3id.org/dingo#participant_of>
#
#
# ObjectProperty: <https://w3id.org/dingo#participant_of>
#
#     Annotations:
#         rdfs:comment "The relation between a (one of the) person(s) or organisation(s) participant of a Project identified by his/her/its role (subject), and the Project.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "participant_of"
#
#     Domain:
#         <https://w3id.org/dingo#Role>
#
#     Range:
#         <https://w3id.org/dingo#Project>
#
#     InverseOf:
#         <https://w3id.org/dingo#participant>
#
#
# ObjectProperty: <https://w3id.org/dingo#person_location>
#
#     Annotations:
#         rdfs:comment "Country or geographical administrative entity where the person must reside or be citizen or have undertaken research up to the moment of applying for funding.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "person_location",
#         <http://www.w3.org/2004/02/skos/core#broader> <http://purl.org/cerif/frapo/hasLocation>
#
#     Domain:
#         <https://w3id.org/dingo#GeographicCriterion>
#
#     Range:
#         <http://schema.org/Country>,
#         <http://schema.org/SupranationalOrganisation>
#
#
# ObjectProperty: <https://w3id.org/dingo#point_in_time>
#
#     Annotations:
#         rdfs:comment "The moment in time when an event occurs.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "point_in_time"
#
#     Range:
#         xsd:date or xsd:dateTime
#
#
# ObjectProperty: <https://w3id.org/dingo#product_or_material_produced>
#
#     Annotations:
#         rdfs:comment "Material, product or output produced by a Project.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "product_or_material_produced",
#         <http://www.w3.org/2004/02/skos/core#broadMatch> <http://schema.org/produces>,
#         <http://www.w3.org/2004/02/skos/core#broader> <http://www.wikidata.org/prop/P1056>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://purl.org/cerif/frapo/hasOutput>
#
#     Domain:
#         <https://w3id.org/dingo#Project>
#
#     Range:
#         rdfs:Resource
#
#
# ObjectProperty: <https://w3id.org/dingo#recipient>
#
#     Annotations:
#         rdfs:comment "The receiver of a GrantPayment or receiver/beneficiary of a GrantShare.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "recipient",
#         <http://www.w3.org/2004/02/skos/core#broadMatch> <http://schema.org/recipient>
#
#     Domain:
#         <https://w3id.org/dingo#GrantPayment> or <https://w3id.org/dingo#GrantShare>
#
#     Range:
#         <https://w3id.org/dingo#Organisation> or <https://w3id.org/dingo#Person>
#
#
# ObjectProperty: <https://w3id.org/dingo#role_type>
#
#     Annotations:
#         rdfs:comment "Item representing the specific class of a Role.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "role_type"
#
#     Domain:
#         <https://w3id.org/dingo#Role>
#
#     Range:
#         rdfs:Resource
#
#
# ObjectProperty: <https://w3id.org/dingo#start_time>
#
#     Annotations:
#         rdfs:comment "The time an item starts to exist/operate or a statement starts being valid.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "start_time",
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://purl.org/cerif/frapo/hasStartDate>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://schema.org/startTime>
#
#     Range:
#         xsd:date or xsd:dateTime
#
#
# ObjectProperty: <https://w3id.org/dingo#takes_role>
#
#     Annotations:
#         rdfs:comment "The role (object) assumed or assigned to a person or organisation or entity (subject).",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "takes_role"
#
#     Domain:
#         <https://w3id.org/dingo#Organisation> or <https://w3id.org/dingo#Person>
#
#     Range:
#         <https://w3id.org/dingo#Role>
#
#     InverseOf:
#         <https://w3id.org/dingo#entity_taking_role>
#
#
# ObjectProperty: <https://w3id.org/dingo#thematic_area>
#
#     Annotations:
#         rdfs:comment "Topics and/or area of interest.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "thematic_area"
#
#     Domain:
#         <https://w3id.org/dingo#ThematicCriterion>
#
#     Range:
#         rdfs:Resource
#
#
# ObjectProperty: <https://w3id.org/dingo#used_in>
#
#     Annotations:
#         rdfs:comment "Database or information system where the identifier is/was used.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "used_in"
#
#     Domain:
#         <https://w3id.org/dingo#Identifier>
#
#     Range:
#         <https://w3id.org/dingo#InformationBase>
#
#
# DataProperty: <https://w3id.org/dingo#abstract_or_summary_description>
#
#     Annotations:
#         rdfs:comment "Short summary description of a project.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "abstract_or_summary_description"
#
#     Domain:
#         <https://w3id.org/dingo#Project>
#
#     Range:
#         xsd:string
#
#
# DataProperty: <https://w3id.org/dingo#additionalName>
#
#     Annotations:
#         rdfs:comment "Additional part of a person's beyond given name and surname, can be used for a middle name.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "additionalName"
#
#     Domain:
#         <https://w3id.org/dingo#Person>
#
#     Range:
#         xsd:string
#
#
# DataProperty: <https://w3id.org/dingo#criterion_description>
#
#     Annotations:
#         rdfs:comment "Description of the eligibility, targets and other relevant points of the FundingScheme.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "criterion_description"
#
#     Domain:
#         <https://w3id.org/dingo#Criterion>
#
#     Range:
#         xsd:string
#
#
# DataProperty: <https://w3id.org/dingo#crossref_grantid>
#
#     Annotations:
#         rdfs:comment "Identifier for funding in the Crossref registry.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "crossref_grantid"
#
#     Domain:
#         <https://w3id.org/dingo#Grant>
#
#     Range:
#         xsd:string
#
#
# DataProperty: <https://w3id.org/dingo#crossref_id>
#
#     Annotations:
#         rdfs:comment "Identifier for an organisation that funds research, in the Crossref registry.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "crossref_id"
#
#     Domain:
#         <https://w3id.org/dingo#FundingAgency>
#
#     Range:
#         xsd:string
#
#
# DataProperty: <https://w3id.org/dingo#degree_title>
#
#     Annotations:
#         rdfs:comment "Title denoting the academic degree.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "degree_title",
#         <http://www.w3.org/2004/02/skos/core#realted> <http://purl.org/cerif/frapo/hasDegreeSuffix>
#
#     Domain:
#         <https://w3id.org/dingo#AcademicDegree>
#
#     Range:
#         xsd:string
#
#
# DataProperty: <https://w3id.org/dingo#early_termination>
#
#     Annotations:
#         rdfs:comment "Indicates if the role was ended ahead of time with respect to the grant contract of project ending.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "early_termination"
#
#     Domain:
#         <https://w3id.org/dingo#Role>
#
#     Range:
#         xsd:boolean
#
#
# DataProperty: <https://w3id.org/dingo#givenName>
#
#     Annotations:
#         rdfs:comment "Part of a person's name that individuates the person within the (typically closest) group that shares the same surname.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "givenName",
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://schema.org/givenName>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://www.wikidata.org/prop/P735>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://xmlns.com/foaf/0.1/firstName>
#
#     Domain:
#         <https://w3id.org/dingo#Person>
#
#     Range:
#         xsd:string
#
#
# DataProperty: <https://w3id.org/dingo#id_value>
#
#     Annotations:
#         rdfs:comment "String representing the identifier.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "id_value"
#
#     Domain:
#         <https://w3id.org/dingo#Identifier>
#
#     Range:
#         xsd:string
#
#
# DataProperty: <https://w3id.org/dingo#max_age>
#
#     Annotations:
#         rdfs:comment "Maximum age allowed.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "max_age",
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://www.wikidata.org/prop/P4135>
#
#     Domain:
#         <https://w3id.org/dingo#AgeCriterion>
#
#     Range:
#         xsd:positiveInteger
#
#
# DataProperty: <https://w3id.org/dingo#max_years_from_baseline_degree>
#
#     Annotations:
#         rdfs:comment "Maximum number of years counting from the year of when the dg:baseline_academic_degree was obtained.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "max_years_from_baseline_degree"
#
#     Domain:
#         <https://w3id.org/dingo#CareerStageCriterion>
#
#     Range:
#         xsd:positiveInteger
#
#
# DataProperty: <https://w3id.org/dingo#min_age>
#
#     Annotations:
#         rdfs:comment "Minimum age required.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "min_age",
#         <http://www.w3.org/2004/02/skos/core#narrowMatch> <http://www.wikidata.org/prop/P2899>
#
#     Domain:
#         <https://w3id.org/dingo#AgeCriterion>
#
#     Range:
#         xsd:positiveInteger
#
#
# DataProperty: <https://w3id.org/dingo#min_research_years>
#
#     Annotations:
#         rdfs:comment "Minimum number of research years required.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "min_research_years"
#
#     Domain:
#         <https://w3id.org/dingo#CareerStageCriterion>
#
#     Range:
#         xsd:positiveInteger
#
#
# DataProperty: <https://w3id.org/dingo#min_years_from_baseline_degree>
#
#     Annotations:
#         rdfs:comment "Minimum number of years counting from the year of when the dg:baseline_academic_degree was obtained.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "min_years_from_baseline_degree"
#
#     Domain:
#         <https://w3id.org/dingo#CareerStageCriterion>
#
#     Range:
#         xsd:positiveInteger
#
#
# DataProperty: <https://w3id.org/dingo#orcid_id>
#
#     Annotations:
#         rdfs:comment "Nonproprietary alphanumeric code to uniquely identify scientific and other academic authors.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "orcid_id",
#         <http://www.w3.org/2004/02/skos/core#equivalentProperty> <http://purl.org/cerif/frapo/hasORCID>
#
#     Domain:
#         <https://w3id.org/dingo#Person>
#
#     Range:
#         xsd:string
#
#
# DataProperty: <https://w3id.org/dingo#percentage_employment>
#
#     Annotations:
#         rdfs:comment "Minimum percentage of employment required (for example to be eligible for funding).",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "percentage_employment"
#
#     Domain:
#         <https://w3id.org/dingo#EmploymentCriterion>
#
#     Range:
#         xsd:positiveInteger
#
#
# DataProperty: <https://w3id.org/dingo#percentage_working_time>
#
#     Annotations:
#         rdfs:comment "Amount of working time in percentage.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "percentage_working_time"
#
#     Domain:
#         <https://w3id.org/dingo#WorkingTimeCriterion>
#
#     Range:
#         xsd:positiveInteger
#
#
# DataProperty: <https://w3id.org/dingo#role_label>
#
#     Annotations:
#         rdfs:comment "Label (name) of a Role.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "role_label",
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://schema.org/roleName>
#
#     Domain:
#         <https://w3id.org/dingo#Role>
#
#     Range:
#         xsd:string
#
#
# DataProperty: <https://w3id.org/dingo#short_name>
#
#     Annotations:
#         rdfs:comment "Acronym or short name of an organisation or project or funding scheme.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "short_name",
#         <http://www.w3.org/2004/02/skos/core#broadMatch> <http://purl.org/cerif/frapo/hasAcronym>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://www.wikidata.org/prop/P1813>
#
#     Domain:
#         <https://w3id.org/dingo#FundingScheme> or <https://w3id.org/dingo#Organisation> or <https://w3id.org/dingo#Project>
#
#     Range:
#         xsd:string
#
#
# DataProperty: <https://w3id.org/dingo#surname>
#
#     Annotations:
#         rdfs:comment "Part of a person's name shared with a group (typically family or tribe or clan depending on the culture), and/or used in formal contexts or with people that do not know the person well.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "surname",
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://schema.org/familyName>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://www.wikidata.org/prop/P734>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://xmlns.com/foaf/0.1/family_name>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://xmlns.com/foaf/0.1/surname>
#
#     Domain:
#         <https://w3id.org/dingo#Person>
#
#     Range:
#         xsd:string
#
#
# DataProperty: <https://w3id.org/dingo#title>
#
#     Annotations:
#         rdfs:comment "The title of a project (original or translated).",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "title"
#
#     Domain:
#         <https://w3id.org/dingo#Project>
#
#     Range:
#         xsd:string
#
#
# DataProperty: <https://w3id.org/dingo#wikidata_item_id>
#
#     Annotations:
#         rdfs:comment "Identifier for a class or item existing in Wikidata.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "wikidata_item_id"
#
#     Domain:
#         <https://w3id.org/dingo#Grant>
#
#     Range:
#         xsd:string
#
#
# Class: <http://schema.org/Country>
#
#
# Class: <http://schema.org/EducationalOrganization>
#
#     EquivalentTo:
#         <https://w3id.org/dingo#EducationOrganisation>
#
#
# Class: <http://schema.org/GovernmentOrganization>
#
#     EquivalentTo:
#         <https://w3id.org/dingo#GovernmentalOrganisation>
#
#
# Class: <http://schema.org/MedicalOrganization>
#
#     EquivalentTo:
#         <https://w3id.org/dingo#HealthcareOrganisation>
#
#
# Class: <http://schema.org/MonetaryAmount>
#
#
# Class: <http://schema.org/Organization>
#
#     EquivalentTo:
#         <https://w3id.org/dingo#Organisation>
#
#
# Class: <http://schema.org/PerformingGroup>
#
#     EquivalentTo:
#         <https://w3id.org/dingo#PerformingGroup>
#
#
# Class: <http://schema.org/Person>
#
#     EquivalentTo:
#         <https://w3id.org/dingo#Person>
#
#
# Class: <http://schema.org/PostalAddress>
#
#
# Class: <http://schema.org/SportsOrganisation>
#
#     EquivalentTo:
#         <https://w3id.org/dingo#SportsOrganisation>
#
#
# Class: <http://schema.org/SupranationalOrganisation>
#
#
# Class: <http://schema.org/url>
#
#
# Class: <http://www.wikidata.org/entity/Q189533>
#
#     EquivalentTo:
#         <https://w3id.org/dingo#AcademicDegree>
#
#
# Class: <http://www.wikidata.org/entity/Q43229>
#
#     EquivalentTo:
#         <https://w3id.org/dingo#Organisation>
#
#
# Class: <http://xmlns.com/foaf/0.1/Person>
#
#     EquivalentTo:
#         <https://w3id.org/dingo#Person>
#
#     Individuals:
#         _:0,
#         _:1,
#         _:2,
#         _:3,
#         _:4,
#         _:5
#
#
# Class: <https://w3id.org/dingo#AcademicDegree>
#
#     Annotations:
#         rdfs:comment "The class for academic degrees: college or university diploma.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "AcademicDegree"
#
#     EquivalentTo:
#         <http://www.wikidata.org/entity/Q189533>
#
#
# Class: <https://w3id.org/dingo#AgeCriterion>
#
#     Annotations:
#         rdfs:comment "Specifies that grants are awarded to projects on the basis of age limits.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "AgeCriterion"
#
#     SubClassOf:
#         <https://w3id.org/dingo#Criterion>
#
#
# Class: <https://w3id.org/dingo#ArchiveOrganisation>
#
#     Annotations:
#         rdfs:comment "Institution that holds artifacts and other objects of scientific, artistic, cultural, historical, or other importance.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "ArchiveOrganisation"
#
#     SubClassOf:
#         <https://w3id.org/dingo#Organisation>
#
#
# Class: <https://w3id.org/dingo#BottomUpCriterion>
#
#     Annotations:
#         rdfs:comment "Specifies that grants are awarded to projects on the basis of the research proposal itself without restriction on theme/subject or research area. The funding body does not specifies beforehand missions, targets nor topics of the research projects that can apply.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "BottomUpCriterion"
#
#     SubClassOf:
#         <https://w3id.org/dingo#Criterion>
#
#
# Class: <https://w3id.org/dingo#CareerPurposeCriterion>
#
#     Annotations:
#         rdfs:comment "Specifies that grants are awarded on the basis of career-related goals and applicants must be at a defined career stage (defined academic degree) to be achieved.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "CareerPurposeCriterion"
#
#     SubClassOf:
#         <https://w3id.org/dingo#Criterion>
#
#
# Class: <https://w3id.org/dingo#CareerStageCriterion>
#
#     Annotations:
#         rdfs:comment "Specifies that grants are awarded to projects on the basis of career stage limits.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "CareerStageCriterion"
#
#     SubClassOf:
#         <https://w3id.org/dingo#Criterion>
#
#
# Class: <https://w3id.org/dingo#Company>
#
#     Annotations:
#         rdfs:comment "A commercial business.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "Company",
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://purl.org/cerif/frapo/Company>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://schema.org/Corporation>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://www.wikidata.org/entity/Q783794>
#
#     SubClassOf:
#         <https://w3id.org/dingo#Organisation>
#
#
# Class: <https://w3id.org/dingo#Criterion>
#
#     Annotations:
#         rdfs:comment "Specification of Grant coverage, Grant eligibility, Grant reimbursement rates, Grant specific criteria for funding, Grant population targets, and similar features.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "Criterion"
#
#
# Class: <https://w3id.org/dingo#CulturalOrganisation>
#
#     Annotations:
#         rdfs:comment "Cultural institution or cultural organization is an organization within a culture/subculture that works for the preservation or promotion of culture.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "CulturalOrganisation"
#
#     SubClassOf:
#         <https://w3id.org/dingo#Organisation>
#
#
# Class: <https://w3id.org/dingo#EducationOrganisation>
#
#     Annotations:
#         rdfs:comment "Institution that provides education.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "EducationOrganisation"
#
#     EquivalentTo:
#         <http://schema.org/EducationalOrganization>
#
#     SubClassOf:
#         <https://w3id.org/dingo#Organisation>
#
#
# Class: <https://w3id.org/dingo#EmploymentCriterion>
#
#     Annotations:
#         rdfs:comment "Specifies that grants are awarded on the basis of employment conditions by an organisation eligible for funding at the time of applying or receiving the funds.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "EmploymentCriterion"
#
#     SubClassOf:
#         <https://w3id.org/dingo#Criterion>
#
#
# Class: <https://w3id.org/dingo#FacilityOrganisation>
#
#     Annotations:
#         rdfs:comment "A place providing for a particular purpose.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "FacilityOrganisation"
#
#     SubClassOf:
#         <https://w3id.org/dingo#Organisation>
#
#
# Class: <https://w3id.org/dingo#ForProfitOrganisation>
#
#     Annotations:
#         rdfs:comment "For profit entity.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "ForProfictOrganisation"
#
#     SubClassOf:
#         <https://w3id.org/dingo#Organisation>
#
#
# Class: <https://w3id.org/dingo#FundingAgency>
#
#     Annotations:
#         rdfs:comment "The class for funding agencies: organisations that materially disburse and administer the Grant process.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "FundingAgency",
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://purl.org/cerif/frapo/FundingAgency>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://schema.org/FundingAgency>
#
#     SubClassOf:
#         <https://w3id.org/dingo#Organisation>
#
#
# Class: <https://w3id.org/dingo#FundingScheme>
#
#     Annotations:
#         rdfs:comment "The class for funding schemes: plans, designs, and/or programs that determines and organizes the funding.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "FundingScheme",
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://purl.org/cerif/frapo/FundingProgramme>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://schema.org/FundingScheme>
#
#
# Class: <https://w3id.org/dingo#GeographicCriterion>
#
#     Annotations:
#         rdfs:comment "Specifies that grants are awarded to projects on the basis of geographic areas, either where the project has to be implemented, or where the researcher must have been operating before applying for funding, or where the participants must be resident or citizens.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "GeographicCriterion"
#
#     SubClassOf:
#         <https://w3id.org/dingo#Criterion>
#
#
# Class: <https://w3id.org/dingo#GovernmentalOrganisation>
#
#     Annotations:
#         rdfs:comment "Organisation or agency depending on a government, State or other supranational organisation and mainly operated by the government.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "GovernmentalOrganisation",
#         <http://www.w3.org/2004/02/skos/core#relatedMatch> <http://purl.org/cerif/frapo/GovernmentOrganization>
#
#     EquivalentTo:
#         <http://schema.org/GovernmentOrganization>
#
#     SubClassOf:
#         <https://w3id.org/dingo#Organisation>
#
#
# Class: <https://w3id.org/dingo#Grant>
#
#     Annotations:
#         rdfs:comment "The class for grant: a disbursed fund payed to a recipient or beneficiary and the process for it.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "Grant",
#         <http://www.w3.org/2004/02/skos/core#broadMatch> <http://www.wikidata.org/entity/Q230788>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://purl.org/cerif/frapo/Funding>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://schema.org/MonetaryGrant>,
#         <http://www.w3.org/2004/02/skos/core#narrowMatch> <http://purl.org/cerif/frapo/Grant>
#
#
# Class: <https://w3id.org/dingo#GrantPayment>
#
#     Annotations:
#         rdfs:comment "The class for grant payments: a single payment to a recipient or beneficiary within a Grant.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "GrantPayment",
#         <http://www.w3.org/2004/02/skos/core#broadMatch> <http://purl.org/cerif/frapo/Payment>,
#         <http://www.w3.org/2004/02/skos/core#broadMatch> <http://www.wikidata.org/entity/Q1148747>
#
#
# Class: <https://w3id.org/dingo#GrantShare>
#
#     Annotations:
#         rdfs:comment "The class for grant shares: the full or proper portion or part allotted or belonging to or contributed to an individual entity within a Grant.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "GrantShare"
#
#
# Class: <https://w3id.org/dingo#HealthcareOrganisation>
#
#     Annotations:
#         rdfs:comment "Organization that provides health care and related services.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "HealthcareOrganisation"
#
#     EquivalentTo:
#         <http://schema.org/MedicalOrganization>
#
#     SubClassOf:
#         <https://w3id.org/dingo#Organisation>
#
#
# Class: <https://w3id.org/dingo#HigherEducationOrganisation>
#
#     Annotations:
#         rdfs:comment "Place of postsecondary education (e.g., universities, vocational universities, community colleges, liberal arts colleges, institutes of technology, and others).",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "HigherEducationOrganisation"
#
#     SubClassOf:
#         <https://w3id.org/dingo#Organisation>
#
#
# Class: <https://w3id.org/dingo#Identifier>
#
#     Annotations:
#         rdfs:comment "The class for identifiers.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "Identifier",
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://www.wikidata.org/entity/Q6545185>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://www.wikidata.org/entity/Q853614>
#
#
# Class: <https://w3id.org/dingo#InformationBase>
#
#     Annotations:
#         rdfs:comment "An organized collection of data and/or information. It can use any available technology. The temr can also indicate in general the information system built integrating such information bases.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "InformationBase"
#
#
# Class: <https://w3id.org/dingo#InfrastructurePurposeCriterion>
#
#     Annotations:
#         rdfs:comment "Specifies that grants are awarded to cover for the expenses of infrastructure.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "InfrastructurePurposeCriterion"
#
#     SubClassOf:
#         <https://w3id.org/dingo#Criterion>
#
#
# Class: <https://w3id.org/dingo#IntergovernmentalOrganisation>
#
#     Annotations:
#         rdfs:comment "Organization composed primarily of sovereign states. Example: United Nations.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "IntergovernmentalOrganisation"
#
#     SubClassOf:
#         <https://w3id.org/dingo#Organisation>
#
#
# Class: <https://w3id.org/dingo#NonprofitOrganisation>
#
#     Annotations:
#         rdfs:comment "Business entity that pays no income tax, as it furthers a religious, scientific or social cause, providing a public benefit.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "NonprofitOrganisation",
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://purl.org/cerif/frapo/NotForProfitOrganization>
#
#     SubClassOf:
#         <https://w3id.org/dingo#Organisation>
#
#
# Class: <https://w3id.org/dingo#Organisation>
#
#     Annotations:
#         rdfs:comment "The class for organisations: social entities with a collective goal.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "Organisation",
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://www.wikidata.org/entity/Q43229>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://xmlns.com/foaf/0.1/Oranization>
#
#     EquivalentTo:
#         <http://schema.org/Organization>,
#         <http://www.wikidata.org/entity/Q43229>
#
#
# Class: <https://w3id.org/dingo#OrganisationRole>
#
#     Annotations:
#         rdfs:comment "The class for organisation roles: function assumed by or ascribed to an organisation that takes part in something.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "OrganisationRole"
#
#     SubClassOf:
#         <https://w3id.org/dingo#Role>
#
#
# Class: <https://w3id.org/dingo#OrganisationalCriterion>
#
#     Annotations:
#         rdfs:comment "Specifies that grants are awarded on the basis of specified organisational form of the project, for instance demanding for participation of different research groups (synergy).",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "OrganisationalCriterion"
#
#     SubClassOf:
#         <https://w3id.org/dingo#Criterion>
#
#
# Class: <https://w3id.org/dingo#PerformingGroup>
#
#     Annotations:
#         rdfs:comment "A performance group, such as a band, an orchestra, or a circus.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "PerformingGroup"
#
#     EquivalentTo:
#         <http://schema.org/PerformingGroup>
#
#     SubClassOf:
#         <https://w3id.org/dingo#Organisation>
#
#
# Class: <https://w3id.org/dingo#Person>
#
#     Annotations:
#         rdfs:comment "The class for persons: alive, dead, undead, or fictional.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "Person",
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://www.wikidata.org/entity/Q215627>,
#         <http://www.w3.org/2004/02/skos/core#relatedMatch> <http://www.wikidata.org/entity/Q215627>,
#         <http://www.w3.org/2004/02/skos/core#relatedMatch> <http://www.wikidata.org/entity/Q5>
#
#     EquivalentTo:
#         <http://schema.org/Person>,
#         <http://xmlns.com/foaf/0.1/Person>
#
#
# Class: <https://w3id.org/dingo#PersonRole>
#
#     Annotations:
#         rdfs:comment "The class for person roles: function assumed by or ascribed to a person that takes part in something.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "PersonRole"
#
#     SubClassOf:
#         <https://w3id.org/dingo#Role>
#
#
# Class: <https://w3id.org/dingo#Project>
#
#     Annotations:
#         rdfs:comment "The class for projects: an organised endeavour (collective or individual) planned to reach a particular aim or achieve a result.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "Project",
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://schema.org/Project>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://www.wikidata.org/entity/Q170584>,
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://xmlns.com/foaf/0.1/Project>,
#         <http://www.w3.org/2004/02/skos/core#narrowMatch> <http://purl.org/cerif/frapo/Investigation>,
#         <http://www.w3.org/2004/02/skos/core#narrowMatch> <http://purl.org/cerif/frapo/Project>
#
#
# Class: <https://w3id.org/dingo#ResearchPerformingOrganisation>
#
#     Annotations:
#         rdfs:comment "Organisations devoted to research activities.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "ResearchPerformingOrganisation",
#         <http://www.w3.org/2004/02/skos/core#relatedMatch> <http://purl.org/cerif/frapo/ResearchInstitute>
#
#     SubClassOf:
#         <https://w3id.org/dingo#Organisation>
#
#
# Class: <https://w3id.org/dingo#Role>
#
#     Annotations:
#         rdfs:comment "The class for roles: the function assumed by or ascribed to an entity (typically person, group of persons or organisation) in a particular situation.
# It can be used to precise or represent additional information about a relationship or property such as participation or membership. The class should be only used to derive subclasses.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "Role",
#         <http://www.w3.org/2004/02/skos/core#closeMatch> <http://schema.org/Role>
#
#
# Class: <https://w3id.org/dingo#SportsOrganisation>
#
#     Annotations:
#         rdfs:comment "Represents the class of all sports organizations, including sports teams, governing bodies, and sports associations.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "SportsOrganisation"
#
#     EquivalentTo:
#         <http://schema.org/SportsOrganisation>
#
#     SubClassOf:
#         <https://w3id.org/dingo#Organisation>
#
#
# Class: <https://w3id.org/dingo#SupranationalOrganisation>
#
#     Annotations:
#         rdfs:comment "International organisation with power and influence in the jurisdictions of its member states. Example: European Union.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "SupranationalOrganisation"
#
#     SubClassOf:
#         <https://w3id.org/dingo#Organisation>
#
#
# Class: <https://w3id.org/dingo#ThematicCriterion>
#
#     Annotations:
#         rdfs:comment "Specifies that grants are awarded to projects on the basis of specified thematic/subject areas or well-defined areas of investigation indicated by the funding body.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "ThematicCriterion"
#
#     SubClassOf:
#         <https://w3id.org/dingo#Criterion>
#
#
# Class: <https://w3id.org/dingo#WorkingTimeCriterion>
#
#     Annotations:
#         rdfs:comment "Specifies that grants are awarded to projects on the basis of percentage of work time specifically devoted to the funded research.",
#         rdfs:isDefinedBy <https://w3id.org/dingo#>,
#         rdfs:label "WorkingTimeCriterion"
#
#     SubClassOf:
#         <https://w3id.org/dingo#Criterion>
#
#
# Class: rdfs:Resource
#
#
# Class: xsd:anyURI
#
#
# Class: xsd:date
#
#
# Class: xsd:dateTime
#
#
# Class: xsd:string
#
#
# Individual: _:0
#
#     Annotations:
#         <http://xmlns.com/foaf/0.1/name> "Alexis-Michel Mugabushaka"
#
#     Types:
#         <http://xmlns.com/foaf/0.1/Person>
#
#
# Individual: _:1
#
#     Annotations:
#         <http://xmlns.com/foaf/0.1/name> "Dan Brickley"
#
#     Types:
#         <http://xmlns.com/foaf/0.1/Person>
#
#
# Individual: _:2
#
#     Annotations:
#         <http://xmlns.com/foaf/0.1/name> "Eric Prud'hommeaux"
#
#     Types:
#         <http://xmlns.com/foaf/0.1/Person>
#
#
# Individual: _:3
#
#     Annotations:
#         <http://xmlns.com/foaf/0.1/name> "Diego Chialva"
#
#     Types:
#         <http://xmlns.com/foaf/0.1/Person>
#
#
# Individual: _:4
#
#     Annotations:
#         <http://xmlns.com/foaf/0.1/name> "Andra Waagmeester"
#
#     Types:
#         <http://xmlns.com/foaf/0.1/Person>
#
#
# Individual: _:5
#
#     Annotations:
#         <http://xmlns.com/foaf/0.1/name> "Thomas Baker"
#
#     Types:
#         <http://xmlns.com/foaf/0.1/Person>

# %% [markdown]
# ## Lexical Views

# %% [markdown]
# ### Lex(S)

# %%
def extract_schema_lexical_view(schema_dict) -> list:
    """
    does not repeat column names that appear more than once
    """
    lexical_view = []
    
    # Process tables in the order they appear in the dictionary
    for table_name in schema_dict.keys():
        table_data = schema_dict[table_name]
        
        # Add table name first
        lexical_view.append(table_name)
        
        # Add columns in the order they appear in the list
        for column in table_data['columns']:
            lexical_view.append(column)
        
        # Add primary keys in order (if any)
        for pk in table_data['primary_keys']:
            lexical_view.append(pk)
        
        # Add foreign key information in order (if any)
        for fk in table_data['foreign_keys']:
            lexical_view.append(fk['ref_table'])  # Referenced table name
            for ref_col in fk['ref_columns']:
                lexical_view.append(ref_col)
                
    # Remove duplicates while preserving order
    seen = set()
    unique_lexical_view = []
    for item in lexical_view:
        if item not in seen:
            seen.add(item)
            unique_lexical_view.append(item)
    return unique_lexical_view

# %%
def extract_schema_lexical_view(schema_dict) -> list:
    """
    Returns format: ['tablename: column1, column2, column3', 'tablename2: column1, column2']
    """
    lexical_view = []
    
    # Process tables in the order they appear in the dictionary
    for table_name in schema_dict.keys():
        table_data = schema_dict[table_name]
        
        # Get all columns for this table
        columns = table_data['columns']
        
        # Create the formatted string for this table
        if columns:
            columns_str = ', '.join(columns)
            lexical_view.append(f"{table_name}: {columns_str}")
        else:
            lexical_view.append(f"{table_name}: ")
    
    return lexical_view

# %%
extract_schema_lexical_view(schema)
# Out:
# ['granter_application: id, created_at, updated_at, state, codename, title, other_data, company_id, opportunity_id, profile_creator_id, pricing_option, ai_review_state, consortium_id, sale_confirmed, approved_grant_amount, success_fee, success_payment_amount, upfront_payment_amount, initial_summary, writer_mode',
#  'granter_applicationfile: id, created_at, updated_at, name, uploaded_file, vector_indexed, type, application_id, document_type_id',
#  'granter_company: id, created_at, updated_at, name, legal_name, address, post_code, city, country, url, legal_form, activity_date, company_id, tax_id, social_security_id, is_sme, employees_n, annual_revenue, description, cover_image, website_data, owner_id, stripe_customer_id, digital_component, future_goals_infrastructure, future_goals_internationalization, future_goals_machinery_and_equipments, future_goals_marketing, future_goals_rd, green_component, team_description, future_goals_hr, onboarding_state, matches_generating, userless, cae, whitelabel_id, related_operations, shareholders, other_data, source, subscription_id, extra_information, matching_order, agent_language',
#  'granter_companyfile: id, created_at, updated_at, name, uploaded_file, company_id, document_type_id, vector_indexed, codename, type, uploaded_by_id',
#  'granter_companymemory: id, created_at, updated_at, content, vector_indexed, company_id, created_by_id, type',
#  'granter_consortium: id, created_at, updated_at, opportunity_id, project_description, state',
#  'granter_consortiumpartner: id, created_at, updated_at, partner_description, company_id, consortium_id, partner_type_id',
#  'granter_consortiumpartnertype: id, created_at, updated_at, codename, description, description_en, description_pt, title, title_en, title_pt, type, description_es, description_it, description_pl, title_es, title_it, title_pl',
#  'granter_consortiumpartnertype_consortium: id, consortiumpartnertype_id, consortium_id',
#  'granter_eligibilitycriteria: id, title, description, opportunity_id',
#  'granter_generalopportunityfile: id, created_at, updated_at, codename, name, uploaded_file',
#  'granter_generalopportunityfile_opportunities: id, generalopportunityfile_id, opportunity_id',
#  'granter_matchgroup: id, created_at, updated_at, status, fundamentation, company_id, opportunity_id',
#  'granter_opportunity: id, created_at, updated_at, type, codename, state, name, fe_value, url, description, cover_image, upfront_fee, force_closing_soon, assistant_id, last_email_reminder, prep_time, location, last_email_push, free_applications, internal_submission, small_cover_image, crawler_data_id, expected_success_rate, success_fee, difficulty_level, eligibility_criteria, eligible_expenses, financial_information, financing_rate, project_duration_months, project_max_value, project_min_value, admissible_projects, form_questions, currency, difficulty_level_fundamentation, tags_fundamentation',
#  'granter_opportunityfile: id, created_at, updated_at, name, uploaded_file, vector_indexed, opportunity_id, codename',
#  'granter_timeline: id, created_at, updated_at, type, title, description, date, time, opportunity_id, time_diff, is_prediction']

# %% [markdown]
# ### Lex(E)

# %%
def extract_ontology_lexical_view(ontology_path: str) -> list:
    """
    Returns format: ['label: comment', 'label2: comment2']
    Pairs labels with their corresponding comments
    """
    with open(ontology_path, 'r', encoding='utf-8') as f:
        content = f.read()
        
    lexical_view = []
    
    # Find all rdfs:label and rdfs:comment matches with their positions
    label_pattern = r'rdfs:label\s+"([^"]+)"'
    comment_pattern = r'rdfs:comment\s+"([^"]+)"'
    
    # Get all matches in order
    labels = [match.group(1).replace(" ", "") for match in re.finditer(label_pattern, content)]
    comments = [match.group(1) for match in re.finditer(comment_pattern, content)]
    comments.pop(0) # Remove the first comment as it does not correspond to any label

    # Pair them sequentially (comment[i] goes with label[i])
    for i in range(len(labels)):
        if i < len(comments):
            lexical_view.append(f"{labels[i]}: {comments[i]}")
        else:
            lexical_view.append(f"{labels[i]}: ")
    
    return lexical_view

# %%
extract_ontology_lexical_view('external_ontologies/DINGO-Manchester.omn')
# Out:
# ['academic_degree: Qualification awarded to the person taking the role by a higher education organisation, normally at a college or university.',
#  'affiliation: An organization that this person is affiliated with. For example, a school/university, a club, or a team.',
#  'agency_identifier: Identifier (for example of Project, Grant, GrantPayment, PersonRole instance, OrganizationRole instance, FundingScheme, Person, Organisation) in the database/archive of the funding agency/funding body/funder.',
#  'baseline_academic_degree: Academic degree used as minimal/reference point for establishing a set of age limits or other classification.',
#  'beneficiary: The relation between the Grant (subject) and a (one of the) person(s) or organisation(s) receiving benefits from it identified by his/her/its role.',
#  'beneficiary_of: The relation between a (one of the) person(s) or organisation(s) receiving benefits from a Grant identified by his/her/its role (subject), and the Grant.',
#  'budget: Amount of money necessary or planned for a determined project/activity.',
#  'country: Country where the organisation is located ufficially.',
#  'criterion: Property by which a distinction or classification is made. When applied to, for instance, FundingScheme items it indicates criterion item establishing the eligibility conditions, target and other relevant points of the FundingScheme to fund an application.',
#  'disbursed_by: The relation between the disbursed grant (subject) and the funding agency (object).',
#  'disburses: The relation between the funding agency (subject) and the disbursed grant (object).',
#  'economic_value: Amount or value expressed in a specific currency (relationship between the item and a value expressed in a currency unit).',
#  'employer: A person or company that provides a job (possibly paying wages or a salary) to the person taking the role.',
#  'end_time: The time an item ceases to exist or a statement stops being valid.',
#  'entity_taking_role: The person or organisation or entity (object) assuming or to whom is assigned the role (subject).',
#  'excluded_academic_degree: Academic degree possessing which the subject of the statement cannot apply to the funding program.',
#  'title: Specialisation of a person, project or organisation.',
#  'finances: The relation between the Grant (subject) and the Project (object).',
#  'funded_by: The relation between the Project (subject) and the Grant (object).',
#  'funder: The ultimate funder who decided and is ultimately responsible for the funding scheme.\n(Example: FundingScheme Horizon2020 dg:funder European Commission).',
#  'grid_id: Institutional identifier from the GRID.ac global research identifier database.',
#  'hasPart: The relation between a superset and its direct subset(s). Indicates an item that is a part (also in generalised sense) of the subject item.',
#  'has_implementation: The relationship between the decision, plan, program (subject) and the grant (object) that the grant is the concrete realisation of.',
#  'headquarters_location: Address of the headquarters of the organisation.',
#  'id_context_agent: Organization, Person, Agency related to the identifiers (for instance, creator, attributor, curator, maintainer, or similar). The specific semantic should be indicated with dedicated ontologies, such as PROV-O.',
#  'implementation_country: Country where the project must be implemented.',
#  'implementation_of: The relationship between the grant (subject) and the decision, plan, program (object) that the grant is the concrete realisation of.',
#  'implemented_by: The relationship between the decision, plan, program (subject) and the funding agency (object) that the funding agency implements and administers.',
#  'implements: The relationship between the funding agency (subject) and the decision, plan, program (object) that the funding agency implements and administers.',
#  'inception: Date or point in time when the subject was founded/created.',
#  'isPartOf: The relation between a subset and its direct superset(s). Indicates an item that is a part (also in generalised sense) of the object item.',
#  'legalName: The official name of the organization, for example the registered company name.',
#  'objective: Desired result or outcome.',
#  'official_website: URL of the official website of an item.',
#  'organisation_location: Country or geographical administrative entity where an organisation must be established to apply for funding.',
#  'participant: The relation between the Project (subject) and a (one of the) person(s) or organisation(s) contributing to or taking part in it identified by his/her/its role.',
#  'participant_of: The relation between a (one of the) person(s) or organisation(s) participant of a Project identified by his/her/its role (subject), and the Project.',
#  'person_location: Country or geographical administrative entity where the person must reside or be citizen or have undertaken research up to the moment of applying for funding.',
#  'point_in_time: The moment in time when an event occurs.',
#  'product_or_material_produced: Material, product or output produced by a Project.',
#  'recipient: The receiver of a GrantPayment or receiver/beneficiary of a GrantShare.',
#  'role_type: Item representing the specific class of a Role.',
#  'start_time: The time an item starts to exist/operate or a statement starts being valid.',
#  'takes_role: The role (object) assumed or assigned to a person or organisation or entity (subject).',
#  'thematic_area: Topics and/or area of interest.',
#  'used_in: Database or information system where the identifier is/was used.',
#  'abstract_or_summary_description: Short summary description of a project.',
#  "additionalName: Additional part of a person's beyond given name and surname, can be used for a middle name.",
#  'criterion_description: Description of the eligibility, targets and other relevant points of the FundingScheme.',
#  'crossref_grantid: Identifier for funding in the Crossref registry.',
#  'crossref_id: Identifier for an organisation that funds research, in the Crossref registry.',
#  'degree_title: Title denoting the academic degree.',
#  'early_termination: Indicates if the role was ended ahead of time with respect to the grant contract of project ending.',
#  "givenName: Part of a person's name that individuates the person within the (typically closest) group that shares the same surname.",
#  'id_value: String representing the identifier.',
#  'max_age: Maximum age allowed.',
#  'max_years_from_baseline_degree: Maximum number of years counting from the year of when the dg:baseline_academic_degree was obtained.',
#  'min_age: Minimum age required.',
#  'min_research_years: Minimum number of research years required.',
#  'min_years_from_baseline_degree: Minimum number of years counting from the year of when the dg:baseline_academic_degree was obtained.',
#  'orcid_id: Nonproprietary alphanumeric code to uniquely identify scientific and other academic authors.',
#  'percentage_employment: Minimum percentage of employment required (for example to be eligible for funding).',
#  'percentage_working_time: Amount of working time in percentage.',
#  'role_label: Label (name) of a Role.',
#  'short_name: Acronym or short name of an organisation or project or funding scheme.',
#  "surname: Part of a person's name shared with a group (typically family or tribe or clan depending on the culture), and/or used in formal contexts or with people that do not know the person well.",
#  'title: The title of a project (original or translated).',
#  'wikidata_item_id: Identifier for a class or item existing in Wikidata.',
#  'AcademicDegree: The class for academic degrees: college or university diploma.',
#  'AgeCriterion: Specifies that grants are awarded to projects on the basis of age limits.',
#  'ArchiveOrganisation: Institution that holds artifacts and other objects of scientific, artistic, cultural, historical, or other importance.',
#  'BottomUpCriterion: Specifies that grants are awarded to projects on the basis of the research proposal itself without restriction on theme/subject or research area. The funding body does not specifies beforehand missions, targets nor topics of the research projects that can apply.',
#  'CareerPurposeCriterion: Specifies that grants are awarded on the basis of career-related goals and applicants must be at a defined career stage (defined academic degree) to be achieved.',
#  'CareerStageCriterion: Specifies that grants are awarded to projects on the basis of career stage limits.',
#  'Company: A commercial business.',
#  'Criterion: Specification of Grant coverage, Grant eligibility, Grant reimbursement rates, Grant specific criteria for funding, Grant population targets, and similar features.',
#  'CulturalOrganisation: Cultural institution or cultural organization is an organization within a culture/subculture that works for the preservation or promotion of culture.',
#  'EducationOrganisation: Institution that provides education.',
#  'EmploymentCriterion: Specifies that grants are awarded on the basis of employment conditions by an organisation eligible for funding at the time of applying or receiving the funds.',
#  'FacilityOrganisation: A place providing for a particular purpose.',
#  'ForProfictOrganisation: For profit entity.',
#  'FundingAgency: The class for funding agencies: organisations that materially disburse and administer the Grant process.',
#  'FundingScheme: The class for funding schemes: plans, designs, and/or programs that determines and organizes the funding.',
#  'GeographicCriterion: Specifies that grants are awarded to projects on the basis of geographic areas, either where the project has to be implemented, or where the researcher must have been operating before applying for funding, or where the participants must be resident or citizens.',
#  'GovernmentalOrganisation: Organisation or agency depending on a government, State or other supranational organisation and mainly operated by the government.',
#  'Grant: The class for grant: a disbursed fund payed to a recipient or beneficiary and the process for it.',
#  'GrantPayment: The class for grant payments: a single payment to a recipient or beneficiary within a Grant.',
#  'GrantShare: The class for grant shares: the full or proper portion or part allotted or belonging to or contributed to an individual entity within a Grant.',
#  'HealthcareOrganisation: Organization that provides health care and related services.',
#  'HigherEducationOrganisation: Place of postsecondary education (e.g., universities, vocational universities, community colleges, liberal arts colleges, institutes of technology, and others).',
#  'Identifier: The class for identifiers.',
#  'InformationBase: An organized collection of data and/or information. It can use any available technology. The temr can also indicate in general the information system built integrating such information bases.',
#  'InfrastructurePurposeCriterion: Specifies that grants are awarded to cover for the expenses of infrastructure.',
#  'IntergovernmentalOrganisation: Organization composed primarily of sovereign states. Example: United Nations.',
#  'NonprofitOrganisation: Business entity that pays no income tax, as it furthers a religious, scientific or social cause, providing a public benefit.',
#  'Organisation: The class for organisations: social entities with a collective goal.',
#  'OrganisationRole: The class for organisation roles: function assumed by or ascribed to an organisation that takes part in something.',
#  'OrganisationalCriterion: Specifies that grants are awarded on the basis of specified organisational form of the project, for instance demanding for participation of different research groups (synergy).',
#  'PerformingGroup: A performance group, such as a band, an orchestra, or a circus.',
#  'Person: The class for persons: alive, dead, undead, or fictional.',
#  'PersonRole: The class for person roles: function assumed by or ascribed to a person that takes part in something.',
#  'Project: The class for projects: an organised endeavour (collective or individual) planned to reach a particular aim or achieve a result.',
#  'ResearchPerformingOrganisation: Organisations devoted to research activities.',
#  'Role: The class for roles: the function assumed by or ascribed to an entity (typically person, group of persons or organisation) in a particular situation.\nIt can be used to precise or represent additional information about a relationship or property such as participation or membership. The class should be only used to derive subclasses.',
#  'SportsOrganisation: Represents the class of all sports organizations, including sports teams, governing bodies, and sports associations.',
#  'SupranationalOrganisation: International organisation with power and influence in the jurisdictions of its member states. Example: European Union.',
#  'ThematicCriterion: Specifies that grants are awarded to projects on the basis of specified thematic/subject areas or well-defined areas of investigation indicated by the funding body.',
#  'WorkingTimeCriterion: Specifies that grants are awarded to projects on the basis of percentage of work time specifically devoted to the funded research.']

# %% [markdown]
# # RAG of Relevant Knowledge

# %% [markdown]
# The **retrieval** will be done over:<br>
# + The Growing core ontology<br>
# + The External Ontology Repository<br>
# + The Textual Descriptions of the RDB

# %% [markdown]
# ## Chunking (the textual descriptions of the database)

# %%
def chunk_text(text: str, chunk_size=1200, chunk_overlap=100):
    """
    Chunk text and return plain strings (no metadata)
    """
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size, 
        chunk_overlap=chunk_overlap
    )
    return text_splitter.split_text(text)

# %%
readme_database_chunks = chunk_text(readme_database_content, 500)
print(readme_database_chunks[0])
# Out:
# # Granter Database Schema
# This document explains the relationships between the main tables used in **Granter**, the AI-powered grant application platform.
# ---
# ## Tables and Relationships
# ### **granter_company**
# - Represents a company that applies to funding opportunities.
# - **Relations:**
#   - Can create **granter_applications** for opportunities.
#   - Has associated **granter_companyfiles** for company-related context.

# %% [markdown]
# ## Embedding amd Indexing

# %%
INDEX_PATH_CORE = "../../storage/faiss_RIGOR/core"
INDEX_PATH_EXTERNAL_ONT = "../../storage/faiss_RIGOR/external_ontologies"
INDEX_PATH_TEXTUAL_DESC = "../../storage/faiss_RIGOR/textual_descriptions"

def embed_and_index(text_chunks: list, index_path: str):
    """
    Embed and index text chunks in the given directory
    """
    os.makedirs(os.path.dirname(index_path), exist_ok=True)

    vectorstore = FAISS.from_texts(text_chunks, embedding)
    vectorstore.save_local(index_path)
    print(f"Index saved at {index_path}. {len(text_chunks)} text chunks embedded and stored.")

# %%
#lexS = extract_schema_lexical_view(schema)
lexE = extract_ontology_lexical_view('external_ontologies/DINGO-Manchester.omn')

index_list = [INDEX_PATH_EXTERNAL_ONT, INDEX_PATH_TEXTUAL_DESC]
content_list = [lexE, readme_database_chunks]

for i, content in enumerate(content_list):
    if not os.path.exists(index_list[i]) or not os.listdir(index_list[i]):
        embed_and_index(content, index_list[i])
        print(f"Indexed {len(content)} text chunks in {index_list[i]}.")
    else:
        print('Embeddings already exist. Skipped indexing')
# Out:
# Embeddings already exist. Skipped indexing
# Embeddings already exist. Skipped indexing

# %% [markdown]
# ## Retrieval Functions

# %%
def retrieve(input, index_path, k=4):
    vectorstore = FAISS.load_local(index_path, embedding, 
                                   allow_dangerous_deserialization=True)
    docs = vectorstore.similarity_search(input, k=k)

    return [doc.page_content for doc in docs]

#print(retrieve("application file", INDEX_PATH_TEXTUAL_DESC, 2)[0])
print(retrieve("application", INDEX_PATH_EXTERNAL_ONT, 2)[0])
# Out:
# organisation_location: Country or geographical administrative entity where an organisation must be established to apply for funding.

# %%
def docTable(relation: str):
    """
    returns the textual description of a relation r
    """
    return retrieve(f"relation: {relation}", INDEX_PATH_TEXTUAL_DESC, 2)


def docAttr(relation: str, attribute: str):
    """
    returns the textual description of an attribute a in relation r
    """
    return retrieve(f"relation: {relation}, attribute: {attribute}", INDEX_PATH_TEXTUAL_DESC, 1)

# %% [markdown]
# # LLM Prompt Construction and Ontology Generation

# %%
from dotenv import load_dotenv
load_dotenv()
GROQ_API_KEY = os.getenv("GROQ_API_KEY")

from langchain_groq import ChatGroq

groqllm = ChatGroq(
    model="llama-3.1-8b-instant",
    api_key=GROQ_API_KEY,
    temperature=0
)

# %%
table = schema['granter_application']
core_ontology = ""

prompt = f"""
    Generate ontology elements with provenance annotations for database table {'granter_application'}, based on:

    [CONTEXT]
    - Database Schema of the table \n{json.dumps('granter_application')}\n
    - Take semantics from the External Ontology Knowledge \n{"\n".join(retrieve('granter_application', INDEX_PATH_EXTERNAL_ONT))}\n
    - Take semantics from the Relevant Documents \n{"\n".join(docTable('granter_application'))}
    - 

    [INSTRUCTIONS]
    1. Include these elements:
        Classes (subclass of owl:Thing)
        Data properties with domain/range
        Object properties with domain/range
        Use only one Domain: and one Range: per property. If multiple options exist, select the most general or create a shared superclass.
    2. Use Turtle/RDF syntax format
    3. Do not create a property named "is". Use rdf:type for instance membership, rdfs:subClassOf for class hierarchies, and owl:sameAs for instance equality.
    4. Stick to camel case for naming the ontology elements.
    5. Use this format example:

    @prefix prov: <http://www.w3.org/ns/prov#> .
    @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
    @prefix owl: <http://www.w3.org/2002/07/owl#> .
    @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
    @prefix : <http://example.org/my-ontology#> .

    :{'granter_application'} a owl:Class ;
        prov:wasDerivedFrom <http://example.org/provenance/{'granter_application'}> .

    :has_column_name a owl:DatatypeProperty ;
        rdfs:domain :{'granter_application'} ;
        rdfs:range xsd:string ;
        prov:wasDerivedFrom <http://example.org/provenance/{'granter_application'}/column_name> .

    :relates_to_table a owl:ObjectProperty ;
        rdfs:domain :{'granter_application'} ;
        rdfs:range :RelatedTable ;
        prov:wasDerivedFrom <http://example.org/provenance/{'granter_application'}/fk_column> .

    Only output Turtle syntax and nothing else. [OUTPUT]
"""

# %%
print("\n".join(retrieve('granter_application', INDEX_PATH_EXTERNAL_ONT)))
# Out:
# recipient: The receiver of a GrantPayment or receiver/beneficiary of a GrantShare.
# GrantPayment: The class for grant payments: a single payment to a recipient or beneficiary within a Grant.
# Grant: The class for grant: a disbursed fund payed to a recipient or beneficiary and the process for it.
# CareerPurposeCriterion: Specifies that grants are awarded on the basis of career-related goals and applicants must be at a defined career stage (defined academic degree) to be achieved.

# %%
print("\n".join(docTable('granter_application')))
# Out:
# ---
# ### **granter_companymemory**
# - Small text snippets stored as vectors for RAG purposes.
# - Help provide semantic context when drafting applications.
# - **Relations:**
#   - Belongs to a **granter_company**.
# ---
# ### **granter_opportunity**
# - Represents a funding opportunity (grant, tax incentive, investment, or loan).
# - **Relations:**
#   - Can have multiple **granter_applications** from different companies.
#   - Has associated **granter_opportunityfiles**.
# - Has associated **granter_companyfiles** for company-related context.
#   - Has associated **granter_companymemories** (vectorized text snippets for RAG).
# ---
# ### **granter_application**
# - An application generated for a specific **company** and a specific **opportunity**.
# - **Relations:**
#   - Belongs to a **granter_company**.
#   - Belongs to a **granter_opportunity**.
#   - Has associated **granter_applicationfiles** (files relevant to this application).
# ---
# ### **granter_applicationfile**

# %%
delta_ontology = groqllm.invoke(prompt)

# %%
print(delta_ontology.content)
# Out:
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix : <http://example.org/granter_ontology#> .
#
# :GrantPayment a owl:Class ;
#     rdfs:comment "The class for grant payments: a single payment to a recipient or beneficiary within a Grant." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantPayment> .
#
# :Grant a owl:Class ;
#     rdfs:comment "The class for grant: a disbursed fund paid to a recipient or beneficiary and the process for it." ;
#     prov:wasDerivedFrom <http://example.org/provenance/Grant> .
#
# :Recipient a owl:Class ;
#     rdfs:comment "The receiver of a GrantPayment or receiver/beneficiary of a GrantShare." ;
#     prov:wasDerivedFrom <http://example.org/provenance/Recipient> ;
#     rdfs:subClassOf owl:Thing .
#
# :CareerPurposeCriterion a owl:Class ;
#     rdfs:comment "Specifies that grants are awarded on the basis of career-related goals and applicants must be at a defined career stage (defined academic degree) to be achieved." ;
#     prov:wasDerivedFrom <http://example.org/provenance/CareerPurposeCriterion> .
#
# :GrantrCompanyMemory a owl:Class ;
#     rdfs:comment "Small text snippets stored as vectors for RAG purposes." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrCompanyMemory> ;
#     rdfs:subClassOf owl:Thing .
#
# :GrantrCompanyMemoryBelongsTo a owl:ObjectProperty ;
#     rdfs:domain :GrantrCompanyMemory ;
#     rdfs:range :GrantrCompany ;
#     rdfs:comment "Belongs to a granter company." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrCompanyMemoryBelongsTo> .
#
# :GrantrOpportunity a owl:Class ;
#     rdfs:comment "Represents a funding opportunity (grant, tax incentive, investment, or loan)." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrOpportunity> .
#
# :GrantrOpportunityHasApplication a owl:ObjectProperty ;
#     rdfs:domain :GrantrOpportunity ;
#     rdfs:range :GrantrApplication ;
#     rdfs:comment "Can have multiple granter applications from different companies." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrOpportunityHasApplication> .
#
# :GrantrOpportunityHasFile a owl:ObjectProperty ;
#     rdfs:domain :GrantrOpportunity ;
#     rdfs:range :GrantrOpportunityFile ;
#     rdfs:comment "Has associated granter opportunity files." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrOpportunityHasFile> .
#
# :GrantrCompany a owl:Class ;
#     rdfs:comment "Represents a company." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrCompany> ;
#     rdfs:subClassOf owl:Thing .
#
# :GrantrCompanyHasMemory a owl:ObjectProperty ;
#     rdfs:domain :GrantrCompany ;
#     rdfs:range :GrantrCompanyMemory ;
#     rdfs:comment "Has associated granter company memories." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrCompanyHasMemory> .
#
# :GrantrApplication a owl:Class ;
#     rdfs:comment "An application generated for a specific company and a specific opportunity." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrApplication> .
#
# :GrantrApplicationBelongsToCompany a owl:ObjectProperty ;
#     rdfs:domain :GrantrApplication ;
#     rdfs:range :GrantrCompany ;
#     rdfs:comment "Belongs to a granter company." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrApplicationBelongsToCompany> .
#
# :GrantrApplicationBelongsToOpportunity a owl:ObjectProperty ;
#     rdfs:domain :GrantrApplication ;
#     rdfs:range :GrantrOpportunity ;
#     rdfs:comment "Belongs to a granter opportunity." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrApplicationBelongsToOpportunity> .
#
# :GrantrApplicationHasFile a owl:ObjectProperty ;
#     rdfs:domain :GrantrApplication ;
#     rdfs:range :GrantrApplicationFile ;
#     rdfs:comment "Has associated granter application files." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrApplicationHasFile> .
#
# :GrantrApplicationHasColumn a owl:DatatypeProperty ;
#     rdfs:domain :GrantrApplication ;
#     rdfs:range xsd:string ;
#     rdfs:comment "Has a column name." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrApplicationHasColumn> .
#
# :GrantrApplicationHasForeignKey a owl:ObjectProperty ;
#     rdfs:domain :GrantrApplication ;
#     rdfs:range :RelatedTable ;
#     rdfs:comment "Has a foreign key column." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrApplicationHasForeignKey> .
#
# :RelatedTable a owl:Class ;
#     rdfs:comment "A table related to the granter application." ;
#     prov:wasDerivedFrom <http://example.org/provenance/RelatedTable> ;
#     rdfs:subClassOf owl:Thing .
#
# :GrantrApplicationFile a owl:Class ;
#     rdfs:comment "Files relevant to the granter application." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrApplicationFile> ;
#     rdfs:subClassOf owl:Thing .

# %%
type(delta_ontology.content)
# Out:
# str

# %% [markdown]
# # Validation and Refinement

# %% [markdown]
# ### Prompt

# %%
from rdflib import Graph

def validate_turtle_string(turtle_str: str) -> tuple[bool, str]:
    """
    Validates whether the input string is valid Turtle syntax.

    Returns:
        - is_valid (bool): True if valid, False otherwise
        - error_msg (str): Error message if invalid, else empty
    """
    try:
        g = Graph()
        g.parse(data=turtle_str, format="turtle")
        return True, ""
    except Exception as e:
        return False, str(e)

# %%
is_valid, error_message = validate_turtle_string(delta_ontology.content)

if not is_valid:
    additional_syntax_hint = f"""
[SYNTAX ISSUES DETECTED]

Note: The delta ontology provided is NOT valid Turtle syntax.

Please make the following minimal syntax corrections before further validation:
- Declare all prefixes used in the ontology explicitly (e.g., rdf:, rdfs:, owl:, xsd:, prov:).
- Use angle brackets <...> for all full IRI references.
- Each property must have exactly one rdfs:domain and one rdfs:range.
- Ensure rdfs:range only uses valid OWL classes or XSD types (e.g., xsd:string).
- Remove annotation-style keywords like 'Annotations:' and instead use Turtle triples for metadata.
- Avoid misplaced punctuation or unclosed blocks.

Parsing error: {error_message}
"""
else:
    additional_syntax_hint = ""

# %%
print(additional_syntax_hint)

# %%
evaluator_prompt = f"""
    You are an expert in OWL 2 DL ontology modeling and validation.

    Your task is to review the following delta ontology fragment generated from a relational database table, along with its schema and relevant context.

    [DELTA-ONTOLOGY]
    {delta_ontology}

    [DATABASE SCHEMA]
    {table}

    [CORE ONTOLOGY CONTEXT]
    {core_ontology if core_ontology else "(empty as of now)"}

    {additional_syntax_hint}

    [VALIDATION CRITERIA]
    1. **Coherence with Core Ontology**  
    - Do NOT redefine an existing class, property, or concept already present in the core ontology with the same meaning.
    - Reuse existing ontology elements where possible instead of creating duplicates.

    2. **Alignment with Input Table Schema**  
    - Every significant column and foreign key in the table must be represented as an appropriate ontology element (class, data property, or object property).
    - Naming should reflect the database semantics clearly and consistently.

    3. **Syntactic Validity**  
    - The ontology must conform to valid Turtle/RDF syntax.
    - Use proper prefixes and IRI declarations.
    - Exactly one rdfs:domain and one rdfs:range per property.

    4. **Logical Consistency**  
    - No contradictory class axioms or property constraints.
    - No circular subclass relationships.
    - Correct choice between object properties and data properties.

    5. **Clarity and Naming Quality**  
    - Use self-explanatory, domain-relevant names.
    - Avoid generic or meaningless labels.
    - All elements should follow camel case naming patterns.

    [YOUR TASK]
    - Check the delta ontology fragment against all criteria above.
    - If issues are found, provide a corrected version of the ontology in valid Turtle syntax.
    - Make minimal necessary changes to preserve the author's intent while ensuring correctness and OWL 2 DL compliance.
    - Ensure all elements keep their provenance annotations.

    [OUTPUT FORMAT]
    Respond ONLY with:
    1. "Status: PASS" if the ontology fragment meets all criteria, or "Status: FAIL" if it does not.
    2. If FAIL, provide:
        a. A short bullet list of the issues found.
        b. A corrected Turtle syntax version of the ontology fragment, and enclose it between triple backticks (```), on their own lines.

    Do NOT include any other commentary outside this format.
    Always enclose the corrected ontology with triple backticks for programmatic extraction.
"""

# %%
revision = groqllm.invoke(evaluator_prompt)
print(revision.content)
# Out:
# Status: FAIL
#
# * Issue 1: The ontology fragment contains a redefinition of the existing class `owl:Thing` with the same meaning.
# * Issue 2: The property `:GrantrApplicationHasColumn` is a data property with a range of `xsd:string`, but it should be an object property with a range of `owl:Thing` or a more specific class.
# * Issue 3: The property `:GrantrApplicationHasForeignKey` is an object property with a range of `:RelatedTable`, but it should be an object property with a range of `owl:Thing` or a more specific class.
# * Issue 4: The class `:GrantrCompanyMemory` is a subclass of `owl:Thing`, but it should be a subclass of a more specific class or not subclass of `owl:Thing` at all.
#
# ```turtle
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix : <http://example.org/granter_ontology#> .
#
# :GrantPayment a owl:Class ;
#     rdfs:comment "The class for grant payments: a single payment to a recipient or beneficiary within a Grant." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantPayment> .
#
# :Grant a owl:Class ;
#     rdfs:comment "The class for grant: a disbursed fund paid to a recipient or beneficiary and the process for it." ;
#     prov:wasDerivedFrom <http://example.org/provenance/Grant> .
#
# :Recipient a owl:Class ;
#     rdfs:comment "The receiver of a GrantPayment or receiver/beneficiary of a GrantShare." ;
#     prov:wasDerivedFrom <http://example.org/provenance/Recipient> ;
#     rdfs:subClassOf owl:Thing .
#
# :CareerPurposeCriterion a owl:Class ;
#     rdfs:comment "Specifies that grants are awarded on the basis of career-related goals and applicants must be at a defined career stage (defined academic degree) to be achieved." ;
#     prov:wasDerivedFrom <http://example.org/provenance/CareerPurposeCriterion> .
#
# :GrantrCompanyMemory a owl:Class ;
#     rdfs:comment "Small text snippets stored as vectors for RAG purposes." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrCompanyMemory> .
#
# :GrantrCompanyMemoryBelongsTo a owl:ObjectProperty ;
#     rdfs:domain :GrantrCompanyMemory ;
#     rdfs:range :GrantrCompany ;
#     rdfs:comment "Belongs to a granter company." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrCompanyMemoryBelongsTo> .
#
# :GrantrOpportunity a owl:Class ;
#     rdfs:comment "Represents a funding opportunity (grant, tax incentive, investment, or loan)." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrOpportunity> .
#
# :GrantrOpportunityHasApplication a owl:ObjectProperty ;
#     rdfs:domain :GrantrOpportunity ;
#     rdfs:range :GrantrApplication ;
#     rdfs:comment "Can have multiple granter applications from different companies." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrOpportunityHasApplication> .
#
# :GrantrOpportunityHasFile a owl:ObjectProperty ;
#     rdfs:domain :GrantrOpportunity ;
#     rdfs:range :GrantrOpportunityFile ;
#     rdfs:comment "Has associated granter opportunity files." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrOpportunityHasFile> .
#
# :GrantrCompany a owl:Class ;
#     rdfs:comment "Represents a company." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrCompany> ;
#     rdfs:subClassOf owl:Thing .
#
# :GrantrCompanyHasMemory a owl:ObjectProperty ;
#     rdfs:domain :GrantrCompany ;
#     rdfs:range :GrantrCompanyMemory ;
#     rdfs:comment "Has associated granter company memories." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrCompanyHasMemory> .
#
# :GrantrApplication a owl:Class ;
#     rdfs:comment "An application generated for a specific company and a specific opportunity." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrApplication> .
#
# :GrantrApplicationBelongsToCompany a owl:ObjectProperty ;
#     rdfs:domain :GrantrApplication ;
#     rdfs:range :GrantrCompany ;
#     rdfs:comment "Belongs to a granter company." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrApplicationBelongsToCompany> .
#
# :GrantrApplicationBelongsToOpportunity a owl:ObjectProperty ;
#     rdfs:domain :GrantrApplication ;
#     rdfs:range :GrantrOpportunity ;
#     rdfs:comment "Belongs to a granter opportunity." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrApplicationBelongsToOpportunity> .
#
# :GrantrApplicationHasFile a owl:ObjectProperty ;
#     rdfs:domain :GrantrApplication ;
#     rdfs:range :GrantrApplicationFile ;
#     rdfs:comment "Has associated granter application files." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrApplicationHasFile> .
#
# :GrantrApplicationHasColumn a owl:ObjectProperty ;
#     rdfs:domain :GrantrApplication ;
#     rdfs:range owl:Thing ;
#     rdfs:comment "Has a column name." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrApplicationHasColumn> .
#
# :GrantrApplicationHasForeignKey a owl:ObjectProperty ;
#     rdfs:domain :GrantrApplication ;
#     rdfs:range owl:Thing ;
#     rdfs:comment "Has a foreign key column." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrApplicationHasForeignKey> .
#
# :RelatedTable a owl:Class ;
#     rdfs:comment "A table related to the granter application." ;
#     prov:wasDerivedFrom <http://example.org/provenance/RelatedTable> ;
#     rdfs:subClassOf owl:Thing .
#
# :GrantrApplicationFile a owl:Class ;
#     rdfs:comment "Files relevant to the granter application." ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantrApplicationFile> ;
#     rdfs:subClassOf owl:Thing .
# ```

# %%
# Check if validation passed
if "Status: PASS" in revision.content:
    print(delta_ontology.content, True)
else:
    # Extract corrected ontology from revision
    lines = revision.content.split('\n')
    corrected_start = False
    corrected_ontology = []
    
    for line in lines:
        if corrected_start:
            corrected_ontology.append(line)
        elif line.strip().startswith('Class:') or line.strip().startswith('DataProperty:') or line.strip().startswith('ObjectProperty:'):
            corrected_start = True
            corrected_ontology.append(line)
    
    if corrected_ontology:
        print('\n'.join(corrected_ontology), True)
    else:
        print(f"Warning: Could not extract corrected ontology for table {'granter_application'}")
        print(delta_ontology, False)
# Out:
# Warning: Could not extract corrected ontology for table granter_application
# content='@prefix prov: <http://www.w3.org/ns/prov#> .\n@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .\n@prefix owl: <http://www.w3.org/2002/07/owl#> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix : <http://example.org/granter_ontology#> .\n\n:GrantPayment a owl:Class ;\n    rdfs:comment "The class for grant payments: a single payment to a recipient or beneficiary within a Grant." ;\n    prov:wasDerivedFrom <http://example.org/provenance/GrantPayment> .\n\n:Grant a owl:Class ;\n    rdfs:comment "The class for grant: a disbursed fund paid to a recipient or beneficiary and the process for it." ;\n    prov:wasDerivedFrom <http://example.org/provenance/Grant> .\n\n:Recipient a owl:Class ;\n    rdfs:comment "The receiver of a GrantPayment or receiver/beneficiary of a GrantShare." ;\n    prov:wasDerivedFrom <http://example.org/provenance/Recipient> ;\n    rdfs:subClassOf owl:Thing .\n\n:CareerPurposeCriterion a owl:Class ;\n    rdfs:comment "Specifies that grants are awarded on the basis of career-related goals and applicants must be at a defined career stage (defined academic degree) to be achieved." ;\n    prov:wasDerivedFrom <http://example.org/provenance/CareerPurposeCriterion> .\n\n:GrantrCompanyMemory a owl:Class ;\n    rdfs:comment "Small text snippets stored as vectors for RAG purposes." ;\n    prov:wasDerivedFrom <http://example.org/provenance/GrantrCompanyMemory> ;\n    rdfs:subClassOf owl:Thing .\n\n:GrantrCompanyMemoryBelongsTo a owl:ObjectProperty ;\n    rdfs:domain :GrantrCompanyMemory ;\n    rdfs:range :GrantrCompany ;\n    rdfs:comment "Belongs to a granter company." ;\n    prov:wasDerivedFrom <http://example.org/provenance/GrantrCompanyMemoryBelongsTo> .\n\n:GrantrOpportunity a owl:Class ;\n    rdfs:comment "Represents a funding opportunity (grant, tax incentive, investment, or loan)." ;\n    prov:wasDerivedFrom <http://example.org/provenance/GrantrOpportunity> .\n\n:GrantrOpportunityHasApplication a owl:ObjectProperty ;\n    rdfs:domain :GrantrOpportunity ;\n    rdfs:range :GrantrApplication ;\n    rdfs:comment "Can have multiple granter applications from different companies." ;\n    prov:wasDerivedFrom <http://example.org/provenance/GrantrOpportunityHasApplication> .\n\n:GrantrOpportunityHasFile a owl:ObjectProperty ;\n    rdfs:domain :GrantrOpportunity ;\n    rdfs:range :GrantrOpportunityFile ;\n    rdfs:comment "Has associated granter opportunity files." ;\n    prov:wasDerivedFrom <http://example.org/provenance/GrantrOpportunityHasFile> .\n\n:GrantrCompany a owl:Class ;\n    rdfs:comment "Represents a company." ;\n    prov:wasDerivedFrom <http://example.org/provenance/GrantrCompany> ;\n    rdfs:subClassOf owl:Thing .\n\n:GrantrCompanyHasMemory a owl:ObjectProperty ;\n    rdfs:domain :GrantrCompany ;\n    rdfs:range :GrantrCompanyMemory ;\n    rdfs:comment "Has associated granter company memories." ;\n    prov:wasDerivedFrom <http://example.org/provenance/GrantrCompanyHasMemory> .\n\n:GrantrApplication a owl:Class ;\n    rdfs:comment "An application generated for a specific company and a specific opportunity." ;\n    prov:wasDerivedFrom <http://example.org/provenance/GrantrApplication> .\n\n:GrantrApplicationBelongsToCompany a owl:ObjectProperty ;\n    rdfs:domain :GrantrApplication ;\n    rdfs:range :GrantrCompany ;\n    rdfs:comment "Belongs to a granter company." ;\n    prov:wasDerivedFrom <http://example.org/provenance/GrantrApplicationBelongsToCompany> .\n\n:GrantrApplicationBelongsToOpportunity a owl:ObjectProperty ;\n    rdfs:domain :GrantrApplication ;\n    rdfs:range :GrantrOpportunity ;\n    rdfs:comment "Belongs to a granter opportunity." ;\n    prov:wasDerivedFrom <http://example.org/provenance/GrantrApplicationBelongsToOpportunity> .\n\n:GrantrApplicationHasFile a owl:ObjectProperty ;\n    rdfs:domain :GrantrApplication ;\n    rdfs:range :GrantrApplicationFile ;\n    rdfs:comment "Has associated granter application files." ;\n    prov:wasDerivedFrom <http://example.org/provena ...

# %%
def extract_ontology_block(text: str) -> str:
    """
    Extracts the ontology code block from a mixed LLM output.
    Looks for content between triple backticks (```).

    Parameters:
        text (str): The full output from the LLM.

    Returns:
        str: The extracted ontology block as a string, or an empty string if not found.
    """
    inside_block = False
    lines = []
    
    for line in text.splitlines():
        if line.strip().startswith("```"):
            if inside_block:
                break  # end of block
            else:
                inside_block = True
                continue  # skip the line with ```
        if inside_block:
            lines.append(line)
    
    return "\n".join(lines).strip()

# %%
from rdflib import Graph, RDF, OWL

def extract_names(turtle_str):
    """
    Extract ontology elements (local names without full URIs).
    Returns:
        - class_names: ontology classes (entities)
        - object_property_names: ontology object properties (relationships)
        - datatype_property_names: ontology datatype properties (attributes)
    """
    g = Graph()
    g.parse(data=turtle_str, format="turtle")
    
    def get_local_name(uri):
        uri_str = str(uri)
        if '#' in uri_str: 
            return uri_str.split('#')[-1]
        return uri_str.split('/')[-1]
    
    # Classes
    class_uris = [s for s, _, _ in g.triples((None, RDF.type, OWL.Class))]
    class_names = [get_local_name(uri) for uri in class_uris]
    
    # Object properties
    object_prop_uris = [s for s, _, _ in g.triples((None, RDF.type, OWL.ObjectProperty))]
    object_property_names = [get_local_name(uri) for uri in object_prop_uris]
    
    # Datatype properties
    data_prop_uris = [s for s, _, _ in g.triples((None, RDF.type, OWL.DatatypeProperty))]
    datatype_property_names = [get_local_name(uri) for uri in data_prop_uris]
    
    return (
        sorted(class_names),
        sorted(object_property_names),
        sorted(datatype_property_names),
    )

# %%
classes, relations, attributes = extract_names(extract_ontology_block(revision.content))

core_context = f"""Class names: {', '.join(classes)}
\nObject properties (relations): {', '.join(relations)}
\nDatatype properties (attributes): {', '.join(attributes)}
"""

print(", ".join(core_context))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 classes, relations, attributes = extract_names(extract_ontology_block(revision.content))
#       3 core_context = f"""Class names: {', '.join(classes)}
#       4 \nObject properties (relations): {', '.join(relations)}
#       5 \nDatatype properties (attributes): {', '.join(attributes)}
#       6 """
#       8 print(", ".join(core_context))
#
# NameError: name 'extract_ontology_block' is not defined

# %% [markdown]
# # Iterative Integration and Completion

# %% [markdown]
# Recreate and Embed Lex(Ot) at each iteration to then retrieve it

# %% [markdown]
# ## Function to extract corrected ontology from Judge LLM output

# %%
def extract_ontology_block(text: str) -> str:
    """
    Extracts the ontology code block from a mixed LLM output.
    Looks for content between triple backticks (```).

    Parameters:
        text (str): The full output from the LLM.

    Returns:
        str: The extracted ontology block as a string, or an empty string if not found.
    """
    inside_block = False
    lines = []
    
    for line in text.splitlines():
        if line.strip().startswith("```"):
            if inside_block:
                break  # end of block
            else:
                inside_block = True
                continue  # skip the line with ```
        if inside_block:
            lines.append(line)
    
    return "\n".join(lines).strip()

# %% [markdown]
# ## Function to create delta ontology

# %%
from rdflib import Graph

def validate_turtle_string(turtle_str: str) -> tuple[bool, str]:
    """
    Validates whether the input string is valid Turtle syntax.

    Returns:
        - is_valid (bool): True if valid, False otherwise
        - error_msg (str): Error message if invalid, else empty
    """
    try:
        g = Graph()
        g.parse(data=turtle_str, format="turtle")
        return True, ""
    except Exception as e:
        return False, str(e)

# %%
def build_table_ontology(table_name: str, table_schema: dict, core_ontology: str):

    classes, relations, attributes = extract_names(core_ontology)
    core_context = f"""Class names: {', '.join(classes)}
\nObject properties (relations): {', '.join(relations)}
\nDatatype properties (attributes): {', '.join(attributes)}
"""

    prompt = f"""
    Generate ontology elements with provenance annotations for database table {table_name}, based on:

    [CONTEXT]
    - Database Schema of the table \n{json.dumps(table_schema)}\n
    - Take semantics from the External Ontology Knowledge \n{"\n".join(retrieve(table_name, INDEX_PATH_EXTERNAL_ONT))}\n
    - Take semantics from the Relevant Documents \n{"\n".join(docTable(table_name))}\n
    - Take semantics from the Core Ontology Knowledge \n{core_context if core_ontology else "(empty as of now)"}\n

    [INSTRUCTIONS]
    1. Include these elements:
        Classes (subclass of owl:Thing)
        Data properties with domain/range
        Object properties with domain/range
        Use only one Domain: and one Range: per property. If multiple options exist, select the most general or create a shared superclass.
    2. Use Turtle/RDF syntax format
    3. Do not create a property named "is". Use rdf:type for instance membership, rdfs:subClassOf for class hierarchies, and owl:sameAs for instance equality.
    4. Stick to camel case for naming the ontology elements.
    5. Use this format example:

    @prefix prov: <http://www.w3.org/ns/prov#> .
    @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
    @prefix owl: <http://www.w3.org/2002/07/owl#> .
    @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
    @prefix : <http://example.org/my-ontology#> .

    :{table_name} a owl:Class ;
        prov:wasDerivedFrom <http://example.org/provenance/{table_name}> .

    :has_column_name a owl:DatatypeProperty ;
        rdfs:domain :{table_name} ;
        rdfs:range xsd:string ;
        prov:wasDerivedFrom <http://example.org/provenance/{table_name}/column_name> .

    :relates_to_table a owl:ObjectProperty ;
        rdfs:domain :{table_name} ;
        rdfs:range :RelatedTable ;
        prov:wasDerivedFrom <http://example.org/provenance/{table_name}/fk_column> .

    Only output Turtle syntax and nothing else. [OUTPUT]
    """

    delta_ontology = gpt41_nano.invoke(prompt).content
    print(prompt)



    is_valid, error_message = validate_turtle_string(delta_ontology)

    if not is_valid:
        additional_syntax_hint = f"""
    [SYNTAX ISSUES DETECTED]

    Note: The delta ontology provided is NOT valid Turtle syntax.

    Please make the following minimal syntax corrections before further validation:
    - Declare all prefixes used in the ontology explicitly (e.g., rdf:, rdfs:, owl:, xsd:, prov:).
    - Use angle brackets <...> for all full IRI references.
    - Each property must have exactly one rdfs:domain and one rdfs:range.
    - Ensure rdfs:range only uses valid OWL classes or XSD types (e.g., xsd:string).
    - Remove annotation-style keywords like 'Annotations:' and instead use Turtle triples for metadata.
    - Avoid misplaced punctuation or unclosed blocks.

    Parsing error: {error_message}
    """
    else:
        additional_syntax_hint = ""




    evaluator_prompt = f"""
    You are an expert in OWL 2 DL ontology modeling and validation.

    Your task is to review the following delta ontology fragment generated from a relational database table, along with its schema and relevant context.

    [DELTA-ONTOLOGY]
    {delta_ontology}

    [DATABASE SCHEMA]
    {table_schema}

    [CORE ONTOLOGY CONTEXT]
    {core_ontology if core_ontology else "(empty as of now)"}

    {additional_syntax_hint}

    [VALIDATION CRITERIA]
    1. **Coherence with Core Ontology**  
    - Do NOT redefine an existing class, property, or concept already present in the core ontology with the same meaning.
    - Reuse existing ontology elements where possible instead of creating duplicates.

    2. **Alignment with Input Table Schema**  
    - Every significant column and foreign key in the table must be represented as an appropriate ontology element (class, data property, or object property).
    - Naming should reflect the database semantics clearly and consistently.

    3. **Syntactic Validity**  
    - The ontology must conform to valid Turtle/RDF syntax.
    - Use proper prefixes and IRI declarations.
    - Exactly one rdfs:domain and one rdfs:range per property.

    4. **Logical Consistency**  
    - No contradictory class axioms or property constraints.
    - No circular subclass relationships.
    - Correct choice between object properties and data properties.

    5. **Clarity and Naming Quality**  
    - Use self-explanatory, domain-relevant names.
    - Avoid generic or meaningless labels.
    - All elements should follow camel case naming patterns.

    [YOUR TASK]
    - Check the delta ontology fragment against all criteria above.
    - If issues are found, provide a corrected version of the ontology in valid Turtle syntax.
    - Make minimal necessary changes to preserve the author's intent while ensuring correctness and OWL 2 DL compliance.
    - Ensure all elements keep their provenance annotations.

    [OUTPUT FORMAT]
    Respond ONLY with:
    1. "Status: PASS" if the ontology fragment meets all criteria, or "Status: FAIL" if it does not.
    2. If FAIL, provide:
        a. A short bullet list of the issues found.
        b. A corrected Turtle syntax version of the ontology fragment, and enclose it between triple backticks (```), on their own lines.

    Do NOT include any other commentary outside this format.
    Always enclose the corrected ontology with triple backticks for programmatic extraction.
    """

    revision = gpt41_nano.invoke(evaluator_prompt).content

    
    if "Status: PASS" in revision:
        print("JudgeLLM Validation succeeded.")
        valid = validate_turtle_string(delta_ontology)
        print(valid)
        if valid[0]:
            return delta_ontology
        else:
            print("Syntax Validation failed.\n\n")
            return delta_ontology
    else:
        print("JudgeLLM Validation failed. Corrected Version:")
        valid = validate_turtle_string(extract_ontology_block(revision))
        print(valid)
        if valid[0]:
            return extract_ontology_block(revision)
        else:
            print("Syntax Validation failed.\n\n")
            return extract_ontology_block(revision)

# %%
core = build_table_ontology('granter_application', schema['granter_application'], '')
# Out:
# JudgeLLM Validation failed. Corrected Version:
# (True, '')
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix : <http://example.org/ontology#> .
#
# ### Classes
# :Grant a owl:Class ;
#     rdfs:label "Grant" ;
#     prov:wasDerivedFrom <http://example.org/provenance/Grant> .
#
# :GrantPayment a owl:Class ;
#     rdfs:label "GrantPayment" ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantPayment> .
#
# :Recipient a owl:Class ;
#     rdfs:label "Recipient" ;
#     prov:wasDerivedFrom <http://example.org/provenance/Recipient> .
#
# :Beneficiary a owl:Class ;
#     rdfs:label "Beneficiary" ;
#     prov:wasDerivedFrom <http://example.org/provenance/Beneficiary> .
#
# :CareerPurposeCriterion a owl:Class ;
#     rdfs:label "CareerPurposeCriterion" ;
#     prov:wasDerivedFrom <http://example.org/provenance/CareerPurposeCriterion> .
#
# :Application a owl:Class ;
#     rdfs:label "Application" ;
#     prov:wasDerivedFrom <http://example.org/provenance/Application> .
#
# :ApplicationFile a owl:Class ;
#     rdfs:label "ApplicationFile" ;
#     prov:wasDerivedFrom <http://example.org/provenance/ApplicationFile> .
#
# :Company a owl:Class ;
#     rdfs:label "Company" ;
#     prov:wasDerivedFrom <http://example.org/provenance/Company> .
#
# :Opportunity a owl:Class ;
#     rdfs:label "Opportunity" ;
#     prov:wasDerivedFrom <http://example.org/provenance/Opportunity> .
#
# :CompanyMemory a owl:Class ;
#     rdfs:label "CompanyMemory" ;
#     prov:wasDerivedFrom <http://example.org/provenance/CompanyMemory> .
#
# ### Data Properties
# :applicationId a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/id> .
#
# :createdAt a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/created_at> .
#
# :updatedAt a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/updated_at> .
#
# :state a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/state> .
#
# :codename a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/codename> .
#
# :title a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/title> .
#
# :otherData a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/other_data> .
#
# :pricingOption a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/pricing_option> .
#
# :aiReviewState a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/ai_review_state> .
#
# :saleConfirmed a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:boolean ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/sale_confirmed> .
#
# :approvedGrantAmount a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/approved_grant_amount> .
#
# :successFee a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/success_fee> .
#
# :successPaymentAmount a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/success_payment_amount> .
#
# :upfrontPaymentAmount a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/upfront_payment_amount> .
#
# :initialSummary a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/initial_summary> .
#
# :writerMode a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/writer_mode> .
#
# ### Object Properties
# :hasApplicationFile a owl:ObjectProperty ;
#     rdfs:domain :Application ;
#     rdfs:range :ApplicationFile ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/hasApplicationFile> .
#
# :belongsToCompany a owl:ObjectProperty ;
#     rdfs:domain :Application ;
#     rdfs:range :Company ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/belongsToCompany> .
#
# :belongsToOpportunity a owl:ObjectProperty ;
#     rdfs:domain :Application ;
#     rdfs:range :Opportunity ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/belongsToOpportunity> .
#
# :relatedToCompanyMemory a owl:ObjectProperty ;
#     rdfs:domain :Application ;
#     rdfs:range :CompanyMemory ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/relatedToCompanyMemory> .
#
# :appliesForOpportunity a owl:ObjectProperty ;
#     rdfs:domain :Application ;
#     rdfs:range :Opportunity ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/appliesForOpportunity> .
#
# :hasGrant a owl:ObjectProperty ;
#     rdfs:domain :Application ;
#     rdfs:range :Grant ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/hasGrant> .
#
# :hasGrantPayment a owl:ObjectProperty ;
#     rdfs:domain :Grant ;
#     rdfs:range :GrantPayment ;
#     prov:wasDerivedFrom <http://example.org/provenance/grant/hasGrantPayment> .
#
# :receivesFrom a owl:ObjectProperty ;
#     rdfs:domain :GrantPayment ;
#     rdfs:range :Recipient ;
#     prov:wasDerivedFrom <http://example.org/provenance/grantpayment/receivesFrom> .
#
# :beneficiaryOf a owl:ObjectProperty ;
#     rdfs:domain :Grant ;
#     rdfs:range :Beneficiary ;
#     prov:wasDerivedFrom <http://example.org/provenance/grant/beneficiaryOf> .
#
# :hasCareerPurposeCriterion a owl:ObjectProperty ;
#     rdfs:domain :Grant ;
#     rdfs:range :CareerPurposeCriterion ;
#     prov:wasDerivedFrom <http://example.org/provenance/grant/hasCareerPurposeCriterion> .
#
# ### Provenance Annotations for the Table
# :GranterApplication a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application> .
#
# :hasId a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/id> .
#
# :hasCreatedAt a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/created_at> .
#
# :hasUpdatedAt a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/updated_at> .
#
# :hasState a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/state> .
#
# :hasCodename a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/codename> .
#
# :hasTitle a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/title> .
#
# :hasOtherData a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/other_data> .
#
# :hasCompanyId a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range :Company ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/company_id> .
#
# :hasOpportunityId a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range :Opportunity ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/opportunity_id> .
#
# :hasProfileCreatorId a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range :ProfileCreator ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/profile_creator_id> .
#
# :hasPricingOption a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/pricing_option> .
#
# :hasAiReviewState a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/ai_review_state> .
#
# :hasConsortiumId a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range :Consortium ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/consortium_id> .
#
# :hasSaleConfirmed a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:boolean ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/sale_confirmed> .
#
# :hasApprovedGrantAmount a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/approved_grant_amount> .
#
# :hasSuccessFee a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/success_fee> .
#
# :hasSuccessPaymentAmount a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/success_payment_amount> .
#
# :hasUpfrontPaymentAmount a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/upfront_payment_amount> .
#
# :hasInitialSummary a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/initial_summary> .
#
# :hasWriterMode a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/writer_mode> .

# %%
print(core)
# Out:
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix : <http://example.org/ontology#> .
#
# ### Classes
# :Grant a owl:Class ;
#     rdfs:label "Grant" ;
#     prov:wasDerivedFrom <http://example.org/provenance/Grant> .
#
# :GrantPayment a owl:Class ;
#     rdfs:label "GrantPayment" ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantPayment> .
#
# :Recipient a owl:Class ;
#     rdfs:label "Recipient" ;
#     prov:wasDerivedFrom <http://example.org/provenance/Recipient> .
#
# :Beneficiary a owl:Class ;
#     rdfs:label "Beneficiary" ;
#     prov:wasDerivedFrom <http://example.org/provenance/Beneficiary> .
#
# :CareerPurposeCriterion a owl:Class ;
#     rdfs:label "CareerPurposeCriterion" ;
#     prov:wasDerivedFrom <http://example.org/provenance/CareerPurposeCriterion> .
#
# :Application a owl:Class ;
#     rdfs:label "Application" ;
#     prov:wasDerivedFrom <http://example.org/provenance/Application> .
#
# :ApplicationFile a owl:Class ;
#     rdfs:label "ApplicationFile" ;
#     prov:wasDerivedFrom <http://example.org/provenance/ApplicationFile> .
#
# :Company a owl:Class ;
#     rdfs:label "Company" ;
#     prov:wasDerivedFrom <http://example.org/provenance/Company> .
#
# :Opportunity a owl:Class ;
#     rdfs:label "Opportunity" ;
#     prov:wasDerivedFrom <http://example.org/provenance/Opportunity> .
#
# :CompanyMemory a owl:Class ;
#     rdfs:label "CompanyMemory" ;
#     prov:wasDerivedFrom <http://example.org/provenance/CompanyMemory> .
#
# ### Data Properties
# :applicationId a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/id> .
#
# :createdAt a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/created_at> .
#
# :updatedAt a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/updated_at> .
#
# :state a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/state> .
#
# :codename a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/codename> .
#
# :title a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/title> .
#
# :otherData a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/other_data> .
#
# :pricingOption a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/pricing_option> .
#
# :aiReviewState a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/ai_review_state> .
#
# :saleConfirmed a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:boolean ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/sale_confirmed> .
#
# :approvedGrantAmount a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/approved_grant_amount> .
#
# :successFee a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/success_fee> .
#
# :successPaymentAmount a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/success_payment_amount> .
#
# :upfrontPaymentAmount a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/upfront_payment_amount> .
#
# :initialSummary a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/initial_summary> .
#
# :writerMode a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/writer_mode> .
#
# ### Object Properties
# :hasApplicationFile a owl:ObjectProperty ;
#     rdfs:domain :Application ;
#     rdfs:range :ApplicationFile ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/hasApplicationFile> .
#
# :belongsToCompany a owl:ObjectProperty ;
#     rdfs:domain :Application ;
#     rdfs:range :Company ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/belongsToCompany> .
#
# :belongsToOpportunity a owl:ObjectProperty ;
#     rdfs:domain :Application ;
#     rdfs:range :Opportunity ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/belongsToOpportunity> .
#
# :relatedToCompanyMemory a owl:ObjectProperty ;
#     rdfs:domain :Application ;
#     rdfs:range :CompanyMemory ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/relatedToCompanyMemory> .
#
# :appliesForOpportunity a owl:ObjectProperty ;
#     rdfs:domain :Application ;
#     rdfs:range :Opportunity ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/appliesForOpportunity> .
#
# :hasGrant a owl:ObjectProperty ;
#     rdfs:domain :Application ;
#     rdfs:range :Grant ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/hasGrant> .
#
# :hasGrantPayment a owl:ObjectProperty ;
#     rdfs:domain :Grant ;
#     rdfs:range :GrantPayment ;
#     prov:wasDerivedFrom <http://example.org/provenance/grant/hasGrantPayment> .
#
# :receivesFrom a owl:ObjectProperty ;
#     rdfs:domain :GrantPayment ;
#     rdfs:range :Recipient ;
#     prov:wasDerivedFrom <http://example.org/provenance/grantpayment/receivesFrom> .
#
# :beneficiaryOf a owl:ObjectProperty ;
#     rdfs:domain :Grant ;
#     rdfs:range :Beneficiary ;
#     prov:wasDerivedFrom <http://example.org/provenance/grant/beneficiaryOf> .
#
# :hasCareerPurposeCriterion a owl:ObjectProperty ;
#     rdfs:domain :Grant ;
#     rdfs:range :CareerPurposeCriterion ;
#     prov:wasDerivedFrom <http://example.org/provenance/grant/hasCareerPurposeCriterion> .
#
# ### Provenance Annotations for the Table
# :GranterApplication a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application> .
#
# :hasId a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/id> .
#
# :hasCreatedAt a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/created_at> .
#
# :hasUpdatedAt a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/updated_at> .
#
# :hasState a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/state> .
#
# :hasCodename a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/codename> .
#
# :hasTitle a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/title> .
#
# :hasOtherData a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/other_data> .
#
# :hasCompanyId a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range :Company ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/company_id> .
#
# :hasOpportunityId a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range :Opportunity ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/opportunity_id> .
#
# :hasProfileCreatorId a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range :ProfileCreator ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/profile_creator_id> .
#
# :hasPricingOption a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/pricing_option> .
#
# :hasAiReviewState a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/ai_review_state> .
#
# :hasConsortiumId a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range :Consortium ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/consortium_id> .
#
# :hasSaleConfirmed a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:boolean ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/sale_confirmed> .
#
# :hasApprovedGrantAmount a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/approved_grant_amount> .
#
# :hasSuccessFee a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/success_fee> .
#
# :hasSuccessPaymentAmount a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/success_payment_amount> .
#
# :hasUpfrontPaymentAmount a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/upfront_payment_amount> .
#
# :hasInitialSummary a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/initial_summary> .
#
# :hasWriterMode a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/writer_mode> .

# %%
validate_turtle_string(core)
# Out:
# (True, '')

# %%
extract_names(core)
# Out:
# (['Application',
#   'ApplicationFile',
#   'Beneficiary',
#   'CareerPurposeCriterion',
#   'Company',
#   'CompanyMemory',
#   'Grant',
#   'GrantPayment',
#   'GranterApplication',
#   'Opportunity',
#   'Recipient'],
#  ['appliesForOpportunity',
#   'belongsToCompany',
#   'belongsToOpportunity',
#   'beneficiaryOf',
#   'hasAiReviewState',
#   'hasApplicationFile',
#   'hasApprovedGrantAmount',
#   'hasCareerPurposeCriterion',
#   'hasCompanyId',
#   'hasConsortiumId',
#   'hasGrant',
#   'hasGrantPayment',
#   'hasInitialSummary',
#   'hasOpportunityId',
#   'hasPricingOption',
#   'hasProfileCreatorId',
#   'hasSaleConfirmed',
#   'hasSuccessFee',
#   'hasSuccessPaymentAmount',
#   'hasUpfrontPaymentAmount',
#   'hasWriterMode',
#   'receivesFrom',
#   'relatedToCompanyMemory'],
#  ['aiReviewState',
#   'applicationId',
#   'approvedGrantAmount',
#   'codename',
#   'createdAt',
#   'hasCodename',
#   'hasCreatedAt',
#   'hasId',
#   'hasOtherData',
#   'hasState',
#   'hasTitle',
#   'hasUpdatedAt',
#   'initialSummary',
#   'otherData',
#   'pricingOption',
#   'saleConfirmed',
#   'state',
#   'successFee',
#   'successPaymentAmount',
#   'title',
#   'updatedAt',
#   'upfrontPaymentAmount',
#   'writerMode'])

# %%
delta = build_table_ontology('granter_company', schema['granter_company'], core)
# Out:
#     Generate ontology elements with provenance annotations for database table granter_company, based on:
#
#     [CONTEXT]
#     - Database Schema of the table
# {"columns": ["id", "created_at", "updated_at", "name", "legal_name", "address", "post_code", "city", "country", "url", "legal_form", "activity_date", "company_id", "tax_id", "social_security_id", "is_sme", "employees_n", "annual_revenue", "description", "cover_image", "website_data", "owner_id", "stripe_customer_id", "digital_component", "future_goals_infrastructure", "future_goals_internationalization", "future_goals_machinery_and_equipments", "future_goals_marketing", "future_goals_rd", "green_component", "team_description", "future_goals_hr", "onboarding_state", "matches_generating", "userless", "cae", "whitelabel_id", "related_operations", "shareholders", "other_data", "source", "subscription_id", "extra_information", "matching_order", "agent_language"], "primary_keys": ["id"], "foreign_keys": [{"columns": ["owner_id"], "ref_table": "granter_profile", "ref_columns": ["id"]}, {"columns": ["subscription_id"], "ref_table": "granter_subscription", "ref_columns": ["id"]}, {"columns": ["whitelabel_id"], "ref_table": "granter_whitelabel", "ref_columns": ["id"]}]}
#
#     - Take semantics from the External Ontology Knowledge
# Company: A commercial business.
# recipient: The receiver of a GrantPayment or receiver/beneficiary of a GrantShare.
# GrantShare: The class for grant shares: the full or proper portion or part allotted or belonging to or contributed to an individual entity within a Grant.
# GrantPayment: The class for grant payments: a single payment to a recipient or beneficiary within a Grant.
#
#     - Take semantics from the Relevant Documents
# ---
# ### **granter_companymemory**
# - Small text snippets stored as vectors for RAG purposes.
# - Help provide semantic context when drafting applications.
# - **Relations:**
#   - Belongs to a **granter_company**.
# ---
# ### **granter_opportunity**
# - Represents a funding opportunity (grant, tax incentive, investment, or loan).
# - **Relations:**
#   - Can have multiple **granter_applications** from different companies.
#   - Has associated **granter_opportunityfiles**.
# ---
# ### **granter_consortium**
# - Represents a consortium formed by multiple companies.
# - Used to apply to opportunities jointly.
# - **Relations:**
#   - Can include multiple **granter_consortiumpartners**.
#   - Can be linked to **granter_applications** when a consortium applies instead of a single company.
# ---
# ### **granter_consortiumpartner**
# - Represents a company persona or role within a **consortium** (e.g., lead applicant, research partner, SME partner).
# - **Relations:**
#     - Take semantics from the Core Ontology Knowledge
# Class names: Application, ApplicationFile, Beneficiary, CareerPurposeCriterion, Company, CompanyMemory, Grant, GrantPayment, GranterApplication, Opportunity, Recipient
#
# Object properties (relations): appliesForOpportunity, belongsToCompany, belongsToOpportunity, beneficiaryOf, hasAiReviewState, hasApplicationFile, hasApprovedGrantAmount, hasCareerPurposeCriterion, hasCompanyId, hasConsortiumId, hasGrant, hasGrantPayment, hasInitialSummary, hasOpportunityId, hasPricingOption, hasProfileCreatorId, hasSaleConfirmed, hasSuccessFee, hasSuccessPaymentAmount, hasUpfrontPaymentAmount, hasWriterMode, receivesFrom, relatedToCompanyMemory
#
# Datatype properties (attributes): aiReviewState, applicationId, approvedGrantAmount, codename, createdAt, hasCodename, hasCreatedAt, hasId, hasOtherData, hasState, hasTitle, hasUpdatedAt, initialSummary, otherData, pricingOption, saleConfirmed, state, successFee, successPaymentAmount, title, updatedAt, upfrontPaymentAmount, writerMode
#
#
#
#     [INSTRUCTIONS]
#     1. Include these elements:
#         Classes (subclass of owl:Thing)
#         Data properties with domain/range
#         Object properties with domain/range
#         Use only one Domain: and one Range: per property. If multiple options exist, select the most general or create a shared superclass.
#     2. Use Turtle/RDF syntax format
#     3. Do not create a property named "is". Use rdf:type for instance membership, rdfs:subClassOf for class hierarchies, and owl:sameAs for instance equality.
#     4. Stick to camel case for naming the ontology elements.
#     5. Use this format example:
#
#     @prefix prov: <http://www.w3.org/ns/prov#> .
#     @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#     @prefix owl: <http://www.w3.org/2002/07/owl#> .
#     @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#     @prefix : <http://example.org/my-ontology#> .
#
#     :granter_company a owl:Class ;
#         prov:wasDerivedFrom <http://example.org/provenance/granter_company> .
#
#     :has_column_name a owl:DatatypeProperty ;
#         rdfs:domain :granter_company ;
#         rdfs:range xsd:string ;
#         prov:wasDerivedFrom <http://example.org/provenance/granter_company/column_name> .
#
#     :relates_to_table a owl:ObjectProperty ;
#         rdfs:domain :granter_company ;
#         rdfs:range :RelatedTable ;
#         prov:wasDerivedFrom <http://example.org/provenance/granter_company/fk_column> .
#
#     Only output Turtle syntax and nothing else. [OUTPUT]
#
# JudgeLLM Validation failed. Corrected Version:
# (True, '')

# %%
print(delta)
# Out:
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix : <http://example.org/ontology#> .
#
# ### Reuse core classes and properties, avoiding redefinition
# ### Classes
# :GranterCompany a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company> .
#
# :Company a owl:Class ;
#     rdfs:subClassOf :GranterCompany ;
#     prov:wasDerivedFrom <http://example.org/provenance/ontology/Company> .
#
# :Recipient a owl:Class ;
#     rdfs:subClassOf :Company ;
#     prov:wasDerivedFrom <http://example.org/provenance/ontology/Recipient> .
#
# :GrantShare a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/ontology/GrantShare> .
#
# :GrantPayment a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/ontology/GrantPayment> .
#
# :CompanyMemory a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/ontology/CompanyMemory> .
#
# ### Data Properties
# :hasColumnName a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/column_name> .
#
# :hasCreatedAt a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/created_at> .
#
# :hasUpdatedAt a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/updated_at> .
#
# :hasName a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/name> .
#
# :hasLegalName a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/legal_name> .
#
# :hasAddress a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/address> .
#
# :hasPostCode a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/post_code> .
#
# :hasCity a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/city> .
#
# :hasCountry a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/country> .
#
# :hasUrl a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:anyURI ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/url> .
#
# :hasLegalForm a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/legal_form> .
#
# :hasActivityDate a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:date ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/activity_date> .
#
# :hasCompanyId a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/company_id> .
#
# :hasTaxId a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/tax_id> .
#
# :hasSocialSecurityId a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/social_security_id> .
#
# :hasIsSme a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:boolean ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/is_sme> .
#
# :hasEmployeesN a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/employees_n> .
#
# :hasAnnualRevenue a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/annual_revenue> .
#
# :hasDescription a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/description> .
#
# :hasCoverImage a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:anyURI ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/cover_image> .
#
# :hasWebsiteData a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/website_data> .
#
# :hasOwnerId a owl:ObjectProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range :GranterProfile ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/owner_id> .
#
# :hasStripeCustomerId a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/stripe_customer_id> .
#
# :hasDigitalComponent a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/digital_component> .
#
# :hasFutureGoalsInfrastructure a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/future_goals_infrastructure> .
#
# :hasFutureGoalsInternationalization a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/future_goals_internationalization> .
#
# :hasFutureGoalsMachineryAndEquipments a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/future_goals_machinery_and_equipments> .
#
# :hasFutureGoalsMarketing a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/future_goals_marketing> .
#
# :hasFutureGoalsRd a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/future_goals_rd> .
#
# :hasGreenComponent a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/green_component> .
#
# :hasTeamDescription a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/team_description> .
#
# :hasFutureGoalsHr a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/future_goals_hr> .
#
# :hasOnboardingState a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/onboarding_state> .
#
# :hasMatchingGenerating a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:boolean ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/matches_generating> .
#
# :hasUserless a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:boolean ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/userless> .
#
# :hasCae a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/cae> .
#
# :hasWhitelabelId a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/whitelabel_id> .
#
# :hasRelatedOperations a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/related_operations> .
#
# :hasShareholders a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/shareholders> .
#
# :hasOtherData a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/other_data> .
#
# :hasSource a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/source> .
#
# :hasSubscriptionId a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/subscription_id> .
#
# :hasExtraInformation a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/extra_information> .
#
# :hasMatchingOrder a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/matching_order> .
#
# :hasAgentLanguage a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/agent_language> .
#
# :belongsToOwner a owl:ObjectProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range :GranterProfile ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/owner_id> .
#
# :belongsToSubscription a owl:ObjectProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range :GranterSubscription ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/subscription_id> .
#
# :belongsToWhitelabel a owl:ObjectProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range :GranterWhitelabel ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/whitelabel_id> .
#
# :relatedToCompanyMemory a owl:ObjectProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range :CompanyMemory ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/related_data> .

# %%
validate_turtle_string(delta)
# Out:
# (True, '')

# %%
extract_names(delta)
# Out:
# (['Company',
#   'CompanyMemory',
#   'GrantPayment',
#   'GrantShare',
#   'GranterCompany',
#   'Recipient'],
#  ['belongsToOwner',
#   'belongsToSubscription',
#   'belongsToWhitelabel',
#   'hasOwnerId',
#   'relatedToCompanyMemory'],
#  ['hasActivityDate',
#   'hasAddress',
#   'hasAgentLanguage',
#   'hasAnnualRevenue',
#   'hasCae',
#   'hasCity',
#   'hasColumnName',
#   'hasCompanyId',
#   'hasCountry',
#   'hasCoverImage',
#   'hasCreatedAt',
#   'hasDescription',
#   'hasDigitalComponent',
#   'hasEmployeesN',
#   'hasExtraInformation',
#   'hasFutureGoalsHr',
#   'hasFutureGoalsInfrastructure',
#   'hasFutureGoalsInternationalization',
#   'hasFutureGoalsMachineryAndEquipments',
#   'hasFutureGoalsMarketing',
#   'hasFutureGoalsRd',
#   'hasGreenComponent',
#   'hasIsSme',
#   'hasLegalForm',
#   'hasLegalName',
#   'hasMatchingGenerating',
#   'hasMatchingOrder',
#   'hasName',
#   'hasOnboardingState',
#   'hasOtherData',
#   'hasPostCode',
#   'hasRelatedOperations',
#   'hasShareholders',
#   'hasSocialSecurityId',
#   'hasSource',
#   'hasStripeCustomerId',
#   'hasSubscriptionId',
#   'hasTaxId',
#   'hasTeamDescription',
#   'hasUpdatedAt',
#   'hasUrl',
#   'hasUserless',
#   'hasWebsiteData',
#   'hasWhitelabelId'])

# %% [markdown]
# ## Merging the ontologies

# %%
from rdflib import Graph

def merge_ontologies_ttl(core_ttl: str, delta_ttl: str) -> str:
    """
    Merge two OWL ontologies in Turtle format (as strings) and return the merged ontology as a Turtle string.
    Uses RDFLib's built-in graph merging with automatic triple deduplication.
    
    Parameters:
        core_ttl (str): Core ontology (Turtle format string)
        delta_ttl (str): Delta ontology (Turtle format string)
        
    Returns:
        str: Merged ontology in Turtle syntax
    """
    # Parse both ontologies
    core_graph = Graph()
    core_graph.parse(data=core_ttl, format="turtle")

    delta_graph = Graph()
    delta_graph.parse(data=delta_ttl, format="turtle")

    # Merge delta into core
    core_graph += delta_graph  # RDFLib automatically deduplicates identical triples

    # Serialize the merged ontology back to Turtle
    return core_graph.serialize(format="turtle")

# %%
Ot1 = merge_ontologies_ttl(core, delta)
print(Ot1)
# Out:
# @prefix : <http://example.org/ontology#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# :GrantShare a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/ontology/GrantShare> .
#
# :aiReviewState a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/ai_review_state> .
#
# :applicationId a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/id> .
#
# :appliesForOpportunity a owl:ObjectProperty ;
#     rdfs:domain :Application ;
#     rdfs:range :Opportunity ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/appliesForOpportunity> .
#
# :approvedGrantAmount a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/approved_grant_amount> .
#
# :belongsToCompany a owl:ObjectProperty ;
#     rdfs:domain :Application ;
#     rdfs:range :Company ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/belongsToCompany> .
#
# :belongsToOpportunity a owl:ObjectProperty ;
#     rdfs:domain :Application ;
#     rdfs:range :Opportunity ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/belongsToOpportunity> .
#
# :belongsToOwner a owl:ObjectProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range :GranterProfile ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/owner_id> .
#
# :belongsToSubscription a owl:ObjectProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range :GranterSubscription ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/subscription_id> .
#
# :belongsToWhitelabel a owl:ObjectProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range :GranterWhitelabel ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/whitelabel_id> .
#
# :beneficiaryOf a owl:ObjectProperty ;
#     rdfs:domain :Grant ;
#     rdfs:range :Beneficiary ;
#     prov:wasDerivedFrom <http://example.org/provenance/grant/beneficiaryOf> .
#
# :codename a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/codename> .
#
# :createdAt a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/created_at> .
#
# :hasActivityDate a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:date ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/activity_date> .
#
# :hasAddress a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/address> .
#
# :hasAgentLanguage a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/agent_language> .
#
# :hasAiReviewState a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/ai_review_state> .
#
# :hasAnnualRevenue a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/annual_revenue> .
#
# :hasApplicationFile a owl:ObjectProperty ;
#     rdfs:domain :Application ;
#     rdfs:range :ApplicationFile ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/hasApplicationFile> .
#
# :hasApprovedGrantAmount a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/approved_grant_amount> .
#
# :hasCae a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/cae> .
#
# :hasCareerPurposeCriterion a owl:ObjectProperty ;
#     rdfs:domain :Grant ;
#     rdfs:range :CareerPurposeCriterion ;
#     prov:wasDerivedFrom <http://example.org/provenance/grant/hasCareerPurposeCriterion> .
#
# :hasCity a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/city> .
#
# :hasCodename a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/codename> .
#
# :hasColumnName a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/column_name> .
#
# :hasCompanyId a owl:DatatypeProperty,
#         owl:ObjectProperty ;
#     rdfs:domain :GranterApplication,
#         :GranterCompany ;
#     rdfs:range :Company,
#         xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/company_id>,
#         <http://example.org/provenance/granter_company/company_id> .
#
# :hasConsortiumId a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range :Consortium ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/consortium_id> .
#
# :hasCountry a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/country> .
#
# :hasCoverImage a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:anyURI ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/cover_image> .
#
# :hasCreatedAt a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication,
#         :GranterCompany ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/created_at>,
#         <http://example.org/provenance/granter_company/created_at> .
#
# :hasDescription a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/description> .
#
# :hasDigitalComponent a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/digital_component> .
#
# :hasEmployeesN a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/employees_n> .
#
# :hasExtraInformation a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/extra_information> .
#
# :hasFutureGoalsHr a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/future_goals_hr> .
#
# :hasFutureGoalsInfrastructure a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/future_goals_infrastructure> .
#
# :hasFutureGoalsInternationalization a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/future_goals_internationalization> .
#
# :hasFutureGoalsMachineryAndEquipments a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/future_goals_machinery_and_equipments> .
#
# :hasFutureGoalsMarketing a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/future_goals_marketing> .
#
# :hasFutureGoalsRd a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/future_goals_rd> .
#
# :hasGrant a owl:ObjectProperty ;
#     rdfs:domain :Application ;
#     rdfs:range :Grant ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/hasGrant> .
#
# :hasGrantPayment a owl:ObjectProperty ;
#     rdfs:domain :Grant ;
#     rdfs:range :GrantPayment ;
#     prov:wasDerivedFrom <http://example.org/provenance/grant/hasGrantPayment> .
#
# :hasGreenComponent a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/green_component> .
#
# :hasId a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/id> .
#
# :hasInitialSummary a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/initial_summary> .
#
# :hasIsSme a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:boolean ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/is_sme> .
#
# :hasLegalForm a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/legal_form> .
#
# :hasLegalName a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/legal_name> .
#
# :hasMatchingGenerating a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:boolean ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/matches_generating> .
#
# :hasMatchingOrder a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/matching_order> .
#
# :hasName a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/name> .
#
# :hasOnboardingState a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/onboarding_state> .
#
# :hasOpportunityId a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range :Opportunity ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/opportunity_id> .
#
# :hasOtherData a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication,
#         :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/other_data>,
#         <http://example.org/provenance/granter_company/other_data> .
#
# :hasOwnerId a owl:ObjectProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range :GranterProfile ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/owner_id> .
#
# :hasPostCode a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/post_code> .
#
# :hasPricingOption a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/pricing_option> .
#
# :hasProfileCreatorId a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range :ProfileCreator ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/profile_creator_id> .
#
# :hasRelatedOperations a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/related_operations> .
#
# :hasSaleConfirmed a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:boolean ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/sale_confirmed> .
#
# :hasShareholders a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/shareholders> .
#
# :hasSocialSecurityId a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/social_security_id> .
#
# :hasSource a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/source> .
#
# :hasState a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/state> .
#
# :hasStripeCustomerId a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/stripe_customer_id> .
#
# :hasSubscriptionId a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/subscription_id> .
#
# :hasSuccessFee a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/success_fee> .
#
# :hasSuccessPaymentAmount a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/success_payment_amount> .
#
# :hasTaxId a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/tax_id> .
#
# :hasTeamDescription a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/team_description> .
#
# :hasTitle a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/title> .
#
# :hasUpdatedAt a owl:DatatypeProperty ;
#     rdfs:domain :GranterApplication,
#         :GranterCompany ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/updated_at>,
#         <http://example.org/provenance/granter_company/updated_at> .
#
# :hasUpfrontPaymentAmount a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/upfront_payment_amount> .
#
# :hasUrl a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:anyURI ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/url> .
#
# :hasUserless a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:boolean ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/userless> .
#
# :hasWebsiteData a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/website_data> .
#
# :hasWhitelabelId a owl:DatatypeProperty ;
#     rdfs:domain :GranterCompany ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/whitelabel_id> .
#
# :hasWriterMode a owl:ObjectProperty ;
#     rdfs:domain :GranterApplication ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/writer_mode> .
#
# :initialSummary a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/initial_summary> .
#
# :otherData a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/other_data> .
#
# :pricingOption a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/pricing_option> .
#
# :receivesFrom a owl:ObjectProperty ;
#     rdfs:domain :GrantPayment ;
#     rdfs:range :Recipient ;
#     prov:wasDerivedFrom <http://example.org/provenance/grantpayment/receivesFrom> .
#
# :relatedToCompanyMemory a owl:ObjectProperty ;
#     rdfs:domain :Application,
#         :GranterCompany ;
#     rdfs:range :CompanyMemory ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/relatedToCompanyMemory>,
#         <http://example.org/provenance/granter_company/related_data> .
#
# :saleConfirmed a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:boolean ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/sale_confirmed> .
#
# :state a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/state> .
#
# :successFee a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/success_fee> .
#
# :successPaymentAmount a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/success_payment_amount> .
#
# :title a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/title> .
#
# :updatedAt a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/updated_at> .
#
# :upfrontPaymentAmount a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/upfront_payment_amount> .
#
# :writerMode a owl:DatatypeProperty ;
#     rdfs:domain :Application ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/application/writer_mode> .
#
# :ApplicationFile a owl:Class ;
#     rdfs:label "ApplicationFile" ;
#     prov:wasDerivedFrom <http://example.org/provenance/ApplicationFile> .
#
# :Beneficiary a owl:Class ;
#     rdfs:label "Beneficiary" ;
#     prov:wasDerivedFrom <http://example.org/provenance/Beneficiary> .
#
# :CareerPurposeCriterion a owl:Class ;
#     rdfs:label "CareerPurposeCriterion" ;
#     prov:wasDerivedFrom <http://example.org/provenance/CareerPurposeCriterion> .
#
# :CompanyMemory a owl:Class ;
#     rdfs:label "CompanyMemory" ;
#     prov:wasDerivedFrom <http://example.org/provenance/CompanyMemory>,
#         <http://example.org/provenance/ontology/CompanyMemory> .
#
# :Recipient a owl:Class ;
#     rdfs:label "Recipient" ;
#     rdfs:subClassOf :Company ;
#     prov:wasDerivedFrom <http://example.org/provenance/Recipient>,
#         <http://example.org/provenance/ontology/Recipient> .
#
# :GrantPayment a owl:Class ;
#     rdfs:label "GrantPayment" ;
#     prov:wasDerivedFrom <http://example.org/provenance/GrantPayment>,
#         <http://example.org/provenance/ontology/GrantPayment> .
#
# :Company a owl:Class ;
#     rdfs:label "Company" ;
#     rdfs:subClassOf :GranterCompany ;
#     prov:wasDerivedFrom <http://example.org/provenance/Company>,
#         <http://example.org/provenance/ontology/Company> .
#
# :Opportunity a owl:Class ;
#     rdfs:label "Opportunity" ;
#     prov:wasDerivedFrom <http://example.org/provenance/Opportunity> .
#
# :Grant a owl:Class ;
#     rdfs:label "Grant" ;
#     prov:wasDerivedFrom <http://example.org/provenance/Grant> .
#
# :GranterApplication a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application> .
#
# :Application a owl:Class ;
#     rdfs:label "Application" ;
#     prov:wasDerivedFrom <http://example.org/provenance/Application> .
#
# :GranterCompany a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company> .

# %%
type(Ot1)
# Out:
# str

# %%
validate_turtle_string(Ot1)
# Out:
# (True, '')

# %%
extract_names(Ot1)
# Out:
# (['Application',
#   'ApplicationFile',
#   'Beneficiary',
#   'CareerPurposeCriterion',
#   'Company',
#   'CompanyMemory',
#   'Grant',
#   'GrantPayment',
#   'GrantShare',
#   'GranterApplication',
#   'GranterCompany',
#   'Opportunity',
#   'Recipient'],
#  ['appliesForOpportunity',
#   'belongsToCompany',
#   'belongsToOpportunity',
#   'belongsToOwner',
#   'belongsToSubscription',
#   'belongsToWhitelabel',
#   'beneficiaryOf',
#   'hasAiReviewState',
#   'hasApplicationFile',
#   'hasApprovedGrantAmount',
#   'hasCareerPurposeCriterion',
#   'hasCompanyId',
#   'hasConsortiumId',
#   'hasGrant',
#   'hasGrantPayment',
#   'hasInitialSummary',
#   'hasOpportunityId',
#   'hasOwnerId',
#   'hasPricingOption',
#   'hasProfileCreatorId',
#   'hasSaleConfirmed',
#   'hasSuccessFee',
#   'hasSuccessPaymentAmount',
#   'hasUpfrontPaymentAmount',
#   'hasWriterMode',
#   'receivesFrom',
#   'relatedToCompanyMemory'],
#  ['aiReviewState',
#   'applicationId',
#   'approvedGrantAmount',
#   'codename',
#   'createdAt',
#   'hasActivityDate',
#   'hasAddress',
#   'hasAgentLanguage',
#   'hasAnnualRevenue',
#   'hasCae',
#   'hasCity',
#   'hasCodename',
#   'hasColumnName',
#   'hasCompanyId',
#   'hasCountry',
#   'hasCoverImage',
#   'hasCreatedAt',
#   'hasDescription',
#   'hasDigitalComponent',
#   'hasEmployeesN',
#   'hasExtraInformation',
#   'hasFutureGoalsHr',
#   'hasFutureGoalsInfrastructure',
#   'hasFutureGoalsInternationalization',
#   'hasFutureGoalsMachineryAndEquipments',
#   'hasFutureGoalsMarketing',
#   'hasFutureGoalsRd',
#   'hasGreenComponent',
#   'hasId',
#   'hasIsSme',
#   'hasLegalForm',
#   'hasLegalName',
#   'hasMatchingGenerating',
#   'hasMatchingOrder',
#   'hasName',
#   'hasOnboardingState',
#   'hasOtherData',
#   'hasPostCode',
#   'hasRelatedOperations',
#   'hasShareholders',
#   'hasSocialSecurityId',
#   'hasSource',
#   'hasState',
#   'hasStripeCustomerId',
#   'hasSubscriptionId',
#   'hasTaxId',
#   'hasTeamDescription',
#   'hasTitle',
#   'hasUpdatedAt',
#   'hasUrl',
#   'hasUserless',
#   'hasWebsiteData',
#   'hasWhitelabelId',
#   'initialSummary',
#   'otherData',
#   'pricingOption',
#   'saleConfirmed',
#   'state',
#   'successFee',
#   'successPaymentAmount',
#   'title',
#   'updatedAt',
#   'upfrontPaymentAmount',
#   'writerMode'])

# %% [markdown]
# # Running the whole thing

# %%
schema
# Out:
# {'granter_application': {'columns': ['id',
#    'created_at',
#    'updated_at',
#    'state',
#    'codename',
#    'title',
#    'other_data',
#    'company_id',
#    'opportunity_id',
#    'profile_creator_id',
#    'pricing_option',
#    'ai_review_state',
#    'consortium_id',
#    'sale_confirmed',
#    'approved_grant_amount',
#    'success_fee',
#    'success_payment_amount',
#    'upfront_payment_amount',
#    'initial_summary',
#    'writer_mode'],
#   'primary_keys': ['id'],
#   'foreign_keys': [{'columns': ['company_id'],
#     'ref_table': 'granter_company',
#     'ref_columns': ['id']},
#    {'columns': ['consortium_id'],
#     'ref_table': 'granter_consortium',
#     'ref_columns': ['id']},
#    {'columns': ['opportunity_id'],
#     'ref_table': 'granter_opportunity',
#     'ref_columns': ['id']},
#    {'columns': ['profile_creator_id'],
#     'ref_table': 'granter_profile',
#     'ref_columns': ['id']}]},
#  'granter_applicationfile': {'columns': ['id',
#    'created_at',
#    'updated_at',
#    'name',
#    'uploaded_file',
#    'vector_indexed',
#    'type',
#    'application_id',
#    'document_type_id'],
#   'primary_keys': ['id'],
#   'foreign_keys': [{'columns': ['application_id'],
#     'ref_table': 'granter_application',
#     'ref_columns': ['id']},
#    {'columns': ['document_type_id'],
#     'ref_table': 'granter_doctype',
#     'ref_columns': ['id']}]},
#  'granter_company': {'columns': ['id',
#    'created_at',
#    'updated_at',
#    'name',
#    'legal_name',
#    'address',
#    'post_code',
#    'city',
#    'country',
#    'url',
#    'legal_form',
#    'activity_date',
#    'company_id',
#    'tax_id',
#    'social_security_id',
#    'is_sme',
#    'employees_n',
#    'annual_revenue',
#    'description',
#    'cover_image',
#    'website_data',
#    'owner_id',
#    'stripe_customer_id',
#    'digital_component',
#    'future_goals_infrastructure',
#    'future_goals_internationalization',
#    'future_goals_machinery_and_equipments',
#    'future_goals_marketing',
#    'future_goals_rd',
#    'green_component',
#    'team_description',
#    'future_goals_hr',
#    'onboarding_state',
#    'matches_generating',
#    'userless',
#    'cae',
#    'whitelabel_id',
#    'related_operations',
#    'shareholders',
#    'other_data',
#    'source',
#    'subscription_id',
#    'extra_information',
#    'matching_order',
#    'agent_language'],
#   'primary_keys': ['id'],
#   'foreign_keys': [{'columns': ['owner_id'],
#     'ref_table': 'granter_profile',
#     'ref_columns': ['id']},
#    {'columns': ['subscription_id'],
#     'ref_table': 'granter_subscription',
#     'ref_columns': ['id']},
#    {'columns': ['whitelabel_id'],
#     'ref_table': 'granter_whitelabel',
#     'ref_columns': ['id']}]},
#  'granter_companyfile': {'columns': ['id',
#    'created_at',
#    'updated_at',
#    'name',
#    'uploaded_file',
#    'company_id',
#    'document_type_id',
#    'vector_indexed',
#    'codename',
#    'type',
#    'uploaded_by_id'],
#   'primary_keys': ['id'],
#   'foreign_keys': [{'columns': ['company_id'],
#     'ref_table': 'granter_company',
#     'ref_columns': ['id']},
#    {'columns': ['document_type_id'],
#     'ref_table': 'granter_doctype',
#     'ref_columns': ['id']},
#    {'columns': ['uploaded_by_id'],
#     'ref_table': 'granter_profile',
#     'ref_columns': ['id']}]},
#  'granter_companymemory': {'columns': ['id',
#    'created_at',
#    'updated_at',
#    'content',
#    'vector_indexed',
#    'company_id',
#    'created_by_id',
#    'type'],
#   'primary_keys': ['id'],
#   'foreign_keys': [{'columns': ['created_by_id'],
#     'ref_table': 'granter_profile',
#     'ref_columns': ['id']},
#    {'columns': ['company_id'],
#     'ref_table': 'granter_company',
#     'ref_columns': ['id']}]},
#  'granter_consortium': {'columns': ['id',
#    'created_at',
#    'updated_at',
#    'opportunity_id',
#    'project_description',
#    'state'],
#   'primary_keys': ['id'],
#   'foreign_keys': [{'columns': ['opportunity_id'],
#     'ref_table': 'granter_opportunity',
#     'ref_columns': ['id']}]},
#  'granter_consortiumpartner': {'columns': ['id',
#    'created_at',
#    'updated_at',
#    'partner_description',
#    'company_id',
#    'consortium_id',
#    'partner_type_id'],
#   'primary_keys': ['id'],
#   'foreign_keys': [{'columns': ['company_id'],
#     'ref_table': 'granter_company',
#     'ref_columns': ['id']},
#    {'columns': ['consortium_id'],
#     'ref_table': 'granter_consortium',
#     'ref_columns': ['id']},
#    {'columns': ['partner_type_id'],
#     'ref_table': 'granter_consortiumpartnertype',
#     'ref_columns': ['id']}]},
#  'granter_consortiumpartnertype': {'columns': ['id',
#    'created_at',
#    'updated_at',
#    'codename',
#    'description',
#    'description_en',
#    'description_pt',
#    'title',
#    'title_en',
#    'title_pt',
#    'type',
#    'description_es',
#    'description_it',
#    'description_pl',
#    'title_es',
#    'title_it',
#    'title_pl'],
#   'primary_keys': ['id'],
#   'foreign_keys': []},
#  'granter_consortiumpartnertype_consortium': {'columns': ['id',
#    'consortiumpartnertype_id',
#    'consortium_id'],
#   'primary_keys': ['id'],
#   'foreign_keys': [{'columns': ['consortium_id'],
#     'ref_table': 'granter_consortium',
#     'ref_columns': ['id']},
#    {'columns': ['consortiumpartnertype_id'],
#     'ref_table': 'granter_consortiumpartnertype',
#     'ref_columns': ['id']}]},
#  'granter_eligibilitycriteria': {'columns': ['id',
#    'title',
#    'description',
#    'opportunity_id'],
#   'primary_keys': ['id'],
#   'foreign_keys': [{'columns': ['opportunity_id'],
#     'ref_table': 'granter_opportunity',
#     'ref_columns': ['id']}]},
#  'granter_generalopportunityfile': {'columns': ['id',
#    'created_at',
#    'updated_at',
#    'codename',
#    'name',
#    'uploaded_file'],
#   'primary_keys': ['id'],
#   'foreign_keys': []},
#  'granter_generalopportunityfile_opportunities': {'columns': ['id',
#    'generalopportunityfile_id',
#    'opportunity_id'],
#   'primary_keys': ['id'],
#   'foreign_keys': [{'columns': ['generalopportunityfile_id'],
#     'ref_table': 'granter_generalopportunityfile',
#     'ref_columns': ['id']},
#    {'columns': ['opportunity_id'],
#     'ref_table': 'granter_opportunity',
#     'ref_columns': ['id']}]},
#  'granter_matchgroup': {'columns': ['id',
#    'created_at',
#    'updated_at',
#    'status',
#    'fundamentation',
#    'company_id',
#    'opportunity_id'],
#   'primary_keys': ['id'],
#   'foreign_keys': [{'columns': ['company_id'],
#     'ref_table': 'granter_company',
#     'ref_columns': ['id']},
#    {'columns': ['opportunity_id'],
#     'ref_table': 'granter_opportunity',
#     'ref_columns': ['id']}]},
#  'granter_opportunity': {'columns': ['id',
#    'created_at',
#    'updated_at',
#    'type',
#    'codename',
#    'state',
#    'name',
#    'fe_value',
#    'url',
#    'description',
#    'cover_image',
#    'upfront_fee',
#    'force_closing_soon',
#    'assistant_id',
#    'last_email_reminder',
#    'prep_time',
#    'location',
#    'last_email_push',
#    'free_applications',
#    'internal_submission',
#    'small_cover_image',
#    'crawler_data_id',
#    'expected_success_rate',
#    'success_fee',
#    'difficulty_level',
#    'eligibility_criteria',
#    'eligible_expenses',
#    'financial_information',
#    'financing_rate',
#    'project_duration_months',
#    'project_max_value',
#    'project_min_value',
#    'admissible_projects',
#    'form_questions',
#    'currency',
#    'difficulty_level_fundamentation',
#    'tags_fundamentation'],
#   'primary_keys': ['id'],
#   'foreign_keys': []},
#  'granter_opportunityfile': {'columns': ['id',
#    'created_at',
#    'updated_at',
#    'name',
#    'uploaded_file',
#    'vector_indexed',
#    'opportunity_id',
#    'codename'],
#   'primary_keys': ['id'],
#   'foreign_keys': [{'columns': ['opportunity_id'],
#     'ref_table': 'granter_opportunity',
#     'ref_columns': ['id']}]},
#  'granter_timeline': {'columns': ['id',
#    'created_at',
#    'updated_at',
#    'type',
#    'title',
#    'description',
#    'date',
#    'time',
#    'opportunity_id',
#    'time_diff',
#    'is_prediction'],
#   'primary_keys': ['id'],
#   'foreign_keys': [{'columns': ['opportunity_id'],
#     'ref_table': 'granter_opportunity',
#     'ref_columns': ['id']}]}}

# %%
# Replace the fk_tables line with this:

def sort_by_fk_dependencies(fk_tables, schema):
    """Sort tables by foreign key dependencies - referenced tables come first"""
    ordered = []
    remaining = fk_tables.copy()
    
    while remaining:
        # Find tables whose FK references are already processed
        ready = []
        for table in remaining:
            fk_refs = [fk['ref_table'] for fk in schema[table]['foreign_keys']]
            # Check if all FK references are either already processed or have no FKs themselves
            if all(ref in ordered or ref not in fk_tables for ref in fk_refs):
                ready.append(table)
        
        if ready:
            ordered.extend(ready)
            for table in ready:
                remaining.remove(table)
        else:
            # Handle circular dependencies - just add remaining tables
            ordered.extend(remaining)
            break
    
    return ordered

# Processing order
table_names = list(schema.keys())
no_fk_tables = [name for name in table_names if not schema[name]['foreign_keys']]
fk_tables = [name for name in table_names if schema[name]['foreign_keys']]
fk_tables = sort_by_fk_dependencies(fk_tables, schema)  # Sort by FK dependencies
processing_order = no_fk_tables + fk_tables
print(no_fk_tables)
print(fk_tables)
print(processing_order)
# Out:
# ['granter_consortiumpartnertype', 'granter_generalopportunityfile', 'granter_opportunity']
# ['granter_company', 'granter_consortium', 'granter_eligibilitycriteria', 'granter_generalopportunityfile_opportunities', 'granter_opportunityfile', 'granter_timeline', 'granter_application', 'granter_companyfile', 'granter_companymemory', 'granter_consortiumpartner', 'granter_consortiumpartnertype_consortium', 'granter_matchgroup', 'granter_applicationfile']
# ['granter_consortiumpartnertype', 'granter_generalopportunityfile', 'granter_opportunity', 'granter_company', 'granter_consortium', 'granter_eligibilitycriteria', 'granter_generalopportunityfile_opportunities', 'granter_opportunityfile', 'granter_timeline', 'granter_application', 'granter_companyfile', 'granter_companymemory', 'granter_consortiumpartner', 'granter_consortiumpartnertype_consortium', 'granter_matchgroup', 'granter_applicationfile']

# %%
#table_names = list(schema.keys())
#no_fk_tables = [name for name in table_names if not schema[name]['foreign_keys']]
#fk_tables = [name for name in table_names if schema[name]['foreign_keys']]
#processing_order = no_fk_tables + fk_tables
#print(no_fk_tables)
#print(fk_tables)
# Out:
# ['granter_consortiumpartnertype', 'granter_generalopportunityfile', 'granter_opportunity']
# ['granter_application', 'granter_applicationfile', 'granter_company', 'granter_companyfile', 'granter_companymemory', 'granter_consortium', 'granter_consortiumpartner', 'granter_consortiumpartnertype_consortium', 'granter_eligibilitycriteria', 'granter_generalopportunityfile_opportunities', 'granter_matchgroup', 'granter_opportunityfile', 'granter_timeline']

# %%
print(f"Processing {len(processing_order)} tables: {processing_order}")

core_ontology = ""
successful = []
failed = []

for table in processing_order:
    print(f"Processing {table}...", end=" ")
    
    try:
        delta = build_table_ontology(table, schema[table], core_ontology)
        core_ontology = merge_ontologies_ttl(core_ontology, delta)
        print("✅")
        successful.append(table)
    except Exception as e:
        print(f"❌ {e}")
        failed.append(table)

print(f"\nSuccess: {len(successful)}, Failed: {len(failed)}")
if failed:
    print(f"Failed tables: {failed}")

is_valid, error = validate_turtle_string(core_ontology)
print(f"Final ontology valid: {is_valid}")
if not is_valid:
    print(f"Error: {error}")
# Out:
# Processing 16 tables: ['granter_consortiumpartnertype', 'granter_generalopportunityfile', 'granter_opportunity', 'granter_company', 'granter_consortium', 'granter_eligibilitycriteria', 'granter_generalopportunityfile_opportunities', 'granter_opportunityfile', 'granter_timeline', 'granter_application', 'granter_companyfile', 'granter_companymemory', 'granter_consortiumpartner', 'granter_consortiumpartnertype_consortium', 'granter_matchgroup', 'granter_applicationfile']
# Processing granter_consortiumpartnertype...
#     Generate ontology elements with provenance annotations for database table granter_consortiumpartnertype, based on:
#
#     [CONTEXT]
#     - Database Schema of the table
# {"columns": ["id", "created_at", "updated_at", "codename", "description", "description_en", "description_pt", "title", "title_en", "title_pt", "type", "description_es", "description_it", "description_pl", "title_es", "title_it", "title_pl"], "primary_keys": ["id"], "foreign_keys": []}
#
#     - Take semantics from the External Ontology Knowledge
# GrantShare: The class for grant shares: the full or proper portion or part allotted or belonging to or contributed to an individual entity within a Grant.
# OrganisationalCriterion: Specifies that grants are awarded on the basis of specified organisational form of the project, for instance demanding for participation of different research groups (synergy).
# recipient: The receiver of a GrantPayment or receiver/beneficiary of a GrantShare.
# GrantPayment: The class for grant payments: a single payment to a recipient or beneficiary within a Grant.
#
#     - Take semantics from the Relevant Documents
# ---
# ### **granter_consortium**
# - Represents a consortium formed by multiple companies.
# - Used to apply to opportunities jointly.
# - **Relations:**
#   - Can include multiple **granter_consortiumpartners**.
#   - Can be linked to **granter_applications** when a consortium applies instead of a single company.
# ---
# ### **granter_consortiumpartner**
# - Represents a company persona or role within a **consortium** (e.g., lead applicant, research partner, SME partner).
# - **Relations:**
# ---
# ### **granter_companymemory**
# - Small text snippets stored as vectors for RAG purposes.
# - Help provide semantic context when drafting applications.
# - **Relations:**
#   - Belongs to a **granter_company**.
# ---
# ### **granter_opportunity**
# - Represents a funding opportunity (grant, tax incentive, investment, or loan).
# - **Relations:**
#   - Can have multiple **granter_applications** from different companies.
#   - Has associated **granter_opportunityfiles**.
#
#     - Take semantics from the Core Ontology Knowledge
# (empty as of now)
#
#
#     [INSTRUCTIONS]
#     1. Include these elements:
#         Classes (subclass of owl:Thing)
#         Data properties with domain/range
#         Object properties with domain/range
#         Use only one Domain: and one Range: per property. If multiple options exist, select the most general or create a shared superclass.
#     2. Use Turtle/RDF syntax format
#     3. Do not create a property named "is". Use rdf:type for instance membership, rdfs:subClassOf for class hierarchies, and owl:sameAs for instance equality.
#     4. Stick to camel case for naming the ontology elements.
#     5. Use this format example:
#
#     @prefix prov: <http://www.w3.org/ns/prov#> .
#     @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#     @prefix owl: <http://www.w3.org/2002/07/owl#> .
#     @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#     @prefix : <http://example.org/my-ontology#> .
#
#     :granter_consortiumpartnertype a owl:Class ;
#         prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype> .
#
#     :has_column_name a owl:DatatypeProperty ;
#         rdfs:domain :granter_consortiumpartnertype ;
#         rdfs:range xsd:string ;
#         prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype/column_name> .
#
#     :relates_to_table a owl:ObjectProperty ;
#         rdfs:domain :granter_consortiumpartnertype ;
#         rdfs:range :RelatedTable ;
#         prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype/fk_column> .
#
#     Only output Turtle syntax and nothing else. [OUTPUT]
#
# JudgeLLM Validation succeeded.
# (True, '')
# ✅
# Processing granter_generalopportunityfile...
#     Generate ontology elements with provenance annotations for database table granter_generalopportunityfile, based on:
#
#     [CONTEXT]
#     - Database Schema of the table
# {"columns": ["id", "created_at", "updated_at", "codename", "name", "uploaded_file"], "primary_keys": ["id"], "foreign_keys": []}
#
#     - Take semantics from the External Ontology Knowledge
# person_location: Country or geographical administrative entity where the person must reside or be citizen or have undertaken research up to the moment of applying for funding.
# grid_id: Institutional identifier from the GRID.ac global research identifier database.
# GeographicCriterion: Specifies that grants are awarded to projects on the basis of geographic areas, either where the project has to be implemented, or where the researcher must have been operating before applying for funding, or where the participants must be resident or citizens.
# agency_identifier: Identifier (for example of Project, Grant, GrantPayment, PersonRole instance, OrganizationRole instance, FundingScheme, Person, Organisation) in the database/archive of the funding agency/funding body/funder.
#
#     - Take semantics from the Relevant Documents
# - Belongs to a **granter_opportunity**.
# ---
# ### **granter_generalopportunityfile**
# - Files that are not tied to a single opportunity.
# - Provide context across **multiple opportunities**.
# ---
# ### **granter_timeline**
# - Represents important dates for an **opportunity** (opening, submission deadlines, evaluations, etc.).
# - **Relations:**
#   - Belongs to a **granter_opportunity**.
# ---
# ### **granter_consortium**
# - Represents a consortium formed by multiple companies.
# ---
# ### **granter_applicationfile**
# - Files tied to a specific **application**.
# - Usually provide company or project-specific context for that application.
# - **Relations:**
#   - Belongs to a **granter_application**.
# ---
# ### **granter_companyfile**
# - Files that contain general company context (used for RAG purposes).
# - **Relations:**
#   - Belongs to a **granter_company**.
# ---
# ### **granter_companymemory**
# - Small text snippets stored as vectors for RAG purposes.
#
#     - Take semantics from the Core Ontology Knowledge
# Class names: GrantPayment, GrantShare, GranterConsortium, GranterConsortiumPartner, GranterOpportunity, OrganisationalCriterion, Recipient
#
# Object properties (relations): hasGrantShare, hasRecipient, hasTitle, includesPartner, linkedToOpportunity
#
# Datatype properties (attributes): hasCodeName, hasCreatedAt, hasDescription, hasDescriptionEn, hasDescriptionEs, hasDescriptionIt, hasDescriptionPl, hasDescriptionPt, hasId, hasOpportunityDescription, hasOpportunityId, hasOpportunityTitle, hasPartnerDescription, hasPartnerId, hasPartnerRole, hasPaymentAmount, hasPaymentDate, hasPaymentId, hasTitle, hasTitleEn, hasTitleEs, hasTitleIt, hasTitlePl, hasTitlePt, hasType, hasUpdatedAt
#
#
#
#     [INSTRUCTIONS]
#     1. Include these elements:
#         Classes (subclass of owl:Thing)
#         Data properties with domain/range
#         Object properties with domain/range
#         Use only one Domain: and one Range: per property. If multiple options exist, select the most general or create a shared superclass.
#     2. Use Turtle/RDF syntax format
#     3. Do not create a property named "is". Use rdf:type for instance membership, rdfs:subClassOf for class hierarchies, and owl:sameAs for instance equality.
#     4. Stick to camel case for naming the ontology elements.
#     5. Use this format example:
#
#     @prefix prov: <http://www.w3.org/ns/prov#> .
#     @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#     @prefix owl: <http://www.w3.org/2002/07/owl#> .
#     @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#     @prefix : <http://example.org/my-ontology#> .
#
#     :granter_generalopportunityfile a owl:Class ;
#         prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile> .
#
#     :has_column_name a owl:DatatypeProperty ;
#         rdfs:domain :granter_generalopportunityfile ;
#         rdfs:range xsd:string ;
#         prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile/column_name> .
#
#     :relates_to_table a owl:ObjectProperty ;
#         rdfs:domain :granter_generalopportunityfile ;
#         rdfs:range :RelatedTable ;
#         prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile/fk_column> .
#
#     Only output Turtle syntax and nothing else. [OUTPUT]
#
# JudgeLLM Validation failed. Corrected Version:
# (True, '')
# ✅
# Processing granter_opportunity...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 11
#       8 print(f"Processing {table}...", end=" ")
#      10 try:
# ---> 11     delta = build_table_ontology(table, schema[table], core_ontology)
#      12     core_ontology = merge_ontologies_ttl(core_ontology, delta)
#      13     print("✅")
#
# Cell In[29], line 51, in build_table_ontology(table_name, table_schema, core_ontology)
#       4     core_context = f"""Class names: {', '.join(classes)}
#       5 \nObject properties (relations): {', '.join(relations)}
#       6 \nDatatype properties (attributes): {', '.join(attributes)}
#       7 """
#       9     prompt = f"""
#      10     Generate ontology elements with provenance annotations for database table {table_name}, based on:
#      11
#    (...)     48     Only output Turtle syntax and nothing else. [OUTPUT]
#      49     """
# ---> 51     delta_ontology = gpt41_nano.invoke(prompt).content
#      52     print(prompt)
#      56     is_valid, error_message = validate_turtle_string(delta_ontology)
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\langchain_core\language_models\chat_models.py:383, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     371 @override
#     372 def invoke(
#     373     self,
#    (...)    378     **kwargs: Any,
#     379 ) -> BaseMessage:
#     380     config = ensure_config(config)
#     381     return cast(
#     382         "ChatGeneration",
# --> 383         self.generate_prompt(
#     384             [self._convert_input(input)],
#     385             stop=stop,
#     386             callbacks=config.get("callbacks"),
#     387             tags=config.get("tags"),
#     388             metadata=config.get("metadata"),
#     389             run_name=config.get("run_name"),
#     390             run_id=config.pop("run_id", None),
#     391             **kwargs,
#     392         ).generations[0][0],
#     393     ).message
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\langchain_core\language_models\chat_models.py:1006, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     997 @override
#     998 def generate_prompt(
#     999     self,
#    (...)   1003     **kwargs: Any,
#    1004 ) -> LLMResult:
#    1005     prompt_messages = [p.to_messages() for p in prompts]
# -> 1006     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\langchain_core\language_models\chat_models.py:825, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     822 for i, m in enumerate(input_messages):
#     823     try:
#     824         results.append(
# --> 825             self._generate_with_cache(
#     826                 m,
#     827                 stop=stop,
#     828                 run_manager=run_managers[i] if run_managers else None,
#     829                 **kwargs,
#     830             )
#     831         )
#     832     except BaseException as e:
#     833         if run_managers:
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\langchain_core\language_models\chat_models.py:1072, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1070     result = generate_from_stream(iter(chunks))
#    1071 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1072     result = self._generate(
#    1073         messages, stop=stop, run_manager=run_manager, **kwargs
#    1074     )
#    1075 else:
#    1076     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\langchain_openai\chat_models\base.py:1177, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1175     generation_info = {"headers": dict(raw_response.headers)}
#    1176 else:
# -> 1177     response = self.client.create(**payload)
#    1178 return self._create_chat_result(response, generation_info)
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\openai\resources\chat\completions\completions.py:1150, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1104 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1105 def create(
#    1106     self,
#    (...)   1147     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1148 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1149     validate_response_format(response_format)
# -> 1150     return self._post(
#    1151         "/chat/completions",
#    1152         body=maybe_transform(
#    1153             {
#    1154                 "messages": messages,
#    1155                 "model": model,
#    1156                 "audio": audio,
#    1157                 "frequency_penalty": frequency_penalty,
#    1158                 "function_call": function_call,
#    1159                 "functions": functions,
#    1160                 "logit_bias": logit_bias,
#    1161                 "logprobs": logprobs,
#    1162                 "max_completion_tokens": max_completion_tokens,
#    1163                 "max_tokens": max_tokens,
#    1164                 "metadata": metadata,
#    1165                 "modalities": modalities,
#    1166                 "n": n,
#    1167                 "parallel_tool_calls": parallel_tool_calls,
#    1168                 "prediction": prediction,
#    1169                 "presence_penalty": presence_penalty,
#    1170                 "prompt_cache_key": prompt_cache_key,
#    1171                 "reasoning_effort": reasoning_effort,
#    1172                 "response_format": response_format,
#    1173                 "safety_identifier": safety_identifier,
#    1174                 "seed": seed,
#    1175                 "service_tier": service_tier,
#    1176                 "stop": stop,
#    1177                 "store": store,
#    1178                 "stream": stream,
#    1179                 "stream_options": stream_options,
#    1180                 "temperature": temperature,
#    1181                 "tool_choice": tool_choice,
#    1182                 "tools": tools,
#    1183                 "top_logprobs": top_logprobs,
#    1184                 "top_p": top_p,
#    1185                 "user": user,
#    1186                 "verbosity": verbosity,
#    1187                 "web_search_options": web_search_options,
#    1188             },
#    1189             completion_create_params.CompletionCreateParamsStreaming
#    1190             if stream
#    1191             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1192         ),
#    1193         options=make_request_options(
#    1194             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1195         ),
#    1196         cast_to=ChatCompletion,
#    1197         stream=stream or False,
#    1198         stream_cls=Stream[ChatCompletionChunk],
#    1199     )
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\openai\_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     980 response = None
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#     988     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\ssl.py:1233, in SSLSocket.recv(self, buflen, flags)
#    1229     if flags != 0:
#    1230         raise ValueError(
#    1231             "non-zero flags not allowed in calls to recv() on %s" %
#    1232             self.__class__)
# -> 1233     return self.read(buflen)
#    1234 else:
#    1235     return super().recv(buflen, flags)
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\ssl.py:1106, in SSLSocket.read(self, len, buffer)
#    1104         return self._sslobj.read(len, buffer)
#    1105     else:
# -> 1106         return self._sslobj.read(len)
#    1107 except SSLError as x:
#    1108     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
# Retry failed tables
if failed:
    print(f"\n🔄 Retrying {len(failed)} failed tables...")
    
    retry_successful = []
    retry_failed = []
    
    for table in failed:
        print(f"Retrying {table}...", end=" ")
        
        try:
            delta = build_table_ontology(table, schema[table], core_ontology)
            core_ontology = merge_ontologies_ttl(core_ontology, delta)
            print("✅")
            retry_successful.append(table)
        except Exception as e:
            print(f"❌ {e}")
            retry_failed.append(table)
    
    # Update the lists
    successful.extend(retry_successful)
    failed = retry_failed
    
    print(f"\nRetry Results:")
    print(f"✅ Newly successful: {len(retry_successful)}")
    print(f"❌ Still failed: {len(retry_failed)}")
# Out:
# 🔄 Retrying 2 failed tables...
# Retrying granter_application... JudgeLLM Validation succeeded.
# (True, '')
# ✅
# Retrying granter_applicationfile... JudgeLLM Validation failed. Corrected Version:
# (True, '')
# ✅
#
# Retry Results:
# ✅ Newly successful: 2
# ❌ Still failed: 0

# %%
validate_turtle_string(core_ontology)
# Out:
# (True, '')

# %%
print(core_ontology)
# Out:
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://example.org/ontology#GrantPayment> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/grant_payment> .
#
# <http://example.org/ontology#OrganisationalCriterion> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/OrganisationalCriterion> .
#
# <http://example.org/ontology#admissibleProjects> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/admissible_projects> .
#
# <http://example.org/ontology#aiReviewState> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterApplication> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/ai_review_state> .
#
# <http://example.org/ontology#applicationCodename> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterApplication> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/codename> .
#
# <http://example.org/ontology#applicationId> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterApplication> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/id> .
#
# <http://example.org/ontology#applicationState> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterApplication> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/state> .
#
# <http://example.org/ontology#applicationTitle> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterApplication> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/title> .
#
# <http://example.org/ontology#approvedGrantAmount> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterApplication> ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/approved_grant_amount> .
#
# <http://example.org/ontology#assistantId> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/assistant_id> .
#
# <http://example.org/ontology#belongsToApplication> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_applicationfile> ;
#     rdfs:range <http://example.org/ontology#granter_application> ;
#     prov:wasDerivedFrom <http://provenance.example.org/granter_applicationfile/foreign_key_application_id> .
#
# <http://example.org/ontology#belongsToCompany> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#GranterCompanyFile>,
#         <http://example.org/ontology#granter_companyfile>,
#         <http://example.org/ontology#granter_matchcheck> ;
#     rdfs:range <http://example.org/ontology#GranterCompany>,
#         <http://example.org/ontology#granter_company> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/relationship>,
#         <http://example.org/provenance/granter_matchcheck/belongs_to_company> .
#
# <http://example.org/ontology#belongsToCompanyMemory> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range <http://example.org/ontology#granterCompanyMemory>,
#         <http://example.org/ontology#granter_companymemory> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/belongs_to_company_memory> .
#
# <http://example.org/ontology#belongsToConsortium> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range <http://example.org/ontology#granterConsortium>,
#         <http://example.org/ontology#granter_consortium> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/belongs_to_consortium> .
#
# <http://example.org/ontology#belongsToDocumentType> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_applicationfile>,
#         <http://example.org/ontology#granter_companyfile> ;
#     rdfs:range <http://example.org/ontology#granter_doctype> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/relationship>,
#         <http://provenance.example.org/granter_applicationfile/foreign_key_document_type_id> .
#
# <http://example.org/ontology#belongsToGeneralOpportunityFile> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range <http://example.org/ontology#granterGeneralOpportunityFile> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/belongs_to_general_opportunity_file> .
#
# <http://example.org/ontology#belongsToOpportunity> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#GranterGeneralOpportunityFile>,
#         <http://example.org/ontology#GranterOpportunityFile>,
#         <http://example.org/ontology#granter_eligibilitycriteria>,
#         <http://example.org/ontology#granter_generalopportunityfile>,
#         <http://example.org/ontology#granter_timeline> ;
#     rdfs:range <http://example.org/ontology#GranterOpportunity>,
#         <http://example.org/ontology#granter_opportunity> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_eligibilitycriteria/belongs_to_opportunity>,
#         <http://example.org/provenance/granter_generalopportunityfile/belongsToOpportunity>,
#         <http://example.org/provenance/granter_opportunityfile/belongsToOpportunity>,
#         <http://example.org/provenance/granter_timeline/belongsToOpportunity> .
#
# <http://example.org/ontology#belongsToOpportunityFile> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunityfile> ;
#     rdfs:range <http://example.org/ontology#granter_opportunity> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunityfile/belongsToOpportunity> .
#
# <http://example.org/ontology#belongs_to_company> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_companymemory>,
#         <http://example.org/ontology#granter_matchcheck> ;
#     rdfs:range <http://example.org/ontology#granter_company> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companymemory/belongs_to_company>,
#         <http://example.org/provenance/granter_matchcheck/company> .
#
# <http://example.org/ontology#belongs_to_companymemory> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_companymemory> ;
#     rdfs:range <http://example.org/ontology#granter_company> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companymemory/company> .
#
# <http://example.org/ontology#belongs_to_eligibilitycriteria> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_matchcheck> ;
#     rdfs:range <http://example.org/ontology#granter_eligibilitycriteria> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_matchcheck/eligibilitycriteria> .
#
# <http://example.org/ontology#belongs_to_granter_opportunity> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunityfile> ;
#     rdfs:range <http://example.org/ontology#granter_opportunity> ;
#     prov:wasDerivedFrom <http://example.org/provenance/belongs_to_granter_opportunity> .
#
# <http://example.org/ontology#belongs_to_opportunity> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_generalopportunityfile> ;
#     rdfs:range <http://example.org/ontology#granter_opportunity> ;
#     prov:wasDerivedFrom <http://example.org/provenance/belongs_to_opportunity> .
#
# <http://example.org/ontology#career_purpose_criterion> a owl:Class ;
#     rdfs:subClassOf <http://example.org/ontology#Criterion> ;
#     prov:wasDerivedFrom <http://example.org/provenance/career_purpose_criterion> .
#
# <http://example.org/ontology#codename> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/codename> .
#
# <http://example.org/ontology#companyId> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterApplication>,
#         <http://example.org/ontology#GranterPartner> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/company_id>,
#         <http://example.org/provenance/granter_consortiumpartner/company_id> .
#
# <http://example.org/ontology#consortiumId> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterApplication>,
#         <http://example.org/ontology#GranterPartner> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/consortium_id>,
#         <http://example.org/provenance/granter_consortiumpartner/consortium_id> .
#
# <http://example.org/ontology#coverImage> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:anyURI ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/cover_image> .
#
# <http://example.org/ontology#crawlerDataId> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/crawler_data_id> .
#
# <http://example.org/ontology#createdAt> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterApplication>,
#         <http://example.org/ontology#GranterPartner>,
#         <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/created_at>,
#         <http://example.org/provenance/granter_consortiumpartner/created_at>,
#         <http://example.org/provenance/granter_opportunity/created_at> .
#
# <http://example.org/ontology#created_by> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_companymemory>,
#         <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range <http://example.org/ontology#granter_profile> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companymemory/created_by> .
#
# <http://example.org/ontology#criterion> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/criterion> .
#
# <http://example.org/ontology#criterion_description> a owl:Class ;
#     rdfs:subClassOf <http://example.org/ontology#Criterion> ;
#     prov:wasDerivedFrom <http://example.org/provenance/criterion_description> .
#
# <http://example.org/ontology#currency> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/currency> .
#
# <http://example.org/ontology#description> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/description> .
#
# <http://example.org/ontology#difficultyLevel> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/difficulty_level> .
#
# <http://example.org/ontology#difficultyLevelFundamentation> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/difficulty_level_fundamentation> .
#
# <http://example.org/ontology#eligibilityCriteria> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/eligibility_criteria> .
#
# <http://example.org/ontology#eligibleExpenses> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/eligible_expenses> .
#
# <http://example.org/ontology#expectedSuccessRate> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/expected_success_rate> .
#
# <http://example.org/ontology#feValue> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/fe_value> .
#
# <http://example.org/ontology#financialInformation> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/financial_information> .
#
# <http://example.org/ontology#financingRate> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/financing_rate> .
#
# <http://example.org/ontology#forceClosingSoon> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:boolean ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/force_closing_soon> .
#
# <http://example.org/ontology#formQuestions> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/form_questions> .
#
# <http://example.org/ontology#freeApplications> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/free_applications> .
#
# <http://example.org/ontology#funded_by> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#Project> ;
#     rdfs:range <http://example.org/ontology#Grant> ;
#     prov:wasDerivedFrom <http://example.org/provenance/funded_by> .
#
# <http://example.org/ontology#funding_scheme_criteria> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/funding_scheme_criteria> .
#
# <http://example.org/ontology#granterCompany> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company> .
#
# <http://example.org/ontology#granterPartnerType> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype> .
#
# <http://example.org/ontology#granter_applications> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_applications> .
#
# <http://example.org/ontology#granter_consortium_column> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium/column_name> .
#
# <http://example.org/ontology#granter_opportunityfiles> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunityfiles> .
#
# <http://example.org/ontology#grouped_in_matchgroup> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_matchcheck> ;
#     rdfs:range <http://example.org/ontology#granter_matchgroup> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_matchcheck/matchgroup> .
#
# <http://example.org/ontology#hasApplication> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range <http://example.org/ontology#granterApplication> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/has_application> .
#
# <http://example.org/ontology#hasApplicationFile> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#GranterApplication> ;
#     rdfs:range <http://example.org/ontology#GranterApplicationFile> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/has_application_file> .
#
# <http://example.org/ontology#hasAssociatedEligibilities> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium>,
#         <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range <http://example.org/ontology#granter_eligibilitycriteria> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium/hasEligibilities>,
#         <http://example.org/provenance/granter_opportunity/hasEligibilities> .
#
# <http://example.org/ontology#hasAssociatedFiles> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range <http://example.org/ontology#granter_opportunityfile> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/hasFiles> .
#
# <http://example.org/ontology#hasAssociatedOpportunityFiles> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium> ;
#     rdfs:range <http://example.org/ontology#granter_opportunityfile> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium/hasOpportunityFiles> .
#
# <http://example.org/ontology#hasAssociatedTimelines> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium>,
#         <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range <http://example.org/ontology#granter_timeline> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium/hasTimelines>,
#         <http://example.org/provenance/granter_opportunity/hasTimelines> .
#
# <http://example.org/ontology#hasColumnCreatedAt> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterOpportunityFile>,
#         <http://example.org/ontology#granter_companyfile> ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/column_created_at>,
#         <http://example.org/provenance/granter_opportunityfile/column_created_at> .
#
# <http://example.org/ontology#hasColumnDescription> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium_part_type> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype/column_description> .
#
# <http://example.org/ontology#hasColumnDescriptionEn> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium_part_type> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype/column_description_en> .
#
# <http://example.org/ontology#hasColumnDescriptionPt> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium_part_type> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype/column_description_pt> .
#
# <http://example.org/ontology#hasColumnId> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterOpportunityFile>,
#         <http://example.org/ontology#granter_companyfile> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunityfile/column_id>,
#         <http://provenance.example.org/granter_companyfile/column_id> .
#
# <http://example.org/ontology#hasColumnIdForCompanyFile> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterCompanyFile>,
#         <http://example.org/ontology#granter_companyfile> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/column_id>,
#         <http://provenance.example.org/granter_companyfile/column_id> .
#
# <http://example.org/ontology#hasColumnIdForConsortiumPartType> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterConsortiumPartType>,
#         <http://example.org/ontology#granter_consortium_part_type> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype/column_id>,
#         <http://provenance.example.org/granter_consortiumpartnertype/column_id> .
#
# <http://example.org/ontology#hasColumnIdForGeneralOpportunityFile> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterGeneralOpportunityFile>,
#         <http://example.org/ontology#granter_generalopportunityfile> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile/column_id>,
#         <http://provenance.example.org/granter_generalopportunityfile/column_id> .
#
# <http://example.org/ontology#hasColumnIdForGeneralOpportunityFileOpportunities> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_generalopportunityfile_opportunities> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile_opportunities/generalopportunityfile_id_column> .
#
# <http://example.org/ontology#hasColumnName> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_companyfile> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/column_name> .
#
# <http://example.org/ontology#hasColumnOpportunityId> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterGeneralOpportunityFile>,
#         <http://example.org/ontology#granter_generalopportunityfile>,
#         <http://example.org/ontology#granter_generalopportunityfile_opportunities> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile/opportunity_id_column>,
#         <http://example.org/provenance/granter_generalopportunityfile_opportunities/opportunity_id_column> .
#
# <http://example.org/ontology#hasColumnTitle> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium_part_type> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype/column_title> .
#
# <http://example.org/ontology#hasColumnTitleEn> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium_part_type> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype/column_title_en> .
#
# <http://example.org/ontology#hasColumnTitlePt> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium_part_type> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype/column_title_pt> .
#
# <http://example.org/ontology#hasColumnType> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_companyfile> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/column_type> .
#
# <http://example.org/ontology#hasColumnUpdatedAt> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterOpportunityFile>,
#         <http://example.org/ontology#granter_companyfile>,
#         <http://example.org/ontology#granter_generalopportunityfile> ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/column_updated_at>,
#         <http://example.org/provenance/granter_generalopportunityfile/column_updated_at>,
#         <http://example.org/provenance/granter_opportunityfile/column_updated_at> .
#
# <http://example.org/ontology#hasCompany> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#GranterApplication> ;
#     rdfs:range <http://example.org/ontology#GranterCompany> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/has_company> .
#
# <http://example.org/ontology#hasEligibilityCriteria> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#GranterOpportunity> ;
#     rdfs:range <http://example.org/ontology#GranterEligibilityCriteria> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/has_eligibility_criteria> .
#
# <http://example.org/ontology#hasFile> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range <http://example.org/ontology#granterOpportunityFile> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/has_file> .
#
# <http://example.org/ontology#hasForeignKeyOpportunity> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#GranterConsortium> ;
#     rdfs:range <http://example.org/ontology#GranterOpportunity> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium/foreign_key_opportunity> .
#
# <http://example.org/ontology#hasIdentifier> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterPartner> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartner/id> .
#
# <http://example.org/ontology#hasMatchCheck> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_eligibilitycriteria> ;
#     rdfs:range <http://example.org/ontology#granter_matchcheck> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_eligibilitycriteria/has_matchcheck> .
#
# <http://example.org/ontology#hasMatchGroup> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_matchcheck> ;
#     rdfs:range <http://example.org/ontology#granter_matchgroup> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_matchcheck/has_matchgroup> .
#
# <http://example.org/ontology#hasOpportunity> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#GranterApplication> ;
#     rdfs:range <http://example.org/ontology#GranterOpportunity> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/has_opportunity> .
#
# <http://example.org/ontology#hasOpportunityId> a owl:DatatypeProperty,
#         owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#GranterConsortium>,
#         <http://example.org/ontology#granter_generalopportunityfile_opportunities> ;
#     rdfs:range <http://example.org/ontology#GranterOpportunity>,
#         xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium/opportunity_id>,
#         <http://example.org/provenance/granter_generalopportunityfile_opportunities/generalopportunityfile_id_column> .
#
# <http://example.org/ontology#hasOpportunityIdObject> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium> ;
#     rdfs:range <http://example.org/ontology#granter_opportunity> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium/opportunity_id> .
#
# <http://example.org/ontology#hasPartnerDescription> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterPartner> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartner/partner_description> .
#
# <http://example.org/ontology#hasPrimaryKeyId> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterConsortium> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium/id> .
#
# <http://example.org/ontology#hasProvenance> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_generalopportunityfile> ;
#     rdfs:range prov:Entity ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile/hasProvenance> .
#
# <http://example.org/ontology#hasTimeline> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#GranterOpportunity>,
#         <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range <http://example.org/ontology#GranterTimeline>,
#         <http://example.org/ontology#granterTimeline> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/has_timeline> .
#
# <http://example.org/ontology#has_career_stage> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#CareerPurposeCriterion> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/career_stage> .
#
# <http://example.org/ontology#has_column_codename> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_companyfile>,
#         <http://example.org/ontology#granter_consortium_part_type>,
#         <http://example.org/ontology#granter_generalopportunityfile> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/column_codename>,
#         <http://example.org/provenance/granter_consortiumpartnertype/column_codename>,
#         <http://example.org/provenance/granter_generalopportunityfile/column_codename> .
#
# <http://example.org/ontology#has_column_company_id> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_companyfile> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/column_company_id> .
#
# <http://example.org/ontology#has_column_conortiumpartnertype_id> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortiumpartnertype> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype/column_conortiumpartnertype_id> .
#
# <http://example.org/ontology#has_column_consortium_id> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortiumpartnertype> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype/column_consortium_id> .
#
# <http://example.org/ontology#has_column_created_at> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_applicationfile>,
#         <http://example.org/ontology#granter_companyfile>,
#         <http://example.org/ontology#granter_consortium_part_type>,
#         <http://example.org/ontology#granter_generalopportunityfile>,
#         <http://example.org/ontology#granter_timeline> ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/column_created_at>,
#         <http://example.org/provenance/granter_consortiumpartnertype/column_created_at>,
#         <http://example.org/provenance/granter_generalopportunityfile/column_created_at>,
#         <http://example.org/provenance/granter_timeline/column_created_at>,
#         <http://provenance.example.org/granter_applicationfile/column_created_at> .
#
# <http://example.org/ontology#has_column_date> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_timeline> ;
#     rdfs:range xsd:date ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_timeline/column_date> .
#
# <http://example.org/ontology#has_column_description> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium_part_type>,
#         <http://example.org/ontology#granter_timeline> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype/column_description>,
#         <http://example.org/provenance/granter_timeline/column_description> .
#
# <http://example.org/ontology#has_column_description_en> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium_part_type> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype/column_description_en> .
#
# <http://example.org/ontology#has_column_description_pt> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium_part_type> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype/column_description_pt> .
#
# <http://example.org/ontology#has_column_document_type_id> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_companyfile> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/column_document_type_id> .
#
# <http://example.org/ontology#has_column_generalopportunityfile_id> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_generalopportunityfile_opportunities> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile_opportunities/generalopportunityfile_id_column> .
#
# <http://example.org/ontology#has_column_id> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_applicationfile>,
#         <http://example.org/ontology#granter_companyfile>,
#         <http://example.org/ontology#granter_consortium_part_type>,
#         <http://example.org/ontology#granter_consortiumpartnertype>,
#         <http://example.org/ontology#granter_generalopportunityfile>,
#         <http://example.org/ontology#granter_generalopportunityfile_opportunities>,
#         <http://example.org/ontology#granter_timeline> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/column_id>,
#         <http://example.org/provenance/granter_consortiumpartnertype/column_id>,
#         <http://example.org/provenance/granter_generalopportunityfile/column_id>,
#         <http://example.org/provenance/granter_generalopportunityfile_opportunities/id_column>,
#         <http://example.org/provenance/granter_timeline/column_id>,
#         <http://provenance.example.org/granter_applicationfile/column_id> .
#
# <http://example.org/ontology#has_column_id_for_companyfile> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_companyfile> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/column_id> .
#
# <http://example.org/ontology#has_column_id_for_consortium_part_type> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium_part_type> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype/column_id> .
#
# <http://example.org/ontology#has_column_id_for_general_opportunity_file> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_generalopportunityfile> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile/column_id> .
#
# <http://example.org/ontology#has_column_is_prediction> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_timeline> ;
#     rdfs:range xsd:boolean ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_timeline/column_is_prediction> .
#
# <http://example.org/ontology#has_column_name> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_applicationfile>,
#         <http://example.org/ontology#granter_companyfile>,
#         <http://example.org/ontology#granter_companymemory>,
#         <http://example.org/ontology#granter_eligibilitycriteria>,
#         <http://example.org/ontology#granter_generalopportunityfile> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/column_name>,
#         <http://example.org/provenance/granter_companymemory/column_name>,
#         <http://example.org/provenance/granter_eligibilitycriteria/column_name>,
#         <http://example.org/provenance/granter_generalopportunityfile/column_name>,
#         <http://provenance.example.org/granter_applicationfile/column_name> .
#
# <http://example.org/ontology#has_column_opportunity_id> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_generalopportunityfile_opportunities>,
#         <http://example.org/ontology#granter_timeline> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile_opportunities/opportunity_id_column>,
#         <http://example.org/provenance/granter_timeline/column_opportunity_id> .
#
# <http://example.org/ontology#has_column_time> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_timeline> ;
#     rdfs:range xsd:time ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_timeline/column_time> .
#
# <http://example.org/ontology#has_column_time_diff> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_timeline> ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_timeline/column_time_diff> .
#
# <http://example.org/ontology#has_column_title> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium_part_type>,
#         <http://example.org/ontology#granter_timeline> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype/column_title>,
#         <http://example.org/provenance/granter_timeline/column_title> .
#
# <http://example.org/ontology#has_column_title_en> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium_part_type> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype/column_title_en> .
#
# <http://example.org/ontology#has_column_title_pt> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium_part_type> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype/column_title_pt> .
#
# <http://example.org/ontology#has_column_type> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_companyfile>,
#         <http://example.org/ontology#granter_consortium_part_type>,
#         <http://example.org/ontology#granter_timeline> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/column_type>,
#         <http://example.org/provenance/granter_consortiumpartnertype/column_type>,
#         <http://example.org/provenance/granter_timeline/column_type> .
#
# <http://example.org/ontology#has_column_updated_at> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_applicationfile>,
#         <http://example.org/ontology#granter_companyfile>,
#         <http://example.org/ontology#granter_consortium_part_type>,
#         <http://example.org/ontology#granter_generalopportunityfile>,
#         <http://example.org/ontology#granter_timeline> ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/column_updated_at>,
#         <http://example.org/provenance/granter_consortiumpartnertype/column_updated_at>,
#         <http://example.org/provenance/granter_generalopportunityfile/column_updated_at>,
#         <http://example.org/provenance/granter_timeline/column_updated_at>,
#         <http://provenance.example.org/granter_applicationfile/column_updated_at> .
#
# <http://example.org/ontology#has_column_uploaded_by_id> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_companyfile> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/column_uploaded_by_id> .
#
# <http://example.org/ontology#has_column_uploaded_file> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_companyfile>,
#         <http://example.org/ontology#granter_generalopportunityfile> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/column_uploaded_file>,
#         <http://example.org/provenance/granter_generalopportunityfile/column_uploaded_file> .
#
# <http://example.org/ontology#has_column_vector_indexed> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_companyfile> ;
#     rdfs:range xsd:boolean ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/column_vector_indexed> .
#
# <http://example.org/ontology#has_content> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_companymemory> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companymemory/content> .
#
# <http://example.org/ontology#has_created_at> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_companyfile>,
#         <http://example.org/ontology#granter_companymemory>,
#         <http://example.org/ontology#granter_consortium>,
#         <http://example.org/ontology#granter_generalopportunityfile>,
#         <http://example.org/ontology#granter_matchgroup> ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companymemory/created_at>,
#         <http://example.org/provenance/granter_consortium/created_at>,
#         <http://example.org/provenance/granter_matchgroup/created_at> .
#
# <http://example.org/ontology#has_description> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_eligibilitycriteria> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_eligibilitycriteria/description> .
#
# <http://example.org/ontology#has_eligibility_requirements> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#Criterion> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/criterion_eligibility> .
#
# <http://example.org/ontology#has_foreign_key_opportunity> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium> ;
#     rdfs:range <http://example.org/ontology#granter_opportunity> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium/opportunity_id_fk> .
#
# <http://example.org/ontology#has_fundamentation> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_matchgroup> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_matchgroup/fundamentation> .
#
# <http://example.org/ontology#has_id> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_matchgroup> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_matchgroup/id> .
#
# <http://example.org/ontology#has_opportunity_id> a owl:DatatypeProperty,
#         owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium>,
#         <http://example.org/ontology#granter_eligibilitycriteria> ;
#     rdfs:range <http://example.org/ontology#granter_opportunity>,
#         xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium/opportunity_id>,
#         <http://example.org/provenance/granter_eligibilitycriteria/opportunity_id> .
#
# <http://example.org/ontology#has_primary_key_id> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium> ;
#     rdfs:range xsd:integer ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium/id> .
#
# <http://example.org/ontology#has_project_description> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium/project_description> .
#
# <http://example.org/ontology#has_provenance> a owl:DatatypeProperty,
#         owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_generalopportunityfile_opportunities>,
#         <http://example.org/ontology#granter_matchgroup> ;
#     rdfs:range xsd:string,
#         prov:Entity ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile_opportunities>,
#         <http://example.org/provenance/granter_matchgroup/provenance> .
#
# <http://example.org/ontology#has_semantic_description> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#Criterion> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/criterion_description> .
#
# <http://example.org/ontology#has_state> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium/state> .
#
# <http://example.org/ontology#has_status> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_matchgroup> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_matchgroup/status> .
#
# <http://example.org/ontology#has_text_snippet> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_companymemory> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companymemory/snippet> .
#
# <http://example.org/ontology#has_type> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_applicationfile>,
#         <http://example.org/ontology#granter_companymemory>,
#         <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companymemory/type>,
#         <http://provenance.example.org/granter_applicationfile/column_type> .
#
# <http://example.org/ontology#has_updated_at> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_companyfile>,
#         <http://example.org/ontology#granter_companymemory>,
#         <http://example.org/ontology#granter_consortium>,
#         <http://example.org/ontology#granter_generalopportunityfile>,
#         <http://example.org/ontology#granter_matchgroup> ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companymemory/updated_at>,
#         <http://example.org/provenance/granter_consortium/updated_at>,
#         <http://example.org/provenance/granter_matchgroup/updated_at> .
#
# <http://example.org/ontology#has_uploaded_file> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_applicationfile> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://provenance.example.org/granter_applicationfile/column_uploaded_file> .
#
# <http://example.org/ontology#has_vector_indexed> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_companyfile>,
#         <http://example.org/ontology#granter_companymemory> ;
#     rdfs:range xsd:boolean ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companymemory/vector_indexed> .
#
# <http://example.org/ontology#initialSummary> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterApplication> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/initial_summary> .
#
# <http://example.org/ontology#internalSubmission> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:boolean ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/internal_submission> .
#
# <http://example.org/ontology#lastEmailPush> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/last_email_push> .
#
# <http://example.org/ontology#lastEmailReminder> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/last_email_reminder> .
#
# <http://example.org/ontology#location> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/location> .
#
# <http://example.org/ontology#matchesCriteria> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_matchcheck> ;
#     rdfs:range <http://example.org/ontology#granter_eligibilitycriteria> ;
# ...
#
# <http://example.org/ontology#projectMaxValue> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/project_max_value> .
#
# <http://example.org/ontology#projectMinValue> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/project_min_value> .
#
# <http://example.org/ontology#provenanceContext> a owl:AnnotationProperty ;
#     rdfs:label "Provenance Context"@en ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile/context> .
#
# <http://example.org/ontology#provenanceForCompanyFile> a prov:Entity ;
#     rdfs:domain <http://example.org/ontology#granter_companyfile> ;
#     prov:wasDerivedFrom <http://example.org/provenance/source/granter_companyfile> .
#
# <http://example.org/ontology#providesContextAcrossMultipleOpportunities> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#GranterGeneralOpportunityFile> ;
#     rdfs:range <http://example.org/ontology#GranterOpportunity> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile/providesContext> .
#
# <http://example.org/ontology#recipient> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#GrantShare> ;
#     rdfs:range <http://example.org/ontology#Organization> ;
#     prov:wasDerivedFrom <http://example.org/provenance/recipient> .
#
# <http://example.org/ontology#relatedToAgencyIdentifier> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_generalopportunityfile> ;
#     rdfs:range <http://example.org/ontology#agency_identifier> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile/relatedToAgencyIdentifier> .
#
# <http://example.org/ontology#relatedToGeographicCriterion> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_generalopportunityfile> ;
#     rdfs:range <http://example.org/ontology#GeographicCriterion> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile/relatedToGeographicCriterion> .
#
# <http://example.org/ontology#relatedToGridID> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_generalopportunityfile> ;
#     rdfs:range <http://example.org/ontology#grid_id> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile/relatedToGridID> .
#
# <http://example.org/ontology#relatedToOpportunity> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#GranterGeneralOpportunityFile>,
#         <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range <http://example.org/ontology#GranterOpportunity>,
#         <http://example.org/ontology#granter_timeline> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile/relatedToOpportunity>,
#         <http://example.org/provenance/granter_opportunity/hasTimeline> .
#
# <http://example.org/ontology#relatedToPersonLocation> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_generalopportunityfile> ;
#     rdfs:range <http://example.org/ontology#person_location> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile/relatedToPersonLocation> .
#
# <http://example.org/ontology#relatedToTable> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_company>,
#         <http://example.org/ontology#granter_companyfile> ;
#     rdfs:range <http://example.org/ontology#RelatedTable> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company/related_table>,
#         <http://example.org/provenance/granter_companyfile/related_table> .
#
# <http://example.org/ontology#relatesToCompany> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#GranterPartner> ;
#     rdfs:range <http://example.org/ontology#GranterCompany> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartner/relates_to_company> .
#
# <http://example.org/ontology#relatesToConsortium> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#GranterPartner> ;
#     rdfs:range <http://example.org/ontology#GranterConsortium> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartner/relates_to_consortium> .
#
# <http://example.org/ontology#relatesToPartnerType> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#GranterPartner> ;
#     rdfs:range <http://example.org/ontology#GranterPartnerType> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartner/relates_to_partner_type> .
#
# <http://example.org/ontology#relates_to_company> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_matchgroup> ;
#     rdfs:range <http://example.org/ontology#granter_company> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_matchgroup/company> .
#
# <http://example.org/ontology#relates_to_granter_opportunity> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium>,
#         <http://example.org/ontology#granter_generalopportunityfile_opportunities> ;
#     rdfs:range <http://example.org/ontology#granter_opportunity> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium/foreign_key_opportunity>,
#         <http://example.org/provenance/granter_generalopportunityfile_opportunities/relates_to_granter_opportunity> .
#
# <http://example.org/ontology#relates_to_granter_opportunityfile> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_generalopportunityfile_opportunities> ;
#     rdfs:range <http://example.org/ontology#granter_opportunityfile> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile_opportunities/relates_to_granter_opportunityfile> .
#
# <http://example.org/ontology#relates_to_opportunity> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_matchgroup> ;
#     rdfs:range <http://example.org/ontology#granter_opportunity> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_matchgroup/opportunity> .
#
# <http://example.org/ontology#relates_to_table> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_consortium_part_type> ;
#     rdfs:range <http://example.org/ontology#RelatedTable> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype/fk_column> .
#
# <http://example.org/ontology#residence_country> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#person_location> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/person_location/country> .
#
# <http://example.org/ontology#saleConfirmed> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterApplication> ;
#     rdfs:range xsd:boolean ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/sale_confirmed> .
#
# <http://example.org/ontology#smallCoverImage> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:anyURI ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/small_cover_image> .
#
# <http://example.org/ontology#state> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/state> .
#
# <http://example.org/ontology#successFee> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterApplication>,
#         <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/success_fee>,
#         <http://example.org/provenance/granter_opportunity/success_fee> .
#
# <http://example.org/ontology#successPaymentAmount> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterApplication> ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/success_payment_amount> .
#
# <http://example.org/ontology#tagsFundamentation> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/tags_fundamentation> .
#
# <http://example.org/ontology#targets_audience> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#Criterion> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/criterion_targets> .
#
# <http://example.org/ontology#type> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/type> .
#
# <http://example.org/ontology#updatedAt> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterApplication>,
#         <http://example.org/ontology#GranterPartner>,
#         <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:dateTime ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/updated_at>,
#         <http://example.org/provenance/granter_consortiumpartner/updated_at>,
#         <http://example.org/provenance/granter_opportunity/updated_at> .
#
# <http://example.org/ontology#upfrontFee> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/upfront_fee> .
#
# <http://example.org/ontology#upfrontPaymentAmount> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterApplication> ;
#     rdfs:range xsd:decimal ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/upfront_payment_amount> .
#
# <http://example.org/ontology#uploadedByProfile> a owl:ObjectProperty ;
#     rdfs:domain <http://example.org/ontology#granter_companyfile> ;
#     rdfs:range <http://example.org/ontology#granter_profile> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile/relationship> .
#
# <http://example.org/ontology#url> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_opportunity> ;
#     rdfs:range xsd:anyURI ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity/url> .
#
# <http://example.org/ontology#vector_indexed> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#granter_applicationfile> ;
#     rdfs:range xsd:boolean ;
#     prov:wasDerivedFrom <http://provenance.example.org/granter_applicationfile/column_vector_indexed> .
#
# <http://example.org/ontology#writerMode> a owl:DatatypeProperty ;
#     rdfs:domain <http://example.org/ontology#GranterApplication> ;
#     rdfs:range xsd:string ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application/writer_mode> .
#
# <http://example.org/ontology#GeographicCriterion> a owl:Class .
#
# <http://example.org/ontology#Grant> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/grant> .
#
# <http://example.org/ontology#GrantShare> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/grant_share> .
#
# <http://example.org/ontology#GranterApplicationFile> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_applicationfile> .
#
# <http://example.org/ontology#agency_identifier> a owl:Class .
#
# <http://example.org/ontology#granterCompanyMemory> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companymemory> .
#
# <http://example.org/ontology#granterConsortium> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium> .
#
# <http://example.org/ontology#grid_id> a owl:Class .
#
# <http://example.org/ontology#Company> a owl:Class .
#
# <http://example.org/ontology#GranterCompanyFile> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile> .
#
# <http://example.org/ontology#RelatedTable> a owl:Class ;
#     rdfs:label "Related Table"@en ;
#     prov:wasDerivedFrom <http://example.org/provenance/related_table> .
#
# <http://example.org/ontology#granter_profile> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_profile> .
#
# <http://example.org/ontology#person_location> a owl:Class ;
#     rdfs:subClassOf <http://example.org/ontology#Criterion> ;
#     prov:wasDerivedFrom <http://example.org/provenance/person_location> .
#
# <http://example.org/ontology#GranterCompany> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company> .
#
# <http://example.org/ontology#GranterOpportunityFile> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunityfile> .
#
# <http://example.org/ontology#GranterGeneralOpportunityFile> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile> .
#
# <http://example.org/ontology#granter_company> a owl:Class ;
#     rdfs:subClassOf <http://example.org/ontology#Company> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_company> .
#
# <http://example.org/ontology#Criterion> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/Criterion> .
#
# <http://example.org/ontology#GranterOpportunity> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity> .
#
# <http://example.org/ontology#granter_eligibilitycriteria> a owl:Class ;
#     rdfs:subClassOf <http://example.org/ontology#Criterion> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_eligibilitycriteria> .
#
# <http://example.org/ontology#granter_matchcheck> a owl:Class ;
#     rdfs:subClassOf <http://example.org/ontology#owl:Thing> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_matchcheck> .
#
# <http://example.org/ontology#granter_applicationfile> a owl:Class ;
#     prov:wasDerivedFrom <http://provenance.example.org/granter_applicationfile> .
#
# <http://example.org/ontology#granter_generalopportunityfile_opportunities> a owl:Class ;
#     rdfs:subClassOf <http://example.org/ontology#granter_generalopportunityfile> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile_opportunities> .
#
# <http://example.org/ontology#GranterPartner> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartner> .
#
# <http://example.org/ontology#granter_companymemory> a owl:Class ;
#     rdfs:subClassOf <http://example.org/ontology#Company> ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companymemory> .
#
# <http://example.org/ontology#granter_matchgroup> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_matchgroup> .
#
# <http://example.org/ontology#granter_consortium> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortium> .
#
# <http://example.org/ontology#granter_timeline> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_timeline> .
#
# <http://example.org/ontology#granter_consortium_part_type> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_consortiumpartnertype> .
#
# <http://example.org/ontology#granter_generalopportunityfile> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_generalopportunityfile> .
#
# <http://example.org/ontology#GranterApplication> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_application> .
#
# <http://example.org/ontology#granter_companyfile> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_companyfile> .
#
# <http://example.org/ontology#granter_opportunity> a owl:Class ;
#     prov:wasDerivedFrom <http://example.org/provenance/granter_opportunity> .

# %%
def save_and_validate_ttl(ontology_string: str, filename: str = None):
    """
    Save ontology string as .ttl file with validation
    """
    # Validate first
    is_valid, error = validate_turtle_string(ontology_string)
    if not is_valid:
        print(f"Invalid Turtle syntax: {error}")
        return None
    
    output_dir = "../../output/ontologies/RDB"
    os.makedirs(output_dir, exist_ok=True)
    filepath = os.path.join(output_dir, filename)
    
    try:
        g = Graph()
        g.parse(data=ontology_string, format="turtle")
        g.serialize(destination=filepath, format="turtle")
        
        print(f"Ontology saved: {filename}")
        print(f"{len(g)} triples")
        print(f"{os.path.getsize(filepath):,} bytes")
        return filepath
    except Exception as e:
        print(f"Save failed: {e}")
        return None

save_and_validate_ttl(core_ontology, 'rigor_ontology.ttl')
# Out:
# Ontology saved: rigor_ontology.ttl
# 951 triples
# 66,568 bytes
# '../../output/ontologies/RDB\\rigor_ontology.ttl'
