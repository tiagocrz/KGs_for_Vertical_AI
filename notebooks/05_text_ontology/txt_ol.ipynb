# %%
import nltk
from nltk import sent_tokenize
from typing import List
from rdflib import Graph

from langchain_openai import AzureChatOpenAI
import os
from dotenv import load_dotenv
load_dotenv()

gpt41_nano = AzureChatOpenAI(
    azure_deployment = os.getenv("AZURE_DEPLOYMENT_GPT41_NANO"),
    api_version = os.getenv("AZURE_OPENAI_API_VERSION"),
    azure_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT"),
    api_key = os.getenv("AZURE_OPENAI_API_KEY"),
    temperature = 0.3
)
# Out:
# c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
prompt_c_step_1 = "Extract classes in ttl format from the following text, only return the created ttl code. Make sure to label all classes as of type rdfs:Class: \n\n"


prompt_c_step_2 = """Extract individuals and relations in ttl format from the following sentence, based on the given classes.
Only return the ttl code, include the classes, individuals, and relations in this sentence. 
Make sure to label all classes as of rdfs:Class, all individuals as owl:NamedIndividual, and all properties as owl:ObjectProperty, owl:DatatypeProperty, or owl:AnnotationProperty: """

prompt_c_step_2 = """Extract individuals and relations in ttl format from the following sentence, based on the given classes.
Only return the ttl code, include the classes, individuals, and relations in this sentence. 
Make sure to label all classes as of rdfs:Class, all individuals as owl:NamedIndividual, and all properties as owl:ObjectProperty, owl:DatatypeProperty, or owl:AnnotationProperty. 

Follow correct Turtle syntax:
- Use ';' to separate multiple predicates for the same subject.
- Use ',' to separate multiple objects of the same predicate.
- End each subject block with '.' before starting a new subject.
- Do not switch subjects inside the same ';' chain.
"""

# %%
# ---------------------------------- TOOLS ----------------------------------

nltk.download('punkt')
def read_text_file(file: str) -> list:
    """
    Read a text file and return a list of sentences.
    """
    with open(file, 'r', encoding='utf-8') as file:
        text = file.read()
        sentences = nltk.sent_tokenize(text, language='portuguese')
    return sentences




def get_azure_response(text, prompt, ontology_info=None):
    """Get response from Azure OpenAI"""
    if ontology_info is None:
        message_content = f"{prompt}{text}"
    else:
        # Convert ontology_info list to string if needed
        if isinstance(ontology_info, list):
            ontology_info = "\n".join(ontology_info)
        message_content = f"{prompt} {text}, {ontology_info}"

    response = gpt41_nano.invoke(message_content)
    
    return response.content




def get_results_from_response(response_content: str) -> List[str]:
    """Extract results from Azure OpenAI response content"""
    standard_prefixes = [
        "@prefix : <http://example.org#> .",
        "@prefix owl: <http://www.w3.org/2002/07/owl#> .",
        "@prefix prov: <http://www.w3.org/ns/prov#> .",
        "@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .",
        "@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .",
        "@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> ."
    ]
    try:
        response_content = response_content.split('\n')
        response_content = [line for line in response_content if not any(line.strip().startswith(prefix) 
                                                                         for prefix in standard_prefixes)]
        
        while '' in response_content: 
            response_content.remove('')
        while '```ttl' in response_content:
            response_content.remove('```ttl')
        while '```' in response_content:
            response_content.remove('```')
        return response_content
    except Exception as e:
        print(f'Error processing response: {e}')
        return []
    


#def clean_relations(relations: List):
#    ttl_output = []
#    for relation in relations:
#        for triple in relation:
#            if triple:
#                cleaned_triple = triple.strip().strip('```').strip("ttl").strip("```")
#                ttl_output.append(cleaned_triple)
#    return ttl_output
#
#
#                
#
#def gpt_results_to_ttl(relations: List):
#    ttl_output = "\n".join(clean_relations(relations))
#    return ttl_output




def gpt_results_to_ttl(relations: List, output: str):
    ttl_output = []
    clean_relations(relations, ttl_output)

    with open(output, 'w', encoding='utf-8') as f:
        f.write("\n".join(ttl_output))
        
    return "\n".join(ttl_output)


def clean_relations(relations, ttl_output):
    for relation in relations:
        for triple in relation:
            if triple:
                cleaned_triple = triple.strip().strip('```').strip("ttl").strip("```")
                ttl_output.append(cleaned_triple)




def validate_turtle_string(turtle_str: str) -> tuple[bool, str]:
    """
    Validates whether the input string is valid Turtle syntax.

    Returns:
        - is_valid (bool): True if valid, False otherwise
        - error_msg (str): Error message if invalid, else empty
    """
    try:
        g = Graph()
        g.parse(data=turtle_str, format="turtle")
        return True, ""
    except Exception as e:
        return False, str(e)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\tiago\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# ACABAR DE MUDAR O PROMPT
def build_validation_prompt(results, error_message) -> str:
        
    prompt_validator = f"""
    You are an expert in turtle ontology modeling and validation.
    Your task is to review the following generated ontology, and correct the syntax issues present.

    [ONTOLOGY INFO]
    {results}

    [SYNTAX ISSUES DETECTED]

    Note: The delta ontology provided is NOT valid Turtle syntax.

    Please make the following minimal syntax corrections before further validation:
    - Use angle brackets <...> for all full IRI references.
    - Each property must have exactly one rdfs:domain and one rdfs:range.
    - Ensure rdfs:range only uses valid OWL classes or XSD types (e.g., xsd:string).
    - Remove annotation-style keywords like 'Annotations:' and instead use Turtle triples for metadata.
    - Avoid misplaced punctuation or unclosed blocks.

    Parsing error: {error_message}

    [VALIDATION CRITERIA]
    **Syntactic Validity**  
    - The ontology must conform to valid Turtle/RDF syntax.
    - Use proper prefixes and IRI declarations.
    - Exactly one rdfs:domain and one rdfs:range per property.

    [YOUR TASK]
    - Check the ontology against the criteria above.
    - If issues are found, provide a corrected version of the given ontology in valid Turtle syntax.
    - Make minimal necessary changes to preserve the author's intent while ensuring correctness and turtle compliance.
    - The generated ontology does not have any declared prefixes purposely, so do NOT add any.

    [OUTPUT FORMAT]
    Respond ONLY with a corrected Turtle syntax version of the exact same ontology.
    Do NOT include any other commentary outside this format.
    Do NOT reduce the ontology content. Make only syntax adjustments.
    """
    return prompt_validator

# %%
def extract_ontology_block(text: str) -> str:
    inside_block = False
    lines = []
    
    for line in text.splitlines():
        if line.strip().startswith("```"):
            if inside_block:
                break  # end of block
            else:
                inside_block = True
                continue  # skip the line with ```
        if inside_block:
            lines.append(line)
    
    return "\n".join(lines).strip()




def save_and_validate_ttl(ontology_string: str, filename: str = None):
    """
    Save ontology string as .ttl file with validation
    """
    is_valid, error = validate_turtle_string(ontology_string)
    if not is_valid:
        print(f"Invalid Turtle syntax: {error}")
        return None
    
    output_dir = "output/ontologies/text"
    os.makedirs(output_dir, exist_ok=True)
    filepath = os.path.join(output_dir, filename)
    
    try:
        g = Graph()
        g.parse(data=ontology_string, format="turtle")
        g.serialize(destination=filepath, format="turtle")
        
        print(f"Ontology saved: {filename}")
        print(f"{len(g)} triples")
        print(f"{os.path.getsize(filepath):,} bytes")
        return filepath
    except Exception as e:
        print(f"Save failed: {e}")
        return None




def query_azure_gpt(text: list):
    """Query Azure GPT with the text"""
    relations = []

    try:
        response_1 = get_azure_response(text, prompt_c_step_1)
        
        for sentence in text:
            response_2 = get_azure_response(sentence, prompt_c_step_2, get_results_from_response(response_1))
            relations.append(get_results_from_response(response_2))

    except Exception as e:
        print(f"Error querying Azure GPT: {e}")
        return []

    print(f"Extracted {len(relations)} relation sets")
    return relations

# %% [markdown]
# # Running

# %%
import os
os.chdir('../..')

# %%
text = read_text_file('data/texts/application_example.txt')

# Classes
response_1 = get_azure_response(text, prompt_c_step_1)
print(response_1)
# Out:
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# :VouchersParaStartups a rdfs:Class .
#
# :AtividadeEconómicaPrincipal doBeneficiário a rdfs:Class .
#
# :Projeto a rdfs:Class .
#
# :AgenteDeIA a rdfs:Class .
#
# :FerramentaDeCandidatura a rdfs:Class .
#
# :MetodologiasDeIA a rdfs:Class .
#
# :ModeloDeNegocio a rdfs:Class .
#
# :EquipeDeGestao a rdfs:Class .
#
# :LiderancaDoProjeto a rdfs:Class .
#
# :Tecnologia e Desenvolvimento a rdfs:Class .
#
# :ImpactoECompetitividade a rdfs:Class .
#
# :PropostaDeValor a rdfs:Class .
#
# :ProdutoDigital a rdfs:Class .
#
# :Investimentos a rdfs:Class .
#
# :CustosComRecursosHumanos a rdfs:Class .
#
# :Certificacoes a rdfs:Class .
#
# :ServicosExternos a rdfs:Class .
#
# :Equipamentos a rdfs:Class .
#
# :PropriedadeIntelectual a rdfs:Class .

# %%
standard_prefixes = [
        "@prefix : <http://example.org#> .",
        "@prefix owl: <http://www.w3.org/2002/07/owl#> .",
        "@prefix prov: <http://www.w3.org/ns/prov#> .",
        "@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .",
        "@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .",
        "@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> ."
    ]

# Relations and Individuals
unsuccessful = []
relations = []
for i, sentence in enumerate(text):
    print(f"Processing sentence {i+1}/{len(text)}")
    response_2 = get_azure_response(sentence, prompt_c_step_2, 
                                    get_results_from_response(response_1))
    response_2_with_prefixes = ("\n".join(standard_prefixes) + 
                                "\n" + 
                                "\n".join(get_results_from_response(response_2)))

    is_valid, error_message = validate_turtle_string(response_2_with_prefixes)
    print(is_valid)

    retry_count = 0
    max_retries = 3
    while is_valid == False and retry_count < max_retries:
        print(f"Retrying attempt {retry_count+1}/{max_retries} to response {i+1} due to error: {error_message}")

        fix = gpt41_nano.invoke(build_validation_prompt(response_2_with_prefixes,  
                                                    error_message)).content
        retry_count += 1
        is_valid, error_message = validate_turtle_string(fix)

    if is_valid:
        print(f"Successfully validated response {i+1} after {retry_count} attempts.")
        relations.append(get_results_from_response(response_2))
    else:
        print(f"Failed to correct response {i+1} after {retry_count} attempts. Skipping.")
        unsuccessful.append((i, sentence))
        continue
    
print(f"Successfully processed {len(text) - len(unsuccessful)} sentences.\n\nUnsuccessful sentences: {[text[i] for i, _ in unsuccessful]}")
# Out:
# Processing sentence 1/125
# False
# Retrying attempt 1/3 to response 1 due to error: at line 8 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b'ersParaStartups a rdfs:Class .\n:AtividadeEcon\xc3\xb3micaPrincipal'^b' doBenefici\xc3\xa1rio a rdfs:Class .\n:Projeto a rdfs:Class .\n:Age'..."
# Successfully validated response 1 after 1 attempts.
# Processing sentence 2/125
# True
# Successfully validated response 2 after 0 attempts.
# Processing sentence 3/125
# True
# Successfully validated response 3 after 0 attempts.
# Processing sentence 4/125
# True
# Successfully validated response 4 after 0 attempts.
# Processing sentence 5/125
# True
# Successfully validated response 5 after 0 attempts.
# Processing sentence 6/125
# False
# Retrying attempt 1/3 to response 6 due to error: at line 31 of <>:
# Bad syntax (objectList expected) at ^ in:
# "...b'ty .\n:ElaboracaoDeCandidaturas a owl:ObjectProperty .\n:Para '^b'a utiliza\xc3\xa7\xc3\xa3o por parte das empresas na elabora\xc3\xa7\xc3\xa3o de can'..."
# Successfully validated response 6 after 1 attempts.
# Processing sentence 7/125
# False
# Retrying attempt 1/3 to response 7 due to error: at line 16 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b' rdfs:Class .\n:LiderancaDoProjeto a rdfs:Class .\n:Tecnologia'^b' e Desenvolvimento a rdfs:Class .\n:ImpactoECompetitividade a'..."
# Successfully validated response 7 after 1 attempts.
# Processing sentence 8/125
# False
# Retrying attempt 1/3 to response 8 due to error: at line 17 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b' rdfs:Class .\n:LiderancaDoProjeto a rdfs:Class .\n:Tecnologia'^b' e Desenvolvimento a rdfs:Class .\n:ImpactoECompetitividade a'..."
# Successfully validated response 8 after 1 attempts.
# Processing sentence 9/125
# False
# Retrying attempt 1/3 to response 9 due to error: at line 39 of <>:
# Bad syntax (expected directive or statement) at ^ in:
# "...b':ObjectProperty .\n:relatedIndividuals a owl:ObjectProperty .'^b'\n// Example individuals (if needed, otherwise only classes a'..."
# Retrying attempt 2/3 to response 9 due to error: at line 76 of <>:
# Bad syntax (expected directive or statement) at ^ in:
# "...b'erty ;\n    rdfs:domain :Projeto ;\n    rdfs:range :Projeto .\n'^b'\n// Example individuals (if needed, otherwise only classes a'..."
# Retrying attempt 3/3 to response 9 due to error: at line 76 of <>:
# Bad syntax (expected directive or statement) at ^ in:
# "...b'erty ;\n    rdfs:domain :Projeto ;\n    rdfs:range :Projeto .\n'^b'\n// Example individuals (if needed, otherwise only classes a'..."
# Failed to correct response 9 after 3 attempts. Skipping.
# Processing sentence 10/125
# True
# Successfully validated response 10 after 0 attempts.
# Processing sentence 11/125
# False
# Retrying attempt 1/3 to response 11 due to error: at line 17 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b' rdfs:Class .\n:LiderancaDoProjeto a rdfs:Class .\n:Tecnologia'^b' e Desenvolvimento a rdfs:Class .\n:ImpactoECompetitividade a'..."
# Successfully validated response 11 after 1 attempts.
# Processing sentence 12/125
# False
# Retrying attempt 1/3 to response 12 due to error: at line 41 of <>:
# Bad syntax (objectList expected) at ^ in:
# "...b'ectProperty .\n:financiamentoDe a owl:ObjectProperty .\n:para '^b'a a owl:AnnotationProperty .\n:parteDe a owl:ObjectProperty .'..."
# Successfully validated response 12 after 1 attempts.
# Processing sentence 13/125
# False
# Retrying attempt 1/3 to response 13 due to error: at line 51 of <>:
# Bad syntax (objectList expected) at ^ in:
# "...b'arMetodologias a :agregarMetodologias .\n:AgenteDeIA :agenteD'^b'eIA .\n:GANs :GANs .\n:AdvICL :AdvICL .\n:geracaoDeConteudos :g'..."
# Successfully validated response 13 after 1 attempts.
# Processing sentence 14/125
# False
# Retrying attempt 1/3 to response 14 due to error: at line 17 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b' rdfs:Class .\n:LiderancaDoProjeto a rdfs:Class .\n:Tecnologia'^b' e Desenvolvimento a rdfs:Class .\n:ImpactoECompetitividade a'..."
# Successfully validated response 14 after 1 attempts.
# Processing sentence 15/125
# False
# Retrying attempt 1/3 to response 15 due to error: at line 66 of <>:
# Bad syntax (expected directive or statement) at ^ in:
# "...b'8 a :Equipamentos .\n:individual19 a :PropriedadeIntelectual '^b'.\n; hasName "VouchersParaStartups" .\n; hasType "Program" .\n;'..."
# Successfully validated response 15 after 1 attempts.
# Processing sentence 16/125
# False
# Retrying attempt 1/3 to response 16 due to error: at line 17 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b' rdfs:Class .\n:LiderancaDoProjeto a rdfs:Class .\n:Tecnologia'^b' e Desenvolvimento a rdfs:Class .\n:ImpactoECompetitividade a'..."
# Successfully validated response 16 after 1 attempts.
# Processing sentence 17/125
# True
# Successfully validated response 17 after 0 attempts.
# Processing sentence 18/125
# False
# Retrying attempt 1/3 to response 18 due to error: at line 48 of <>:
# Bad syntax (objectList expected) at ^ in:
# "...b'entaDeCandidatura a owl:NamedIndividual .\n:GranTer :perspect'^b'iva ;\n  :ateAoFinalDe "2025" .\n:GranTer :entradaEmMercados :'..."
# Retrying attempt 2/3 to response 18 due to error: at line 80 of <>:
# Bad syntax (objectList expected) at ^ in:
# "...b'ntaDeCandidatura a owl:NamedIndividual .\n\n:GranTer :perspect'^b'iva ;\n  :ateAoFinalDe "2025" .\n\n:GranTer :entradaEmMercados '..."
# Retrying attempt 3/3 to response 18 due to error: at line 80 of <>:
# Bad syntax (objectList expected) at ^ in:
# "...b'ntaDeCandidatura a owl:NamedIndividual .\n\n:GranTer :perspect'^b'iva ;\n  :ateAoFinalDe "2025" .\n\n:GranTer :entradaEmMercados '..."
# Failed to correct response 18 after 3 attempts. Skipping.
# Processing sentence 19/125
# False
# Retrying attempt 1/3 to response 19 due to error: at line 9 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b'ersParaStartups a rdfs:Class .\n:AtividadeEcon\xc3\xb3micaPrincipal'^b' doBenefici\xc3\xa1rio a rdfs:Class .\n:Projeto a rdfs:Class .\n:Age'..."
# Retrying attempt 2/3 to response 19 due to error: at line 10 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b'rsParaStartups a rdfs:Class .\n\n:AtividadeEcon\xc3\xb3micaPrincipal'^b' doBenefici\xc3\xa1rio a rdfs:Class .\n\n:Projeto a rdfs:Class .\n\n:A'..."
# Retrying attempt 3/3 to response 19 due to error: at line 10 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b'rsParaStartups a rdfs:Class .\n\n:AtividadeEcon\xc3\xb3micaPrincipal'^b' doBenefici\xc3\xa1rio a rdfs:Class .\n\n:Projeto a rdfs:Class .\n\n:A'..."
# Failed to correct response 19 after 3 attempts. Skipping.
# Processing sentence 20/125
# False
# Retrying attempt 1/3 to response 20 due to error: at line 9 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b'ersParaStartups a rdfs:Class .\n:AtividadeEcon\xc3\xb3micaPrincipal'^b' doBenefici\xc3\xa1rio a rdfs:Class .\n:Projeto a rdfs:Class .\n:Age'..."
# Retrying attempt 2/3 to response 20 due to error: at line 9 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b'ersParaStartups a rdfs:Class .\n:AtividadeEcon\xc3\xb3micaPrincipal'^b' doBenefici\xc3\xa1rio a rdfs:Class .\n:Projeto a rdfs:Class .\n:Age'..."
# Retrying attempt 3/3 to response 20 due to error: at line 10 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b'rsParaStartups a rdfs:Class .\n\n:AtividadeEcon\xc3\xb3micaPrincipal'^b' doBenefici\xc3\xa1rio a rdfs:Class .\n\n:Projeto a rdfs:Class .\n\n:A'..."
# Failed to correct response 20 after 3 attempts. Skipping.
# Processing sentence 21/125
# True
# Successfully validated response 21 after 0 attempts.
# Processing sentence 22/125
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#date, Converter=<function parse_xsd_date at 0x000001DF95238EA0>
# Traceback (most recent call last):
#   File "c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\rdflib\term.py", line 2163, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#            ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\rdflib\xsd_datetime.py", line 593, in parse_xsd_date
#     return parse_date(date_string if not minus else ("-" + date_string))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: Invalid isoformat string: '2024-12'
# True
# Successfully validated response 22 after 0 attempts.
# Processing sentence 23/125
# True
# Successfully validated response 23 after 0 attempts.
# Processing sentence 24/125
# True
# Successfully validated response 24 after 0 attempts.
# Processing sentence 25/125
# False
# Retrying attempt 1/3 to response 25 due to error: at line 41 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b'moEntidadeCompetente a owl:NamedIndividual .\n:AtividadesDeID'^b' na :Empresa a :AtividadeEcon\xc3\xb3micaPrincipal .\n# Relations\n:'..."
# Retrying attempt 2/3 to response 25 due to error: at line 49 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b'oEntidadeCompetente a owl:NamedIndividual .\n\n:AtividadesDeID'^b' na :Empresa a :AtividadeEcon\xc3\xb3micaPrincipal .\n\n# Relations\n'..."
# Retrying attempt 3/3 to response 25 due to error: at line 49 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b'oEntidadeCompetente a owl:NamedIndividual .\n\n:AtividadesDeID'^b' na :Empresa a :AtividadeEcon\xc3\xb3micaPrincipal .\n\n# Relations\n'..."
# Failed to correct response 25 after 3 attempts. Skipping.
# Processing sentence 26/125
# False
# Retrying attempt 1/3 to response 26 due to error: at line 9 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b'ersParaStartups a rdfs:Class .\n:AtividadeEcon\xc3\xb3micaPrincipal'^b' doBenefici\xc3\xa1rio a rdfs:Class .\n:Projeto a rdfs:Class .\n:Age'..."
# Retrying attempt 2/3 to response 26 due to error: at line 9 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b'ersParaStartups a rdfs:Class .\n:AtividadeEcon\xc3\xb3micaPrincipal'^b' doBenefici\xc3\xa1rio a rdfs:Class .\n:Projeto a rdfs:Class .\n:Age'..."
# Retrying attempt 3/3 to response 26 due to error: at line 9 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b'ersParaStartups a rdfs:Class .\n:AtividadeEcon\xc3\xb3micaPrincipal'^b' doBenefici\xc3\xa1rio a rdfs:Class .\n:Projeto a rdfs:Class .\n:Age'..."
# Failed to correct response 26 after 3 attempts. Skipping.
# Processing sentence 27/125
# True
# Successfully validated response 27 after 0 attempts.
# Processing sentence 28/125
# False
# Retrying attempt 1/3 to response 28 due to error: at line 9 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b'ersParaStartups a rdfs:Class .\n:AtividadeEcon\xc3\xb3micaPrincipal'^b' doBenefici\xc3\xa1rio a rdfs:Class .\n:Projeto a rdfs:Class .\n:Age'..."
# Retrying attempt 2/3 to response 28 due to error: at line 9 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b'ersParaStartups a rdfs:Class .\n:AtividadeEcon\xc3\xb3micaPrincipal'^b' doBenefici\xc3\xa1rio a rdfs:Class .\n:Projeto a rdfs:Class .\n:Age'..."
# Retrying attempt 3/3 to response 28 due to error: at line 9 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b'ersParaStartups a rdfs:Class .\n:AtividadeEcon\xc3\xb3micaPrincipal'^b' doBenefici\xc3\xa1rio a rdfs:Class .\n:Projeto a rdfs:Class .\n:Age'..."
# Failed to correct response 28 after 3 attempts. Skipping.
# Processing sentence 29/125
# False
# Retrying attempt 1/3 to response 29 due to error: at line 32 of <>:
# Bad syntax (objectList expected) at ^ in:
# "...b'l:ObjectProperty .\n:compromisso a owl:ObjectProperty .\n:com '^b'a a owl:ObjectProperty .\n:producao a owl:ObjectProperty .\n:s'..."
# Successfully validated response 29 after 1 attempts.
# Processing sentence 30/125
# True
# Successfully validated response 30 after 0 attempts.
# Processing sentence 31/125
# False
# Retrying attempt 1/3 to response 31 due to error: at line 27 of <>:
# Bad syntax (objectList expected) at ^ in:
# "...b'dfs:Class .\n:PropriedadeIntelectual a rdfs:Class .\n:confere '^b'a a owl:ObjectProperty .\n:projeto a owl:ObjectProperty .\n:gr'..."
# Successfully validated response 31 after 1 attempts.
# Processing sentence 32/125
# False
# Retrying attempt 1/3 to response 32 due to error: at line 57 of <>:
# Bad syntax (Prefix "ex:" not bound) at ^ in:
# "...b'opriedadeIntelectual .\n:ex:effort a owl:NamedIndividual ;\n  '^b'  ex:orientadoPara ex:solucaoRobusta ;\n    ex:respondeA ex:u'..."
# Retrying attempt 2/3 to response 32 due to error: at line 81 of <>:
# Bad syntax (Prefix "ex:" not bound) at ^ in:
# "...b'priedadeIntelectual .\n\n:ex:effort a owl:NamedIndividual ;\n  '^b'  ex:orientadoPara ex:solucaoRobusta ;\n    ex:respondeA ex:u'..."
# Retrying attempt 3/3 to response 32 due to error: at line 81 of <>:
# Bad syntax (Prefix "ex:" not bound) at ^ in:
# "...b'priedadeIntelectual .\n\n:ex:effort a owl:NamedIndividual ;\n  '^b'  ex:orientadoPara ex:solucaoRobusta ;\n    ex:respondeA ex:u'..."
# Failed to correct response 32 after 3 attempts. Skipping.
# Processing sentence 33/125
# False
# Retrying attempt 1/3 to response 33 due to error: at line 9 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b'ersParaStartups a rdfs:Class .\n:AtividadeEcon\xc3\xb3micaPrincipal'^b' doBenefici\xc3\xa1rio a rdfs:Class .\n:Projeto a rdfs:Class .\n:Age'..."
# Retrying attempt 2/3 to response 33 due to error: at line 10 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b'rsParaStartups a rdfs:Class .\n\n:AtividadeEcon\xc3\xb3micaPrincipal'^b' doBenefici\xc3\xa1rio a rdfs:Class .\n\n:Projeto a rdfs:Class .\n\n:A'..."
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 29
#      26 while is_valid == False and retry_count < max_retries:
#      27     print(f"Retrying attempt {retry_count+1}/{max_retries} to response {i+1} due to error: {error_message}")
# ---> 29     fix = gpt41_nano.invoke(build_validation_prompt(response_2_with_prefixes,
#      30                                                 error_message)).content
#      31     retry_count += 1
#      32     is_valid, error_message = validate_turtle_string(fix)
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\langchain_core\language_models\chat_models.py:383, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     371 @override
#     372 def invoke(
#     373     self,
#    (...)    378     **kwargs: Any,
#     379 ) -> BaseMessage:
#     380     config = ensure_config(config)
#     381     return cast(
#     382         "ChatGeneration",
# --> 383         self.generate_prompt(
#     384             [self._convert_input(input)],
#     385             stop=stop,
#     386             callbacks=config.get("callbacks"),
#     387             tags=config.get("tags"),
#     388             metadata=config.get("metadata"),
#     389             run_name=config.get("run_name"),
#     390             run_id=config.pop("run_id", None),
#     391             **kwargs,
#     392         ).generations[0][0],
#     393     ).message
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\langchain_core\language_models\chat_models.py:1006, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     997 @override
#     998 def generate_prompt(
#     999     self,
#    (...)   1003     **kwargs: Any,
#    1004 ) -> LLMResult:
#    1005     prompt_messages = [p.to_messages() for p in prompts]
# -> 1006     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\langchain_core\language_models\chat_models.py:825, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     822 for i, m in enumerate(input_messages):
#     823     try:
#     824         results.append(
# --> 825             self._generate_with_cache(
#     826                 m,
#     827                 stop=stop,
#     828                 run_manager=run_managers[i] if run_managers else None,
#     829                 **kwargs,
#     830             )
#     831         )
#     832     except BaseException as e:
#     833         if run_managers:
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\langchain_core\language_models\chat_models.py:1072, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1070     result = generate_from_stream(iter(chunks))
#    1071 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1072     result = self._generate(
#    1073         messages, stop=stop, run_manager=run_manager, **kwargs
#    1074     )
#    1075 else:
#    1076     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\langchain_openai\chat_models\base.py:1177, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1175     generation_info = {"headers": dict(raw_response.headers)}
#    1176 else:
# -> 1177     response = self.client.create(**payload)
#    1178 return self._create_chat_result(response, generation_info)
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\openai\resources\chat\completions\completions.py:1150, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1104 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1105 def create(
#    1106     self,
#    (...)   1147     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1148 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1149     validate_response_format(response_format)
# -> 1150     return self._post(
#    1151         "/chat/completions",
#    1152         body=maybe_transform(
#    1153             {
#    1154                 "messages": messages,
#    1155                 "model": model,
#    1156                 "audio": audio,
#    1157                 "frequency_penalty": frequency_penalty,
#    1158                 "function_call": function_call,
#    1159                 "functions": functions,
#    1160                 "logit_bias": logit_bias,
#    1161                 "logprobs": logprobs,
#    1162                 "max_completion_tokens": max_completion_tokens,
#    1163                 "max_tokens": max_tokens,
#    1164                 "metadata": metadata,
#    1165                 "modalities": modalities,
#    1166                 "n": n,
#    1167                 "parallel_tool_calls": parallel_tool_calls,
#    1168                 "prediction": prediction,
#    1169                 "presence_penalty": presence_penalty,
#    1170                 "prompt_cache_key": prompt_cache_key,
#    1171                 "reasoning_effort": reasoning_effort,
#    1172                 "response_format": response_format,
#    1173                 "safety_identifier": safety_identifier,
#    1174                 "seed": seed,
#    1175                 "service_tier": service_tier,
#    1176                 "stop": stop,
#    1177                 "store": store,
#    1178                 "stream": stream,
#    1179                 "stream_options": stream_options,
#    1180                 "temperature": temperature,
#    1181                 "tool_choice": tool_choice,
#    1182                 "tools": tools,
#    1183                 "top_logprobs": top_logprobs,
#    1184                 "top_p": top_p,
#    1185                 "user": user,
#    1186                 "verbosity": verbosity,
#    1187                 "web_search_options": web_search_options,
#    1188             },
#    1189             completion_create_params.CompletionCreateParamsStreaming
#    1190             if stream
#    1191             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1192         ),
#    1193         options=make_request_options(
#    1194             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1195         ),
#    1196         cast_to=ChatCompletion,
#    1197         stream=stream or False,
#    1198         stream_cls=Stream[ChatCompletionChunk],
#    1199     )
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\openai\_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     980 response = None
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#     988     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\ssl.py:1233, in SSLSocket.recv(self, buflen, flags)
#    1229     if flags != 0:
#    1230         raise ValueError(
#    1231             "non-zero flags not allowed in calls to recv() on %s" %
#    1232             self.__class__)
# -> 1233     return self.read(buflen)
#    1234 else:
#    1235     return super().recv(buflen, flags)
#
# File c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\ssl.py:1106, in SSLSocket.read(self, len, buffer)
#    1104         return self._sslobj.read(len, buffer)
#    1105     else:
# -> 1106         return self._sslobj.read(len)
#    1107 except SSLError as x:
#    1108     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
# ontology = gpt_results_to_ttl(relations)
ontology = gpt_results_to_ttl(relations, 'output/ontologies/text/text_ontology_val.txt')

#with open('output/ontologies/text/text_ontology_val.txt', 'r', encoding='utf-8') as f:
#    ontology = f.read()


# extra ...

# Add prefixes since gpt_results_to_ttl doesn't include them
ontology = "\n".join(standard_prefixes) + "\n\n" + ontology
# ... extra
print(ontology)

is_valid, error_message = validate_turtle_string(ontology)
filename = "text_ontology_val.ttl"

if is_valid:
    print("Final ontology is valid Turtle syntax.")
    save_and_validate_ttl(ontology, filename=filename)

else:
    print(f"Ontology is invalid: {error_message}")
    #current_ontology = ontology
    #for i in range(6):
    #    print(f"Attempt {i+1} to validate ontology")
    #    # validator_prompt = build_validation_prompt(current_ontology) 
    #    
    #    validator_prompt = build_merge_validation_prompt(relations)

    #    revision = gpt41_nano.invoke(validator_prompt).content
    #    current_ontology = extract_ontology_block(revision)
    #    print(current_ontology)
    #    is_valid, error_message = validate_turtle_string(current_ontology)
    #
    #    if is_valid:
    #        print("Final ontology is valid Turtle syntax.")
    #        save_and_validate_ttl(current_ontology, filename=filename)
    #        break
# Out:
# @prefix : <http://example.org#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
#
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal doBeneficiário a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :Tecnologia e Desenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# :GranterAI a owl:NamedIndividual ;
# a :AgenteDeIA .
# :Startups a owl:NamedIndividual ;
# a :VouchersParaStartups .
# :AtividadePrincipalGranter a owl:NamedIndividual ;
# a :AtividadeEconómicaPrincipal ;
# :pertenceA :GranterAI .
# :ProjetoInnovacao a owl:NamedIndividual ;
# a :Projeto .
# :TecnologiaIA a owl:NamedIndividual ;
# a :Tecnologia .
# :AplicacoesCandidaturas a owl:NamedIndividual ;
# a :FerramentaDeCandidatura .
# :MetodologiaIA a owl:NamedIndividual ;
# a :MetodologiasDeIA .
# :ModeloNegocioInnovador a owl:NamedIndividual ;
# a :ModeloDeNegocio .
# :EquipeGestao a owl:NamedIndividual ;
# a :EquipeDeGestao .
# :LiderProjetoX a owl:NamedIndividual ;
# a :LiderancaDoProjeto .
# :TecnologiaDesenvolvimentoX a owl:NamedIndividual ;
# a :Tecnologia .
# :ImpactoCompetitivoX a owl:NamedIndividual ;
# a :ImpactoECompetitividade .
# :PropostaValorX a owl:NamedIndividual ;
# a :PropostaDeValor .
# :ProdutoDigitalX a owl:NamedIndividual ;
# a :ProdutoDigital .
# :InvestimentosX a owl:NamedIndividual ;
# a :Investimentos .
# :CustosHumanosX a owl:NamedIndividual ;
# a :CustosComRecursosHumanos .
# :CertificacaoX a owl:NamedIndividual ;
# a :Certificacoes .
# :ServicosExternosX a owl:NamedIndividual ;
# a :ServicosExternos .
# :EquipamentoX a owl:NamedIndividual ;
# a :Equipamentos .
# :PropriedadeIntelectualX a owl:NamedIndividual ;
# a :PropriedadeIntelectual .
# :GranterAI :hasProjeto :ProjetoInnovacao ;
# :hasAtividadePrincipal :AtividadePrincipalGranter ;
# :hasTecnologia :TecnologiaIA ;
# :hasEquipe :EquipeGestao ;
# :hasLider :LiderProjetoX ;
# :hasImpacto :ImpactoCompetitivoX ;
# :hasValorProposto :PropostaValorX ;
# :hasProduto :ProdutoDigitalX ;
# :hasInvestimentos :InvestimentosX ;
# :hasCustosHumanos :CustosHumanosX ;
# :hasCertificacao :CertificacaoX ;
# :hasServicoExterno :ServicosExternosX ;
# :hasEquipamento :EquipamentoX ;
# :hasPropriedadeIntelectual :PropriedadeIntelectualX .
# # Relations
# :hasProjeto a owl:ObjectProperty .
# :hasAtividadePrincipal a owl:ObjectProperty .
# :hasTecnologia a owl:ObjectProperty .
# :hasEquipe a owl:ObjectProperty .
# :hasLider a owl:ObjectProperty .
# :hasImpacto a owl:ObjectProperty .
# :hasValorProposto a owl:ObjectProperty .
# :hasProduto a owl:ObjectProperty .
# :hasInvestimentos a owl:ObjectProperty .
# :hasCustosHumanos a owl:ObjectProperty .
# :hasCertificacao a owl:ObjectProperty .
# :hasServicoExterno a owl:ObjectProperty .
# :hasEquipamento a owl:ObjectProperty .
# :hasPropriedadeIntelectual a owl:ObjectProperty .
# @prefix : <http://example.org/> .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipalDoBeneficiário a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :TecnologiaEDesenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# :passaPelaCriacao a owl:ObjectProperty .
# :apoiarNaElaboracaoDeCandidaturas a owl:ObjectProperty .
# :integraAtividadesDeInvestigacaoEDesenvolvimento a owl:ObjectProperty .
# :incorporaMetodologiasAvancadas a owl:ObjectProperty .
# :permiteGerarConteudos a owl:ObjectProperty .
# :contextoDosClientes a owl:ObjectProperty .
# :projetoProposto a owl:NamedIndividual .
# :agenteIA1 a owl:NamedIndividual .
# :empresa1 a owl:NamedIndividual .
# :candidatura1 a owl:NamedIndividual .
# :programaDeFinanciamento1 a owl:NamedIndividual .
# :metodologiaGANs a owl:NamedIndividual .
# :metodologiaAdvICL a owl:NamedIndividual .
# :conteudoEspecializado1 a owl:NamedIndividual .
# :clienteX a owl:NamedIndividual .
# :atividadeInvestigacao1 a owl:NamedIndividual .
# :atividadeDesenvolvimentoTecnologico1 a owl:NamedIndividual .
# :projetoProposto :passaPelaCriacao :agenteIA1 .
# :agenteIA1 :apoiarNaElaboracaoDeCandidaturas :empresa1 .
# :empresa1 :passaPelaCriacao :candidatura1 .
# :candidatura1 :integrarAtividadesDeInvestigacaoEDesenvolvimento :atividadeInvestigacao1, :atividadeDesenvolvimentoTecnologico1 .
# :atividadeInvestigacao1 :incorporaMetodologiasAvancadas :metodologiaGANs .
# :atividadeDesenvolvimentoTecnologico1 :incorporaMetodologiasAvancadas :metodologiaAdvICL .
# :metodologiaGANs :permiteGerarConteudos :conteudoEspecializado1 .
# :metodologiaAdvICL :permiteGerarConteudos :conteudoEspecializado1 .
# :conteudoEspecializado1 :adaptadoAoContextoDe :clienteX .
# @prefix : <http://example.org/> .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :TecnologiaEDesenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# @prefix : <http://example.org/> .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :TecnologiaEDesenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# :adaptação a owl:ObjectProperty .
# :mercados a owl:ObjectProperty .
# :ênfaseNaAutomação a owl:ObjectProperty .
# :setorDeAltaIntensidadeTecnológica a owl:Class .
# :potencialDeCrescimento a owl:DatatypeProperty .
# :enquadramento a owl:ObjectProperty .
# :sectorDeAltaIntensidadeTecnológica a owl:NamedIndividual .
# :potencialDeCrescimentoValue a xsd:float .
# :enquadramentoValue a owl:NamedIndividual .
# # Individuals (if any specific individuals are to be defined, they would be added here)
# @prefix : <http://example.org/> .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :TecnologiaEDesenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# :ResumoDoProjeto a owl:AnnotationProperty .
# :limite a owl:DatatypeProperty .
# :ResumoDoProjeto a owl:NamedIndividual .
# :ResumoDoProjeto a :Projeto .
# :ResumoDoProjeto :limite "1000"^^xsd:integer .
# :GranteraAI a owl:NamedIndividual .
# :GranteraAI a :Startup .
# :GranteraAI :dedicadaA :SolucõesDeIA .
# :SolucõesDeIA a rdfs:Class .
# :ÁreaDoFinanciamentoPúblico a rdfs:Class .
# :GranteraAI :temSoluções :SolucõesDeIA .
# @prefix : <http://example.org/> .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :TecnologiaEDesenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# :Granters a owl:ObjectProperty .
# :PretendeDesenvolver a owl:ObjectProperty .
# :UtilizacaoPorParteDasEmpresas a owl:ObjectProperty .
# :ElaboracaoDeCandidaturas a owl:ObjectProperty .
# :Para a utilização por parte das empresas na elaboração de candidaturas a programas de financiamento a owl:AnnotationProperty .
# :agenteDeIA1 a :AgenteDeIA .
# :empresa1 a :Empresa .
# :programaDeFinanciamento1 a :Programa .
# :granter1 a :Granters .
# :agenteDeIA1 :PretendeDesenvolver :agenteDeIA2 .
# :agenteDeIA2 a :AgenteDeIA .
# :empresa1 :UtilizacaoPorParteDasEmpresas :programaDeFinanciamento1 .
# :empresa1 a :Empresa .
# :programaDeFinanciamento1 a :Programa .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :Tecnologia e Desenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# @prefix : <http://example.org/> .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :Tecnologia e Desenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# :hasFundingProgram a owl:ObjectProperty .
# :hasMainEconomicActivity a owl:ObjectProperty .
# :hasProject a owl:ObjectProperty .
# :hasAgentDeIA a owl:ObjectProperty .
# :hasCandidatureTool a owl:ObjectProperty .
# :usesMetodologiasDeIA a owl:ObjectProperty .
# :hasBusinessModel a owl:ObjectProperty .
# :hasManagementTeam a owl:ObjectProperty .
# :hasProjectLeadership a owl:ObjectProperty .
# :usesTechnologyAndDevelopment a owl:ObjectProperty .
# :aimsAtImpactAndCompetitiveness a owl:ObjectProperty .
# :hasValueProposition a owl:ObjectProperty .
# :producesDigitalProduct a owl:ObjectProperty .
# :hasInvestments a owl:ObjectProperty .
# :incursCostsWithHumanResources a owl:ObjectProperty .
# :hasCertifications a owl:ObjectProperty .
# :usesExternalServices a owl:ObjectProperty .
# :hasEquipment a owl:ObjectProperty .
# :hasIntellectualProperty a owl:ObjectProperty .
# :Realidade e contexto de fundos públicos a owl:NamedIndividual .
# :Redes Generativas Adversariais a owl:NamedIndividual .
# :Adversarial In-Context Learning a owl:NamedIndividual .
# :Conteúdos otimizados a owl:NamedIndividual .
# :Requisitos dos programas de financiamento a owl:NamedIndividual .
# @prefix : <http://example.org/> .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :TecnologiaEDesenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# :representa a owl:ObjectProperty .
# :solucaoEscalavel a owl:DatatypeProperty .
# :potencial a owl:DatatypeProperty .
# @prefix : <http://example.org/> .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :Tecnologia e Desenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# :hasMission a owl:ObjectProperty .
# :hasMission rdfs:domain :GrantersAI .
# :hasMission rdfs:range :Mission .
# :GrantersAI a owl:NamedIndividual .
# :Mission a rdfs:Class .
# :FundosPublicos a owl:NamedIndividual .
# :GrantersAI :hasMission :DemocratizarEFACILITAR .
# :DemocratizarEFACILITAR a owl:NamedIndividual .
# :hasAccess a owl:ObjectProperty .
# :hasAccess rdfs:domain :VouchersParaStartups .
# :hasAccess rdfs:range :FundosPublicos .
# :VouchersParaStartups a owl:NamedIndividual .
# :AccessToPublicFunds a owl:NamedIndividual .
# @prefix : <http://example.org/> .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :TecnologiaEDesenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# :apresentado a owl:ObjectProperty .
# :passaPor a owl:ObjectProperty .
# :criacaoDe a owl:ObjectProperty .
# :utilizacaoPor a owl:ObjectProperty .
# :parteDe a owl:ObjectProperty .
# :elaboracaoDe a owl:ObjectProperty .
# :paraUtilizacaoPor a owl:ObjectProperty .
# :porParteDe a owl:ObjectProperty .
# :destinadaA a owl:ObjectProperty .
# :de a owl:ObjectProperty .
# :do a owl:ObjectProperty .
# :na a owl:ObjectProperty .
# :deFinanciamento a owl:ObjectProperty .
# :financiamentoDe a owl:ObjectProperty .
# :para a a owl:AnnotationProperty .
# :parteDe a owl:ObjectProperty .
# :elaboracaoDe a owl:ObjectProperty .
# :utilizacaoPor a owl:ObjectProperty .
# :porParteDe a owl:ObjectProperty .
# :destinadaA a owl:ObjectProperty .
# :de a owl:ObjectProperty .
# :na a owl:ObjectProperty .
# :deFinanciamento a owl:ObjectProperty .
# :financiamentoDe a owl:ObjectProperty .
# :projeto1 a :Projeto .
# :agenteAI1 a :AgenteDeIA .
# :especialistas1 a :EquipeDeGestao .
# :empresas1 a :EquipeDeGestao .
# :financiamentoOportunidade1 a :VouchersParaStartups .
# :criacaoAgenteAI a :criacaoDe .
# :utilizacaoPorEspecialistas a :utilizacaoPor .
# :elaboracaoDeCandidaturas a :elaboracaoDe .
# :projeto1 :apresentado :agenteAI1 .
# :projeto1 :passaPor :criacaoAgenteAI .
# :projeto1 :paraUtilizacaoPor :especialistas1 .
# :projeto1 :destinadaA :financiamentoOportunidade1 .
# @prefix : <http://example.org/> .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :TecnologiaEDesenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# :agregarMetodologias a owl:ObjectProperty .
# :GANs a owl:NamedIndividual .
# :AdvICL a owl:NamedIndividual .
# :geracaoDeConteudos a owl:NamedIndividual .
# :VouchersParaStartups a :VouchersParaStartups .
# :AtividadeEconómicaPrincipal a :AtividadeEconómicaPrincipal .
# :Projeto a :Projeto .
# :AgenteDeIA a :AgenteDeIA .
# :FerramentaDeCandidatura a :FerramentaDeCandidatura .
# :MetodologiasDeIA a :MetodologiasDeIA .
# :ModeloDeNegocio a :ModeloDeNegocio .
# :EquipeDeGestao a :EquipeDeGestao .
# :LiderancaDoProjeto a :LiderancaDoProjeto .
# :TecnologiaEDesenvolvimento a :TecnologiaEDesenvolvimento .
# :ImpactoECompetitividade a :ImpactoECompetitividade .
# :PropostaDeValor a :PropostaDeValor .
# :ProdutoDigital a :ProdutoDigital .
# :Investimentos a :Investimentos .
# :CustosComRecursosHumanos a :CustosComRecursosHumanos .
# :Certificacoes a :Certificacoes .
# :ServicosExternos a :ServicosExternos .
# :Equipamentos a :Equipamentos .
# :PropriedadeIntelectual a :PropriedadeIntelectual .
# :agregarMetodologias a :agregarMetodologias .
# :AgenteDeIA :agenteDeIA .
# :GANs :GANs .
# :AdvICL :AdvICL .
# :geracaoDeConteudos :geracaoDeConteudos .
# :AgenteDeIA :agenteDeIA .
# :VouchersParaStartups :VouchersParaStartups .
# :AgenteDeIA :agenteDeIA .
# :geracaoDeConteudos :geracaoDeConteudos .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# :VouchersParaStartups :VouchersParaStartups .
# ...
# :individual18 a :Equipamentos .
# :individual19 a :PropriedadeIntelectual .
# ; hasName "VouchersParaStartups" .
# ; hasType "Program" .
# ; hasDescription "A estrutura modular que permite rápida adaptação a diferentes contextos nacionais." .
# :individual2 hasName "Atividade Econômica Principal do Beneficiário" .
# :individual3 hasName "Projeto" .
# :individual4 hasName "Agente de IA" .
# :individual5 hasName "Ferramenta de Candidatura" .
# :individual6 hasName "Metodologias de IA" .
# :individual7 hasName "Modelo de Negócio" .
# :individual8 hasName "Equipe de Gestão" .
# :individual9 hasName "Liderança do Projeto" .
# :individual10 hasName "Tecnologia e Desenvolvimento" .
# :individual11 hasName "Impacto e Competitividade" .
# :individual12 hasName "Proposta de Valor" .
# :individual13 hasName "Produto Digital" .
# :individual14 hasName "Investimentos" .
# :individual15 hasName "Custos com Recursos Humanos" .
# :individual16 hasName "Certificações" .
# :individual17 hasName "Serviços Externos" .
# :individual18 hasName "Equipamentos" .
# :individual19 hasName "Propriedade Intelectual" .
# @prefix : <http://example.org/> .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :Tecnologia e Desenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# :hasMarket a owl:ObjectProperty .
# :hasLanguage a owl:ObjectProperty .
# :hasLegalContext a owl:ObjectProperty .
# :finalProduct a owl:ObjectProperty .
# :relatedTo a owl:ObjectProperty .
# :hasComponent a owl:ObjectProperty .
# :hasFunding a owl:ObjectProperty .
# :hasCost a owl:DatatypeProperty .
# :hasCertification a owl:DatatypeProperty .
# :hasExternalService a owl:ObjectProperty .
# :hasEquipment a owl:ObjectProperty .
# :hasIntellectualProperty a owl:ObjectProperty .
# :individual1 a :VouchersParaStartups .
# :individual2 a :AtividadeEconómicaPrincipal .
# :individual3 a :Projeto .
# :individual4 a :AgenteDeIA .
# :individual5 a :FerramentaDeCandidatura .
# :individual6 a :MetodologiasDeIA .
# :individual7 a :ModeloDeNegocio .
# :individual8 a :EquipeDeGestao .
# :individual9 a :LiderancaDoProjeto .
# :individual10 a :Tecnologia e Desenvolvimento .
# :individual11 a :ImpactoECompetitividade .
# :individual12 a :PropostaDeValor .
# :individual13 a :ProdutoDigital .
# :individual14 a :Investimentos .
# :individual15 a :CustosComRecursosHumanos .
# :individual16 a :Certificacoes .
# :individual17 a :ServicosExternos .
# :individual18 a :Equipamentos .
# :individual19 a :PropriedadeIntelectual .
# :individual1 :hasMarket "any market" .
# :individual1 :hasLanguage "any language" .
# :individual1 :hasLegalContext "any legal context" .
# :individual3 :hasComponent :individual2 .
# :individual3 :hasFunding :individual14 .
# :individual14 :hasCost "cost amount" .
# :individual16 :hasCertification "certification details" .
# :individual17 :hasExternalService "service details" .
# :individual18 :hasEquipment "equipment details" .
# :individual19 :hasIntellectualProperty "property details" .
# @prefix : <http://example.org/> .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :TecnologiaEDesenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# :hasInfrastructure a owl:ObjectProperty .
# :sePreveHighlyAdaptable a owl:DatatypeProperty .
# :permite a owl:ObjectProperty .
# :moldeSeFacilmente a owl:DatatypeProperty .
# :conexao a owl:ObjectProperty .
# :baseDeDados a owl:NamedIndividual .
# :informacaoRelevante a owl:NamedIndividual .
# @prefix : <http://example.org/> .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :TecnologiaEDesenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# :hasProject a owl:ObjectProperty .
# :hasMainEconomicActivity a owl:ObjectProperty .
# :hasSupportType a owl:DatatypeProperty .
# :hasPhase a owl:DatatypeProperty .
# :hasJustification a owl:AnnotationProperty .
# :hasTechnology a owl:ObjectProperty .
# :hasDevelopment a owl:ObjectProperty .
# :hasImpact a owl:ObjectProperty .
# :hasValueProposal a owl:ObjectProperty .
# :hasDigitalProduct a owl:ObjectProperty .
# :hasInvestment a owl:ObjectProperty .
# :hasCostHumanResources a owl:ObjectProperty .
# :hasCertification a owl:ObjectProperty .
# :hasExternalServices a owl:ObjectProperty .
# :hasEquipment a owl:ObjectProperty .
# :hasIntellectualProperty a owl:ObjectProperty .
# :GrantersAI a owl:NamedIndividual ;
# a :Projeto ;
# :hasPhase "initial growth" ;
# :hasJustification "supports the support for startup launch or growth" ;
# :hasSupportType "Apoio ao arranque ou ao crescimento" .
# @prefix : <http://example.org/> .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :TecnologiaEDesenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# :GranterAI a owl:NamedIndividual ;
# a :Empresa ;
# :iniciouAtividadeEm "2024-12"^^xsd:date ;
# :possuiBaseDeEmpresas :Empresa1 .
# :Empresa1 a owl:NamedIndividual ;
# a :Empresa ;
# :nome "Granter.ai" ;
# :registraMaisDe "2500"^^xsd:integer ;
# :registraMaisDeCandidaturas "150"^^xsd:integer ;
# :volumeTotalDeEuros "20000000"^^xsd:decimal .
# :Empresa a rdfs:Class .
# :iniciouAtividadeEm a owl:DatatypeProperty .
# :possuiBaseDeEmpresas a owl:ObjectProperty .
# :registraMaisDe a owl:DatatypeProperty .
# :registraMaisDeCandidaturas a owl:DatatypeProperty .
# :volumeTotalDeEuros a owl:DatatypeProperty .
# @prefix : <http://example.org/> .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :TecnologiaEDesenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# :empresa a owl:NamedIndividual ;
# a :Empresa .
# :conseguiu a owl:ObjectProperty .
# :angariar a owl:ObjectProperty .
# :investimento a owl:NamedIndividual ;
# a :Investimentos .
# :valor a owl:DatatypeProperty .
# :quantia a "400.000€"^^xsd:string .
# :rondasDeInvestimento a owl:ObjectProperty .
# :apresenta a owl:ObjectProperty .
# :crescimento a owl:DatatypeProperty .
# :crescimentoPercentual a owl:DatatypeProperty .
# :empresa a :Empresa .
# :conseguiu a :empresa ;
# :angariar "400.000€"^^xsd:string .
# :empresa a :Empresa ;
# :apresenta "crescimento trimestral sustentado de 45%"^^xsd:string .
# @prefix : <http://example.org/> .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :TecnologiaEDesenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# :refleteModeloDeNegocio a owl:ObjectProperty .
# :temForteAceitacaoNoMercado a owl:AnnotationProperty .
# :emFaseDeExpansao a owl:AnnotationProperty .
# @prefix : <http://example.org/> .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :TecnologiaEDesenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# :GranterAI a owl:NamedIndividual ;
# rdfs:label "Granter.ai" .
# :ProdutoX a owl:NamedIndividual ;
# a :ProdutoDigital ;
# :representaUmSaltoQualitativo "true" .
# :PropostaDeValorX a owl:NamedIndividual ;
# a :PropostaDeValor .
# :MercadoNacional a owl:NamedIndividual .
# :MercadoInternacionalPrioritario1 a owl:NamedIndividual ;
# a :Mercado ;
# rdfs:label "Espanha" .
# :MercadoInternacionalPrioritario2 a owl:NamedIndividual ;
# a :Mercado ;
# rdfs:label "Itália" .
# :MercadoInternacionalPrioritario3 a owl:NamedIndividual ;
# a :Mercado ;
# rdfs:label "EUA" .
# :ProdutoX :temPropostaDeValor :PropostaDeValorX ;
# :atuaEmMercado :MercadoNacional, :MercadoInternacionalPrioritario1, :MercadoInternacionalPrioritario2, :MercadoInternacionalPrioritario3 .
# # Relations (example, based on the sentence context)
# :ProdutoX :representaUmSaltoQualitativo "true" ;
# :naPropostaDeValor :PropostaDeValorX ;
# :noMercado :MercadoNacional, :MercadoInternacionalPrioritario1, :MercadoInternacionalPrioritario2, :MercadoInternacionalPrioritario3 .
# @prefix : <http://example.org/> .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :TecnologiaEDesenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# :desenvolvimento a owl:ObjectProperty .
# :formaInterna a owl:ObjectProperty .
# :vontade a owl:ObjectProperty .
# :manter a owl:ObjectProperty .
# :compromisso a owl:ObjectProperty .
# :com a a owl:ObjectProperty .
# :producao a owl:ObjectProperty .
# :softwareProprietario a owl:Individual .
# :VouchersParaStartups a owl:NamedIndividual .
# :AtividadeEconómicaPrincipal a owl:NamedIndividual .
# :doBeneficiário a owl:NamedIndividual .
# :Projeto a owl:NamedIndividual .
# :AgenteDeIA a owl:NamedIndividual .
# :FerramentaDeCandidatura a owl:NamedIndividual .
# :MetodologiasDeIA a owl:NamedIndividual .
# :ModeloDeNegocio a owl:NamedIndividual .
# :EquipeDeGestao a owl:NamedIndividual .
# :LiderancaDoProjeto a owl:NamedIndividual .
# :TecnologiaEDesenvolvimento a owl:NamedIndividual .
# :ImpactoECompetitividade a owl:NamedIndividual .
# :PropostaDeValor a owl:NamedIndividual .
# :ProdutoDigital a owl:NamedIndividual .
# :Investimentos a owl:NamedIndividual .
# :CustosComRecursosHumanos a owl:NamedIndividual .
# :Certificacoes a owl:NamedIndividual .
# :ServicosExternos a owl:NamedIndividual .
# :Equipamentos a owl:NamedIndividual .
# :PropriedadeIntelectual a owl:NamedIndividual .
# @prefix : <http://example.org/> .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :TecnologiaEDesenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# :hasKnowledge a owl:ObjectProperty .
# :hasComponent a owl:ObjectProperty .
# :hasApplication a owl:ObjectProperty .
# :hasFunding a owl:ObjectProperty .
# :hasTeamMember a owl:ObjectProperty .
# :hasLeadership a owl:ObjectProperty .
# :usesTechnology a owl:ObjectProperty .
# :aimsAtImpact a owl:ObjectProperty .
# :offersValue a owl:ObjectProperty .
# :producesProduct a owl:ObjectProperty .
# :requiresInvestment a owl:ObjectProperty .
# :incursCosts a owl:ObjectProperty .
# :hasCertification a owl:ObjectProperty .
# :relatesToExternalServices a owl:ObjectProperty .
# :includesEquipment a owl:ObjectProperty .
# :protectsIntellectualProperty a owl:ObjectProperty .
# # Individuals (examples)
# :KnowledgeTechnical a owl:NamedIndividual .
# :ResearchComponent a owl:NamedIndividual .
# :AppliedResearch a owl:NamedIndividual .
# :ExperimentalDevelopment a owl:NamedIndividual .
# @prefix : <http://example.org/> .
# :VouchersParaStartups a rdfs:Class .
# :AtividadeEconómicaPrincipal a rdfs:Class .
# :Projeto a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :FerramentaDeCandidatura a rdfs:Class .
# :MetodologiasDeIA a rdfs:Class .
# :ModeloDeNegocio a rdfs:Class .
# :EquipeDeGestao a rdfs:Class .
# :LiderancaDoProjeto a rdfs:Class .
# :TecnologiaEDesenvolvimento a rdfs:Class .
# :ImpactoECompetitividade a rdfs:Class .
# :PropostaDeValor a rdfs:Class .
# :ProdutoDigital a rdfs:Class .
# :Investimentos a rdfs:Class .
# :CustosComRecursosHumanos a rdfs:Class .
# :Certificacoes a rdfs:Class .
# :ServicosExternos a rdfs:Class .
# :Equipamentos a rdfs:Class .
# :PropriedadeIntelectual a rdfs:Class .
# :confere a a owl:ObjectProperty .
# :projeto a owl:ObjectProperty .
# :grauDeComplexidade a owl:DatatypeProperty .
# :significativo a owl:DatatypeProperty .
# :metodologias a owl:ObjectProperty .
# :como a a owl:ObjectProperty .
# :as a owl:ObjectProperty .
# :RedesGenerativasAdversariais a owl:NamedIndividual .
# :AdvICL a owl:NamedIndividual .
# :GANs a owl:NamedIndividual .
# :AdversarialInContextLearning a owl:NamedIndividual .
# :VouchersParaStartups, :RedesGenerativasAdversariais, :AdvICL, :GANs, :AdversarialInContextLearning a owl:NamedIndividual .
# # Relations
# :confere a :RedesGenerativasAdversariais, :AdvICL, :GANs, :AdversarialInContextLearning .
# :metodologias a :GANs, :AdvICL .
# :como a :RedesGenerativasAdversariais, :AdversarialInContextLearning .
# Ontology is invalid: at line 9 of <>:
# Bad syntax (expected '.' or '}' or ']' at end of statement) at ^ in:
# "...b'ersParaStartups a rdfs:Class .\n:AtividadeEcon\xc3\xb3micaPrincipal'^b' doBenefici\xc3\xa1rio a rdfs:Class .\n:Projeto a rdfs:Class .\n:Age'..."
