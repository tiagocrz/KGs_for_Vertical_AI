# %%
import sys
sys.path.append(os.path.abspath('../../'))
import os
print("Current working directory:", os.getcwd())
sys.path.append(os.path.abspath('..'))

print(os.listdir(os.path.abspath('../../')))

# %%
from src.build_kg import abuild_kg, save_graph_to_csv, extract_local_names 
from src.txt_ontology_learning import validate_turtle_string
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from src.build_kg import abuild_kg, save_graph_to_csv, extract_local_names
#       2 from src.txt_ontology_learning import validate_turtle_string
#
# ModuleNotFoundError: No module named 'src'

# %%
with open('results/ontologies/text/text_ontology_new_prompt.txt', 'r', encoding='utf-8') as f:
    ontology = f.read()

# extra ...

# Add prefixes since gpt_results_to_ttl doesn't include them
standard_prefixes = [
    '@prefix : <http://example.org/> .',
    "@prefix owl: <http://www.w3.org/2002/07/owl#> .",
    "@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .",
    "@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .",
    "@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> ."
]
ontology = "\n".join(standard_prefixes) + "\n\n" + ontology
print(ontology)
is_valid, error_message = validate_turtle_string(ontology)
print(error_message)

# %% [markdown]
# # RDB Ontology Knowledge Graph

# %%
rdb_ont_kg = await abuild_kg(
    input_path="data/texts/application_example.txt",
    ontology_path="results/ontologies/RDB/rigor_ontology_few_fixes.ttl",
    html_output="results/KGs/rdb_ontology/rdb_ontology_kg.html"
)

# %%
save_graph_to_csv(graph_documents = rdb_ont_kg, 
                  output_file="results/KGs/rdb_ontology/rdb_ontology_kg.csv")

# %%
import webbrowser
webbrowser.open(f"file://{os.path.abspath('results/KGs/rdb_ontology/rdb_ontology_kg.html')}")

# %% [markdown]
# # Text Ontology Knowledge Graph

# %%
extract_local_names('results/ontologies/text/text_ontology_10sens.ttl')

# %%
txt_ont_kg = await abuild_kg(
    input_path="data/texts/application_example.txt",
    ontology_path="results/ontologies/text/text_ontology_few_fixes.ttl",
    html_output="results/KGs/txt_ontology/txt_ontology_kg.html"
)

# %%
save_graph_to_csv(graph_documents = txt_ont_kg, 
                  output_file="results/KGs/txt_ontology/txt_ontology_kg.csv")

# %%
import webbrowser
webbrowser.open(f"file://{os.path.abspath('results/KGs/txt_ontology/txt_ontology_kg.html')}")

# %% [markdown]
# # Dingo Ontology Knowledge Graph

# %%
dingo_ont_kg = await abuild_kg(
    input_path="data/texts/application_example.txt",
    ontology_path="notebooks/04_rdb_ontology/external_ontologies/DINGO-OWL.ttl",
    html_output="results/KGs/dingo/dingo_ontology_kg.html"
)

# %%
# Save DINGO graph to CSV
save_graph_to_csv(graph_documents = dingo_ont_kg, 
                  output_file="results/KGs/dingo/dingo_ontology_kg.csv")

# %%
# Open DINGO visualization
webbrowser.open(f"file://{os.path.abspath('results/KGs/dingo/dingo_ontology_kg.html')}")

# %% [markdown]
# # Comparison of Knowledge Graphs
#
# This notebook builds and compares three different knowledge graphs:
#
# 1. **RDB Ontology KG**: Knowledge graph generated from a relational database ontology (RIGOR methodology)
# 2. **Text Ontology KG**: Knowledge graph generated from text documents
# 3. **DINGO Ontology KG**: Knowledge graph generated using the DINGO ontology
#
# The graphs are saved as both HTML visualizations and CSV files for further analysis.
