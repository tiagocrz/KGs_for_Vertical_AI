# %%
import os
os.chdir('..')

from src.build_kg import abuild_kg, save_graph_to_csv

# %%
from src.build_kg import abuild_kg, save_graph_to_csv

# %%
# rdb ontology kg

rdb_ont_kg = await abuild_kg(
    input_path="data/texts/opportunity_example.txt",
    ontology_path="output/ontologies/rigor_ontology_few_fixes.ttl",
    html_output="output/KGs/rdb_ontology_kg.html"
)
# Out:
# Loaded content from data/texts/opportunity_example.txt
# Split into 19 chunks
# Converting text to graph documents...
# Merged: 398 nodes, 290 relationships
# Graph saved to c:\Users\tiago\Documents\Granter Ai Internship\Implementation\KGs_for_Vertical_AI\knowledge_graph.html
# Knowledge graph built successfully!
# HTML visualization: c:\Users\tiago\Documents\Granter Ai Internship\Implementation\KGs_for_Vertical_AI\knowledge_graph.html

# %%
save_graph_to_csv(graph_documents = rdb_ont_kg, 
                  output_file="output/KGs/rdb_ontology_kg.csv")
# Out:
# Graph saved to: c:\Users\tiago\Documents\Granter Ai Internship\rdb_ontology_kg.csv
# Total nodes: 398
# Total edges: 290

# %%
import webbrowser
webbrowser.open(f"file://{os.path.abspath('output/KGs/rdb_ontology_kg.html')}")
# Out:
# True
