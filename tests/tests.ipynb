# %%
import os
os.chdir('..')

# %%
from src.build_kg import abuild_kg, save_graph_to_csv, extract_local_names 
from src.txt_ontology_learning import validate_turtle_string
# Out:
# c:\Users\tiago\anaconda3\envs\Graph_implementation\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\tiago\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
with open('output/ontologies/text/text_ontology_new_prompt.txt', 'r', encoding='utf-8') as f:
    ontology = f.read()

# extra ...

# Add prefixes since gpt_results_to_ttl doesn't include them
standard_prefixes = [
    '@prefix : <http://example.org/> .',
    "@prefix owl: <http://www.w3.org/2002/07/owl#> .",
    "@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .",
    "@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .",
    "@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> ."
]
ontology = "\n".join(standard_prefixes) + "\n\n" + ontology
print(ontology)
is_valid, error_message = validate_turtle_string(ontology)
print(error_message)
# Out:
# @prefix : <http://example.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
#
# :VouchersParaStartupsNovosProdutosDigitaisTecnológicosGranterAi a rdfs:Class .
# :AtividadeEconómicaPrincipalBeneficiário a rdfs:Class .
# :ProjetoProposto a rdfs:Class .
# :SoftwareProprietário a rdfs:Class .
# :SetorTecnológico a rdfs:Class .
# :AgenteDeIA a rdfs:Class .
# :MetodologiasIA a rdfs:Class .
# :RedesGenerativasAdversariais a rdfs:Class .
# :AdversarialInContextLearning a rdfs:Class .
# :FerramentaInteligente a rdfs:Class .
# :ObjetivosDoProjeto a rdfs:Class .
# :MissãoDemocratizarFacilitarAcesso a rdfs:Class .
# :ProcessoInvestigaçãoAplicada a rdfs:Class .
# :ModelosLinguísticos a rdfs:Class .
# :EstruturaModular a rdfs:Class .
# :MercadosInternacionais a rdfs:Class .
# :TransiçãoClimática a rdfs:Class .
# ...

# %% [markdown]
# # rdb ontology kg

# %%
rdb_ont_kg = await abuild_kg(
    input_path="data/texts/application_example.txt",
    ontology_path="output/ontologies/RDB/rigor_ontology_few_fixes.ttl",
    html_output="output/KGs/rdb_ontology/rdb_ontology_kg.html"
)
# Out:
# Input path: data/texts/application_example.txt
# Path exists
# Using ontology constraints: 26 classes, 43 relations
# Loaded content from data/texts/application_example.txt
# Split into 14 chunks
# Classes: ['DatabaseTable', 'ForeignKeyRelation', 'GeographicCriterion', 'Grant', 'GrantPayment', 'GrantShare', 'GranterApplication', 'GranterCompany', 'GranterCompanyMemory', 'GranterConsortium', 'GranterConsortiumPartner', 'GranterConsortiumPartnerType', 'GranterGeneralOpportunityFile', 'GranterGeneralOpportunityFileOpportunities', 'GranterMatchcheck', 'GranterMatchgroup', 'GranterOpportunity', 'GranterOpportunityFile', 'GranterTimeline', 'GrantersApplicationFile', 'Opportunity', 'PersonLocation', 'ProvenanceInfo', 'Recipient', 'granterCompanyMemory', 'provenanceInfo']
# ...

# %%
save_graph_to_csv(graph_documents = rdb_ont_kg, 
                  output_dir="output/KGs/rdb_ontology/")
# Out:
# Graph saved to: c:\Users\tiago\Documents\Granter Ai Internship\Implementation\KGs_for_Vertical_AI\output\KGs\rdb_ontology\rdb_ontology_kg.csv
# Total nodes: 18
# Total edges: 11

# %%
import webbrowser
webbrowser.open(f"file://{os.path.abspath('output/KGs/rdb_ontology_kg.html')}")
# Out:
# True

# %% [markdown]
# # text ontology kg

# %%
extract_local_names('output/ontologies/text/text_ontology_10sens.ttl')
# Out:
# (['AdversarialInContextLearning',
#   'AgenteDeIA',
#   'ApoioAoArranqueOuAoCrescimento',
#   'AtividadeEconómicaPrincipalBeneficiário',
#   'Certificacoes',
#   'Equipamentos',
#   'EquipeDeGestao',
#   'Escalabilidade',
#   'ExpansaoComercial',
#   'FerramentaInteligente',
#   'GestaoDeProduto',
#   'ImpactoNaCompetitividade',
#   'Investimentos',
#   'LiderancaDoProjeto',
#   'MetodologiasIA',
#   'ModeloDeNegócio',
#   'Projeto',
#   'PropostaDeValor',
#   'PropriedadeIntelectual',
#   'ProtecaoDePropriedadeIntelectual',
#   'RecursosHumanos',
#   'RedesGenerativasAdversariais',
#   'ServicosExternos',
#   'SoftwareProprietário',
#   'Tecnologia',
#   'Tipologia',
#   'VouchersParaStartupsNovosProdutosDigitaisTecnológicosGranterAi'],
#  ['aplicaAdversarialInContextLearning',
#   'aplicadoA',
#   'apoia',
#   'baseadoEm',
#   'classificaTipologia',
#   'contaComEquipe',
#   'contrataServicosExternos',
#   'dedicaAoDesenvolvimento',
#   'desenvolveSoftwareProprietário',
# ...

# %%
txt_ont_kg = await abuild_kg(
    input_path="data/texts/application_example.txt",
    ontology_path="output/ontologies/text/text_ontology_few_fixes.ttl",
    html_output="output/KGs/txt_ontology/txt_ontology_kg.html"
)
# Out:
# Input path: data/texts/application_example.txt
# Path exists
# Using ontology constraints: 39 classes, 5 relations
# Loaded content from data/texts/application_example.txt
# Split into 14 chunks
# ...

# %%
save_graph_to_csv(graph_documents = txt_ont_kg, 
                  output_dir="output/KGs/txt_ontology/")
# Out:
# Graph saved to: c:\Users\tiago\Documents\Granter Ai Internship\Implementation\KGs_for_Vertical_AI\output\KGs\txt_ontology\txt_ontology_kg.csv
# Total nodes: 47
# Total edges: 52

# %%
import webbrowser
webbrowser.open(f"file://{os.path.abspath('output/KGs/txt_ontology_kg.html')}")
# Out:
# True

# %% [markdown]
# # Dingo ontology

# %%
dingo_ont_kg = await abuild_kg(
    input_path="data/texts/application_example.txt",
    ontology_path="approaches/04_rdb_ontology/external_ontologies/DINGO-OWL.ttl",
    html_output="output/KGs/dingo_ontology/dingo_ontology_kg.html"
)
# Out:
# Input path: data/texts/application_example.txt
# Path exists
# Using ontology constraints: 55 classes, 68 relations
# Loaded content from data/texts/application_example.txt
# Split into 14 chunks
# ...

# %%
save_graph_to_csv(graph_documents = dingo_ont_kg, 
                  output_dir="output/KGs/dingo_ontology/")
# Out:
# Nodes saved to: c:\Users\tiago\Documents\Granter Ai Internship\Implementation\KGs_for_Vertical_AI\output\KGs\dingo_ontology\nodes.csv
# Edges saved to: c:\Users\tiago\Documents\Granter Ai Internship\Implementation\KGs_for_Vertical_AI\output\KGs\dingo_ontology\edges.csv
# Total nodes: 44
# Total edges: 37

# %%
import webbrowser
webbrowser.open(f"file://{os.path.abspath('output/KGs/dingo_ontology/dingo_ontology_kg.html')}")
# Out:
# True
